# %%
pip install basketball-reference-scraper
# Out:
# Collecting basketball-reference-scraper
#   Downloading basketball_reference_scraper-2.0.0-py3-none-any.whl (51 kB)
#      ---------------------------------------- 51.9/51.9 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: requests in c:\users\pc\anaconda3\lib\site-packages (from basketball-reference-scraper) (2.28.1)
# Requirement already satisfied: six in c:\users\pc\anaconda3\lib\site-packages (from basketball-reference-scraper) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\pc\anaconda3\lib\site-packages (from basketball-reference-scraper) (4.11.1)
# Requirement already satisfied: pytz in c:\users\pc\anaconda3\lib\site-packages (from basketball-reference-scraper) (2022.7)
# Requirement already satisfied: python-dateutil in c:\users\pc\anaconda3\lib\site-packages (from basketball-reference-scraper) (2.8.2)
# Requirement already satisfied: pandas in c:\users\pc\anaconda3\lib\site-packages (from basketball-reference-scraper) (1.5.3)
# Requirement already satisfied: Unidecode in c:\users\pc\anaconda3\lib\site-packages (from basketball-reference-scraper) (1.2.0)
# Requirement already satisfied: soupsieve in c:\users\pc\anaconda3\lib\site-packages (from basketball-reference-scraper) (2.3.2.post1)
# Requirement already satisfied: selenium in c:\users\pc\anaconda3\lib\site-packages (from basketball-reference-scraper) (4.20.0)
# Requirement already satisfied: lxml in c:\users\pc\anaconda3\lib\site-packages (from basketball-reference-scraper) (4.9.1)
# Requirement already satisfied: numpy in c:\users\pc\anaconda3\lib\site-packages (from basketball-reference-scraper) (1.23.5)
# Requirement already satisfied: bs4 in c:\users\pc\anaconda3\lib\site-packages (from basketball-reference-scraper) (0.0.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\pc\anaconda3\lib\site-packages (from requests->basketball-reference-scraper) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\pc\anaconda3\lib\site-packages (from requests->basketball-reference-scraper) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pc\anaconda3\lib\site-packages (from requests->basketball-reference-scraper) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pc\anaconda3\lib\site-packages (from requests->basketball-reference-scraper) (3.4)
# Requirement already satisfied: typing_extensions>=4.9.0 in c:\users\pc\anaconda3\lib\site-packages (from selenium->basketball-reference-scraper) (4.12.2)
# Requirement already satisfied: trio~=0.17 in c:\users\pc\anaconda3\lib\site-packages (from selenium->basketball-reference-scraper) (0.22.2)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\pc\anaconda3\lib\site-packages (from selenium->basketball-reference-scraper) (0.10.3)
# Requirement already satisfied: cffi>=1.14 in c:\users\pc\anaconda3\lib\site-packages (from trio~=0.17->selenium->basketball-reference-scraper) (1.15.1)
# Requirement already satisfied: sniffio in c:\users\pc\anaconda3\lib\site-packages (from trio~=0.17->selenium->basketball-reference-scraper) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\pc\anaconda3\lib\site-packages (from trio~=0.17->selenium->basketball-reference-scraper) (1.1.1)
# Requirement already satisfied: attrs>=20.1.0 in c:\users\pc\anaconda3\lib\site-packages (from trio~=0.17->selenium->basketball-reference-scraper) (22.1.0)
# Requirement already satisfied: sortedcontainers in c:\users\pc\anaconda3\lib\site-packages (from trio~=0.17->selenium->basketball-reference-scraper) (2.4.0)
# Requirement already satisfied: outcome in c:\users\pc\anaconda3\lib\site-packages (from trio~=0.17->selenium->basketball-reference-scraper) (1.2.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\pc\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium->basketball-reference-scraper) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\pc\anaconda3\lib\site-packages (from urllib3<1.27,>=1.21.1->requests->basketball-reference-scraper) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\pc\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium->basketball-reference-scraper) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\pc\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium->basketball-reference-scraper) (0.14.0)
# Installing collected packages: basketball-reference-scraper
# Successfully installed basketball-reference-scraper-2.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
from IPython.display import display, Markdown
import matplotlib.colors as mcolors

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import pandas as pd
import time

# Set up the Selenium WebDriver
service = Service(r"C:\Users\PC\OneDrive\Documents\GitHub\chromedriver-win64\chromedriver.exe")  # Update with your path to chromedriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')  # Run in headless mode
options.add_argument('--disable-gpu')
driver = webdriver.Chrome(service=service, options=options)

# Load the webpage
url = 'https://www.basketball-reference.com/gleague/years/2025.html'
driver.get(url)

# Allow some time for JavaScript to load
time.sleep(5)

# Get the page source
html = driver.page_source

# Parse the HTML with BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')

# Find the table
table = soup.find('table', {'id': 'team-stats-sc-team'})

# Convert to pandas DataFrame
if table:
    team_stats = pd.read_html(str(table))[0]
    
    # Remove the 'Rk' column
    if 'Rk' in team_stats.columns:
        team_stats.drop(columns=['Rk'], inplace=True)
    
    # List of columns to transform to per-game
    per_game_columns = ['FG', 'FGA', '3P', '3PA', '2P', '2PA', 
                        'FT', 'FTA', 'AST', 'STL', 'BLK', 'PF', 'PTS']
    
    # Calculate per-game statistics before dropping 'G'
    if 'G' in team_stats.columns:
        for col in per_game_columns:
            if col in team_stats.columns:  # Ensure the column exists
                team_stats[f'{col}/g'] = team_stats[col] / team_stats['G']
    
    # Drop specified columns and their per-game equivalents
    drop_columns = ['TOV', 'ORB', 'DRB', 'TRB', 'Pace', 'ORtg']
    team_stats.drop(columns=[col for col in drop_columns if col in team_stats.columns], inplace=True)
    team_stats.drop(columns=[f'{col}/g' for col in drop_columns if f'{col}/g' in team_stats.columns], inplace=True)
    
    # Rename specific columns
    rename_mapping = {
        'FG/g': 'FGM/g',
        '3P/g': '3PM/g',
        '2P/g': '2PM/g',
        'FT/g': 'FTM/g'
    }
    team_stats.rename(columns=rename_mapping, inplace=True)
    
    # Drop the 'G' and 'MP' columns after calculations
    team_stats.drop(columns=['G', 'MP'], inplace=True, errors='ignore')

    # Define the desired column order
    desired_order = [
        'Team', 'FGM/g', 'FGA/g', 'FG%', '3PM/g', '3PA/g', '3P%', '2PM/g',
        '2PA/g', '2P%', 'FTM/g', 'FTA/g', 'FT%', 'AST/g', 'STL/g', 'BLK/g', 'PF/g', 'PTS/g'
    ]
    
    # Reorder columns (ignoring missing ones in the DataFrame)
    team_stats = team_stats[[col for col in desired_order if col in team_stats.columns]]

    # Round all numeric columns to three decimal points
    numeric_cols = team_stats.select_dtypes(include='number').columns
    team_stats[numeric_cols] = team_stats[numeric_cols].round(3)
    
    # Filter rows for Raptors 905 and League Average
    filtered_teams = team_stats.loc[team_stats['Team'].isin(['Raptors 905', 'League Average'])]
    
else:
    print("Table with id 'team-stats-sc-team' not found.")

# Quit the driver
driver.quit()

filtered_teams
# Out:
#               Team   FGM/g   FGA/g    FG%   3PM/g   3PA/g    3P%   2PM/g  \
# 10     Raptors 905  43.500  91.625  0.475  12.750  36.875  0.346  30.750
# 31  League Average  42.375  93.625  0.453  13.375  39.500  0.338  29.125
#
#      2PA/g    2P%   FTM/g  FTA/g    FT%   AST/g  STL/g  BLK/g    PF/g    PTS/g
# 10  54.750  0.562   8.375   13.0  0.644  27.375  12.25   7.25  16.125  113.250
# 31  54.125  0.537  11.250   15.0  0.749  24.625   9.75   6.00  10.875  116.625

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import time

# Set up the Selenium WebDriver
service = Service(r"C:\Users\PC\OneDrive\Documents\GitHub\chromedriver-win64\chromedriver.exe")  # Update with your path to chromedriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')  # Run in headless mode
options.add_argument('--disable-gpu')
driver = webdriver.Chrome(service=service, options=options)

# Load the webpage
url = 'https://www.basketball-reference.com/gleague/years/2025.html'
driver.get(url)

# Allow some time for JavaScript to load
time.sleep(5)

# Get the page source
html = driver.page_source

# Parse the HTML with BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')

# Find the table
table = soup.find('table', {'id': 'team-stats-sc-team'})

# Convert to pandas DataFrame
if table:
    team_stats = pd.read_html(str(table))[0]
    
    # Remove the 'Rk' column
    if 'Rk' in team_stats.columns:
        team_stats.drop(columns=['Rk'], inplace=True)
    
    # List of columns to transform to per-game
    per_game_columns = ['FG', 'FGA', '3P', '3PA', '2P', '2PA', 
                        'FT', 'FTA', 'AST', 'STL', 'BLK', 'PF', 'PTS']
    
    # Create per-game columns
    for col in per_game_columns:
        if col in team_stats.columns:  # Ensure the column exists
            team_stats[f'{col}/g'] = team_stats[col] / team_stats['G']
    
    # Drop specified columns and their per-game equivalents
    drop_columns = ['TOV', 'ORB', 'DRB', 'TRB', 'Pace', 'ORtg', 'G', 'MP']
    team_stats.drop(columns=[col for col in drop_columns if col in team_stats.columns], inplace=True)
    team_stats.drop(columns=[f'{col}/g' for col in drop_columns if f'{col}/g' in team_stats.columns], inplace=True)
    
    # Rename specific columns
    rename_mapping = {
        'FG/g': 'FGM/g',
        '3P/g': '3PM/g',
        '2P/g': '2PM/g',
        'FT/g': 'FTM/g'
    }
    team_stats.rename(columns=rename_mapping, inplace=True)
    
    # Exclude the "League Average" row
    team_stats = team_stats[team_stats['Team'] != 'League Average'].reset_index(drop=True)
    
    # Define the desired column order
    desired_order = [
        'Team', 'FGM/g', 'FGA/g', 'FG%', '3PM/g', '3PA/g', '3P%', '2PM/g',
        '2PA/g', '2P%', 'FTM/g', 'FTA/g', 'FT%', 'AST/g', 'STL/g', 'BLK/g', 'PF/g', 'PTS/g'
    ]
    
    # Reorder columns (ignoring missing ones in the DataFrame)
    team_stats = team_stats[[col for col in desired_order if col in team_stats.columns]]

    # Round all numeric columns to three decimal points
    numeric_cols = team_stats.select_dtypes(include='number').columns
    team_stats[numeric_cols] = team_stats[numeric_cols].round(3)
    
    # Calculate ranks and append ranks to numeric columns for display
    invert_cols = ['PF/g']  # Specify columns where ranking should be ascending
    df_with_ranks = team_stats.copy()
    for col in numeric_cols:
        # Calculate ranks (invert order for specified columns)
        if col in invert_cols:
            ranks = team_stats[col].rank(ascending=True, method='min').astype(int)
        else:
            ranks = team_stats[col].rank(ascending=False, method='min').astype(int)
        
        # Append ranks to column values for display
        df_with_ranks[col] = team_stats[col].astype(str) + ' (' + ranks.astype(str) + ')'
    
    # Color coding logic
    col_min = team_stats[numeric_cols].min()
    col_max = team_stats[numeric_cols].max()

    def luminance(color):
        rgb = mcolors.hex2color(color)
        return 0.2126 * rgb[0] + 0.7152 * rgb[1] + 0.0722 * rgb[2]

    def color_cells(row):
        colors = []
        for col in numeric_cols:
            value = team_stats.loc[row.name, col]  # Use original numeric value for coloring
            if col in invert_cols:
                # Invert normalization for specified columns
                norm = (col_max[col] - value) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5
            else:
                # Normal normalization
                norm = (value - col_min[col]) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5
            color = mcolors.to_hex(plt.cm.RdYlGn(norm))
            text_color = 'white' if luminance(color) < 0.5 else 'black'
            colors.append(f"background-color: {color}; color: {text_color};")
        return colors

    # Apply the coloring logic to the DataFrame with ranks
    styled_df = df_with_ranks.style.apply(color_cells, subset=numeric_cols, axis=1).format(precision=3)

else:
    print("Table with id 'team-stats-sc-team' not found.")

# Quit the driver
driver.quit()

styled_df
# Out:
# <style type="text/css">
# #T_6106e_row0_col1 {
#   background-color: #54b45f;
#   color: black;
# }
# #T_6106e_row0_col2, #T_6106e_row8_col17, #T_6106e_row10_col8, #T_6106e_row23_col8, #T_6106e_row24_col12 {
#   background-color: #cbe982;
#   color: black;
# }
# #T_6106e_row0_col3 {
#   background-color: #4eb15d;
#   color: black;
# }
# #T_6106e_row0_col4, #T_6106e_row0_col6, #T_6106e_row0_col17, #T_6106e_row1_col1, #T_6106e_row1_col2, #T_6106e_row1_col7, #T_6106e_row1_col8, #T_6106e_row2_col11, #T_6106e_row4_col3, #T_6106e_row4_col9, #T_6106e_row4_col13, #T_6106e_row11_col14, #T_6106e_row12_col15, #T_6106e_row14_col10, #T_6106e_row15_col9, #T_6106e_row16_col5, #T_6106e_row17_col16, #T_6106e_row19_col12 {
#   background-color: #006837;
#   color: white;
# }
# #T_6106e_row0_col5, #T_6106e_row8_col7, #T_6106e_row16_col4 {
#   background-color: #5ab760;
#   color: black;
# }
# #T_6106e_row0_col7, #T_6106e_row2_col4, #T_6106e_row9_col15, #T_6106e_row18_col4, #T_6106e_row22_col13, #T_6106e_row22_col17, #T_6106e_row26_col11, #T_6106e_row28_col13 {
#   background-color: #feda86;
#   color: black;
# }
# #T_6106e_row0_col8, #T_6106e_row0_col14, #T_6106e_row1_col10, #T_6106e_row13_col1, #T_6106e_row20_col14, #T_6106e_row22_col6, #T_6106e_row24_col17, #T_6106e_row30_col10 {
#   background-color: #fdbd6d;
#   color: black;
# }
# #T_6106e_row0_col9, #T_6106e_row5_col14, #T_6106e_row17_col14 {
#   background-color: #e2f397;
#   color: black;
# }
# #T_6106e_row0_col10, #T_6106e_row2_col3, #T_6106e_row12_col10, #T_6106e_row22_col8, #T_6106e_row29_col14 {
#   background-color: #feeda1;
#   color: black;
# }
# #T_6106e_row0_col11, #T_6106e_row12_col11, #T_6106e_row19_col14, #T_6106e_row30_col14 {
#   background-color: #fee999;
#   color: black;
# }
# #T_6106e_row0_col12, #T_6106e_row2_col13, #T_6106e_row3_col15, #T_6106e_row7_col11, #T_6106e_row12_col12, #T_6106e_row20_col13 {
#   background-color: #eff8aa;
#   color: black;
# }
# #T_6106e_row0_col13, #T_6106e_row1_col13, #T_6106e_row12_col2 {
#   background-color: #89cc67;
#   color: black;
# }
# #T_6106e_row0_col15, #T_6106e_row15_col4, #T_6106e_row18_col15 {
#   background-color: #f16640;
#   color: black;
# }
# #T_6106e_row0_col16, #T_6106e_row16_col8, #T_6106e_row17_col5, #T_6106e_row17_col13, #T_6106e_row19_col7, #T_6106e_row26_col3, #T_6106e_row26_col9, #T_6106e_row26_col12, #T_6106e_row27_col15, #T_6106e_row28_col2, #T_6106e_row28_col10, #T_6106e_row28_col11, #T_6106e_row28_col14, #T_6106e_row30_col1, #T_6106e_row30_col4, #T_6106e_row30_col6, #T_6106e_row30_col17 {
#   background-color: #a50026;
#   color: white;
# }
# #T_6106e_row1_col3, #T_6106e_row6_col3, #T_6106e_row7_col7, #T_6106e_row28_col3 {
#   background-color: #bbe278;
#   color: black;
# }
# #T_6106e_row1_col4, #T_6106e_row18_col6, #T_6106e_row24_col8, #T_6106e_row27_col14, #T_6106e_row30_col11 {
#   background-color: #f67c4a;
#   color: black;
# }
# #T_6106e_row1_col5, #T_6106e_row4_col5, #T_6106e_row18_col1 {
#   background-color: #fdc372;
#   color: black;
# }
# #T_6106e_row1_col6, #T_6106e_row7_col6 {
#   background-color: #f88950;
#   color: black;
# }
# #T_6106e_row1_col9, #T_6106e_row3_col1, #T_6106e_row8_col10, #T_6106e_row25_col16 {
#   background-color: #c1e57b;
#   color: black;
# }
# #T_6106e_row1_col11, #T_6106e_row4_col6, #T_6106e_row20_col15, #T_6106e_row26_col6 {
#   background-color: #fff2aa;
#   color: black;
# }
# #T_6106e_row1_col12 {
#   background-color: #e44c34;
#   color: white;
# }
# #T_6106e_row1_col14 {
#   background-color: #e8f59f;
#   color: black;
# }
# #T_6106e_row1_col15 {
#   background-color: #4bb05c;
#   color: black;
# }
# #T_6106e_row1_col16, #T_6106e_row20_col2, #T_6106e_row24_col16 {
#   background-color: #fed27f;
#   color: black;
# }
# #T_6106e_row1_col17 {
#   background-color: #51b35e;
#   color: black;
# }
# #T_6106e_row2_col1, #T_6106e_row6_col5, #T_6106e_row8_col12, #T_6106e_row11_col7, #T_6106e_row19_col11 {
#   background-color: #f4fab0;
#   color: black;
# }
# #T_6106e_row2_col2, #T_6106e_row7_col2, #T_6106e_row22_col16 {
#   background-color: #c7e77f;
#   color: black;
# }
# #T_6106e_row2_col5, #T_6106e_row18_col8, #T_6106e_row21_col7, #T_6106e_row28_col6 {
#   background-color: #feea9b;
#   color: black;
# }
# #T_6106e_row2_col6, #T_6106e_row5_col4, #T_6106e_row11_col11, #T_6106e_row20_col9, #T_6106e_row24_col4, #T_6106e_row24_col9, #T_6106e_row27_col2 {
#   background-color: #feefa3;
#   color: black;
# }
# #T_6106e_row2_col7 {
#   background-color: #e0f295;
#   color: black;
# }
# #T_6106e_row2_col8, #T_6106e_row6_col17 {
#   background-color: #bfe47a;
#   color: black;
# }
# #T_6106e_row2_col9 {
#   background-color: #fed884;
#   color: black;
# }
# #T_6106e_row2_col10, #T_6106e_row17_col10 {
#   background-color: #0f8446;
#   color: white;
# }
# #T_6106e_row2_col12, #T_6106e_row15_col2 {
#   background-color: #fdaf62;
#   color: black;
# }
# #T_6106e_row2_col14, #T_6106e_row14_col12 {
#   background-color: #17934e;
#   color: white;
# }
# #T_6106e_row2_col15, #T_6106e_row7_col15 {
#   background-color: #de402e;
#   color: white;
# }
# #T_6106e_row2_col16 {
#   background-color: #0b7d42;
#   color: white;
# }
# #T_6106e_row2_col17 {
#   background-color: #78c565;
#   color: black;
# }
# #T_6106e_row3_col2 {
#   background-color: #5db961;
#   color: black;
# }
# #T_6106e_row3_col3, #T_6106e_row6_col8, #T_6106e_row15_col5, #T_6106e_row17_col3 {
#   background-color: #fee28f;
#   color: black;
# }
# #T_6106e_row3_col4, #T_6106e_row5_col2, #T_6106e_row7_col13, #T_6106e_row15_col11, #T_6106e_row30_col13 {
#   background-color: #ecf7a6;
#   color: black;
# }
# #T_6106e_row3_col5, #T_6106e_row10_col13, #T_6106e_row19_col5 {
#   background-color: #36a657;
#   color: black;
# }
# #T_6106e_row3_col6, #T_6106e_row14_col14 {
#   background-color: #f57748;
#   color: black;
# }
# #T_6106e_row3_col7 {
#   background-color: #e9f6a1;
#   color: black;
# }
# #T_6106e_row3_col8, #T_6106e_row8_col2, #T_6106e_row9_col9, #T_6106e_row10_col6, #T_6106e_row11_col4, #T_6106e_row15_col8 {
#   background-color: #fee797;
#   color: black;
# }
# #T_6106e_row3_col9, #T_6106e_row12_col5, #T_6106e_row13_col5 {
#   background-color: #70c164;
#   color: black;
# }
# #T_6106e_row3_col10, #T_6106e_row7_col9, #T_6106e_row13_col10, #T_6106e_row18_col12, #T_6106e_row28_col15 {
#   background-color: #fff8b4;
#   color: black;
# }
# #T_6106e_row3_col11, #T_6106e_row6_col9, #T_6106e_row20_col16, #T_6106e_row21_col9 {
#   background-color: #fedc88;
#   color: black;
# }
# #T_6106e_row3_col12 {
#   background-color: #93d168;
#   color: black;
# }
# #T_6106e_row3_col13, #T_6106e_row10_col4, #T_6106e_row16_col14, #T_6106e_row17_col2, #T_6106e_row26_col14 {
#   background-color: #fee08b;
#   color: black;
# }
# #T_6106e_row3_col14, #T_6106e_row8_col6, #T_6106e_row13_col6, #T_6106e_row18_col10, #T_6106e_row22_col4, #T_6106e_row28_col5 {
#   background-color: #fecc7b;
#   color: black;
# }
# #T_6106e_row3_col16, #T_6106e_row19_col15 {
#   background-color: #f57245;
#   color: black;
# }
# #T_6106e_row3_col17, #T_6106e_row10_col1, #T_6106e_row14_col15 {
#   background-color: #9bd469;
#   color: black;
# }
# #T_6106e_row4_col1, #T_6106e_row5_col12, #T_6106e_row16_col13 {
#   background-color: #7dc765;
#   color: black;
# }
# #T_6106e_row4_col2, #T_6106e_row11_col13 {
#   background-color: #fee593;
#   color: black;
# }
# #T_6106e_row4_col4, #T_6106e_row4_col11, #T_6106e_row6_col16, #T_6106e_row19_col2, #T_6106e_row25_col7, #T_6106e_row25_col11, #T_6106e_row28_col4 {
#   background-color: #fdbb6c;
#   color: black;
# }
# #T_6106e_row4_col7, #T_6106e_row6_col13, #T_6106e_row11_col5, #T_6106e_row14_col11 {
#   background-color: #73c264;
#   color: black;
# }
# #T_6106e_row4_col8, #T_6106e_row7_col16, #T_6106e_row12_col17 {
#   background-color: #e6f59d;
#   color: black;
# }
# #T_6106e_row4_col10, #T_6106e_row13_col15, #T_6106e_row15_col14, #T_6106e_row16_col2, #T_6106e_row20_col17, #T_6106e_row21_col17 {
#   background-color: #fede89;
#   color: black;
# }
# #T_6106e_row4_col12, #T_6106e_row4_col17, #T_6106e_row10_col15, #T_6106e_row28_col16, #T_6106e_row29_col15 {
#   background-color: #a0d669;
#   color: black;
# }
# #T_6106e_row4_col14, #T_6106e_row9_col17, #T_6106e_row27_col8 {
#   background-color: #d7ee8a;
#   color: black;
# }
# #T_6106e_row4_col15, #T_6106e_row9_col5, #T_6106e_row18_col11 {
#   background-color: #fed07e;
#   color: black;
# }
# #T_6106e_row4_col16 {
#   background-color: #eef8a8;
#   color: black;
# }
# #T_6106e_row

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import time

# Set up the Selenium WebDriver
service = Service(r"C:\Users\PC\OneDrive\Documents\GitHub\chromedriver-win64\chromedriver.exe")  # Update with your path to chromedriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')  # Run in headless mode
options.add_argument('--disable-gpu')
driver = webdriver.Chrome(service=service, options=options)

# Load the webpage
url = 'https://www.basketball-reference.com/gleague/years/2025.html'
driver.get(url)

# Allow some time for JavaScript to load
time.sleep(5)

# Get the page source
html = driver.page_source

# Parse the HTML with BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')

# Find the table
table = soup.find('table', {'id': 'team-stats-sc-team'})

# Convert to pandas DataFrame
if table:
    team_stats = pd.read_html(str(table))[0]
    
    # Remove the 'Rk' column
    if 'Rk' in team_stats.columns:
        team_stats.drop(columns=['Rk'], inplace=True)
    
    # List of columns to transform to per-game
    per_game_columns = ['FG', 'FGA', '3P', '3PA', '2P', '2PA', 
                        'FT', 'FTA', 'AST', 'STL', 'BLK', 'PF', 'PTS']
    
    # Create per-game columns
    for col in per_game_columns:
        if col in team_stats.columns:  # Ensure the column exists
            team_stats[f'{col}/g'] = team_stats[col] / team_stats['G']
    
    # Drop specified columns and their per-game equivalents
    drop_columns = ['TOV', 'ORB', 'DRB', 'TRB', 'Pace', 'ORtg', 'G', 'MP']
    team_stats.drop(columns=[col for col in drop_columns if col in team_stats.columns], inplace=True)
    team_stats.drop(columns=[f'{col}/g' for col in drop_columns if f'{col}/g' in team_stats.columns], inplace=True)
    
    # Rename specific columns
    rename_mapping = {
        'FG/g': 'FGM/g',
        '3P/g': '3PM/g',
        '2P/g': '2PM/g',
        'FT/g': 'FTM/g'
    }
    team_stats.rename(columns=rename_mapping, inplace=True)
    
    # Exclude the "League Average" row
    team_stats = team_stats[team_stats['Team'] != 'League Average'].reset_index(drop=True)
    
    # Define the desired column order
    desired_order = [
        'Team', 'FGM/g', 'FGA/g', 'FG%', '3PM/g', '3PA/g', '3P%', '2PM/g',
        '2PA/g', '2P%', 'FTM/g', 'FTA/g', 'FT%', 'AST/g', 'STL/g', 'BLK/g', 'PF/g', 'PTS/g'
    ]
    
    # Reorder columns (ignoring missing ones in the DataFrame)
    team_stats = team_stats[[col for col in desired_order if col in team_stats.columns]]

    # Round all numeric columns to three decimal points
    numeric_cols = team_stats.select_dtypes(include='number').columns
    team_stats[numeric_cols] = team_stats[numeric_cols].round(3)
    
    # Filter the row for Raptors 905 only
    raptors_row = team_stats.loc[team_stats['Team'] == 'Raptors 905']
    
    # Calculate ranks and append ranks to numeric columns for display
    invert_cols = ['PF/g']  # Specify columns where ranking should be ascending
    df_with_ranks = team_stats.copy()
    for col in numeric_cols:
        # Calculate ranks (invert order for specified columns)
        if col in invert_cols:
            ranks = team_stats[col].rank(ascending=True, method='min').astype(int)
        else:
            ranks = team_stats[col].rank(ascending=False, method='min').astype(int)
        
        # Append ranks to column values for display
        df_with_ranks[col] = team_stats[col].astype(str) + ' (' + ranks.astype(str) + ')'
    
    # Apply color coding logic to Raptors 905 row
    col_min = team_stats[numeric_cols].min()
    col_max = team_stats[numeric_cols].max()

    def luminance(color):
        rgb = mcolors.hex2color(color)
        return 0.2126 * rgb[0] + 0.7152 * rgb[1] + 0.0722 * rgb[2]

    def color_cells(row):
        colors = []
        for col in numeric_cols:
            value = team_stats.loc[row.name, col]  # Use original numeric value for coloring
            if col in invert_cols:
                # Invert normalization for specified columns
                norm = (col_max[col] - value) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5
            else:
                # Normal normalization
                norm = (value - col_min[col]) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5
            color = mcolors.to_hex(plt.cm.RdYlGn(norm))
            text_color = 'white' if luminance(color) < 0.5 else 'black'
            colors.append(f"background-color: {color}; color: {text_color};")
        return colors

    # Style the Raptors 905 row
    styled_df = df_with_ranks.loc[df_with_ranks['Team'] == 'Raptors 905'].style.apply(
        color_cells, subset=numeric_cols, axis=1
    ).format(precision=3)

else:
    print("Table with id 'team-stats-sc-team' not found.")

# Quit the driver
driver.quit()

styled_df
# Out:
# <style type="text/css">
# #T_e4522_row0_col1 {
#   background-color: #9bd469;
#   color: black;
# }
# #T_e4522_row0_col2 {
#   background-color: #cfeb85;
#   color: black;
# }
# #T_e4522_row0_col3 {
#   background-color: #b3df72;
#   color: black;
# }
# #T_e4522_row0_col4 {
#   background-color: #fee18d;
#   color: black;
# }
# #T_e4522_row0_col5 {
#   background-color: #fff6b0;
#   color: black;
# }
# #T_e4522_row0_col6 {
#   background-color: #feeda1;
#   color: black;
# }
# #T_e4522_row0_col7 {
#   background-color: #addc6f;
#   color: black;
# }
# #T_e4522_row0_col8 {
#   background-color: #cbe982;
#   color: black;
# }
# #T_e4522_row0_col9 {
#   background-color: #9dd569;
#   color: black;
# }
# #T_e4522_row0_col10 {
#   background-color: #f47044;
#   color: black;
# }
# #T_e4522_row0_col11 {
#   background-color: #fece7c;
#   color: black;
# }
# #T_e4522_row0_col12, #T_e4522_row0_col16 {
#   background-color: #a50026;
#   color: white;
# }
# #T_e4522_row0_col13, #T_e4522_row0_col14 {
#   background-color: #36a657;
#   color: black;
# }
# #T_e4522_row0_col15 {
#   background-color: #93d168;
#   color: black;
# }
# #T_e4522_row0_col17 {
#   background-color: #d9ef8b;
#   color: black;
# }
# </style>
# <table id="T_e4522">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e4522_level0_col0" class="col_heading level0 col0" >Team</th>
#       <th id="T_e4522_level0_col1" class="col_heading level0 col1" >FGM/g</th>
#       <th id="T_e4522_level0_col2" class="col_heading level0 col2" >FGA/g</th>
#       <th id="T_e4522_level0_col3" class="col_heading level0 col3" >FG%</th>
#       <th id="T_e4522_level0_col4" class="col_heading level0 col4" >3PM/g</th>
#       <th id="T_e4522_level0_col5" class="col_heading level0 col5" >3PA/g</th>
#       <th id="T_e4522_level0_col6" class="col_heading level0 col6" >3P%</th>
#       <th id="T_e4522_level0_col7" class="col_heading level0 col7" >2PM/g</th>
#       <th id="T_e4522_level0_col8" class="col_heading level0 col8" >2PA/g</th>
#       <th id="T_e4522_level0_col9" class="col_heading level0 col9" >2P%</th>
#       <th id="T_e4522_level0_col10" class="col_heading level0 col10" >FTM/g</th>
#       <th id="T_e4522_level0_col11" class="col_heading level0 col11" >FTA/g</th>
#       <th id="T_e4522_level0_col12" class="col_heading level0 col12" >FT%</th>
#       <th id="T_e4522_level0_col13" class="col_heading level0 col13" >AST/g</th>
#       <th id="T_e4522_level0_col14" class="col_heading level0 col14" >STL/g</th>
#       <th id="T_e4522_level0_col15" class="col_heading level0 col15" >BLK/g</th>
#       <th id="T_e4522_level0_col16" class="col_heading level0 col16" >PF/g</th>
#       <th id="T_e4522_level0_col17" class="col_heading level0 col17" >PTS/g</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4522_level0_row0" class="row_heading level0 row0" >10</th>
#       <td id="T_e4522_row0_col0" class="data row0 col0" >Raptors 905</td>
#       <td id="T_e4522_row0_col1" class="data row0 col1" >43.5 (4)</td>
#       <td id="T_e4522_row0_col2" class="data row0 col2" >91.625 (6)</td>
#       <td id="T_e4522_row0_col3" class="data row0 col3" >0.475 (5)</td>
#       <td id="T_e4522_row0_col4" class="data row0 col4" >12.75 (14)</td>
#       <td id="T_e4522_row0_col5" class="data row0 col5" >36.875 (16)</td>
#       <td id="T_e4522_row0_col6" class="data row0 col6" >0.346 (13)</td>
#       <td id="T_e4522_row0_col7" class="data row0 col7" >30.75 (4)</td>
#       <td id="T_e4522_row0_col8" class="data row0 col8" >54.75 (7)</td>
#       <td id="T_e4522_row0_col9" class="data row0 col9" >0.562 (4)</td>
#       <td id="T_e4522_row0_col10" class="data row0 col10" >8.375 (29)</td>
#       <td id="T_e4522_row0_col11" class="data row0 col11" >13.0 (22)</td>
#       <td id="T_e4522_row0_col12" class="data row0 col12" >0.644 (31)</td>
#       <td id="T_e4522_row0_col13" class="data row0 col13" >27.375 (2)</td>
#       <td id="T_e4522_row0_col14" class="data row0 col14" >12.25 (4)</td>
#       <td id="T_e4522_row0_col15" class="data row0 col15" >7.25 (6)</td>
#       <td id="T_e4522_row0_col16" class="data row0 col16" >16.125 (31)</td>
#       <td id="T_e4522_row0_col17" class="data row0 col17" >113.25 (11)</td>
#     </tr>
#   </tbody>
# </table>

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import time

# Set up the Selenium WebDriver
service = Service(r"C:\Users\PC\OneDrive\Documents\GitHub\chromedriver-win64\chromedriver.exe")  # Update with your path to chromedriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')  # Run in headless mode
options.add_argument('--disable-gpu')
driver = webdriver.Chrome(service=service, options=options)

# Load the webpage
url = 'https://www.basketball-reference.com/gleague/years/2025.html'
driver.get(url)

# Allow some time for JavaScript to load
time.sleep(5)

# Get the page source
html = driver.page_source

# Parse the HTML with BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')

# Find the table
table = soup.find('table', {'id': 'team-stats-sc-team'})

# Convert to pandas DataFrame
if table:
    team_stats = pd.read_html(str(table))[0]
    
    # Remove the 'Rk' column
    if 'Rk' in team_stats.columns:
        team_stats.drop(columns=['Rk'], inplace=True)
    
    # List of columns to transform to per-game
    per_game_columns = ['FG', 'FGA', '3P', '3PA', '2P', '2PA', 
                        'FT', 'FTA', 'AST', 'STL', 'BLK', 'PF', 'PTS']
    
    # Create per-game columns
    for col in per_game_columns:
        if col in team_stats.columns:  # Ensure the column exists
            team_stats[f'{col}/g'] = team_stats[col] / team_stats['G']
    
    # Drop specified columns and their per-game equivalents
    drop_columns = ['TOV', 'ORB', 'DRB', 'TRB', 'Pace', 'ORtg', 'G', 'MP']
    team_stats.drop(columns=[col for col in drop_columns if col in team_stats.columns], inplace=True)
    team_stats.drop(columns=[f'{col}/g' for col in drop_columns if f'{col}/g' in team_stats.columns], inplace=True)
    
    # Rename specific columns
    rename_mapping = {
        'FG/g': 'FGM/g',
        '3P/g': '3PM/g',
        '2P/g': '2PM/g',
        'FT/g': 'FTM/g'
    }
    team_stats.rename(columns=rename_mapping, inplace=True)
    
    # Exclude the "League Average" row
    team_stats = team_stats[team_stats['Team'] != 'League Average'].reset_index(drop=True)
    
    # Define the desired column order
    desired_order = [
        'Team', 'FGM/g', 'FGA/g', 'FG%', '3PM/g', '3PA/g', '3P%', '2PM/g',
        '2PA/g', '2P%', 'FTM/g', 'FTA/g', 'FT%', 'AST/g', 'STL/g', 'BLK/g', 'PF/g', 'PTS/g'
    ]
    
    # Reorder columns (ignoring missing ones in the DataFrame)
    team_stats = team_stats[[col for col in desired_order if col in team_stats.columns]]

    # Round all numeric columns to three decimal points
    numeric_cols = team_stats.select_dtypes(include='number').columns
    team_stats[numeric_cols] = team_stats[numeric_cols].round(3)
    
    # Filter the row for opponent 905 only
    opponent_row = team_stats.loc[team_stats['Team'] == 'Greensboro Swarm']
    
    # Calculate ranks and append ranks to numeric columns for display
    invert_cols = ['PF/g']  # Specify columns where ranking should be ascending
    df_with_ranks = team_stats.copy()
    for col in numeric_cols:
        # Calculate ranks (invert order for specified columns)
        if col in invert_cols:
            ranks = team_stats[col].rank(ascending=True, method='min').astype(int)
        else:
            ranks = team_stats[col].rank(ascending=False, method='min').astype(int)
        
        # Append ranks to column values for display
        df_with_ranks[col] = team_stats[col].astype(str) + ' (' + ranks.astype(str) + ')'
    
    # Apply color coding logic to opponent 905 row
    col_min = team_stats[numeric_cols].min()
    col_max = team_stats[numeric_cols].max()

    def luminance(color):
        rgb = mcolors.hex2color(color)
        return 0.2126 * rgb[0] + 0.7152 * rgb[1] + 0.0722 * rgb[2]

    def color_cells(row):
        colors = []
        for col in numeric_cols:
            value = team_stats.loc[row.name, col]  # Use original numeric value for coloring
            if col in invert_cols:
                # Invert normalization for specified columns
                norm = (col_max[col] - value) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5
            else:
                # Normal normalization
                norm = (value - col_min[col]) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5
            color = mcolors.to_hex(plt.cm.RdYlGn(norm))
            text_color = 'white' if luminance(color) < 0.5 else 'black'
            colors.append(f"background-color: {color}; color: {text_color};")
        return colors

    # Style the opponent 905 row
    styled_df = df_with_ranks.loc[df_with_ranks['Team'] == 'Greensboro Swarm'].style.apply(
        color_cells, subset=numeric_cols, axis=1
    ).format(precision=3)

else:
    print("Table with id 'team-stats-sc-team' not found.")

# Quit the driver
driver.quit()

styled_df
# Out:
# <style type="text/css">
# #T_cb139_row0_col1 {
#   background-color: #fdb768;
#   color: black;
# }
# #T_cb139_row0_col2 {
#   background-color: #fecc7b;
#   color: black;
# }
# #T_cb139_row0_col3 {
#   background-color: #fede89;
#   color: black;
# }
# #T_cb139_row0_col4 {
#   background-color: #b10b26;
#   color: white;
# }
# #T_cb139_row0_col5, #T_cb139_row0_col13 {
#   background-color: #a50026;
#   color: white;
# }
# #T_cb139_row0_col6 {
#   background-color: #fdc171;
#   color: black;
# }
# #T_cb139_row0_col7 {
#   background-color: #bde379;
#   color: black;
# }
# #T_cb139_row0_col8 {
#   background-color: #48ae5c;
#   color: black;
# }
# #T_cb139_row0_col9 {
#   background-color: #fba35c;
#   color: black;
# }
# #T_cb139_row0_col10 {
#   background-color: #0f8446;
#   color: white;
# }
# #T_cb139_row0_col11 {
#   background-color: #36a657;
#   color: black;
# }
# #T_cb139_row0_col12 {
#   background-color: #d9ef8b;
#   color: black;
# }
# #T_cb139_row0_col14 {
#   background-color: #ddf191;
#   color: black;
# }
# #T_cb139_row0_col15 {
#   background-color: #ef633f;
#   color: white;
# }
# #T_cb139_row0_col16 {
#   background-color: #006837;
#   color: white;
# }
# #T_cb139_row0_col17 {
#   background-color: #fff0a6;
#   color: black;
# }
# </style>
# <table id="T_cb139">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb139_level0_col0" class="col_heading level0 col0" >Team</th>
#       <th id="T_cb139_level0_col1" class="col_heading level0 col1" >FGM/g</th>
#       <th id="T_cb139_level0_col2" class="col_heading level0 col2" >FGA/g</th>
#       <th id="T_cb139_level0_col3" class="col_heading level0 col3" >FG%</th>
#       <th id="T_cb139_level0_col4" class="col_heading level0 col4" >3PM/g</th>
#       <th id="T_cb139_level0_col5" class="col_heading level0 col5" >3PA/g</th>
#       <th id="T_cb139_level0_col6" class="col_heading level0 col6" >3P%</th>
#       <th id="T_cb139_level0_col7" class="col_heading level0 col7" >2PM/g</th>
#       <th id="T_cb139_level0_col8" class="col_heading level0 col8" >2PA/g</th>
#       <th id="T_cb139_level0_col9" class="col_heading level0 col9" >2P%</th>
#       <th id="T_cb139_level0_col10" class="col_heading level0 col10" >FTM/g</th>
#       <th id="T_cb139_level0_col11" class="col_heading level0 col11" >FTA/g</th>
#       <th id="T_cb139_level0_col12" class="col_heading level0 col12" >FT%</th>
#       <th id="T_cb139_level0_col13" class="col_heading level0 col13" >AST/g</th>
#       <th id="T_cb139_level0_col14" class="col_heading level0 col14" >STL/g</th>
#       <th id="T_cb139_level0_col15" class="col_heading level0 col15" >BLK/g</th>
#       <th id="T_cb139_level0_col16" class="col_heading level0 col16" >PF/g</th>
#       <th id="T_cb139_level0_col17" class="col_heading level0 col17" >PTS/g</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb139_level0_row0" class="row_heading level0 row0" >18</th>
#       <td id="T_cb139_row0_col0" class="data row0 col0" >Greensboro Swarm</td>
#       <td id="T_cb139_row0_col1" class="data row0 col1" >39.25 (18)</td>
#       <td id="T_cb139_row0_col2" class="data row0 col2" >87.125 (21)</td>
#       <td id="T_cb139_row0_col3" class="data row0 col3" >0.451 (15)</td>
#       <td id="T_cb139_row0_col4" class="data row0 col4" >9.0 (30)</td>
#       <td id="T_cb139_row0_col5" class="data row0 col5" >27.125 (31)</td>
#       <td id="T_cb139_row0_col6" class="data row0 col6" >0.332 (17)</td>
#       <td id="T_cb139_row0_col7" class="data row0 col7" >30.25 (6)</td>
#       <td id="T_cb139_row0_col8" class="data row0 col8" >60.0 (2)</td>
#       <td id="T_cb139_row0_col9" class="data row0 col9" >0.504 (28)</td>
#       <td id="T_cb139_row0_col10" class="data row0 col10" >14.125 (2)</td>
#       <td id="T_cb139_row0_col11" class="data row0 col11" >18.75 (2)</td>
#       <td id="T_cb139_row0_col12" class="data row0 col12" >0.753 (15)</td>
#       <td id="T_cb139_row0_col13" class="data row0 col13" >15.25 (31)</td>
#       <td id="T_cb139_row0_col14" class="data row0 col14" >10.125 (7)</td>
#       <td id="T_cb139_row0_col15" class="data row0 col15" >4.0 (27)</td>
#       <td id="T_cb139_row0_col16" class="data row0 col16" >3.625 (1)</td>
#       <td id="T_cb139_row0_col17" class="data row0 col17" >109.125 (19)</td>
#     </tr>
#   </tbody>
# </table>

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import pandas as pd
import time

# Set up the Selenium WebDriver
service = Service(r"C:\Users\PC\OneDrive\Documents\GitHub\chromedriver-win64\chromedriver.exe")  # Update with your path to chromedriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')  # Run in headless mode
options.add_argument('--disable-gpu')
driver = webdriver.Chrome(service=service, options=options)

# Load the webpage
url = 'https://www.basketball-reference.com/gleague/years/2025.html'
driver.get(url)

# Allow some time for JavaScript to load
time.sleep(5)

# Get the page source
html = driver.page_source

# Parse the HTML with BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')

# Find the table
table = soup.find('table', {'id': 'team-stats-sc-team'})

# Convert to pandas DataFrame
if table:
    team_stats = pd.read_html(str(table))[0]
    
    # Remove the 'Rk' column
    if 'Rk' in team_stats.columns:
        team_stats.drop(columns=['Rk'], inplace=True)
    
    # List of columns to transform to per-game
    per_game_columns = ['FG', 'FGA', '3P', '3PA', '2P', '2PA', 
                        'FT', 'FTA', 'AST', 'STL', 'BLK', 'PF', 'PTS']
    
    # Create per-game columns
    for col in per_game_columns:
        if col in team_stats.columns:  # Ensure the column exists
            team_stats[f'{col}/g'] = team_stats[col] / team_stats['G']
    
    # Drop specified columns and their per-game equivalents
    drop_columns = ['TOV', 'ORB', 'DRB', 'TRB', 'Pace', 'ORtg']
    team_stats.drop(columns=[col for col in drop_columns if col in team_stats.columns], inplace=True)
    team_stats.drop(columns=[f'{col}/g' for col in drop_columns if f'{col}/g' in team_stats.columns], inplace=True)
    
    # Rename specific columns
    rename_mapping = {
        'FG/g': 'FGM/g',
        '3P/g': '3PM/g',
        '2P/g': '2PM/g',
        'FT/g': 'FTM/g'
    }
    team_stats.rename(columns=rename_mapping, inplace=True)
    
    # Define the desired column order
    desired_order = [
        'Team', 'G', 'MP', 'FGM/g', 'FGA/g', 'FG%', '3PM/g', '3PA/g', '3P%', '2PM/g',
        '2PA/g', '2P%', 'FTM/g', 'FTA/g', 'FT%', 'AST/g', 'STL/g', 'BLK/g', 'PF/g', 'PTS/g'
    ]
    
    # Reorder columns (ignoring missing ones in the DataFrame)
    team_stats = team_stats[[col for col in desired_order if col in team_stats.columns]]

    # Round all numeric columns to three decimal points
    numeric_cols = team_stats.select_dtypes(include='number').columns
    team_stats[numeric_cols] = team_stats[numeric_cols].round(3)

else:
    print("Table with id 'team-stats-sc-team' not found.")

# Quit the driver
driver.quit()

team_stats
# Out:
#                         Team   G    MP   FGM/g   FGA/g    FG%   3PM/g   3PA/g  \
# 0                Valley Suns   8  1945  44.625  91.375  0.488  18.750  44.000
# 1         Westchester Knicks   8  1920  46.500  98.250  0.473  11.000  34.250
# 2         San Diego Clippers   8  1945  41.500  91.500  0.454  12.625  36.125
# 3             Rip City Remix   8  1920  42.750  94.750  0.451  14.250  45.000
# 4       Sioux Falls Skyforce   9  2185  44.000  87.444  0.503  12.000  34.222
# 5          Motor City Cruise   9  2210  43.111  89.889  0.480  13.222  35.556
# 6             Stockton Kings   8  1920  41.375  87.500  0.473  15.625  38.125
# 7       Salt Lake City Stars   8  1920  41.375  91.500  0.452  11.250  35.000
# 8                Iowa Wolves  10  2425  42.200  87.600  0.482   9.600  28.500
# 9           Long Island Nets   9  2160  41.333  92.667  0.446  10.889  34.778
# 10               Raptors 905   8  1920  43.500  91.625  0.475  12.750  36.875
# 11              Austin Spurs   9  2185  41.111  93.444  0.440  13.000  43.333
# 12             Maine Celtics   8  1920  40.875  93.500  0.437  13.250  43.375
# 13  Rio Grande Valley Vipers   8  1920  39.375  90.000  0.438  14.625  43.375
# 14        Capital City Go-Go  10  2400  38.000  80.900  0.470  11.100  30.900
# 15          Cleveland Charge   8  1920  40.500  85.375  0.474  10.625  35.625
# 16             Osceola Magic   9  2160  38.889  87.111  0.446  16.889  47.889
# 17          Greensboro Swarm   8  1920  39.250  87.125  0.451   9.000  27.125
# 18       Santa Cruz Warriors   8  1920  39.500  89.625  0.441  12.625  39.750
# 19        Oklahoma City Blue   8  1920  36.000  85.750  0.420  16.250  45.000
# 20         Grand Rapids Gold   8  1945  39.875  86.625  0.460  13.250  36.250
# 21       Delaware Blue Coats   9  2160  38.667  88.556  0.437  12.111  37.667
# 22     College Park Skyhawks   8  1920  39.875  87.375  0.456  12.375  37.125
# 23          Windy City Bulls   9  2210  39.444  89.111  0.443  11.222  34.333
# 24     Mexico City Capitanes   9  2185  36.889  82.556  0.447  13.222  37.778
# 25          South Bay Lakers   8  1920  38.000  86.000  0.442  13.125  40.000
# 26            Memphis Hustle   9  2160  37.778  91.000  0.415  14.889  42.444
# 27          Indiana Mad Ants   9  2235  38.556  88.000  0.438  10.778  33.778
# 28       Birmingham Squadron   8  1920  37.750  79.750  0.473  12.000  34.625
# 29             Texas Legends   8  1920  37.000  88.500  0.418  10.750  37.250
# 30            Wisconsin Herd   8  1920  35.875  85.125  0.421   8.750  30.500
# 31            League Average   8  2040  42.375  93.625  0.453  13.375  39.500
#
#       3P%   2PM/g   2PA/g    2P%   FTM/g   FTA/g    FT%   AST/g   STL/g  \
# 0   0.426  25.875  47.375  0.546  10.375  14.000  0.741  25.750   8.250
# 1   0.321  35.500  64.000  0.555   9.500  14.375  0.661  25.750  10.000
# 2   0.349  28.875  55.375  0.521  14.125  20.375  0.693  22.875  12.625
# 3   0.317  28.500  49.750  0.573  10.625  13.625  0.780  20.875   8.500
# 4   0.351  32.000  53.222  0.601  10.000  12.889  0.776  29.333  10.333
# 5   0.372  29.889  54.333  0.550   9.444  12.000  0.787  25.667  10.111
# 6   0.410  25.750  49.375  0.522  10.125  13.500  0.750  26.250   7.125
# 7   0.321  30.125  56.500  0.533  12.250  15.250  0.803  23.000  10.375
# 8   0.337  32.600  59.100  0.552  11.900  16.100  0.739  25.100  10.100
# 9   0.313  30.444  57.889  0.526  11.889  15.222  0.781  24.556   8.444
# 10  0.346  30.750  54.750  0.562   8.375  13.000  0.644  27.375  12.250
# 11  0.300  28.111  50.111  0.561  10.667  14.222  0.750  21.111  13.333
# 12  0.305  27.625  50.125  0.551  10.375  14.000  0.741  24.000   8.375
# 13  0.337  24.750  46.625  0.531  10.625  14.500  0.733  22.375  12.750
# 14  0.359  26.900  50.000  0.538  14.600  17.900  0.816  21.900   7.400
# 15  0.298  29.875  49.750  0.601  11.500  15.375  0.748  23.625   8.750
# 16  0.353  22.000  39.222  0.561   8.667  11.444  0.757  26.000   8.778
# 17  0.332  30.250  60.000  0.504  14.125  18.750  0.753  15.250  10.125
# 18  0.318  26.875  49.875  0.539   9.750  13.375  0.729  24.000   7.000
# 19  0.361  19.750  40.750  0.485  12.625  15.125  0.835  22.625   9.000
# 20  0.366  26.625  50.375  0.529   9.000  11.000  0.818  22.875   8.250
# 21  0.322  26.556  50.889  0.522  12.222  15.889  0.769  22.222   8.444
# 22  0.333  27.500  50.250  0.547   9.625  12.750  0.755  20.750   7.375
# 23  0.327  28.222  54.778  0.515  11.000  15.222  0.723  22.667   7.667
# 24  0.350  23.667  44.778  0.529  12.222  16.111  0.759  19.111  10.444
# 25  0.328  24.875  46.000  0.541   9.375  12.875  0.728  22.750   9.500
# 26  0.351  22.889  48.556  0.471   8.556  13.556  0.631  26.333   8.778
# 27  0.319  27.778  54.222  0.512  10.889  14.333  0.760  23.556   7.444
# 28  0.347  25.750  45.125  0.571   7.000   9.250  0.757  20.750   5.750
# 29  0.289  26.250  51.250  0.512   7.875  11.875  0.663  18.875   9.125
# 30  0.287  27.125  54.625  0.497   9.500  11.750  0.809  23.000   9.000
# 31  0.338  29.125  54.125  0.537  11.250  15.000  0.749  24.625   9.750
#
#     BLK/g    PF/g    PTS/g
# 0   4.125  17.375  125.125
# 1   8.000  12.250  120.125
# 2   3.750   4.250  118.625
# 3   6.250  14.500  117.000
# 4   5.222   9.889  116.778
# 5   4.889   5.222  115.556
# 6   6.000  12.875  115.125
# 7   3.750   9.625  114.750
# 8   5.900  13.600  114.400
# 9   5.333  14.667  113.778
# 10  7.250  16.125  113.250
# 11  4.667   7.667  113.333
# 12  9.000  11.000  112.625
# 13  5.375   7.875  111.000
# 14  7.300  11.100  111.000
# 15  6.500   9.125  110.375
# 16  6.556  11.111  109.889
# 17  4.000   3.625  109.125
# 18  4.125   6.375  108.500
# 19  4.250  14.125  108.250
# 20  5.750  12.000  107.875
# 21  4.667  10.556  107.889
# 22  6.125   8.625  107.625
# 23  6.444  10.556  106.667
# 24  5.111  12.222  106.000
# 25  7.500   8.500  105.250
# 26  4.333   5.444  104.778
# 27  3.000  10.000  104.222
# 28  5.875   7.625   99.375
# 29  7.250  14.250   97.875
# 30  8.875   8.125   96.500
# 31  6.000  10.875  116.625

# %% [markdown]
# # Standard Stats Against

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import pandas as pd
import time

# Set up the Selenium WebDriver
service = Service(r"C:\Users\PC\OneDrive\Documents\GitHub\chromedriver-win64\chromedriver.exe")  # Update with your path to chromedriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')  # Run in headless mode
options.add_argument('--disable-gpu')
driver = webdriver.Chrome(service=service, options=options)

# Load the webpage
url = 'https://www.basketball-reference.com/gleague/years/2025.html'
driver.get(url)

# Allow some time for JavaScript to load
time.sleep(5)

# Get the page source
html = driver.page_source

# Parse the HTML with BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')

# Find the table
table = soup.find('table', {'id': 'team-stats-sc-opponent'})

# Convert to pandas DataFrame
if table:
    team_stats = pd.read_html(str(table))[0]
    
    # Remove the 'Rk' column
    if 'Rk' in team_stats.columns:
        team_stats.drop(columns=['Rk'], inplace=True)
    
    # List of columns to transform to per-game
    per_game_columns = ['FG', 'FGA', '3P', '3PA', '2P', '2PA', 
                        'FT', 'FTA', 'AST', 'STL', 'BLK', 'PF', 'PTS']
    
    # Calculate per-game statistics before dropping 'G'
    if 'G' in team_stats.columns:
        for col in per_game_columns:
            if col in team_stats.columns:  # Ensure the column exists
                team_stats[f'{col}/g'] = team_stats[col] / team_stats['G']
    
    # Drop specified columns and their per-game equivalents
    drop_columns = ['TOV', 'ORB', 'DRB', 'TRB', 'Pace', 'ORtg', 'FTM/g', 'FT%']
    team_stats.drop(columns=[col for col in drop_columns if col in team_stats.columns], inplace=True)
    team_stats.drop(columns=[f'{col}/g' for col in drop_columns if f'{col}/g' in team_stats.columns], inplace=True)
    
    # Rename specific columns
    rename_mapping = {
        'FG/g': 'FGM/g',
        '3P/g': '3PM/g',
        '2P/g': '2PM/g',
        'FT/g': 'FTM/g'
    }
    team_stats.rename(columns=rename_mapping, inplace=True)
    
    # Drop the 'G' and 'MP' columns after calculations
    team_stats.drop(columns=['G', 'MP'], inplace=True, errors='ignore')

    # Define the desired column order
    desired_order = [
        'Team', 'FGM/g', 'FGA/g', 'FG%', '3PM/g', '3PA/g', '3P%', '2PM/g',
        '2PA/g', '2P%', 'FTA/g', 'AST/g', 'STL/g', 'BLK/g', 'PF/g', 'PTS/g'
    ]
    
    # Reorder columns (ignoring missing ones in the DataFrame)
    team_stats = team_stats[[col for col in desired_order if col in team_stats.columns]]

    # Round all numeric columns to three decimal points
    numeric_cols = team_stats.select_dtypes(include='number').columns
    team_stats[numeric_cols] = team_stats[numeric_cols].round(3)
    
    # Filter rows for Raptors 905 and League Average
    filtered_teams = team_stats.loc[team_stats['Team'].isin(['Raptors 905', 'League Average'])]
    
else:
    print("Table with id 'team-stats-sc-team' not found.")

# Quit the driver
driver.quit()

filtered_teams
# Out:
#               Team   FGM/g   FGA/g    FG%   3PM/g   3PA/g    3P%  2PM/g  \
# 28     Raptors 905  41.875  89.375  0.469  13.875  36.250  0.383   28.0
# 31  League Average  39.444  87.000  0.453  12.444  36.889  0.339   27.0
#
#      2PA/g    2P%   FTA/g   AST/g  STL/g  BLK/g    PF/g    PTS/g
# 28  53.125  0.527  18.125  25.000    8.0  5.875   7.375  119.000
# 31  50.222  0.537  13.889  22.889    9.0  5.556  10.111  108.444

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import time

# Set up the Selenium WebDriver
service = Service(r"C:\Users\PC\OneDrive\Documents\GitHub\chromedriver-win64\chromedriver.exe")  # Update with your path to chromedriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')  # Run in headless mode
options.add_argument('--disable-gpu')
driver = webdriver.Chrome(service=service, options=options)

# Load the webpage
url = 'https://www.basketball-reference.com/gleague/years/2025.html'
driver.get(url)

# Allow some time for JavaScript to load
time.sleep(5)

# Get the page source
html = driver.page_source

# Parse the HTML with BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')

# Find the table
table = soup.find('table', {'id': 'team-stats-sc-opponent'})

# Convert to pandas DataFrame
if table:
    team_stats = pd.read_html(str(table))[0]
    
    # Remove the 'Rk' column
    if 'Rk' in team_stats.columns:
        team_stats.drop(columns=['Rk'], inplace=True)
    
    # List of columns to transform to per-game
    per_game_columns = ['FG', 'FGA', '3P', '3PA', '2P', '2PA', 
                        'FT', 'FTA', 'AST', 'STL', 'BLK', 'PF', 'PTS']
    
    # Create per-game columns
    for col in per_game_columns:
        if col in team_stats.columns:  # Ensure the column exists
            team_stats[f'{col}/g'] = team_stats[col] / team_stats['G']
    
    # Drop specified columns and their per-game equivalents
    drop_columns = ['TOV', 'ORB', 'DRB', 'TRB', 'Pace', 'ORtg', 'G', 'MP']
    team_stats.drop(columns=[col for col in drop_columns if col in team_stats.columns], inplace=True)
    team_stats.drop(columns=[f'{col}/g' for col in drop_columns if f'{col}/g' in team_stats.columns], inplace=True)
    
    # Rename specific columns
    rename_mapping = {
        'FG/g': 'FGM/g',
        '3P/g': '3PM/g',
        '2P/g': '2PM/g',
        'FT/g': 'FTM/g'
    }
    team_stats.rename(columns=rename_mapping, inplace=True)
    
    # Drop 'FTM/g' and 'FT%' columns
    team_stats.drop(columns=['FTM/g', 'FT%'], inplace=True, errors='ignore')

    # Exclude the "League Average" row
    team_stats = team_stats[team_stats['Team'] != 'League Average'].reset_index(drop=True)
    
    # Define the desired column order
    desired_order = [
        'Team', 'FGM/g', 'FGA/g', 'FG%', '3PM/g', '3PA/g', '3P%', '2PM/g',
        '2PA/g', '2P%', 'FTA/g', 'AST/g', 'STL/g', 'BLK/g', 'PF/g', 'PTS/g'
    ]
    
    # Reorder columns (ignoring missing ones in the DataFrame)
    team_stats = team_stats[[col for col in desired_order if col in team_stats.columns]]

    # Round all numeric columns to three decimal points
    numeric_cols = team_stats.select_dtypes(include='number').columns
    team_stats[numeric_cols] = team_stats[numeric_cols].round(3)
    
    # Calculate ranks and append ranks to numeric columns for display
    invert_cols = ['PF/g']  # PF/g will be descending, all others ascending
    df_with_ranks = team_stats.copy()
    for col in numeric_cols:
        # Calculate ranks (invert order for specified columns)
        if col in invert_cols:
            ranks = team_stats[col].rank(ascending=False, method='min').astype(int)
        else:
            ranks = team_stats[col].rank(ascending=True, method='min').astype(int)
        
        # Append ranks to column values for display
        df_with_ranks[col] = team_stats[col].astype(str) + ' (' + ranks.astype(str) + ')'
    
    # Color coding logic
    col_min = team_stats[numeric_cols].min()
    col_max = team_stats[numeric_cols].max()

    def luminance(color):
        rgb = mcolors.hex2color(color)
        return 0.2126 * rgb[0] + 0.7152 * rgb[1] + 0.0722 * rgb[2]

    def color_cells(row):
        colors = []
        for col in numeric_cols:
            value = team_stats.loc[row.name, col]  # Use original numeric value for coloring
            if col in invert_cols:
                # Invert normalization for PF/g (descending order)
                norm = (value - col_min[col]) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5
            else:
                # Normal normalization for ascending order
                norm = (col_max[col] - value) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5
            color = mcolors.to_hex(plt.cm.RdYlGn(norm))
            text_color = 'white' if luminance(color) < 0.5 else 'black'
            colors.append(f"background-color: {color}; color: {text_color};")
        return colors

    # Apply the coloring logic to the DataFrame with ranks
    styled_df = df_with_ranks.style.apply(color_cells, subset=numeric_cols, axis=1).format(precision=3)

else:
    print("Table with id 'team-stats-sc-opponent' not found.")

# Quit the driver
driver.quit()

styled_df
# Out:
# <style type="text/css">
# #T_ca958_row0_col1, #T_ca958_row6_col11 {
#   background-color: #1b9950;
#   color: white;
# }
# #T_ca958_row0_col2, #T_ca958_row7_col2, #T_ca958_row7_col3, #T_ca958_row7_col12, #T_ca958_row13_col3, #T_ca958_row15_col7, #T_ca958_row17_col3, #T_ca958_row27_col3 {
#   background-color: #ddf191;
#   color: black;
# }
# #T_ca958_row0_col3 {
#   background-color: #036e3a;
#   color: white;
# }
# #T_ca958_row0_col4, #T_ca958_row0_col6, #T_ca958_row0_col15, #T_ca958_row1_col1, #T_ca958_row1_col11, #T_ca958_row1_col14, #T_ca958_row2_col3, #T_ca958_row2_col9, #T_ca958_row2_col10, #T_ca958_row2_col13, #T_ca958_row5_col7, #T_ca958_row5_col8, #T_ca958_row6_col2, #T_ca958_row19_col5, #T_ca958_row27_col12 {
#   background-color: #006837;
#   color: white;
# }
# #T_ca958_row0_col5, #T_ca958_row3_col5, #T_ca958_row9_col15, #T_ca958_row11_col3 {
#   background-color: #87cb67;
#   color: black;
# }
# #T_ca958_row0_col7, #T_ca958_row1_col9 {
#   background-color: #fdfebc;
#   color: black;
# }
# #T_ca958_row0_col8, #T_ca958_row16_col13, #T_ca958_row28_col8 {
#   background-color: #fdb365;
#   color: black;
# }
# #T_ca958_row0_col9, #T_ca958_row1_col6, #T_ca958_row25_col6 {
#   background-color: #b5df74;
#   color: black;
# }
# #T_ca958_row0_col10, #T_ca958_row6_col9, #T_ca958_row13_col4, #T_ca958_row30_col5 {
#   background-color: #fee491;
#   color: black;
# }
# #T_ca958_row0_col11, #T_ca958_row1_col4, #T_ca958_row12_col15 {
#   background-color: #a9da6c;
#   color: black;
# }
# #T_ca958_row0_col12, #T_ca958_row17_col6, #T_ca958_row17_col9, #T_ca958_row22_col3 {
#   background-color: #fafdb8;
#   color: black;
# }
# #T_ca958_row0_col13, #T_ca958_row6_col1 {
#   background-color: #bde379;
#   color: black;
# }
# #T_ca958_row0_col14, #T_ca958_row15_col8, #T_ca958_row15_col9 {
#   background-color: #f7fcb4;
#   color: black;
# }
# #T_ca958_row1_col2 {
#   background-color: #04703b;
#   color: white;
# }
# #T_ca958_row1_col3 {
#   background-color: #75c465;
#   color: black;
# }
# #T_ca958_row1_col5, #T_ca958_row19_col1, #T_ca958_row25_col12 {
#   background-color: #d5ed88;
#   color: black;
# }
# #T_ca958_row1_col7, #T_ca958_row7_col6 {
#   background-color: #8ecf67;
#   color: black;
# }
# #T_ca958_row1_col8, #T_ca958_row8_col1 {
#   background-color: #98d368;
#   color: black;
# }
# #T_ca958_row1_col10, #T_ca958_row14_col11, #T_ca958_row21_col14 {
#   background-color: #fee28f;
#   color: black;
# }
# #T_ca958_row1_col12, #T_ca958_row4_col9, #T_ca958_row7_col15, #T_ca958_row12_col4, #T_ca958_row13_col13, #T_ca958_row21_col4 {
#   background-color: #73c264;
#   color: black;
# }
# #T_ca958_row1_col13, #T_ca958_row13_col8, #T_ca958_row24_col13, #T_ca958_row26_col13 {
#   background-color: #fed07e;
#   color: black;
# }
# #T_ca958_row1_col15 {
#   background-color: #07753e;
#   color: white;
# }
# #T_ca958_row2_col1, #T_ca958_row17_col13, #T_ca958_row24_col14 {
#   background-color: #2da155;
#   color: black;
# }
# #T_ca958_row2_col2, #T_ca958_row8_col4, #T_ca958_row10_col12, #T_ca958_row21_col15 {
#   background-color: #f2faae;
#   color: black;
# }
# #T_ca958_row2_col4 {
#   background-color: #f46d43;
#   color: black;
# }
# #T_ca958_row2_col5, #T_ca958_row9_col4, #T_ca958_row10_col11, #T_ca958_row11_col4, #T_ca958_row15_col3, #T_ca958_row15_col4, #T_ca958_row21_col3, #T_ca958_row27_col7, #T_ca958_row29_col2 {
#   background-color: #fdad60;
#   color: black;
# }
# #T_ca958_row2_col6, #T_ca958_row4_col10, #T_ca958_row30_col2 {
#   background-color: #fdb163;
#   color: black;
# }
# #T_ca958_row2_col7, #T_ca958_row16_col5 {
#   background-color: #249d53;
#   color: white;
# }
# #T_ca958_row2_col8, #T_ca958_row14_col7 {
#   background-color: #c9e881;
#   color: black;
# }
# #T_ca958_row2_col11, #T_ca958_row12_col11, #T_ca958_row20_col15, #T_ca958_row27_col5, #T_ca958_row27_col9 {
#   background-color: #eef8a8;
#   color: black;
# }
# #T_ca958_row2_col12, #T_ca958_row4_col14, #T_ca958_row9_col12, #T_ca958_row19_col7 {
#   background-color: #fee18d;
#   color: black;
# }
# #T_ca958_row2_col14, #T_ca958_row25_col1, #T_ca958_row26_col9, #T_ca958_row28_col11 {
#   background-color: #f16640;
#   color: black;
# }
# #T_ca958_row2_col15, #T_ca958_row6_col10, #T_ca958_row24_col8 {
#   background-color: #1e9a51;
#   color: white;
# }
# #T_ca958_row3_col1, #T_ca958_row3_col3, #T_ca958_row8_col15, #T_ca958_row10_col3, #T_ca958_row10_col8 {
#   background-color: #7dc765;
#   color: black;
# }
# #T_ca958_row3_col2, #T_ca958_row7_col10, #T_ca958_row8_col11, #T_ca958_row14_col5 {
#   background-color: #cdea83;
#   color: black;
# }
# #T_ca958_row3_col4 {
#   background-color: #3ca959;
#   color: black;
# }
# #T_ca958_row3_col6, #T_ca958_row15_col2, #T_ca958_row19_col4 {
#   background-color: #7ac665;
#   color: black;
# }
# #T_ca958_row3_col7, #T_ca958_row20_col1 {
#   background-color: #fff8b4;
#   color: black;
# }
# #T_ca958_row3_col8, #T_ca958_row5_col11, #T_ca958_row16_col3, #T_ca958_row20_col6, #T_ca958_row26_col15 {
#   background-color: #fdc171;
#   color: black;
# }
# #T_ca958_row3_col9, #T_ca958_row17_col5, #T_ca958_row18_col1, #T_ca958_row20_col3, #T_ca958_row23_col5, #T_ca958_row28_col9 {
#   background-color: #e2f397;
#   color: black;
# }
# #T_ca958_row3_col10, #T_ca958_row4_col11, #T_ca958_row13_col5, #T_ca958_row13_col7 {
#   background-color: #fffdbc;
#   color: black;
# }
# #T_ca958_row3_col11, #T_ca958_row12_col10, #T_ca958_row16_col6, #T_ca958_row16_col11, #T_ca958_row24_col6, #T_ca958_row30_col3 {
#   background-color: #fa9656;
#   color: black;
# }
# #T_ca958_row3_col12 {
#   background-color: #fed884;
#   color: black;
# }
# #T_ca958_row3_col13, #T_ca958_row5_col6 {
#   background-color: #fdbd6d;
#   color: black;
# }
# #T_ca958_row3_col14, #T_ca958_row16_col8, #T_ca958_row19_col3, #T_ca958_row25_col11 {
#   background-color: #fca55d;
#   color: black;
# }
# #T_ca958_row3_col15, #T_ca958_row8_col3, #T_ca958_row26_col4 {
#   background-color: #3faa59;
#   color: black;
# }
# #T_ca958_row4_col1 {
#   background-color: #84ca66;
#   color: black;
# }
# #T_ca958_row4_col2, #T_ca958_row13_col9, #T_ca958_row17_col4, #T_ca958_row17_col10 {
#   background-color: #e8f59f;
#   color: black;
# }
# #T_ca958_row4_col3, #T_ca958_row9_col3 {
#   background-color: #66bd63;
#   color: black;
# }
# #T_ca958_row4_col4, #T_ca958_row7_col4, #T_ca958_row13_col10, #T_ca958_row14_col3 {
#   background-color: #199750;
#   color: white;
# }
# #T_ca958_row4_col5 {
#   background-color: #15904c;
#   color: white;
# }
# #T_ca958_row4_col6, #T_ca958_row23_col12 {
#   background-color: #c7e77f;
#   color: black;
# }
# #T_ca958_row4_col7, #T_ca958_row8_col13, #T_ca958_row14_col13, #T_ca958_row18_col8, #T_ca958_row24_col15, #T_ca958_row26_col6 {
#   background-color: #feefa3;
#   color: black;
# }
# #T_ca958_row4_col8 {
#   background-color: #e65036;
#   color: white;
# }
# #T_ca958_row4_col12, #T_ca958_row10_col10, #T_ca958_row11_col7, #T_ca958_row16_col2, #T_ca958_row17_col12 {
#   background-color: #a7d96b;
#   color: black;
# }
# #T_ca958_row4_col13 {
#   background-color: #f67f4b;
#   color: black;
# }
# #T_ca958_row4_col15, #T_ca958_row5_col2, #T_ca958_row7_col5, #T_ca958_row12_col6 {
#   background-color: #45ad5b;
#   color: black;
# }
# #T_ca958_row5_col1 {
#   background-color: #0e8245;
#   color: white;
# }
# #T_ca958_row5_col3 {
#   background-color: #51b35e;
#   color: black;
# }
# #T_ca958_row5_col4, #T_ca958_row29_col7, #T_ca958_row30_col10 {
#   background-color: #ca2427;
#   color: white;
# }
# #T_ca958_row5_col5, #T_ca958_row5_col13, #T_ca958_row12_col13, #T_ca958_row23_col14, #T_ca958_row27_col8 {
#   background-color: #de402e;
#   color: white;
# }
# #T_ca958_row5_col9, #T_ca958_row5_col14, #T_ca958_row6_col7, #T_ca958_row16_col12, #T_ca958_row29_col5 {
#   background-color: #c5e67e;
#   color: black;
# }
# #T_ca958_row5_col10, #T_ca958_row15_col5, #T_ca958_row16_col4, #T_ca958_row21_col10 {
#   background-color: #bbe278;
#   color: black;
# }
# #T_ca958_row5_col12 {
#   background-color: #82c966;
#   color: black;
# }
# #T_ca958_row5_col15 {
#   background-color: #5db961;
#   color: black;
# }
# #T_ca958_row6_col3, #T_ca958_row9_col13 {
#   background-color: #f67c4a;
#   color: black;
# }
# #T_ca958_row6_col4, #T_ca958_row18_col12, #T_ca958_row22_col2, #T_ca958_row23_col1, #T_ca958_row29_col6, #T_ca958_row30_col8 {
#   background-color: #fece7c;
#   color: black;
# }
# #T_ca958_row6_col5 {
#   background-color: #9bd469;
#   color: black;
# }
# #T_ca958_row6_col6 {
#   background-color: #ad0

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import time

# Set up the Selenium WebDriver
service = Service(r"C:\Users\PC\OneDrive\Documents\GitHub\chromedriver-win64\chromedriver.exe")  # Update with your path to chromedriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')  # Run in headless mode
options.add_argument('--disable-gpu')
driver = webdriver.Chrome(service=service, options=options)

# Load the webpage
url = 'https://www.basketball-reference.com/gleague/years/2025.html'
driver.get(url)

# Allow some time for JavaScript to load
time.sleep(5)

# Get the page source
html = driver.page_source

# Parse the HTML with BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')

# Find the table
table = soup.find('table', {'id': 'team-stats-sc-opponent'})

# Convert to pandas DataFrame
if table:
    team_stats = pd.read_html(str(table))[0]
    
    # Remove the 'Rk' column
    if 'Rk' in team_stats.columns:
        team_stats.drop(columns=['Rk'], inplace=True)
    
    # List of columns to transform to per-game
    per_game_columns = ['FG', 'FGA', '3P', '3PA', '2P', '2PA', 
                        'FT', 'FTA', 'AST', 'STL', 'BLK', 'PF', 'PTS']
    
    # Create per-game columns
    for col in per_game_columns:
        if col in team_stats.columns:  # Ensure the column exists
            team_stats[f'{col}/g'] = team_stats[col] / team_stats['G']
    
    # Drop specified columns and their per-game equivalents
    drop_columns = ['TOV', 'ORB', 'DRB', 'TRB', 'Pace', 'ORtg', 'G', 'MP']
    team_stats.drop(columns=[col for col in drop_columns if col in team_stats.columns], inplace=True)
    team_stats.drop(columns=[f'{col}/g' for col in drop_columns if f'{col}/g' in team_stats.columns], inplace=True)
    
    # Rename specific columns
    rename_mapping = {
        'FG/g': 'FGM/g',
        '3P/g': '3PM/g',
        '2P/g': '2PM/g',
        'FT/g': 'FTM/g'
    }
    team_stats.rename(columns=rename_mapping, inplace=True)
    
    # Drop 'FTM/g' and 'FT%' columns
    team_stats.drop(columns=['FTM/g', 'FT%'], inplace=True, errors='ignore')

    # Exclude the "League Average" row
    team_stats = team_stats[team_stats['Team'] != 'League Average'].reset_index(drop=True)
    
    # Define the desired column order
    desired_order = [
        'Team', 'FGM/g', 'FGA/g', 'FG%', '3PM/g', '3PA/g', '3P%', '2PM/g',
        '2PA/g', '2P%', 'FTA/g', 'AST/g', 'STL/g', 'BLK/g', 'PF/g', 'PTS/g'
    ]
    
    # Reorder columns (ignoring missing ones in the DataFrame)
    team_stats = team_stats[[col for col in desired_order if col in team_stats.columns]]

    # Round all numeric columns to three decimal points
    numeric_cols = team_stats.select_dtypes(include='number').columns
    team_stats[numeric_cols] = team_stats[numeric_cols].round(3)
    
    # Calculate ranks and append ranks to numeric columns for display
    invert_cols = ['PF/g']  # PF/g will be descending, all others ascending
    df_with_ranks = team_stats.copy()
    for col in numeric_cols:
        # Calculate ranks (invert order for specified columns)
        if col in invert_cols:
            ranks = team_stats[col].rank(ascending=False, method='min').astype(int)
        else:
            ranks = team_stats[col].rank(ascending=True, method='min').astype(int)
        
        # Append ranks to column values for display
        df_with_ranks[col] = team_stats[col].astype(str) + ' (' + ranks.astype(str) + ')'
    
    # Apply color coding logic to Raptors 905 row
    col_min = team_stats[numeric_cols].min()
    col_max = team_stats[numeric_cols].max()

    def luminance(color):
        rgb = mcolors.hex2color(color)
        return 0.2126 * rgb[0] + 0.7152 * rgb[1] + 0.0722 * rgb[2]

    def color_cells(row):
        colors = []
        for col in numeric_cols:
            value = team_stats.loc[row.name, col]  # Use original numeric value for coloring
            if col in invert_cols:
                # Invert normalization for PF/g (descending order)
                norm = (value - col_min[col]) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5
            else:
                # Normal normalization for ascending order
                norm = (col_max[col] - value) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5
            color = mcolors.to_hex(plt.cm.RdYlGn(norm))
            text_color = 'white' if luminance(color) < 0.5 else 'black'
            colors.append(f"background-color: {color}; color: {text_color};")
        return colors

    # Filter for Raptors 905 only
    raptors_row = df_with_ranks[df_with_ranks['Team'] == 'Raptors 905']
    
    # Style the Raptors 905 row
    styled_df = raptors_row.style.apply(color_cells, subset=numeric_cols, axis=1).format(precision=3)

else:
    print("Table with id 'team-stats-sc-opponent' not found.")

# Quit the driver
driver.quit()

styled_df
# Out:
# <style type="text/css">
# #T_88304_row0_col1 {
#   background-color: #fed481;
#   color: black;
# }
# #T_88304_row0_col2 {
#   background-color: #feea9b;
#   color: black;
# }
# #T_88304_row0_col3, #T_88304_row0_col13 {
#   background-color: #feda86;
#   color: black;
# }
# #T_88304_row0_col4 {
#   background-color: #fdb768;
#   color: black;
# }
# #T_88304_row0_col5 {
#   background-color: #d9ef8b;
#   color: black;
# }
# #T_88304_row0_col6, #T_88304_row0_col14 {
#   background-color: #d93429;
#   color: white;
# }
# #T_88304_row0_col7 {
#   background-color: #fff1a8;
#   color: black;
# }
# #T_88304_row0_col8 {
#   background-color: #fdb365;
#   color: black;
# }
# #T_88304_row0_col9 {
#   background-color: #e2f397;
#   color: black;
# }
# #T_88304_row0_col10 {
#   background-color: #a50026;
#   color: white;
# }
# #T_88304_row0_col11 {
#   background-color: #f16640;
#   color: black;
# }
# #T_88304_row0_col12 {
#   background-color: #8ccd67;
#   color: black;
# }
# #T_88304_row0_col15 {
#   background-color: #fa9b58;
#   color: black;
# }
# </style>
# <table id="T_88304">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_88304_level0_col0" class="col_heading level0 col0" >Team</th>
#       <th id="T_88304_level0_col1" class="col_heading level0 col1" >FGM/g</th>
#       <th id="T_88304_level0_col2" class="col_heading level0 col2" >FGA/g</th>
#       <th id="T_88304_level0_col3" class="col_heading level0 col3" >FG%</th>
#       <th id="T_88304_level0_col4" class="col_heading level0 col4" >3PM/g</th>
#       <th id="T_88304_level0_col5" class="col_heading level0 col5" >3PA/g</th>
#       <th id="T_88304_level0_col6" class="col_heading level0 col6" >3P%</th>
#       <th id="T_88304_level0_col7" class="col_heading level0 col7" >2PM/g</th>
#       <th id="T_88304_level0_col8" class="col_heading level0 col8" >2PA/g</th>
#       <th id="T_88304_level0_col9" class="col_heading level0 col9" >2P%</th>
#       <th id="T_88304_level0_col10" class="col_heading level0 col10" >FTA/g</th>
#       <th id="T_88304_level0_col11" class="col_heading level0 col11" >AST/g</th>
#       <th id="T_88304_level0_col12" class="col_heading level0 col12" >STL/g</th>
#       <th id="T_88304_level0_col13" class="col_heading level0 col13" >BLK/g</th>
#       <th id="T_88304_level0_col14" class="col_heading level0 col14" >PF/g</th>
#       <th id="T_88304_level0_col15" class="col_heading level0 col15" >PTS/g</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88304_level0_row0" class="row_heading level0 row0" >28</th>
#       <td id="T_88304_row0_col0" class="data row0 col0" >Raptors 905</td>
#       <td id="T_88304_row0_col1" class="data row0 col1" >41.875 (24)</td>
#       <td id="T_88304_row0_col2" class="data row0 col2" >89.375 (18)</td>
#       <td id="T_88304_row0_col3" class="data row0 col3" >0.469 (22)</td>
#       <td id="T_88304_row0_col4" class="data row0 col4" >13.875 (20)</td>
#       <td id="T_88304_row0_col5" class="data row0 col5" >36.25 (14)</td>
#       <td id="T_88304_row0_col6" class="data row0 col6" >0.383 (28)</td>
#       <td id="T_88304_row0_col7" class="data row0 col7" >28.0 (18)</td>
#       <td id="T_88304_row0_col8" class="data row0 col8" >53.125 (20)</td>
#       <td id="T_88304_row0_col9" class="data row0 col9" >0.527 (10)</td>
#       <td id="T_88304_row0_col10" class="data row0 col10" >18.125 (31)</td>
#       <td id="T_88304_row0_col11" class="data row0 col11" >25.0 (25)</td>
#       <td id="T_88304_row0_col12" class="data row0 col12" >8.0 (6)</td>
#       <td id="T_88304_row0_col13" class="data row0 col13" >5.875 (16)</td>
#       <td id="T_88304_row0_col14" class="data row0 col14" >7.375 (24)</td>
#       <td id="T_88304_row0_col15" class="data row0 col15" >119.0 (29)</td>
#     </tr>
#   </tbody>
# </table>

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import time

# Set up the Selenium WebDriver
service = Service(r"C:\Users\PC\OneDrive\Documents\GitHub\chromedriver-win64\chromedriver.exe")  # Update with your path to chromedriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')  # Run in headless mode
options.add_argument('--disable-gpu')
driver = webdriver.Chrome(service=service, options=options)

# Load the webpage
url = 'https://www.basketball-reference.com/gleague/years/2025.html'
driver.get(url)

# Allow some time for JavaScript to load
time.sleep(5)

# Get the page source
html = driver.page_source

# Parse the HTML with BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')

# Find the table
table = soup.find('table', {'id': 'team-stats-sc-opponent'})

# Convert to pandas DataFrame
if table:
    team_stats = pd.read_html(str(table))[0]
    
    # Remove the 'Rk' column
    if 'Rk' in team_stats.columns:
        team_stats.drop(columns=['Rk'], inplace=True)
    
    # List of columns to transform to per-game
    per_game_columns = ['FG', 'FGA', '3P', '3PA', '2P', '2PA', 
                        'FT', 'FTA', 'AST', 'STL', 'BLK', 'PF', 'PTS']
    
    # Create per-game columns
    for col in per_game_columns:
        if col in team_stats.columns:  # Ensure the column exists
            team_stats[f'{col}/g'] = team_stats[col] / team_stats['G']
    
    # Drop specified columns and their per-game equivalents
    drop_columns = ['TOV', 'ORB', 'DRB', 'TRB', 'Pace', 'ORtg', 'G', 'MP']
    team_stats.drop(columns=[col for col in drop_columns if col in team_stats.columns], inplace=True)
    team_stats.drop(columns=[f'{col}/g' for col in drop_columns if f'{col}/g' in team_stats.columns], inplace=True)
    
    # Rename specific columns
    rename_mapping = {
        'FG/g': 'FGM/g',
        '3P/g': '3PM/g',
        '2P/g': '2PM/g',
        'FT/g': 'FTM/g'
    }
    team_stats.rename(columns=rename_mapping, inplace=True)
    
    # Drop 'FTM/g' and 'FT%' columns
    team_stats.drop(columns=['FTM/g', 'FT%'], inplace=True, errors='ignore')

    # Exclude the "League Average" row
    team_stats = team_stats[team_stats['Team'] != 'League Average'].reset_index(drop=True)
    
    # Define the desired column order
    desired_order = [
        'Team', 'FGM/g', 'FGA/g', 'FG%', '3PM/g', '3PA/g', '3P%', '2PM/g',
        '2PA/g', '2P%', 'FTA/g', 'AST/g', 'STL/g', 'BLK/g', 'PF/g', 'PTS/g'
    ]
    
    # Reorder columns (ignoring missing ones in the DataFrame)
    team_stats = team_stats[[col for col in desired_order if col in team_stats.columns]]

    # Round all numeric columns to three decimal points
    numeric_cols = team_stats.select_dtypes(include='number').columns
    team_stats[numeric_cols] = team_stats[numeric_cols].round(3)
    
    # Calculate ranks and append ranks to numeric columns for display
    invert_cols = ['PF/g']  # PF/g will be descending, all others ascending
    df_with_ranks = team_stats.copy()
    for col in numeric_cols:
        # Calculate ranks (invert order for specified columns)
        if col in invert_cols:
            ranks = team_stats[col].rank(ascending=False, method='min').astype(int)
        else:
            ranks = team_stats[col].rank(ascending=True, method='min').astype(int)
        
        # Append ranks to column values for display
        df_with_ranks[col] = team_stats[col].astype(str) + ' (' + ranks.astype(str) + ')'
    
    # Apply color coding logic to opponent 905 row
    col_min = team_stats[numeric_cols].min()
    col_max = team_stats[numeric_cols].max()

    def luminance(color):
        rgb = mcolors.hex2color(color)
        return 0.2126 * rgb[0] + 0.7152 * rgb[1] + 0.0722 * rgb[2]

    def color_cells(row):
        colors = []
        for col in numeric_cols:
            value = team_stats.loc[row.name, col]  # Use original numeric value for coloring
            if col in invert_cols:
                # Invert normalization for PF/g (descending order)
                norm = (value - col_min[col]) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5
            else:
                # Normal normalization for ascending order
                norm = (col_max[col] - value) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5
            color = mcolors.to_hex(plt.cm.RdYlGn(norm))
            text_color = 'white' if luminance(color) < 0.5 else 'black'
            colors.append(f"background-color: {color}; color: {text_color};")
        return colors

    # Filter for opponent 905 only
    opponent_row = df_with_ranks[df_with_ranks['Team'] == 'Greensboro Swarm']
    
    # Style the opponent 905 row
    styled_df = opponent_row.style.apply(color_cells, subset=numeric_cols, axis=1).format(precision=3)

else:
    print("Table with id 'team-stats-sc-opponent' not found.")

# Quit the driver
driver.quit()

styled_df
# Out:
# <style type="text/css">
# #T_c81b2_row0_col1, #T_c81b2_row0_col11, #T_c81b2_row0_col14 {
#   background-color: #006837;
#   color: white;
# }
# #T_c81b2_row0_col2 {
#   background-color: #04703b;
#   color: white;
# }
# #T_c81b2_row0_col3 {
#   background-color: #75c465;
#   color: black;
# }
# #T_c81b2_row0_col4 {
#   background-color: #a9da6c;
#   color: black;
# }
# #T_c81b2_row0_col5 {
#   background-color: #d5ed88;
#   color: black;
# }
# #T_c81b2_row0_col6 {
#   background-color: #b5df74;
#   color: black;
# }
# #T_c81b2_row0_col7 {
#   background-color: #8ecf67;
#   color: black;
# }
# #T_c81b2_row0_col8 {
#   background-color: #98d368;
#   color: black;
# }
# #T_c81b2_row0_col9 {
#   background-color: #fdfebc;
#   color: black;
# }
# #T_c81b2_row0_col10 {
#   background-color: #fee28f;
#   color: black;
# }
# #T_c81b2_row0_col12 {
#   background-color: #73c264;
#   color: black;
# }
# #T_c81b2_row0_col13 {
#   background-color: #fed07e;
#   color: black;
# }
# #T_c81b2_row0_col15 {
#   background-color: #07753e;
#   color: white;
# }
# </style>
# <table id="T_c81b2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c81b2_level0_col0" class="col_heading level0 col0" >Team</th>
#       <th id="T_c81b2_level0_col1" class="col_heading level0 col1" >FGM/g</th>
#       <th id="T_c81b2_level0_col2" class="col_heading level0 col2" >FGA/g</th>
#       <th id="T_c81b2_level0_col3" class="col_heading level0 col3" >FG%</th>
#       <th id="T_c81b2_level0_col4" class="col_heading level0 col4" >3PM/g</th>
#       <th id="T_c81b2_level0_col5" class="col_heading level0 col5" >3PA/g</th>
#       <th id="T_c81b2_level0_col6" class="col_heading level0 col6" >3P%</th>
#       <th id="T_c81b2_level0_col7" class="col_heading level0 col7" >2PM/g</th>
#       <th id="T_c81b2_level0_col8" class="col_heading level0 col8" >2PA/g</th>
#       <th id="T_c81b2_level0_col9" class="col_heading level0 col9" >2P%</th>
#       <th id="T_c81b2_level0_col10" class="col_heading level0 col10" >FTA/g</th>
#       <th id="T_c81b2_level0_col11" class="col_heading level0 col11" >AST/g</th>
#       <th id="T_c81b2_level0_col12" class="col_heading level0 col12" >STL/g</th>
#       <th id="T_c81b2_level0_col13" class="col_heading level0 col13" >BLK/g</th>
#       <th id="T_c81b2_level0_col14" class="col_heading level0 col14" >PF/g</th>
#       <th id="T_c81b2_level0_col15" class="col_heading level0 col15" >PTS/g</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c81b2_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_c81b2_row0_col0" class="data row0 col0" >Greensboro Swarm</td>
#       <td id="T_c81b2_row0_col1" class="data row0 col1" >35.625 (1)</td>
#       <td id="T_c81b2_row0_col2" class="data row0 col2" >81.375 (2)</td>
#       <td id="T_c81b2_row0_col3" class="data row0 col3" >0.438 (10)</td>
#       <td id="T_c81b2_row0_col4" class="data row0 col4" >11.375 (9)</td>
#       <td id="T_c81b2_row0_col5" class="data row0 col5" >36.125 (13)</td>
#       <td id="T_c81b2_row0_col6" class="data row0 col6" >0.315 (8)</td>
#       <td id="T_c81b2_row0_col7" class="data row0 col7" >24.25 (4)</td>
#       <td id="T_c81b2_row0_col8" class="data row0 col8" >45.25 (5)</td>
#       <td id="T_c81b2_row0_col9" class="data row0 col9" >0.536 (17)</td>
#       <td id="T_c81b2_row0_col10" class="data row0 col10" >15.125 (22)</td>
#       <td id="T_c81b2_row0_col11" class="data row0 col11" >18.375 (1)</td>
#       <td id="T_c81b2_row0_col12" class="data row0 col12" >7.75 (4)</td>
#       <td id="T_c81b2_row0_col13" class="data row0 col13" >6.0 (18)</td>
#       <td id="T_c81b2_row0_col14" class="data row0 col14" >20.5 (1)</td>
#       <td id="T_c81b2_row0_col15" class="data row0 col15" >101.375 (2)</td>
#     </tr>
#   </tbody>
# </table>

# %%
team_stats.columns
# Out:
# Index(['Rk', 'Team', 'G', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P',
#        '2PA', '2P%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL',
#        'BLK', 'TOV', 'PF', 'PTS', 'Pace', 'ORtg'],
#       dtype='object')

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import pandas as pd
import time

# Set up the Selenium WebDriver
service = Service(r"C:\Users\PC\OneDrive\Documents\GitHub\chromedriver-win64\chromedriver.exe")  # Update with your path to chromedriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')  # Run in headless mode
options.add_argument('--disable-gpu')
driver = webdriver.Chrome(service=service, options=options)

# Load the webpage
url = 'https://www.basketball-reference.com/gleague/years/2025.html'
driver.get(url)

# Allow some time for JavaScript to load
time.sleep(5)

# Get the page source
html = driver.page_source

# Parse the HTML with BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')

# Find the table
table = soup.find('table', {'id': 'team-stats-sc-team'})

# Convert to pandas DataFrame
if table:
    team_stats = pd.read_html(str(table))[0]
    print(team_stats)  # Display the DataFrame
else:
    print("Table with id 'team-stats-sc-team' not found.")

# Quit the driver
driver.quit()
# Out:
#       Rk                      Team   G    MP   FG  FGA    FG%   3P  3PA  \
# 0    1.0               Valley Suns   8  1945  357  731  0.488  150  352
# 1    2.0        Westchester Knicks   8  1920  372  786  0.473   88  274
# 2    3.0        San Diego Clippers   8  1945  332  732  0.454  101  289
# 3    4.0            Rip City Remix   8  1920  342  758  0.451  114  360
# 4    5.0      Sioux Falls Skyforce   9  2185  396  787  0.503  108  308
# 5    6.0         Motor City Cruise   9  2210  388  809  0.480  119  320
# 6    7.0            Stockton Kings   8  1920  331  700  0.473  125  305
# 7    8.0      Salt Lake City Stars   8  1920  331  732  0.452   90  280
# 8    9.0               Iowa Wolves  10  2425  422  876  0.482   96  285
# 9   10.0          Long Island Nets   9  2160  372  834  0.446   98  313
# 10  11.0               Raptors 905   8  1920  348  733  0.475  102  295
# 11  12.0              Austin Spurs   9  2185  370  841  0.440  117  390
# 12  13.0             Maine Celtics   8  1920  327  748  0.437  106  347
# 13  14.0  Rio Grande Valley Vipers   8  1920  315  720  0.438  117  347
# 14  15.0        Capital City Go-Go  10  2400  380  809  0.470  111  309
# 15  16.0          Cleveland Charge   8  1920  324  683  0.474   85  285
# 16  17.0             Osceola Magic   9  2160  350  784  0.446  152  431
# 17  18.0          Greensboro Swarm   8  1920  314  697  0.451   72  217
# 18  19.0       Santa Cruz Warriors   8  1920  316  717  0.441  101  318
# 19  20.0        Oklahoma City Blue   8  1920  288  686  0.420  130  360
# 20  21.0         Grand Rapids Gold   8  1945  319  693  0.460  106  290
# 21  22.0       Delaware Blue Coats   9  2160  348  797  0.437  109  339
# 22  23.0     College Park Skyhawks   8  1920  319  699  0.456   99  297
# 23  24.0          Windy City Bulls   9  2210  355  802  0.443  101  309
# 24  25.0     Mexico City Capitanes   9  2185  332  743  0.447  119  340
# 25  26.0          South Bay Lakers   8  1920  304  688  0.442  105  320
# 26  27.0            Memphis Hustle   9  2160  340  819  0.415  134  382
# 27  28.0          Indiana Mad Ants   9  2235  347  792  0.438   97  304
# 28  29.0       Birmingham Squadron   8  1920  302  638  0.473   96  277
# 29  30.0             Texas Legends   8  1920  296  708  0.418   86  298
# 30  31.0            Wisconsin Herd   8  1920  287  681  0.421   70  244
# 31   NaN            League Average   8  2040  339  749  0.453  107  316
#
#       3P%  ...  DRB  TRB  AST  STL  BLK  TOV   PF   PTS   Pace     ORtg
# 0   0.426  ...  -10   53  206   66   33    7  139  1001  -17.5   -707.5
# 1   0.321  ...  -81   63  206   80   64    6   98   961  -34.6   -346.8
# 2   0.349  ...  -46   59  183  101   30    3   34   949    9.1   1286.6
# 3   0.317  ...  -48   55  167   68   50    5  116   936    6.5   1793.8
# 4   0.351  ...  -50   49  264   93   47    9   89  1051  -16.0   -723.7
# 5   0.372  ...  -55   48  231   91   44    6   47  1040  -10.8  -1044.9
# 6   0.410  ...  -41   61  210   57   48    3  103   921    4.7   2430.0
# 7   0.321  ...  -37   70  184   83   30    8   77   918   13.1    872.9
# 8   0.337  ...  -48   76  251  101   59    2  136  1144    9.8   1152.5
# 9   0.313  ...  -26   71  221   76   48    1  132  1024  -27.1   -419.8
# 10  0.346  ...  -40   58  219   98   58   10  129   906   15.8    719.0
# 11  0.300  ...  -80   60  190  120   42   11   69  1020 -104.9   -106.9
# 12  0.305  ...  -67   64  192   67   72   12   88   901  -10.9  -1028.8
# 13  0.337  ...  -53   58  179  102   43    3   63   888  -11.4   -973.9
# 14  0.359  ...  -35   81  219   74   73    9  111  1110    4.3   2554.5
# 15  0.298  ...  -33   54  189   70   52    5   73   883    5.5   2011.2
# 16  0.353  ...  -59   56  234   79   59    6  100   989  -15.0   -732.9
# 17  0.332  ...  -56   59  122   81   32   10   29   873  -29.7   -367.7
# 18  0.318  ...  -23   67  192   56   33    3   51   868   21.1    514.5
# 19  0.361  ...  -43   60  181   72   34    9  113   866   -2.6  -4088.7
# 20  0.366  ...  -55   45  183   66   46    4   96   863  -11.6   -917.4
# 21  0.322  ...  -44   65  200   76   42   10   95   971  -44.8   -240.7
# 22  0.333  ...  -44   53  166   59   49    8   69   861    5.3   2028.1
# 23  0.327  ...  -68   57  204   69   58    6   95   960  -13.1   -793.3
# 24  0.350  ...  -20   68  172   94   46   11  110   954    NaN      NaN
# 25  0.328  ...  -33   58  182   76   60   15   68   842    0.5  21144.1
# 26  0.351  ...  -86   62  237   79   39    5   49   943  -79.8   -131.3
# 27  0.319  ...  -42   69  212   67   27    8   90   938   10.3    978.0
# 28  0.347  ...  -42   41  166   46   47    5   61   795    3.6   2733.6
# 29  0.289  ...  -61   66  151   73   58    3  114   783  -17.7   -553.7
# 30  0.287  ...  -16   60  184   72   71    7   65   772  -49.1   -196.7
# 31  0.338  ...  -47   60  197   78   48    7   87   933  -12.8   -855.3
#
# [32 rows x 27 columns]

# %% [markdown]
# # G League Website

# %% [markdown]
# ## Traditional Stats

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import time

# Set up Selenium WebDriver
service = Service("/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver")  # Update with your path to chromedriver

#Mac file path
#"/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver"

#PC file path
#r"C:\Users\PC\OneDrive\Documents\GitHub\chromedriver-win64\chromedriver.exe"

options = Options()
options.add_argument('--headless')  # Run in headless mode
options.add_argument('--disable-gpu')
options.add_argument('--start-maximized')

driver = webdriver.Chrome(service=service, options=options)

# URL of the webpage to scrape
url = "https://stats.gleague.nba.com/teams/traditional/?sort=W_PCT&dir=-1"

# Load the webpage
driver.get(url)

# Allow time for JavaScript to load
time.sleep(10)  # Adjust the time as per your internet speed and website response time

# Locate the table
table_xpath = '//div[contains(@class, "nba-stat-table__overflow")]/table'
table_element = driver.find_element(By.XPATH, table_xpath)

# Extract the table data
table_html = table_element.get_attribute('outerHTML')

# Convert the table HTML into a pandas DataFrame
team_stats = pd.read_html(table_html)[0]

# Quit the driver
driver.quit()

# Drop the specified columns
columns_to_drop = [
    'Unnamed: 0', 'GP', 'W', 'L', 'WIN%', 'MIN', 'GP RANK', 'W RANK', 'L RANK', 'WIN% RANK', 'MIN RANK', 'PTS RANK',
    'FGM RANK', 'FGA RANK', 'FG% RANK', '3PM RANK', '3PA RANK', '3P% RANK',
    'FTM RANK', 'FTA RANK', 'FT% RANK', 'OREB RANK', 'DREB RANK',
    'REB RANK', 'AST RANK', 'TOV RANK', 'STL RANK', 'BLK RANK', 'BLKA RANK',
    'PF RANK', 'PFD RANK', '+/- RANK'
]
team_stats = team_stats.drop(columns=[col for col in columns_to_drop if col in team_stats.columns])

# Ensure numeric columns are correctly identified
numeric_cols = team_stats.select_dtypes(include=['number']).columns

# Calculate ranks and append ranks to numeric columns for display
invert_cols = ['PF']  # PF will be descending, all others ascending
df_with_ranks = team_stats.copy()

for col in numeric_cols:
    # Calculate ranks (invert order for specified columns)
    if col in invert_cols:
        ranks = team_stats[col].rank(ascending=True, method='min').astype(int)
    else:
        ranks = team_stats[col].rank(ascending=False, method='min').astype(int)
    
    # Append ranks to column values for display
    df_with_ranks[col] = team_stats[col].astype(str) + ' (' + ranks.astype(str) + ')'

# Color coding logic
col_min = team_stats[numeric_cols].min()
col_max = team_stats[numeric_cols].max()

def luminance(color):
    rgb = mcolors.hex2color(color)
    return 0.2126 * rgb[0] + 0.7152 * rgb[1] + 0.0722 * rgb[2]

def color_cells(row):
    colors = []
    for col in numeric_cols:
        value = team_stats.loc[row.name, col]  # Use original numeric value for coloring
        if col in invert_cols:
            # Invert normalization for specified columns
            norm = (col_max[col] - value) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5
        else:
            # Normal normalization
            norm = (value - col_min[col]) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5
        color = mcolors.to_hex(plt.cm.RdYlGn(norm))
        text_color = 'white' if luminance(color) < 0.5 else 'black'
        colors.append(f"background-color: {color}; color: {text_color};")
    return colors

# Apply the coloring logic to the DataFrame with ranks
styled_df = df_with_ranks.style.apply(color_cells, subset=numeric_cols, axis=1).format(precision=3)

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_218a1_row0_col1, #T_218a1_row8_col20, #T_218a1_row9_col15 {
#   background-color: #afdd70;
#   color: black;
# }
# #T_218a1_row0_col2, #T_218a1_row0_col17, #T_218a1_row9_col19, #T_218a1_row10_col19, #T_218a1_row12_col17, #T_218a1_row13_col21, #T_218a1_row20_col17, #T_218a1_row27_col17 {
#   background-color: #daf08d;
#   color: black;
# }
# #T_218a1_row0_col3, #T_218a1_row3_col16, #T_218a1_row6_col1, #T_218a1_row13_col12, #T_218a1_row14_col9, #T_218a1_row19_col16, #T_218a1_row24_col16, #T_218a1_row25_col4, #T_218a1_row30_col16 {
#   background-color: #fee08b;
#   color: black;
# }
# #T_218a1_row0_col4, #T_218a1_row15_col17 {
#   background-color: #51b35e;
#   color: black;
# }
# #T_218a1_row0_col5, #T_218a1_row21_col17 {
#   background-color: #d02927;
#   color: white;
# }
# #T_218a1_row0_col6 {
#   background-color: #c62027;
#   color: white;
# }
# #T_218a1_row0_col7, #T_218a1_row7_col3, #T_218a1_row7_col6, #T_218a1_row7_col20, #T_218a1_row10_col3, #T_218a1_row18_col16, #T_218a1_row27_col7 {
#   background-color: #feea9b;
#   color: black;
# }
# #T_218a1_row0_col8, #T_218a1_row3_col14, #T_218a1_row4_col21, #T_218a1_row14_col6, #T_218a1_row25_col17 {
#   background-color: #b7e075;
#   color: black;
# }
# #T_218a1_row0_col9 {
#   background-color: #bde379;
#   color: black;
# }
# #T_218a1_row0_col10, #T_218a1_row16_col9 {
#   background-color: #e0f295;
#   color: black;
# }
# #T_218a1_row0_col11, #T_218a1_row0_col15, #T_218a1_row12_col2, #T_218a1_row14_col5, #T_218a1_row16_col2, #T_218a1_row19_col15, #T_218a1_row21_col2, #T_218a1_row25_col1 {
#   background-color: #fee593;
#   color: black;
# }
# #T_218a1_row0_col12, #T_218a1_row8_col21, #T_218a1_row29_col14 {
#   background-color: #73c264;
#   color: black;
# }
# #T_218a1_row0_col13, #T_218a1_row3_col19, #T_218a1_row6_col13, #T_218a1_row21_col3, #T_218a1_row21_col19 {
#   background-color: #eff8aa;
#   color: black;
# }
# #T_218a1_row0_col14, #T_218a1_row11_col18, #T_218a1_row17_col19, #T_218a1_row21_col13, #T_218a1_row24_col5 {
#   background-color: #bbe278;
#   color: black;
# }
# #T_218a1_row0_col16, #T_218a1_row9_col9, #T_218a1_row15_col16, #T_218a1_row16_col12, #T_218a1_row16_col20, #T_218a1_row19_col20, #T_218a1_row23_col10 {
#   background-color: #e5f49b;
#   color: black;
# }
# #T_218a1_row0_col18, #T_218a1_row1_col18, #T_218a1_row4_col4, #T_218a1_row24_col4, #T_218a1_row27_col20 {
#   background-color: #c5e67e;
#   color: black;
# }
# #T_218a1_row0_col19, #T_218a1_row5_col19, #T_218a1_row20_col8 {
#   background-color: #fa9857;
#   color: black;
# }
# #T_218a1_row0_col20 {
#   background-color: #70c164;
#   color: black;
# }
# #T_218a1_row0_col21, #T_218a1_row10_col10 {
#   background-color: #0b7d42;
#   color: white;
# }
# #T_218a1_row1_col1, #T_218a1_row9_col6 {
#   background-color: #f4fab0;
#   color: black;
# }
# #T_218a1_row1_col2, #T_218a1_row6_col19, #T_218a1_row11_col19, #T_218a1_row13_col19, #T_218a1_row18_col21, #T_218a1_row19_col1, #T_218a1_row22_col13 {
#   background-color: #fdc776;
#   color: black;
# }
# #T_218a1_row1_col3, #T_218a1_row3_col3, #T_218a1_row5_col11, #T_218a1_row11_col8, #T_218a1_row12_col4, #T_218a1_row22_col1, #T_218a1_row23_col13, #T_218a1_row26_col4 {
#   background-color: #fdbf6f;
#   color: black;
# }
# #T_218a1_row1_col4, #T_218a1_row4_col20 {
#   background-color: #fdfebc;
#   color: black;
# }
# #T_218a1_row1_col5, #T_218a1_row30_col21 {
#   background-color: #bb1526;
#   color: white;
# }
# #T_218a1_row1_col6, #T_218a1_row1_col14, #T_218a1_row4_col18, #T_218a1_row5_col3, #T_218a1_row8_col11, #T_218a1_row8_col15, #T_218a1_row10_col20, #T_218a1_row18_col12, #T_218a1_row19_col4, #T_218a1_row22_col17, #T_218a1_row23_col8, #T_218a1_row23_col9, #T_218a1_row23_col16, #T_218a1_row27_col10, #T_218a1_row27_col19, #T_218a1_row27_col21, #T_218a1_row29_col13, #T_218a1_row30_col1, #T_218a1_row30_col2, #T_218a1_row30_col5, #T_218a1_row30_col7, #T_218a1_row30_col13 {
#   background-color: #a50026;
#   color: white;
# }
# #T_218a1_row1_col7, #T_218a1_row23_col4, #T_218a1_row27_col6 {
#   background-color: #fff1a8;
#   color: black;
# }
# #T_218a1_row1_col8 {
#   background-color: #0d8044;
#   color: white;
# }
# #T_218a1_row1_col9, #T_218a1_row2_col19, #T_218a1_row18_col17 {
#   background-color: #36a657;
#   color: black;
# }
# #T_218a1_row1_col10, #T_218a1_row11_col1, #T_218a1_row13_col14, #T_218a1_row17_col9, #T_218a1_row22_col10 {
#   background-color: #93d168;
#   color: black;
# }
# #T_218a1_row1_col11, #T_218a1_row12_col14 {
#   background-color: #c7e77f;
#   color: black;
# }
# #T_218a1_row1_col12 {
#   background-color: #5db961;
#   color: black;
# }
# #T_218a1_row1_col13, #T_218a1_row7_col2, #T_218a1_row23_col19 {
#   background-color: #96d268;
#   color: black;
# }
# #T_218a1_row1_col15, #T_218a1_row13_col13, #T_218a1_row29_col16 {
#   background-color: #fb9d59;
#   color: black;
# }
# #T_218a1_row1_col16, #T_218a1_row15_col15, #T_218a1_row18_col18, #T_218a1_row27_col18 {
#   background-color: #feefa3;
#   color: black;
# }
# #T_218a1_row1_col17, #T_218a1_row16_col3 {
#   background-color: #fba05b;
#   color: black;
# }
# #T_218a1_row1_col19, #T_218a1_row22_col3 {
#   background-color: #fdbd6d;
#   color: black;
# }
# #T_218a1_row1_col20, #T_218a1_row21_col10 {
#   background-color: #2aa054;
#   color: black;
# }
# #T_218a1_row1_col21, #T_218a1_row2_col16, #T_218a1_row3_col10, #T_218a1_row4_col7, #T_218a1_row5_col8, #T_218a1_row5_col15, #T_218a1_row5_col20, #T_218a1_row7_col4, #T_218a1_row8_col1, #T_218a1_row8_col5, #T_218a1_row8_col14, #T_218a1_row12_col16, #T_218a1_row13_col9, #T_218a1_row15_col2, #T_218a1_row15_col3, #T_218a1_row15_col11, #T_218a1_row15_col13, #T_218a1_row15_col18, #T_218a1_row16_col19, #T_218a1_row20_col6, #T_218a1_row20_col12, #T_218a1_row30_col17 {
#   background-color: #006837;
#   color: white;
# }
# #T_218a1_row2_col1, #T_218a1_row29_col8 {
#   background-color: #c3e67d;
#   color: black;
# }
# #T_218a1_row2_col2, #T_218a1_row9_col18, #T_218a1_row20_col19 {
#   background-color: #fffcba;
#   color: black;
# }
# #T_218a1_row2_col3, #T_218a1_row18_col11, #T_218a1_row28_col17 {
#   background-color: #78c565;
#   color: black;
# }
# #T_218a1_row2_col4, #T_218a1_row16_col13 {
#   background-color: #f67f4b;
#   color: black;
# }
# #T_218a1_row2_col5, #T_218a1_row2_col20, #T_218a1_row3_col20, #T_218a1_row9_col12, #T_218a1_row12_col8, #T_218a1_row21_col20, #T_218a1_row26_col20, #T_218a1_row28_col16 {
#   background-color: #fff3ac;
#   color: black;
# }
# #T_218a1_row2_col6, #T_218a1_row13_col16 {
#   background-color: #4eb15d;
#   color: black;
# }
# #T_218a1_row2_col7, #T_218a1_row28_col1 {
#   background-color: #d42d27;
#   color: white;
# }
# #T_218a1_row2_col8, #T_218a1_row4_col13, #T_218a1_row22_col8 {
#   background-color: #fffebe;
#   color: black;
# }
# #T_218a1_row2_col9, #T_218a1_row10_col11, #T_218a1_row14_col15, #T_218a1_row22_col15, #T_218a1_row23_col6, #T_218a1_row29_col4 {
#   background-color: #fff5ae;
#   color: black;
# }
# #T_218a1_row2_col10 {
#   background-color: #cdea83;
#   color: black;
# }
# #T_218a1_row2_col11, #T_218a1_row11_col4, #T_218a1_row28_col11 {
#   background-color: #7fc866;
#   color: black;
# }
# #T_218a1_row2_col12, #T_218a1_row21_col7, #T_218a1_row29_col5 {
#   background-color: #fcaa5f;
#   color: black;
# }
# #T_218a1_row2_col13, #T_218a1_row6_col20, #T_218a1_row18_col14 {
#   background-color: #feeda1;
#   color: black;
# }
# #T_218a1_row2_col14, #T_218a1_row4_col17, #T_218a1_row8_col8, #T_218a1_row10_col7, #T_218a1_row13_col6, #T_218a1_row16_col6, #T_218a1_row24_col17 {
#   background-color: #fff7b2;
#   color: black;
# }
# #T_218a1_row2_col15, #T_218a1_row18_col7, #T_218a1_row30_col4 {
#   background-color: #be1827;
#   color: white;
# }
# #T_218a1_row2_col17, #T_218a1_row12_col15, #T_218a1_row17_col15, #T_218a1_row17_col17, #T_218a1_row25_col18, #T_218a1_row28_col15, #T_218a1_row30_col14 {
#   background-color: #fee18d;
#   color: black;
# }
# #T_218a1_row2_col18, #T_218a1_row19_col19 {
#   background-color: #a5d86a;
#   color: black;
# }
# #T_218a1_row2_col21 {
#   background-color: #57b65f;
#   color: black;
# }
# #T_218a1_row3_col1, #T_218a1_row3_col9, #T_218a1_row9_col20, #T_218a1_row16_col1, #T_218a1_row24_col8 {
#   background-color: #fafdb8;
#   color: black;
# }
# #T_218a1_row3_col2, #T_218a1_row10_col9, #T_218a1_row28_col7 {
#   background-color: #d83128;
#   color: white;
# }
# #T_218a1_row3_col4, #T_218a1_row1

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import time

# Set up Selenium WebDriver
service = Service("/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver")  # Update with your path to chromedriver

#Mac file path
#"/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver"

#PC file path
#r"C:\Users\PC\OneDrive\Documents\GitHub\chromedriver-win64\chromedriver.exe"

options = Options()
options.add_argument('--headless')  # Run in headless mode
options.add_argument('--disable-gpu')
options.add_argument('--start-maximized')

driver = webdriver.Chrome(service=service, options=options)

# URL of the webpage to scrape
url = "https://stats.gleague.nba.com/teams/traditional/?sort=W_PCT&dir=-1"

# Load the webpage
driver.get(url)

# Allow time for JavaScript to load
time.sleep(10)  # Adjust the time as per your internet speed and website response time

# Locate the table
table_xpath = '//div[contains(@class, "nba-stat-table__overflow")]/table'
table_element = driver.find_element(By.XPATH, table_xpath)

# Extract the table data
table_html = table_element.get_attribute('outerHTML')

# Convert the table HTML into a pandas DataFrame
team_stats = pd.read_html(table_html)[0]

# Quit the driver
driver.quit()

# Drop the specified columns
columns_to_drop = [
    'Unnamed: 0', 'GP', 'W', 'L', 'WIN%', 'MIN', 'GP RANK', 'W RANK', 'L RANK', 'WIN% RANK', 'MIN RANK', 'PTS RANK',
    'FGM RANK', 'FGA RANK', 'FG% RANK', '3PM RANK', '3PA RANK', '3P% RANK',
    'FTM RANK', 'FTA RANK', 'FT% RANK', 'OREB RANK', 'DREB RANK',
    'REB RANK', 'AST RANK', 'TOV RANK', 'STL RANK', 'BLK RANK', 'BLKA RANK',
    'PF RANK', 'PFD RANK', '+/- RANK'
]
team_stats = team_stats.drop(columns=[col for col in columns_to_drop if col in team_stats.columns])

# Ensure numeric columns are correctly identified
numeric_cols = team_stats.select_dtypes(include=['number']).columns

# Calculate ranks and append ranks to numeric columns for display
invert_cols = ['PF']  # PF will be descending, all others ascending
df_with_ranks = team_stats.copy()

for col in numeric_cols:
    # Calculate ranks (invert order for specified columns)
    if col in invert_cols:
        ranks = team_stats[col].rank(ascending=True, method='min').astype(int)
    else:
        ranks = team_stats[col].rank(ascending=False, method='min').astype(int)
    
    # Append ranks to column values for display
    df_with_ranks[col] = team_stats[col].astype(str) + ' (' + ranks.astype(str) + ')'

# Filter for Raptors 905 only
raptors_row = df_with_ranks[df_with_ranks['TEAM'] == 'Raptors 905']

# Color coding logic
col_min = team_stats[numeric_cols].min()
col_max = team_stats[numeric_cols].max()

def luminance(color):
    rgb = mcolors.hex2color(color)
    return 0.2126 * rgb[0] + 0.7152 * rgb[1] + 0.0722 * rgb[2]

def color_cells(row):
    colors = []
    for col in numeric_cols:
        value = team_stats.loc[row.name, col]  # Use original numeric value for coloring
        if col in invert_cols:
            # Invert normalization for PF (descending order)
            norm = (col_max[col] - value) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5            
        else:
            # Normal normalization for ascending order
            norm = (value - col_min[col]) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5
        color = mcolors.to_hex(plt.cm.RdYlGn(norm))
        text_color = 'white' if luminance(color) < 0.5 else 'black'
        colors.append(f"background-color: {color}; color: {text_color};")
    return colors

# Style the Raptors 905 row
styled_df = raptors_row.style.apply(color_cells, subset=numeric_cols, axis=1).format(precision=3)

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_ee1bd_row0_col1, #T_ee1bd_row0_col15 {
#   background-color: #f7fcb4;
#   color: black;
# }
# #T_ee1bd_row0_col2, #T_ee1bd_row0_col3 {
#   background-color: #d7ee8a;
#   color: black;
# }
# #T_ee1bd_row0_col4 {
#   background-color: #d9ef8b;
#   color: black;
# }
# #T_ee1bd_row0_col5 {
#   background-color: #fed27f;
#   color: black;
# }
# #T_ee1bd_row0_col6 {
#   background-color: #fff1a8;
#   color: black;
# }
# #T_ee1bd_row0_col7 {
#   background-color: #feea9b;
#   color: black;
# }
# #T_ee1bd_row0_col8 {
#   background-color: #ea5739;
#   color: white;
# }
# #T_ee1bd_row0_col9 {
#   background-color: #fec877;
#   color: black;
# }
# #T_ee1bd_row0_col10, #T_ee1bd_row0_col19, #T_ee1bd_row0_col21 {
#   background-color: #a50026;
#   color: white;
# }
# #T_ee1bd_row0_col11 {
#   background-color: #feeb9d;
#   color: black;
# }
# #T_ee1bd_row0_col12 {
#   background-color: #e75337;
#   color: white;
# }
# #T_ee1bd_row0_col13 {
#   background-color: #d93429;
#   color: white;
# }
# #T_ee1bd_row0_col14 {
#   background-color: #48ae5c;
#   color: black;
# }
# #T_ee1bd_row0_col16 {
#   background-color: #0f8446;
#   color: white;
# }
# #T_ee1bd_row0_col17 {
#   background-color: #daf08d;
#   color: black;
# }
# #T_ee1bd_row0_col18 {
#   background-color: #feefa3;
#   color: black;
# }
# #T_ee1bd_row0_col20 {
#   background-color: #c5e67e;
#   color: black;
# }
# </style>
# <table id="T_ee1bd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ee1bd_level0_col0" class="col_heading level0 col0" >TEAM</th>
#       <th id="T_ee1bd_level0_col1" class="col_heading level0 col1" >PTS</th>
#       <th id="T_ee1bd_level0_col2" class="col_heading level0 col2" >FGM</th>
#       <th id="T_ee1bd_level0_col3" class="col_heading level0 col3" >FGA</th>
#       <th id="T_ee1bd_level0_col4" class="col_heading level0 col4" >FG%</th>
#       <th id="T_ee1bd_level0_col5" class="col_heading level0 col5" >3PM</th>
#       <th id="T_ee1bd_level0_col6" class="col_heading level0 col6" >3PA</th>
#       <th id="T_ee1bd_level0_col7" class="col_heading level0 col7" >3P%</th>
#       <th id="T_ee1bd_level0_col8" class="col_heading level0 col8" >FTM</th>
#       <th id="T_ee1bd_level0_col9" class="col_heading level0 col9" >FTA</th>
#       <th id="T_ee1bd_level0_col10" class="col_heading level0 col10" >FT%</th>
#       <th id="T_ee1bd_level0_col11" class="col_heading level0 col11" >OREB</th>
#       <th id="T_ee1bd_level0_col12" class="col_heading level0 col12" >DREB</th>
#       <th id="T_ee1bd_level0_col13" class="col_heading level0 col13" >REB</th>
#       <th id="T_ee1bd_level0_col14" class="col_heading level0 col14" >AST</th>
#       <th id="T_ee1bd_level0_col15" class="col_heading level0 col15" >TOV</th>
#       <th id="T_ee1bd_level0_col16" class="col_heading level0 col16" >STL</th>
#       <th id="T_ee1bd_level0_col17" class="col_heading level0 col17" >BLK</th>
#       <th id="T_ee1bd_level0_col18" class="col_heading level0 col18" >BLKA</th>
#       <th id="T_ee1bd_level0_col19" class="col_heading level0 col19" >PF</th>
#       <th id="T_ee1bd_level0_col20" class="col_heading level0 col20" >PFD</th>
#       <th id="T_ee1bd_level0_col21" class="col_heading level0 col21" >+/-</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee1bd_level0_row0" class="row_heading level0 row0" >27</th>
#       <td id="T_ee1bd_row0_col0" class="data row0 col0" >Raptors 905</td>
#       <td id="T_ee1bd_row0_col1" class="data row0 col1" >110.2 (17)</td>
#       <td id="T_ee1bd_row0_col2" class="data row0 col2" >42.3 (6)</td>
#       <td id="T_ee1bd_row0_col3" class="data row0 col3" >91.7 (7)</td>
#       <td id="T_ee1bd_row0_col4" class="data row0 col4" >46.2 (10)</td>
#       <td id="T_ee1bd_row0_col5" class="data row0 col5" >12.2 (17)</td>
#       <td id="T_ee1bd_row0_col6" class="data row0 col6" >36.2 (20)</td>
#       <td id="T_ee1bd_row0_col7" class="data row0 col7" >33.7 (12)</td>
#       <td id="T_ee1bd_row0_col8" class="data row0 col8" >8.1 (29)</td>
#       <td id="T_ee1bd_row0_col9" class="data row0 col9" >13.0 (24)</td>
#       <td id="T_ee1bd_row0_col10" class="data row0 col10" >62.4 (31)</td>
#       <td id="T_ee1bd_row0_col11" class="data row0 col11" >12.7 (15)</td>
#       <td id="T_ee1bd_row0_col12" class="data row0 col12" >29.0 (30)</td>
#       <td id="T_ee1bd_row0_col13" class="data row0 col13" >41.7 (28)</td>
#       <td id="T_ee1bd_row0_col14" class="data row0 col14" >26.3 (5)</td>
#       <td id="T_ee1bd_row0_col15" class="data row0 col15" >18.3 (6)</td>
#       <td id="T_ee1bd_row0_col16" class="data row0 col16" >12.4 (3)</td>
#       <td id="T_ee1bd_row0_col17" class="data row0 col17" >6.7 (8)</td>
#       <td id="T_ee1bd_row0_col18" class="data row0 col18" >5.7 (18)</td>
#       <td id="T_ee1bd_row0_col19" class="data row0 col19" >24.7 (31)</td>
#       <td id="T_ee1bd_row0_col20" class="data row0 col20" >21.4 (7)</td>
#       <td id="T_ee1bd_row0_col21" class="data row0 col21" >-9.0 (31)</td>
#     </tr>
#   </tbody>
# </table>

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import time

# Set up Selenium WebDriver
service = Service("/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver")  # Update with your path to chromedriver

#Mac file path
#"/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver"

#PC file path
#r"C:\Users\PC\OneDrive\Documents\GitHub\chromedriver-win64\chromedriver.exe"

options = Options()
options.add_argument('--headless')  # Run in headless mode
options.add_argument('--disable-gpu')
options.add_argument('--start-maximized')

driver = webdriver.Chrome(service=service, options=options)

# URL of the webpage to scrape
url = "https://stats.gleague.nba.com/teams/traditional/?sort=W_PCT&dir=-1"

# Load the webpage
driver.get(url)

# Allow time for JavaScript to load
time.sleep(10)  # Adjust the time as per your internet speed and website response time

# Locate the table
table_xpath = '//div[contains(@class, "nba-stat-table__overflow")]/table'
table_element = driver.find_element(By.XPATH, table_xpath)

# Extract the table data
table_html = table_element.get_attribute('outerHTML')

# Convert the table HTML into a pandas DataFrame
team_stats = pd.read_html(table_html)[0]

# Quit the driver
driver.quit()

# Drop the specified columns
columns_to_drop = [
    'Unnamed: 0', 'GP', 'W', 'L', 'WIN%', 'MIN', 'GP RANK', 'W RANK', 'L RANK', 'WIN% RANK', 'MIN RANK', 'PTS RANK',
    'FGM RANK', 'FGA RANK', 'FG% RANK', '3PM RANK', '3PA RANK', '3P% RANK',
    'FTM RANK', 'FTA RANK', 'FT% RANK', 'OREB RANK', 'DREB RANK',
    'REB RANK', 'AST RANK', 'TOV RANK', 'STL RANK', 'BLK RANK', 'BLKA RANK',
    'PF RANK', 'PFD RANK', '+/- RANK'
]
team_stats = team_stats.drop(columns=[col for col in columns_to_drop if col in team_stats.columns])

# Ensure numeric columns are correctly identified
numeric_cols = team_stats.select_dtypes(include=['number']).columns

# Calculate ranks and append ranks to numeric columns for display
invert_cols = ['PF']  # PF will be descending, all others ascending
df_with_ranks = team_stats.copy()

for col in numeric_cols:
    # Calculate ranks (invert order for specified columns)
    if col in invert_cols:
        ranks = team_stats[col].rank(ascending=True, method='min').astype(int)
    else:
        ranks = team_stats[col].rank(ascending=False, method='min').astype(int)
    
    # Append ranks to column values for display
    df_with_ranks[col] = team_stats[col].astype(str) + ' (' + ranks.astype(str) + ')'

# Filter for Raptors 905 only
raptors_row = df_with_ranks[df_with_ranks['TEAM'] == 'Westchester Knicks']

# Color coding logic
col_min = team_stats[numeric_cols].min()
col_max = team_stats[numeric_cols].max()

def luminance(color):
    rgb = mcolors.hex2color(color)
    return 0.2126 * rgb[0] + 0.7152 * rgb[1] + 0.0722 * rgb[2]

def color_cells(row):
    colors = []
    for col in numeric_cols:
        value = team_stats.loc[row.name, col]  # Use original numeric value for coloring
        if col in invert_cols:
            # Invert normalization for PF (descending order)
            norm = (col_max[col] - value) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5            
        else:
            # Normal normalization for ascending order
            norm = (value - col_min[col]) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5
        color = mcolors.to_hex(plt.cm.RdYlGn(norm))
        text_color = 'white' if luminance(color) < 0.5 else 'black'
        colors.append(f"background-color: {color}; color: {text_color};")
    return colors

# Style the Raptors 905 row
styled_df = raptors_row.style.apply(color_cells, subset=numeric_cols, axis=1).format(precision=3)

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_c50ff_row0_col1 {
#   background-color: #199750;
#   color: white;
# }
# #T_c50ff_row0_col2, #T_c50ff_row0_col3, #T_c50ff_row0_col11, #T_c50ff_row0_col13, #T_c50ff_row0_col18 {
#   background-color: #006837;
#   color: white;
# }
# #T_c50ff_row0_col4 {
#   background-color: #98d368;
#   color: black;
# }
# #T_c50ff_row0_col5 {
#   background-color: #f8864f;
#   color: black;
# }
# #T_c50ff_row0_col6 {
#   background-color: #fece7c;
#   color: black;
# }
# #T_c50ff_row0_col7 {
#   background-color: #fba35c;
#   color: black;
# }
# #T_c50ff_row0_col8 {
#   background-color: #fdc574;
#   color: black;
# }
# #T_c50ff_row0_col9 {
#   background-color: #fffbb8;
#   color: black;
# }
# #T_c50ff_row0_col10 {
#   background-color: #ee613e;
#   color: white;
# }
# #T_c50ff_row0_col12 {
#   background-color: #54b45f;
#   color: black;
# }
# #T_c50ff_row0_col14 {
#   background-color: #66bd63;
#   color: black;
# }
# #T_c50ff_row0_col15 {
#   background-color: #feefa3;
#   color: black;
# }
# #T_c50ff_row0_col16 {
#   background-color: #e5f49b;
#   color: black;
# }
# #T_c50ff_row0_col17 {
#   background-color: #51b35e;
#   color: black;
# }
# #T_c50ff_row0_col19 {
#   background-color: #fedc88;
#   color: black;
# }
# #T_c50ff_row0_col20 {
#   background-color: #cbe982;
#   color: black;
# }
# #T_c50ff_row0_col21 {
#   background-color: #87cb67;
#   color: black;
# }
# </style>
# <table id="T_c50ff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c50ff_level0_col0" class="col_heading level0 col0" >TEAM</th>
#       <th id="T_c50ff_level0_col1" class="col_heading level0 col1" >PTS</th>
#       <th id="T_c50ff_level0_col2" class="col_heading level0 col2" >FGM</th>
#       <th id="T_c50ff_level0_col3" class="col_heading level0 col3" >FGA</th>
#       <th id="T_c50ff_level0_col4" class="col_heading level0 col4" >FG%</th>
#       <th id="T_c50ff_level0_col5" class="col_heading level0 col5" >3PM</th>
#       <th id="T_c50ff_level0_col6" class="col_heading level0 col6" >3PA</th>
#       <th id="T_c50ff_level0_col7" class="col_heading level0 col7" >3P%</th>
#       <th id="T_c50ff_level0_col8" class="col_heading level0 col8" >FTM</th>
#       <th id="T_c50ff_level0_col9" class="col_heading level0 col9" >FTA</th>
#       <th id="T_c50ff_level0_col10" class="col_heading level0 col10" >FT%</th>
#       <th id="T_c50ff_level0_col11" class="col_heading level0 col11" >OREB</th>
#       <th id="T_c50ff_level0_col12" class="col_heading level0 col12" >DREB</th>
#       <th id="T_c50ff_level0_col13" class="col_heading level0 col13" >REB</th>
#       <th id="T_c50ff_level0_col14" class="col_heading level0 col14" >AST</th>
#       <th id="T_c50ff_level0_col15" class="col_heading level0 col15" >TOV</th>
#       <th id="T_c50ff_level0_col16" class="col_heading level0 col16" >STL</th>
#       <th id="T_c50ff_level0_col17" class="col_heading level0 col17" >BLK</th>
#       <th id="T_c50ff_level0_col18" class="col_heading level0 col18" >BLKA</th>
#       <th id="T_c50ff_level0_col19" class="col_heading level0 col19" >PF</th>
#       <th id="T_c50ff_level0_col20" class="col_heading level0 col20" >PFD</th>
#       <th id="T_c50ff_level0_col21" class="col_heading level0 col21" >+/-</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c50ff_level0_row0" class="row_heading level0 row0" >15</th>
#       <td id="T_c50ff_row0_col0" class="data row0 col0" >Westchester Knicks</td>
#       <td id="T_c50ff_row0_col1" class="data row0 col1" >120.1 (2)</td>
#       <td id="T_c50ff_row0_col2" class="data row0 col2" >46.5 (1)</td>
#       <td id="T_c50ff_row0_col3" class="data row0 col3" >98.8 (1)</td>
#       <td id="T_c50ff_row0_col4" class="data row0 col4" >47.1 (5)</td>
#       <td id="T_c50ff_row0_col5" class="data row0 col5" >11.0 (25)</td>
#       <td id="T_c50ff_row0_col6" class="data row0 col6" >34.4 (25)</td>
#       <td id="T_c50ff_row0_col7" class="data row0 col7" >32.0 (25)</td>
#       <td id="T_c50ff_row0_col8" class="data row0 col8" >9.5 (23)</td>
#       <td id="T_c50ff_row0_col9" class="data row0 col9" >14.4 (12)</td>
#       <td id="T_c50ff_row0_col10" class="data row0 col10" >66.1 (28)</td>
#       <td id="T_c50ff_row0_col11" class="data row0 col11" >18.1 (1)</td>
#       <td id="T_c50ff_row0_col12" class="data row0 col12" >35.3 (5)</td>
#       <td id="T_c50ff_row0_col13" class="data row0 col13" >53.4 (1)</td>
#       <td id="T_c50ff_row0_col14" class="data row0 col14" >25.9 (6)</td>
#       <td id="T_c50ff_row0_col15" class="data row0 col15" >17.6 (12)</td>
#       <td id="T_c50ff_row0_col16" class="data row0 col16" >10.0 (7)</td>
#       <td id="T_c50ff_row0_col17" class="data row0 col17" >8.0 (3)</td>
#       <td id="T_c50ff_row0_col18" class="data row0 col18" >8.3 (1)</td>
#       <td id="T_c50ff_row0_col19" class="data row0 col19" >21.0 (19)</td>
#       <td id="T_c50ff_row0_col20" class="data row0 col20" >21.3 (8)</td>
#       <td id="T_c50ff_row0_col21" class="data row0 col21" >5.8 (7)</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Advanced Stats

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import time

# Set up Selenium WebDriver
service = Service("/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver")  # Update with your path to chromedriver

#Mac file path
#"/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver"

#PC file path
#r"C:\Users\PC\OneDrive\Documents\GitHub\chromedriver-win64\chromedriver.exe"

options = Options()
options.add_argument('--headless')  # Run in headless mode
options.add_argument('--disable-gpu')
options.add_argument('--start-maximized')

driver = webdriver.Chrome(service=service, options=options)

# URL of the webpage to scrape
url = "https://stats.gleague.nba.com/teams/advanced/?sort=W&dir=-1"

# Load the webpage
driver.get(url)

# Allow time for JavaScript to load
time.sleep(10)  # Adjust the time as per your internet speed and website response time

# Locate the table
table_xpath = '//div[contains(@class, "nba-stat-table__overflow")]/table'
table_element = driver.find_element(By.XPATH, table_xpath)

# Extract the table data
table_html = table_element.get_attribute('outerHTML')

# Convert the table HTML into a pandas DataFrame
team_stats = pd.read_html(table_html)[0]

# Quit the driver
driver.quit()

# Drop the specified columns
columns_to_drop = [
    'Unnamed: 0', 'GP', 'W', 'L', 'WIN%', 'MIN', 'GP RANK', 'W RANK', 'L RANK',
       'MIN RANK', 'OffRtg RANK', 'DefRtg RANK', 'NetRtg RANK', 'AST% RANK',
       'AST/TO RANK', 'AST Ratio RANK', 'OREB% RANK', 'DREB% RANK',
       'REB% RANK', 'TO Ratio RANK', 'eFG% RANK', 'TS% RANK', 'PACE RANK',
       'PIE RANK'
]
team_stats = team_stats.drop(columns=[col for col in columns_to_drop if col in team_stats.columns])

# Ensure numeric columns are correctly identified
numeric_cols = team_stats.select_dtypes(include=['number']).columns

# Calculate ranks and append ranks to numeric columns for display
invert_cols = ['DefRtg', 'TOV%']  # PF will be descending, all others ascending
df_with_ranks = team_stats.copy()

for col in numeric_cols:
    # Calculate ranks (invert order for specified columns)
    if col in invert_cols:
        ranks = team_stats[col].rank(ascending=True, method='min').astype(int)
    else:
        ranks = team_stats[col].rank(ascending=False, method='min').astype(int)
    
    # Append ranks to column values for display
    df_with_ranks[col] = team_stats[col].astype(str) + ' (' + ranks.astype(str) + ')'

# Color coding logic
col_min = team_stats[numeric_cols].min()
col_max = team_stats[numeric_cols].max()

def luminance(color):
    rgb = mcolors.hex2color(color)
    return 0.2126 * rgb[0] + 0.7152 * rgb[1] + 0.0722 * rgb[2]

def color_cells(row):
    colors = []
    for col in numeric_cols:
        value = team_stats.loc[row.name, col]  # Use original numeric value for coloring
        if col in invert_cols:
            # Invert normalization for specified columns
            norm = (col_max[col] - value) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5
        else:
            # Normal normalization
            norm = (value - col_min[col]) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5
        color = mcolors.to_hex(plt.cm.RdYlGn(norm))
        text_color = 'white' if luminance(color) < 0.5 else 'black'
        colors.append(f"background-color: {color}; color: {text_color};")
    return colors

# Apply the coloring logic to the DataFrame with ranks
styled_df = df_with_ranks.style.apply(color_cells, subset=numeric_cols, axis=1).format(precision=3)

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_f0544_row0_col1 {
#   background-color: #a5d86a;
#   color: black;
# }
# #T_f0544_row0_col2 {
#   background-color: #0c7f43;
#   color: white;
# }
# #T_f0544_row0_col3, #T_f0544_row6_col6 {
#   background-color: #108647;
#   color: white;
# }
# #T_f0544_row0_col4, #T_f0544_row15_col12, #T_f0544_row20_col2, #T_f0544_row20_col12 {
#   background-color: #fffbb8;
#   color: black;
# }
# #T_f0544_row0_col5, #T_f0544_row17_col4, #T_f0544_row23_col2, #T_f0544_row29_col9 {
#   background-color: #fee695;
#   color: black;
# }
# #T_f0544_row0_col6 {
#   background-color: #d5ed88;
#   color: black;
# }
# #T_f0544_row0_col7, #T_f0544_row19_col7 {
#   background-color: #c3e67d;
#   color: black;
# }
# #T_f0544_row0_col8 {
#   background-color: #42ac5a;
#   color: black;
# }
# #T_f0544_row0_col9, #T_f0544_row2_col1, #T_f0544_row2_col10 {
#   background-color: #36a657;
#   color: black;
# }
# #T_f0544_row0_col10, #T_f0544_row4_col11, #T_f0544_row10_col5, #T_f0544_row15_col1 {
#   background-color: #e5f49b;
#   color: black;
# }
# #T_f0544_row0_col11, #T_f0544_row7_col4, #T_f0544_row10_col8 {
#   background-color: #e2f397;
#   color: black;
# }
# #T_f0544_row0_col12, #T_f0544_row8_col3, #T_f0544_row9_col2, #T_f0544_row11_col10, #T_f0544_row11_col12, #T_f0544_row12_col2, #T_f0544_row14_col10, #T_f0544_row24_col12 {
#   background-color: #8ecf67;
#   color: black;
# }
# #T_f0544_row0_col13, #T_f0544_row4_col10, #T_f0544_row9_col11, #T_f0544_row10_col11, #T_f0544_row16_col10 {
#   background-color: #fff3ac;
#   color: black;
# }
# #T_f0544_row0_col14 {
#   background-color: #148e4b;
#   color: white;
# }
# #T_f0544_row1_col1, #T_f0544_row18_col2, #T_f0544_row22_col13 {
#   background-color: #93d168;
#   color: black;
# }
# #T_f0544_row1_col2, #T_f0544_row1_col3, #T_f0544_row1_col9, #T_f0544_row1_col14, #T_f0544_row6_col8, #T_f0544_row8_col1, #T_f0544_row8_col5, #T_f0544_row8_col6, #T_f0544_row8_col10, #T_f0544_row8_col11, #T_f0544_row8_col12, #T_f0544_row18_col4, #T_f0544_row22_col7, #T_f0544_row24_col13 {
#   background-color: #006837;
#   color: white;
# }
# #T_f0544_row1_col4, #T_f0544_row1_col6, #T_f0544_row3_col5, #T_f0544_row3_col10, #T_f0544_row8_col7, #T_f0544_row8_col9, #T_f0544_row10_col13, #T_f0544_row15_col8, #T_f0544_row27_col2, #T_f0544_row27_col14, #T_f0544_row29_col3, #T_f0544_row29_col12, #T_f0544_row29_col14, #T_f0544_row30_col1, #T_f0544_row30_col11 {
#   background-color: #a50026;
#   color: white;
# }
# #T_f0544_row1_col5, #T_f0544_row24_col5, #T_f0544_row26_col3, #T_f0544_row29_col5 {
#   background-color: #ea5739;
#   color: white;
# }
# #T_f0544_row1_col7, #T_f0544_row19_col4 {
#   background-color: #63bc62;
#   color: black;
# }
# #T_f0544_row1_col8 {
#   background-color: #2da155;
#   color: black;
# }
# #T_f0544_row1_col10, #T_f0544_row24_col9 {
#   background-color: #c9e881;
#   color: black;
# }
# #T_f0544_row1_col11 {
#   background-color: #fdc171;
#   color: black;
# }
# #T_f0544_row1_col12, #T_f0544_row12_col13 {
#   background-color: #f1f9ac;
#   color: black;
# }
# #T_f0544_row1_col13, #T_f0544_row2_col13 {
#   background-color: #f8864f;
#   color: black;
# }
# #T_f0544_row2_col2, #T_f0544_row19_col11, #T_f0544_row25_col2 {
#   background-color: #c7e77f;
#   color: black;
# }
# #T_f0544_row2_col3, #T_f0544_row7_col12, #T_f0544_row18_col6 {
#   background-color: #48ae5c;
#   color: black;
# }
# #T_f0544_row2_col4, #T_f0544_row23_col7, #T_f0544_row26_col4 {
#   background-color: #fed07e;
#   color: black;
# }
# #T_f0544_row2_col5, #T_f0544_row5_col7, #T_f0544_row11_col5, #T_f0544_row12_col1, #T_f0544_row13_col14 {
#   background-color: #d7ee8a;
#   color: black;
# }
# #T_f0544_row2_col6, #T_f0544_row17_col6, #T_f0544_row24_col7 {
#   background-color: #fee999;
#   color: black;
# }
# #T_f0544_row2_col7, #T_f0544_row11_col1 {
#   background-color: #6bbf64;
#   color: black;
# }
# #T_f0544_row2_col8, #T_f0544_row6_col4, #T_f0544_row27_col13 {
#   background-color: #b1de71;
#   color: black;
# }
# #T_f0544_row2_col9, #T_f0544_row3_col7, #T_f0544_row7_col9, #T_f0544_row13_col1, #T_f0544_row24_col11 {
#   background-color: #afdd70;
#   color: black;
# }
# #T_f0544_row2_col11, #T_f0544_row5_col13, #T_f0544_row8_col8, #T_f0544_row21_col1, #T_f0544_row21_col3 {
#   background-color: #fca55d;
#   color: black;
# }
# #T_f0544_row2_col12, #T_f0544_row14_col7, #T_f0544_row19_col5, #T_f0544_row26_col12 {
#   background-color: #fdbf6f;
#   color: black;
# }
# #T_f0544_row2_col14, #T_f0544_row4_col9 {
#   background-color: #84ca66;
#   color: black;
# }
# #T_f0544_row3_col1, #T_f0544_row14_col2, #T_f0544_row16_col6, #T_f0544_row18_col10, #T_f0544_row30_col6 {
#   background-color: #f5fbb2;
#   color: black;
# }
# #T_f0544_row3_col2, #T_f0544_row5_col1, #T_f0544_row5_col6, #T_f0544_row14_col1, #T_f0544_row14_col6 {
#   background-color: #b3df72;
#   color: black;
# }
# #T_f0544_row3_col3, #T_f0544_row14_col5, #T_f0544_row18_col5 {
#   background-color: #ebf7a3;
#   color: black;
# }
# #T_f0544_row3_col4 {
#   background-color: #fee593;
#   color: black;
# }
# #T_f0544_row3_col6 {
#   background-color: #fdbb6c;
#   color: black;
# }
# #T_f0544_row3_col8, #T_f0544_row19_col10, #T_f0544_row23_col5 {
#   background-color: #fdb567;
#   color: black;
# }
# #T_f0544_row3_col9, #T_f0544_row7_col7, #T_f0544_row27_col5 {
#   background-color: #98d368;
#   color: black;
# }
# #T_f0544_row3_col11, #T_f0544_row13_col6, #T_f0544_row27_col4, #T_f0544_row30_col2 {
#   background-color: #cdea83;
#   color: black;
# }
# #T_f0544_row3_col12 {
#   background-color: #05713c;
#   color: white;
# }
# #T_f0544_row3_col13, #T_f0544_row4_col1, #T_f0544_row6_col7, #T_f0544_row7_col5, #T_f0544_row12_col9, #T_f0544_row16_col7 {
#   background-color: #feffbe;
#   color: black;
# }
# #T_f0544_row3_col14 {
#   background-color: #96d268;
#   color: black;
# }
# #T_f0544_row4_col2, #T_f0544_row13_col10 {
#   background-color: #0d8044;
#   color: white;
# }
# #T_f0544_row4_col3 {
#   background-color: #8ccd67;
#   color: black;
# }
# #T_f0544_row4_col4, #T_f0544_row26_col8, #T_f0544_row26_col9 {
#   background-color: #feea9b;
#   color: black;
# }
# #T_f0544_row4_col5 {
#   background-color: #fba05b;
#   color: black;
# }
# #T_f0544_row4_col6, #T_f0544_row12_col11, #T_f0544_row14_col8, #T_f0544_row23_col11, #T_f0544_row25_col11, #T_f0544_row26_col1 {
#   background-color: #fffcba;
#   color: black;
# }
# #T_f0544_row4_col7, #T_f0544_row15_col7, #T_f0544_row19_col2, #T_f0544_row28_col10 {
#   background-color: #fffdbc;
#   color: black;
# }
# #T_f0544_row4_col8, #T_f0544_row5_col4, #T_f0544_row22_col1 {
#   background-color: #60ba62;
#   color: black;
# }
# #T_f0544_row4_col12, #T_f0544_row13_col3, #T_f0544_row25_col8, #T_f0544_row26_col7 {
#   background-color: #dff293;
#   color: black;
# }
# #T_f0544_row4_col13, #T_f0544_row9_col1, #T_f0544_row23_col1 {
#   background-color: #fb9d59;
#   color: black;
# }
# #T_f0544_row4_col14 {
#   background-color: #a7d96b;
#   color: black;
# }
# #T_f0544_row5_col2, #T_f0544_row20_col1 {
#   background-color: #e8f59f;
#   color: black;
# }
# #T_f0544_row5_col3, #T_f0544_row5_col12, #T_f0544_row17_col5 {
#   background-color: #d1ec86;
#   color: black;
# }
# #T_f0544_row5_col5, #T_f0544_row15_col5, #T_f0544_row20_col6 {
#   background-color: #fecc7b;
#   color: black;
# }
# #T_f0544_row5_col8, #T_f0544_row10_col12 {
#   background-color: #fee797;
#   color: black;
# }
# #T_f0544_row5_col9, #T_f0544_row6_col10, #T_f0544_row12_col10 {
#   background-color: #e0f295;
#   color: black;
# }
# #T_f0544_row5_col10, #T_f0544_row12_col5, #T_f0544_row30_col5 {
#   background-color: #fee491;
#   color: black;
# }
# #T_f0544_row5_col11, #T_f0544_row25_col9 {
#   background-color: #fff6b0;
#   color: black;
# }
# #T_f0544_row5_col14, #T_f0544_row13_col2, #T_f0544_row14_col4 {
#   background-color: #f7fcb4;
#   color: black;
# }
# #T_f0544_row6_col1, #T_f0544_row7_col11 {
#   background-color: #7ac665;
#   color: black;
# }
# #T_f0544_row6_col2, #T_f0544_row10_col10 {
#   background-color: #66bd63;
#   color: black;
# }
# #T_f0544_row6_col3, #T_f0544_row22_col9 {
#   background-color: #279f53;
#   color: black;
# }
# #T_f0544_row6_col5, #T_f0544_row14_col3, #T_f0544_row14_col11, #T_f0544_row22_col10 {
#   background-color: #ddf191;
#   color: black;
# }
# #T_f0544_row6_col9 {
#   background-color: #45ad5b;
#   color: black;
# }
# #T_f0544_row6_col11 {
#   background-color: #51b35e;
#   color: black;
# }
# #T_f0544_row6_col12 {
#   background-color: #3faa59;
#   color: black;
# }
# #T_f0544_row

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import time

# Set up Selenium WebDriver
service = Service("/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver")  # Update with your path to chromedriver

#Mac file path
#"/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver"

#PC file path
#r"C:\Users\PC\OneDrive\Documents\GitHub\chromedriver-win64\chromedriver.exe"

options = Options()
options.add_argument('--headless')  # Run in headless mode
options.add_argument('--disable-gpu')
options.add_argument('--start-maximized')

driver = webdriver.Chrome(service=service, options=options)

# URL of the webpage to scrape
url = "https://stats.gleague.nba.com/teams/advanced/?sort=W&dir=-1"

# Load the webpage
driver.get(url)

# Allow time for JavaScript to load
time.sleep(10)  # Adjust the time as per your internet speed and website response time

# Locate the table
table_xpath = '//div[contains(@class, "nba-stat-table__overflow")]/table'
table_element = driver.find_element(By.XPATH, table_xpath)

# Extract the table data
table_html = table_element.get_attribute('outerHTML')

# Convert the table HTML into a pandas DataFrame
team_stats = pd.read_html(table_html)[0]

# Quit the driver
driver.quit()

# Drop the specified columns
columns_to_drop = [
    'Unnamed: 0', 'GP', 'W', 'L', 'WIN%', 'MIN', 'GP RANK', 'W RANK', 'L RANK',
       'MIN RANK', 'OffRtg RANK', 'DefRtg RANK', 'NetRtg RANK', 'AST% RANK',
       'AST/TO RANK', 'AST Ratio RANK', 'OREB% RANK', 'DREB% RANK',
       'REB% RANK', 'TO Ratio RANK', 'eFG% RANK', 'TS% RANK', 'PACE RANK',
       'PIE RANK'
]
team_stats = team_stats.drop(columns=[col for col in columns_to_drop if col in team_stats.columns])

# Ensure numeric columns are correctly identified
numeric_cols = team_stats.select_dtypes(include=['number']).columns

# Calculate ranks and append ranks to numeric columns for display
invert_cols = ['DefRtg', 'TOV%']  # PF will be descending, all others ascending
df_with_ranks = team_stats.copy()

for col in numeric_cols:
    # Calculate ranks (invert order for specified columns)
    if col in invert_cols:
        ranks = team_stats[col].rank(ascending=True, method='min').astype(int)
    else:
        ranks = team_stats[col].rank(ascending=False, method='min').astype(int)
    
    # Append ranks to column values for display
    df_with_ranks[col] = team_stats[col].astype(str) + ' (' + ranks.astype(str) + ')'

# Filter for Raptors 905 only
raptors_row = df_with_ranks[df_with_ranks['TEAM'] == 'Raptors 905']

# Color coding logic
col_min = team_stats[numeric_cols].min()
col_max = team_stats[numeric_cols].max()

def luminance(color):
    rgb = mcolors.hex2color(color)
    return 0.2126 * rgb[0] + 0.7152 * rgb[1] + 0.0722 * rgb[2]

def color_cells(row):
    colors = []
    for col in numeric_cols:
        value = team_stats.loc[row.name, col]  # Use original numeric value for coloring
        if col in invert_cols:
            # Invert normalization for PF (descending order)
            norm = (col_max[col] - value) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5            
        else:
            # Normal normalization for ascending order
            norm = (value - col_min[col]) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5
        color = mcolors.to_hex(plt.cm.RdYlGn(norm))
        text_color = 'white' if luminance(color) < 0.5 else 'black'
        colors.append(f"background-color: {color}; color: {text_color};")
    return colors

# Style the Raptors 905 row
styled_df = raptors_row.style.apply(color_cells, subset=numeric_cols, axis=1).format(precision=3)

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_8ca18_row0_col1 {
#   background-color: #fed481;
#   color: black;
# }
# #T_8ca18_row0_col2 {
#   background-color: #e95538;
#   color: white;
# }
# #T_8ca18_row0_col3 {
#   background-color: #ad0826;
#   color: white;
# }
# #T_8ca18_row0_col4, #T_8ca18_row0_col13 {
#   background-color: #c1e57b;
#   color: black;
# }
# #T_8ca18_row0_col5 {
#   background-color: #feec9f;
#   color: black;
# }
# #T_8ca18_row0_col6 {
#   background-color: #82c966;
#   color: black;
# }
# #T_8ca18_row0_col7 {
#   background-color: #fff5ae;
#   color: black;
# }
# #T_8ca18_row0_col8 {
#   background-color: #f47044;
#   color: black;
# }
# #T_8ca18_row0_col9 {
#   background-color: #f16640;
#   color: black;
# }
# #T_8ca18_row0_col10 {
#   background-color: #fffdbc;
#   color: black;
# }
# #T_8ca18_row0_col11 {
#   background-color: #f4fab0;
#   color: black;
# }
# #T_8ca18_row0_col12 {
#   background-color: #fed884;
#   color: black;
# }
# #T_8ca18_row0_col14 {
#   background-color: #e34933;
#   color: white;
# }
# </style>
# <table id="T_8ca18">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8ca18_level0_col0" class="col_heading level0 col0" >TEAM</th>
#       <th id="T_8ca18_level0_col1" class="col_heading level0 col1" >OffRtg</th>
#       <th id="T_8ca18_level0_col2" class="col_heading level0 col2" >DefRtg</th>
#       <th id="T_8ca18_level0_col3" class="col_heading level0 col3" >NetRtg</th>
#       <th id="T_8ca18_level0_col4" class="col_heading level0 col4" >AST%</th>
#       <th id="T_8ca18_level0_col5" class="col_heading level0 col5" >AST/TO</th>
#       <th id="T_8ca18_level0_col6" class="col_heading level0 col6" >AST Ratio</th>
#       <th id="T_8ca18_level0_col7" class="col_heading level0 col7" >OREB%</th>
#       <th id="T_8ca18_level0_col8" class="col_heading level0 col8" >DREB%</th>
#       <th id="T_8ca18_level0_col9" class="col_heading level0 col9" >REB%</th>
#       <th id="T_8ca18_level0_col10" class="col_heading level0 col10" >TOV%</th>
#       <th id="T_8ca18_level0_col11" class="col_heading level0 col11" >eFG%</th>
#       <th id="T_8ca18_level0_col12" class="col_heading level0 col12" >TS%</th>
#       <th id="T_8ca18_level0_col13" class="col_heading level0 col13" >PACE</th>
#       <th id="T_8ca18_level0_col14" class="col_heading level0 col14" >PIE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8ca18_level0_row0" class="row_heading level0 row0" >28</th>
#       <td id="T_8ca18_row0_col0" class="data row0 col0" >Raptors 905</td>
#       <td id="T_8ca18_row0_col1" class="data row0 col1" >105.2 (24)</td>
#       <td id="T_8ca18_row0_col2" class="data row0 col2" >113.3 (26)</td>
#       <td id="T_8ca18_row0_col3" class="data row0 col3" >-8.1 (29)</td>
#       <td id="T_8ca18_row0_col4" class="data row0 col4" >62.2 (7)</td>
#       <td id="T_8ca18_row0_col5" class="data row0 col5" >1.44 (14)</td>
#       <td id="T_8ca18_row0_col6" class="data row0 col6" >17.9 (5)</td>
#       <td id="T_8ca18_row0_col7" class="data row0 col7" >30.7 (20)</td>
#       <td id="T_8ca18_row0_col8" class="data row0 col8" >64.7 (26)</td>
#       <td id="T_8ca18_row0_col9" class="data row0 col9" >46.8 (27)</td>
#       <td id="T_8ca18_row0_col10" class="data row0 col10" >17.5 (20)</td>
#       <td id="T_8ca18_row0_col11" class="data row0 col11" >52.8 (11)</td>
#       <td id="T_8ca18_row0_col12" class="data row0 col12" >56.6 (23)</td>
#       <td id="T_8ca18_row0_col13" class="data row0 col13" >105.0 (6)</td>
#       <td id="T_8ca18_row0_col14" class="data row0 col14" >46.5 (27)</td>
#     </tr>
#   </tbody>
# </table>

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import time

# Set up Selenium WebDriver
service = Service("/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver")  # Update with your path to chromedriver

#Mac file path
#"/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver"

#PC file path
#r"C:\Users\PC\OneDrive\Documents\GitHub\chromedriver-win64\chromedriver.exe"

options = Options()
options.add_argument('--headless')  # Run in headless mode
options.add_argument('--disable-gpu')
options.add_argument('--start-maximized')

driver = webdriver.Chrome(service=service, options=options)

# URL of the webpage to scrape
url = "https://stats.gleague.nba.com/teams/advanced/?sort=W&dir=-1"

# Load the webpage
driver.get(url)

# Allow time for JavaScript to load
time.sleep(10)  # Adjust the time as per your internet speed and website response time

# Locate the table
table_xpath = '//div[contains(@class, "nba-stat-table__overflow")]/table'
table_element = driver.find_element(By.XPATH, table_xpath)

# Extract the table data
table_html = table_element.get_attribute('outerHTML')

# Convert the table HTML into a pandas DataFrame
team_stats = pd.read_html(table_html)[0]

# Quit the driver
driver.quit()

# Drop the specified columns
columns_to_drop = [
    'Unnamed: 0', 'GP', 'W', 'L', 'WIN%', 'MIN', 'GP RANK', 'W RANK', 'L RANK',
       'MIN RANK', 'OffRtg RANK', 'DefRtg RANK', 'NetRtg RANK', 'AST% RANK',
       'AST/TO RANK', 'AST Ratio RANK', 'OREB% RANK', 'DREB% RANK',
       'REB% RANK', 'TO Ratio RANK', 'eFG% RANK', 'TS% RANK', 'PACE RANK',
       'PIE RANK'
]
team_stats = team_stats.drop(columns=[col for col in columns_to_drop if col in team_stats.columns])

# Ensure numeric columns are correctly identified
numeric_cols = team_stats.select_dtypes(include=['number']).columns

# Calculate ranks and append ranks to numeric columns for display
invert_cols = ['DefRtg', 'TOV%']  # PF will be descending, all others ascending
df_with_ranks = team_stats.copy()

for col in numeric_cols:
    # Calculate ranks (invert order for specified columns)
    if col in invert_cols:
        ranks = team_stats[col].rank(ascending=True, method='min').astype(int)
    else:
        ranks = team_stats[col].rank(ascending=False, method='min').astype(int)
    
    # Append ranks to column values for display
    df_with_ranks[col] = team_stats[col].astype(str) + ' (' + ranks.astype(str) + ')'

# Filter for Raptors 905 only
opponent_row = df_with_ranks[df_with_ranks['TEAM'] == 'Westchester Knicks']

# Color coding logic
col_min = team_stats[numeric_cols].min()
col_max = team_stats[numeric_cols].max()

def luminance(color):
    rgb = mcolors.hex2color(color)
    return 0.2126 * rgb[0] + 0.7152 * rgb[1] + 0.0722 * rgb[2]

def color_cells(row):
    colors = []
    for col in numeric_cols:
        value = team_stats.loc[row.name, col]  # Use original numeric value for coloring
        if col in invert_cols:
            # Invert normalization for PF (descending order)
            norm = (col_max[col] - value) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5            
        else:
            # Normal normalization for ascending order
            norm = (value - col_min[col]) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5
        color = mcolors.to_hex(plt.cm.RdYlGn(norm))
        text_color = 'white' if luminance(color) < 0.5 else 'black'
        colors.append(f"background-color: {color}; color: {text_color};")
    return colors

# Style the Raptors 905 row
styled_df = opponent_row.style.apply(color_cells, subset=numeric_cols, axis=1).format(precision=3)

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_828cb_row0_col1 {
#   background-color: #60ba62;
#   color: black;
# }
# #T_828cb_row0_col2 {
#   background-color: #ecf7a6;
#   color: black;
# }
# #T_828cb_row0_col3 {
#   background-color: #9bd469;
#   color: black;
# }
# #T_828cb_row0_col4 {
#   background-color: #feda86;
#   color: black;
# }
# #T_828cb_row0_col5 {
#   background-color: #fff5ae;
#   color: black;
# }
# #T_828cb_row0_col6 {
#   background-color: #e9f6a1;
#   color: black;
# }
# #T_828cb_row0_col7 {
#   background-color: #006837;
#   color: white;
# }
# #T_828cb_row0_col8 {
#   background-color: #fede89;
#   color: black;
# }
# #T_828cb_row0_col9 {
#   background-color: #279f53;
#   color: black;
# }
# #T_828cb_row0_col10 {
#   background-color: #ddf191;
#   color: black;
# }
# #T_828cb_row0_col11 {
#   background-color: #f8fcb6;
#   color: black;
# }
# #T_828cb_row0_col12 {
#   background-color: #feeda1;
#   color: black;
# }
# #T_828cb_row0_col13 {
#   background-color: #93d168;
#   color: black;
# }
# #T_828cb_row0_col14 {
#   background-color: #69be63;
#   color: black;
# }
# </style>
# <table id="T_828cb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_828cb_level0_col0" class="col_heading level0 col0" >TEAM</th>
#       <th id="T_828cb_level0_col1" class="col_heading level0 col1" >OffRtg</th>
#       <th id="T_828cb_level0_col2" class="col_heading level0 col2" >DefRtg</th>
#       <th id="T_828cb_level0_col3" class="col_heading level0 col3" >NetRtg</th>
#       <th id="T_828cb_level0_col4" class="col_heading level0 col4" >AST%</th>
#       <th id="T_828cb_level0_col5" class="col_heading level0 col5" >AST/TO</th>
#       <th id="T_828cb_level0_col6" class="col_heading level0 col6" >AST Ratio</th>
#       <th id="T_828cb_level0_col7" class="col_heading level0 col7" >OREB%</th>
#       <th id="T_828cb_level0_col8" class="col_heading level0 col8" >DREB%</th>
#       <th id="T_828cb_level0_col9" class="col_heading level0 col9" >REB%</th>
#       <th id="T_828cb_level0_col10" class="col_heading level0 col10" >TOV%</th>
#       <th id="T_828cb_level0_col11" class="col_heading level0 col11" >eFG%</th>
#       <th id="T_828cb_level0_col12" class="col_heading level0 col12" >TS%</th>
#       <th id="T_828cb_level0_col13" class="col_heading level0 col13" >PACE</th>
#       <th id="T_828cb_level0_col14" class="col_heading level0 col14" >PIE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_828cb_level0_row0" class="row_heading level0 row0" >22</th>
#       <td id="T_828cb_row0_col0" class="data row0 col0" >Westchester Knicks</td>
#       <td id="T_828cb_row0_col1" class="data row0 col1" >113.1 (4)</td>
#       <td id="T_828cb_row0_col2" class="data row0 col2" >107.6 (14)</td>
#       <td id="T_828cb_row0_col3" class="data row0 col3" >5.4 (7)</td>
#       <td id="T_828cb_row0_col4" class="data row0 col4" >55.6 (24)</td>
#       <td id="T_828cb_row0_col5" class="data row0 col5" >1.47 (13)</td>
#       <td id="T_828cb_row0_col6" class="data row0 col6" >16.7 (16)</td>
#       <td id="T_828cb_row0_col7" class="data row0 col7" >40.4 (1)</td>
#       <td id="T_828cb_row0_col8" class="data row0 col8" >67.0 (21)</td>
#       <td id="T_828cb_row0_col9" class="data row0 col9" >53.7 (3)</td>
#       <td id="T_828cb_row0_col10" class="data row0 col10" >16.6 (13)</td>
#       <td id="T_828cb_row0_col11" class="data row0 col11" >52.7 (12)</td>
#       <td id="T_828cb_row0_col12" class="data row0 col12" >57.2 (20)</td>
#       <td id="T_828cb_row0_col13" class="data row0 col13" >106.25 (2)</td>
#       <td id="T_828cb_row0_col14" class="data row0 col14" >53.9 (4)</td>
#     </tr>
#   </tbody>
# </table>

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import time

# Set up Selenium WebDriver
service = Service("/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver")  # Update with your path to chromedriver

# Mac file path
# "/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver"

# PC file path
# r"C:\Users\PC\OneDrive\Documents\GitHub\chromedriver-win64\chromedriver.exe"

options = Options()
options.add_argument('--headless')  # Run in headless mode
options.add_argument('--disable-gpu')
options.add_argument('--start-maximized')

driver = webdriver.Chrome(service=service, options=options)

# URL of the webpage to scrape
url = "https://stats.gleague.nba.com/teams/four-factors/?sort=W_PCT&dir=-1"

# Load the webpage
driver.get(url)

# Allow time for JavaScript to load
time.sleep(10)  # Adjust the time as per your internet speed and website response time

# Locate the table
table_xpath = '//div[contains(@class, "nba-stat-table__overflow")]/table'
table_element = driver.find_element(By.XPATH, table_xpath)

# Extract the table data
table_html = table_element.get_attribute('outerHTML')

# Convert the table HTML into a pandas DataFrame
team_stats = pd.read_html(table_html)[0]

# Quit the driver
driver.quit()

# Standardize column names
team_stats.columns = team_stats.columns.str.replace('\xa0', ' ', regex=False).str.strip()

# Drop the specified columns
columns_to_drop = [
    'Unnamed: 0', 'GP', 'W', 'L', 'WIN%', 'MIN', 'GP RANK', 'W RANK', 'L RANK', 'MIN RANK', 'eFG% RANK', 'TO Ratio RANK',
    'OREB% RANK', 'Opp FTA Rate RANK', 'Opp To Ratio RANK', 'WIN% RANK', 'FTA Rate RANK', 'Opp eFG% RANK', 'Opp OREB% RANK'
]
team_stats = team_stats.drop(columns=[col for col in columns_to_drop if col in team_stats.columns])

# Ensure numeric columns are correctly identified
numeric_cols = team_stats.select_dtypes(include=['number']).columns

# Calculate ranks and append ranks to numeric columns for display
invert_cols = ['TOV%', 'Opp eFG%', 'Opp FTA Rate', 'Opp OREB%']  # Columns with descending rank
df_with_ranks = team_stats.copy()

for col in numeric_cols:
    # Calculate ranks (invert order for specified columns)
    if col in invert_cols:
        ranks = team_stats[col].rank(ascending=True, method='min').astype(int)
    else:
        ranks = team_stats[col].rank(ascending=False, method='min').astype(int)
    
    # Append ranks to column values for display
    df_with_ranks[col] = team_stats[col].astype(str) + ' (' + ranks.astype(str) + ')'

# Color coding logic
col_min = team_stats[numeric_cols].min()
col_max = team_stats[numeric_cols].max()

def luminance(color):
    rgb = mcolors.hex2color(color)
    return 0.2126 * rgb[0] + 0.7152 * rgb[1] + 0.0722 * rgb[2]

def color_cells(row):
    colors = []
    for col in numeric_cols:
        value = team_stats.loc[row.name, col]  # Use original numeric value for coloring
        if col in invert_cols:
            # Invert normalization for specified columns
            norm = (col_max[col] - value) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5
        else:
            # Normal normalization
            norm = (value - col_min[col]) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5
        color = mcolors.to_hex(plt.cm.RdYlGn(norm))
        text_color = 'white' if luminance(color) < 0.5 else 'black'
        colors.append(f"background-color: {color}; color: {text_color};")
    return colors

# Apply the coloring logic to the DataFrame with ranks
styled_df = df_with_ranks.style.apply(color_cells, subset=numeric_cols, axis=1).format(precision=3)

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_c28fc_row0_col1, #T_c28fc_row10_col8, #T_c28fc_row28_col5 {
#   background-color: #e2f397;
#   color: black;
# }
# #T_c28fc_row0_col2, #T_c28fc_row30_col3 {
#   background-color: #b9e176;
#   color: black;
# }
# #T_c28fc_row0_col3, #T_c28fc_row6_col1, #T_c28fc_row19_col6, #T_c28fc_row25_col7 {
#   background-color: #e5f49b;
#   color: black;
# }
# #T_c28fc_row0_col4, #T_c28fc_row20_col4 {
#   background-color: #c3e67d;
#   color: black;
# }
# #T_c28fc_row0_col5 {
#   background-color: #78c565;
#   color: black;
# }
# #T_c28fc_row0_col6, #T_c28fc_row3_col1, #T_c28fc_row7_col7 {
#   background-color: #fff6b0;
#   color: black;
# }
# #T_c28fc_row0_col7, #T_c28fc_row29_col7 {
#   background-color: #fafdb8;
#   color: black;
# }
# #T_c28fc_row0_col8 {
#   background-color: #42ac5a;
#   color: black;
# }
# #T_c28fc_row1_col1 {
#   background-color: #fdc171;
#   color: black;
# }
# #T_c28fc_row1_col2 {
#   background-color: #148e4b;
#   color: white;
# }
# #T_c28fc_row1_col3, #T_c28fc_row25_col5 {
#   background-color: #c9e881;
#   color: black;
# }
# #T_c28fc_row1_col4, #T_c28fc_row2_col6 {
#   background-color: #63bc62;
#   color: black;
# }
# #T_c28fc_row1_col5 {
#   background-color: #39a758;
#   color: black;
# }
# #T_c28fc_row1_col6 {
#   background-color: #fdb96a;
#   color: black;
# }
# #T_c28fc_row1_col7 {
#   background-color: #eff8aa;
#   color: black;
# }
# #T_c28fc_row1_col8 {
#   background-color: #2da155;
#   color: black;
# }
# #T_c28fc_row2_col1, #T_c28fc_row8_col8 {
#   background-color: #fca55d;
#   color: black;
# }
# #T_c28fc_row2_col2, #T_c28fc_row14_col4 {
#   background-color: #fec877;
#   color: black;
# }
# #T_c28fc_row2_col3 {
#   background-color: #36a657;
#   color: black;
# }
# #T_c28fc_row2_col4 {
#   background-color: #6bbf64;
#   color: black;
# }
# #T_c28fc_row2_col5 {
#   background-color: #e0422f;
#   color: white;
# }
# #T_c28fc_row2_col7 {
#   background-color: #036e3a;
#   color: white;
# }
# #T_c28fc_row2_col8 {
#   background-color: #b1de71;
#   color: black;
# }
# #T_c28fc_row3_col2, #T_c28fc_row19_col3 {
#   background-color: #f5fbb2;
#   color: black;
# }
# #T_c28fc_row3_col3 {
#   background-color: #fee491;
#   color: black;
# }
# #T_c28fc_row3_col4 {
#   background-color: #d7ee8a;
#   color: black;
# }
# #T_c28fc_row3_col5, #T_c28fc_row15_col3, #T_c28fc_row16_col1 {
#   background-color: #ddf191;
#   color: black;
# }
# #T_c28fc_row3_col6 {
#   background-color: #219c52;
#   color: white;
# }
# #T_c28fc_row3_col7, #T_c28fc_row10_col7, #T_c28fc_row14_col7 {
#   background-color: #fee593;
#   color: black;
# }
# #T_c28fc_row3_col8 {
#   background-color: #fee797;
#   color: black;
# }
# #T_c28fc_row4_col1 {
#   background-color: #7ac665;
#   color: black;
# }
# #T_c28fc_row4_col2, #T_c28fc_row6_col3, #T_c28fc_row9_col1, #T_c28fc_row10_col1, #T_c28fc_row22_col3 {
#   background-color: #fff3ac;
#   color: black;
# }
# #T_c28fc_row4_col3 {
#   background-color: #d9ef8b;
#   color: black;
# }
# #T_c28fc_row4_col4 {
#   background-color: #98d368;
#   color: black;
# }
# #T_c28fc_row4_col5, #T_c28fc_row16_col5 {
#   background-color: #ebf7a3;
#   color: black;
# }
# #T_c28fc_row4_col6 {
#   background-color: #dcf08f;
#   color: black;
# }
# #T_c28fc_row4_col7, #T_c28fc_row18_col8 {
#   background-color: #c62027;
#   color: white;
# }
# #T_c28fc_row4_col8, #T_c28fc_row6_col6 {
#   background-color: #fee28f;
#   color: black;
# }
# #T_c28fc_row5_col1 {
#   background-color: #cdea83;
#   color: black;
# }
# #T_c28fc_row5_col2, #T_c28fc_row6_col5, #T_c28fc_row7_col8, #T_c28fc_row8_col1, #T_c28fc_row8_col3, #T_c28fc_row13_col7, #T_c28fc_row15_col4, #T_c28fc_row23_col6 {
#   background-color: #006837;
#   color: white;
# }
# #T_c28fc_row5_col3, #T_c28fc_row8_col4, #T_c28fc_row17_col8, #T_c28fc_row22_col7, #T_c28fc_row23_col2, #T_c28fc_row27_col6, #T_c28fc_row29_col5, #T_c28fc_row30_col1 {
#   background-color: #a50026;
#   color: white;
# }
# #T_c28fc_row5_col4, #T_c28fc_row9_col7, #T_c28fc_row24_col1 {
#   background-color: #afdd70;
#   color: black;
# }
# #T_c28fc_row5_col5 {
#   background-color: #199750;
#   color: white;
# }
# #T_c28fc_row5_col6, #T_c28fc_row15_col8, #T_c28fc_row25_col4 {
#   background-color: #fede89;
#   color: black;
# }
# #T_c28fc_row5_col7, #T_c28fc_row8_col7, #T_c28fc_row16_col7, #T_c28fc_row17_col7 {
#   background-color: #fa9656;
#   color: black;
# }
# #T_c28fc_row5_col8, #T_c28fc_row20_col3 {
#   background-color: #fdb567;
#   color: black;
# }
# #T_c28fc_row6_col2, #T_c28fc_row20_col8 {
#   background-color: #fed683;
#   color: black;
# }
# #T_c28fc_row6_col4, #T_c28fc_row15_col6, #T_c28fc_row17_col4, #T_c28fc_row25_col6, #T_c28fc_row27_col3 {
#   background-color: #fffdbc;
#   color: black;
# }
# #T_c28fc_row6_col7 {
#   background-color: #f26841;
#   color: black;
# }
# #T_c28fc_row6_col8 {
#   background-color: #60ba62;
#   color: black;
# }
# #T_c28fc_row7_col1, #T_c28fc_row22_col6 {
#   background-color: #51b35e;
#   color: black;
# }
# #T_c28fc_row7_col2, #T_c28fc_row14_col1, #T_c28fc_row15_col2, #T_c28fc_row24_col2, #T_c28fc_row26_col1 {
#   background-color: #fdb768;
#   color: black;
# }
# #T_c28fc_row7_col3, #T_c28fc_row12_col3 {
#   background-color: #e0f295;
#   color: black;
# }
# #T_c28fc_row7_col4, #T_c28fc_row21_col2, #T_c28fc_row22_col4 {
#   background-color: #feffbe;
#   color: black;
# }
# #T_c28fc_row7_col5 {
#   background-color: #d5ed88;
#   color: black;
# }
# #T_c28fc_row7_col6, #T_c28fc_row14_col3, #T_c28fc_row17_col3, #T_c28fc_row28_col6 {
#   background-color: #e9f6a1;
#   color: black;
# }
# #T_c28fc_row8_col2, #T_c28fc_row14_col5 {
#   background-color: #fee08b;
#   color: black;
# }
# #T_c28fc_row8_col5 {
#   background-color: #bfe47a;
#   color: black;
# }
# #T_c28fc_row8_col6, #T_c28fc_row18_col5, #T_c28fc_row30_col6 {
#   background-color: #fcaa5f;
#   color: black;
# }
# #T_c28fc_row9_col2, #T_c28fc_row15_col5 {
#   background-color: #b3df72;
#   color: black;
# }
# #T_c28fc_row9_col3, #T_c28fc_row18_col6, #T_c28fc_row27_col2 {
#   background-color: #fba35c;
#   color: black;
# }
# #T_c28fc_row9_col4 {
#   background-color: #f67a49;
#   color: black;
# }
# #T_c28fc_row9_col5, #T_c28fc_row10_col6, #T_c28fc_row23_col5 {
#   background-color: #8ccd67;
#   color: black;
# }
# #T_c28fc_row9_col6 {
#   background-color: #bde379;
#   color: black;
# }
# #T_c28fc_row9_col8 {
#   background-color: #f7844e;
#   color: black;
# }
# #T_c28fc_row10_col2 {
#   background-color: #be1827;
#   color: white;
# }
# #T_c28fc_row10_col3 {
#   background-color: #66bd63;
#   color: black;
# }
# #T_c28fc_row10_col4, #T_c28fc_row15_col1 {
#   background-color: #f8fcb6;
#   color: black;
# }
# #T_c28fc_row10_col5 {
#   background-color: #ca2427;
#   color: white;
# }
# #T_c28fc_row11_col1, #T_c28fc_row19_col4 {
#   background-color: #9dd569;
#   color: black;
# }
# #T_c28fc_row11_col2 {
#   background-color: #f16640;
#   color: black;
# }
# #T_c28fc_row11_col3, #T_c28fc_row16_col3 {
#   background-color: #8ecf67;
#   color: black;
# }
# #T_c28fc_row11_col4 {
#   background-color: #fdc372;
#   color: black;
# }
# #T_c28fc_row11_col5, #T_c28fc_row27_col5 {
#   background-color: #e95538;
#   color: white;
# }
# #T_c28fc_row11_col6, #T_c28fc_row20_col6 {
#   background-color: #fdfebc;
#   color: black;
# }
# #T_c28fc_row11_col7, #T_c28fc_row19_col2, #T_c28fc_row29_col4 {
#   background-color: #fca85e;
#   color: black;
# }
# #T_c28fc_row11_col8 {
#   background-color: #f2faae;
#   color: black;
# }
# #T_c28fc_row12_col1, #T_c28fc_row16_col8, #T_c28fc_row23_col1, #T_c28fc_row25_col1 {
#   background-color: #fffcba;
#   color: black;
# }
# #T_c28fc_row12_col2 {
#   background-color: #fee695;
#   color: black;
# }
# #T_c28fc_row12_col4, #T_c28fc_row12_col5 {
#   background-color: #eef8a8;
#   color: black;
# }
# #T_c28fc_row12_col6 {
#   background-color: #9bd469;
#   color: black;
# }
# #T_c28fc_row12_col7 {
#   background-color: #2aa054;
#   color: black;
# }
# #T_c28fc_row12_col8, #T_c28fc_row17_col5, #T_c28fc_row27_col4 {
#   background-color: #fff5ae;
#   color: black;
# }
# #T_c28fc_row13_col1 {
#   background-color: #feeda1;
#   color: black;
# }
# #T_c28fc_row13_col2 {
#   background-color: #0b7d42;
#   color: white;
# }
# #T_c28fc_row13_col3 {
#   background-color: #0d8044;
#   color: white;
# }
# #T_c28fc_row13_col4 {
#   background-color: #fdbd6d;
#   color: black;
# }
# #T_c28fc_row13_col5 {
#   background-color: #bb1526;
#   color: white;
# }
# #T_c28fc_row13_col6, #T_c28fc_row27_col1 {
#   background-color: #f4fab0;
#   color: black;
# }
# #T_c28fc_row13_col8, #T_c28fc_row22_col8, #T_c28fc_row26_col3 {
#   background-color: #a9da6c;
#   color: black;

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import time

# Set up Selenium WebDriver
service = Service("/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver")  # Update with your path to chromedriver

#Mac file path
#"/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver"

#PC file path
#r"C:\Users\PC\OneDrive\Documents\GitHub\chromedriver-win64\chromedriver.exe"

options = Options()
options.add_argument('--headless')  # Run in headless mode
options.add_argument('--disable-gpu')
options.add_argument('--start-maximized')

driver = webdriver.Chrome(service=service, options=options)

# URL of the webpage to scrape
url = "https://stats.gleague.nba.com/teams/four-factors/?sort=W_PCT&dir=-1"

# Load the webpage
driver.get(url)

# Allow time for JavaScript to load
time.sleep(10)  # Adjust the time as per your internet speed and website response time

# Locate the table
table_xpath = '//div[contains(@class, "nba-stat-table__overflow")]/table'
table_element = driver.find_element(By.XPATH, table_xpath)

# Extract the table data
table_html = table_element.get_attribute('outerHTML')

# Convert the table HTML into a pandas DataFrame
team_stats = pd.read_html(table_html)[0]

# Quit the driver
driver.quit()

# Standardize column names
team_stats.columns = team_stats.columns.str.replace('\xa0', ' ', regex=False).str.strip()

# Drop the specified columns
columns_to_drop = [
    'Unnamed: 0', 'GP', 'W', 'L', 'WIN%', 'MIN', 'GP RANK', 'W RANK', 'L RANK', 'MIN RANK', 'eFG% RANK', 'TO Ratio RANK',
    'OREB% RANK', 'Opp FTA Rate RANK', 'Opp To Ratio RANK', 'WIN% RANK', 'FTA Rate RANK', 'Opp eFG% RANK', 'Opp OREB% RANK'
]

team_stats = team_stats.drop(columns=[col for col in columns_to_drop if col in team_stats.columns])

# Ensure numeric columns are correctly identified
numeric_cols = team_stats.select_dtypes(include=['number']).columns

# Check for NaN or inf values
#print("Checking for NaN and inf values...")
#print(team_stats[numeric_cols].isna().sum())
#print((team_stats[numeric_cols] == np.inf).sum())
#print((team_stats[numeric_cols] == -np.inf).sum())

# Calculate ranks and append ranks to numeric columns for display
invert_cols = ['TOV%', 'Opp eFG%', 'Opp FTA Rate', 'Opp OREB%']  # PF will be descending, all others ascending
df_with_ranks = team_stats.copy()

for col in numeric_cols:
    # Calculate ranks (invert order for specified columns)
    if col in invert_cols:
        ranks = team_stats[col].rank(ascending=True, method='min').astype(int)
    else:
        ranks = team_stats[col].rank(ascending=False, method='min').astype(int)
    
    # Append ranks to column values for display
    df_with_ranks[col] = team_stats[col].astype(str) + ' (' + ranks.astype(str) + ')'

# Filter for Raptors 905 only
raptors_row = df_with_ranks[df_with_ranks['TEAM'] == 'Raptors 905']

# Color coding logic
col_min = team_stats[numeric_cols].min()
col_max = team_stats[numeric_cols].max()

def luminance(color):
    rgb = mcolors.hex2color(color)
    return 0.2126 * rgb[0] + 0.7152 * rgb[1] + 0.0722 * rgb[2]

def color_cells(row):
    colors = []
    for col in numeric_cols:
        value = team_stats.loc[row.name, col]  # Use original numeric value for coloring
        if col in invert_cols:
            # Invert normalization for PF (descending order)
            norm = (col_max[col] - value) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5            
        else:
            # Normal normalization for ascending order
            norm = (value - col_min[col]) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5
        color = mcolors.to_hex(plt.cm.RdYlGn(norm))
        text_color = 'white' if luminance(color) < 0.5 else 'black'
        colors.append(f"background-color: {color}; color: {text_color};")
    return colors

# Style the Raptors 905 row
styled_df = raptors_row.style.apply(color_cells, subset=numeric_cols, axis=1).format(precision=3)

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_10faa_row0_col1 {
#   background-color: #f4fab0;
#   color: black;
# }
# #T_10faa_row0_col2 {
#   background-color: #fba35c;
#   color: black;
# }
# #T_10faa_row0_col3 {
#   background-color: #fffdbc;
#   color: black;
# }
# #T_10faa_row0_col4 {
#   background-color: #fff5ae;
#   color: black;
# }
# #T_10faa_row0_col5 {
#   background-color: #e95538;
#   color: white;
# }
# #T_10faa_row0_col6 {
#   background-color: #a50026;
#   color: white;
# }
# #T_10faa_row0_col7 {
#   background-color: #7dc765;
#   color: black;
# }
# #T_10faa_row0_col8 {
#   background-color: #f47044;
#   color: black;
# }
# </style>
# <table id="T_10faa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_10faa_level0_col0" class="col_heading level0 col0" >TEAM</th>
#       <th id="T_10faa_level0_col1" class="col_heading level0 col1" >eFG%</th>
#       <th id="T_10faa_level0_col2" class="col_heading level0 col2" >FTA Rate</th>
#       <th id="T_10faa_level0_col3" class="col_heading level0 col3" >TOV%</th>
#       <th id="T_10faa_level0_col4" class="col_heading level0 col4" >OREB%</th>
#       <th id="T_10faa_level0_col5" class="col_heading level0 col5" >Opp eFG%</th>
#       <th id="T_10faa_level0_col6" class="col_heading level0 col6" >Opp FTA Rate</th>
#       <th id="T_10faa_level0_col7" class="col_heading level0 col7" >Opp TOV%</th>
#       <th id="T_10faa_level0_col8" class="col_heading level0 col8" >Opp OREB%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10faa_level0_row0" class="row_heading level0 row0" >27</th>
#       <td id="T_10faa_row0_col0" class="data row0 col0" >Raptors 905</td>
#       <td id="T_10faa_row0_col1" class="data row0 col1" >52.8 (11)</td>
#       <td id="T_10faa_row0_col2" class="data row0 col2" >0.142 (25)</td>
#       <td id="T_10faa_row0_col3" class="data row0 col3" >17.5 (20)</td>
#       <td id="T_10faa_row0_col4" class="data row0 col4" >30.7 (20)</td>
#       <td id="T_10faa_row0_col5" class="data row0 col5" >55.4 (25)</td>
#       <td id="T_10faa_row0_col6" class="data row0 col6" >0.205 (31)</td>
#       <td id="T_10faa_row0_col7" class="data row0 col7" >19.0 (6)</td>
#       <td id="T_10faa_row0_col8" class="data row0 col8" >35.3 (26)</td>
#     </tr>
#   </tbody>
# </table>

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import time

# Set up Selenium WebDriver
service = Service("/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver")  # Update with your path to chromedriver

#Mac file path
#"/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver"

#PC file path
#r"C:\Users\PC\OneDrive\Documents\GitHub\chromedriver-win64\chromedriver.exe"

options = Options()
options.add_argument('--headless')  # Run in headless mode
options.add_argument('--disable-gpu')
options.add_argument('--start-maximized')

driver = webdriver.Chrome(service=service, options=options)

# URL of the webpage to scrape
url = "https://stats.gleague.nba.com/teams/four-factors/?sort=W_PCT&dir=-1"

# Load the webpage
driver.get(url)

# Allow time for JavaScript to load
time.sleep(10)  # Adjust the time as per your internet speed and website response time

# Locate the table
table_xpath = '//div[contains(@class, "nba-stat-table__overflow")]/table'
table_element = driver.find_element(By.XPATH, table_xpath)

# Extract the table data
table_html = table_element.get_attribute('outerHTML')

# Convert the table HTML into a pandas DataFrame
team_stats = pd.read_html(table_html)[0]

# Quit the driver
driver.quit()

# Standardize column names
team_stats.columns = team_stats.columns.str.replace('\xa0', ' ', regex=False).str.strip()

# Drop the specified columns
columns_to_drop = [
    'Unnamed: 0', 'GP', 'W', 'L', 'WIN%', 'MIN', 'GP RANK', 'W RANK', 'L RANK', 'MIN RANK', 'eFG% RANK', 'TO Ratio RANK',
    'OREB% RANK', 'Opp FTA Rate RANK', 'Opp To Ratio RANK', 'WIN% RANK', 'FTA Rate RANK', 'Opp eFG% RANK', 'Opp OREB% RANK'
]

team_stats = team_stats.drop(columns=[col for col in columns_to_drop if col in team_stats.columns])

# Ensure numeric columns are correctly identified
numeric_cols = team_stats.select_dtypes(include=['number']).columns

# Check for NaN or inf values
#print("Checking for NaN and inf values...")
#print(team_stats[numeric_cols].isna().sum())
#print((team_stats[numeric_cols] == np.inf).sum())
#print((team_stats[numeric_cols] == -np.inf).sum())

# Calculate ranks and append ranks to numeric columns for display
invert_cols = ['TOV%', 'Opp eFG%', 'Opp FTA Rate', 'Opp OREB%']  # PF will be descending, all others ascending
df_with_ranks = team_stats.copy()

for col in numeric_cols:
    # Calculate ranks (invert order for specified columns)
    if col in invert_cols:
        ranks = team_stats[col].rank(ascending=True, method='min').astype(int)
    else:
        ranks = team_stats[col].rank(ascending=False, method='min').astype(int)
    
    # Append ranks to column values for display
    df_with_ranks[col] = team_stats[col].astype(str) + ' (' + ranks.astype(str) + ')'

# Filter for Raptors 905 only
opponents_row = df_with_ranks[df_with_ranks['TEAM'] == 'Westchester Knicks']

# Color coding logic
col_min = team_stats[numeric_cols].min()
col_max = team_stats[numeric_cols].max()

def luminance(color):
    rgb = mcolors.hex2color(color)
    return 0.2126 * rgb[0] + 0.7152 * rgb[1] + 0.0722 * rgb[2]

def color_cells(row):
    colors = []
    for col in numeric_cols:
        value = team_stats.loc[row.name, col]  # Use original numeric value for coloring
        if col in invert_cols:
            # Invert normalization for PF (descending order)
            norm = (col_max[col] - value) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5            
        else:
            # Normal normalization for ascending order
            norm = (value - col_min[col]) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5
        color = mcolors.to_hex(plt.cm.RdYlGn(norm))
        text_color = 'white' if luminance(color) < 0.5 else 'black'
        colors.append(f"background-color: {color}; color: {text_color};")
    return colors

# Style the Raptors 905 row
styled_df = opponents_row.style.apply(color_cells, subset=numeric_cols, axis=1).format(precision=3)

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_0be07_row0_col1 {
#   background-color: #f8fcb6;
#   color: black;
# }
# #T_0be07_row0_col2 {
#   background-color: #fdb768;
#   color: black;
# }
# #T_0be07_row0_col3 {
#   background-color: #ddf191;
#   color: black;
# }
# #T_0be07_row0_col4 {
#   background-color: #006837;
#   color: white;
# }
# #T_0be07_row0_col5 {
#   background-color: #b3df72;
#   color: black;
# }
# #T_0be07_row0_col6 {
#   background-color: #fffdbc;
#   color: black;
# }
# #T_0be07_row0_col7 {
#   background-color: #fee18d;
#   color: black;
# }
# #T_0be07_row0_col8 {
#   background-color: #fede89;
#   color: black;
# }
# </style>
# <table id="T_0be07">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0be07_level0_col0" class="col_heading level0 col0" >TEAM</th>
#       <th id="T_0be07_level0_col1" class="col_heading level0 col1" >eFG%</th>
#       <th id="T_0be07_level0_col2" class="col_heading level0 col2" >FTA Rate</th>
#       <th id="T_0be07_level0_col3" class="col_heading level0 col3" >TOV%</th>
#       <th id="T_0be07_level0_col4" class="col_heading level0 col4" >OREB%</th>
#       <th id="T_0be07_level0_col5" class="col_heading level0 col5" >Opp eFG%</th>
#       <th id="T_0be07_level0_col6" class="col_heading level0 col6" >Opp FTA Rate</th>
#       <th id="T_0be07_level0_col7" class="col_heading level0 col7" >Opp TOV%</th>
#       <th id="T_0be07_level0_col8" class="col_heading level0 col8" >Opp OREB%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0be07_level0_row0" class="row_heading level0 row0" >15</th>
#       <td id="T_0be07_row0_col0" class="data row0 col0" >Westchester Knicks</td>
#       <td id="T_0be07_row0_col1" class="data row0 col1" >52.7 (12)</td>
#       <td id="T_0be07_row0_col2" class="data row0 col2" >0.146 (21)</td>
#       <td id="T_0be07_row0_col3" class="data row0 col3" >16.6 (13)</td>
#       <td id="T_0be07_row0_col4" class="data row0 col4" >40.4 (1)</td>
#       <td id="T_0be07_row0_col5" class="data row0 col5" >50.7 (9)</td>
#       <td id="T_0be07_row0_col6" class="data row0 col6" >0.165 (20)</td>
#       <td id="T_0be07_row0_col7" class="data row0 col7" >16.4 (19)</td>
#       <td id="T_0be07_row0_col8" class="data row0 col8" >33.0 (21)</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(team_stats.columns.tolist())
# Out:
# ['TEAM', 'eFG%', 'FTA Rate', 'TOV%', 'OREB%', 'Opp eFG%', 'Opp FTA\xa0Rate', 'Opp TOV%', 'Opp OREB%', 'Opp FTA\xa0Rate RANK', 'Opp To\xa0Ratio RANK']

# %%
team_stats.columns
# Out:
# Index(['TEAM', 'eFG%', 'FTA Rate', 'TOV%', 'OREB%', 'Opp eFG%', 'Opp FTA Rate',
#        'Opp TOV%', 'Opp OREB%', 'Opp FTA Rate RANK', 'Opp To Ratio RANK'],
#       dtype='object')

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import time

# Set up Selenium WebDriver
service = Service("/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver")  # Update with your path to chromedriver

# Mac file path
# "/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver"

# PC file path
# r"C:\Users\PC\OneDrive\Documents\GitHub\chromedriver-win64\chromedriver.exe"

options = Options()
options.add_argument('--headless')  # Run in headless mode
options.add_argument('--disable-gpu')
options.add_argument('--start-maximized')

driver = webdriver.Chrome(service=service, options=options)

# URL of the webpage to scrape
url = "https://stats.gleague.nba.com/teams/misc/?sort=W&dir=-1"

# Load the webpage
driver.get(url)

# Allow time for JavaScript to load
time.sleep(10)  # Adjust the time as per your internet speed and website response time

# Locate the table
table_xpath = '//div[contains(@class, "nba-stat-table__overflow")]/table'
table_element = driver.find_element(By.XPATH, table_xpath)

# Extract the table data
table_html = table_element.get_attribute('outerHTML')

# Convert the table HTML into a pandas DataFrame
team_stats = pd.read_html(table_html)[0]

# Quit the driver
driver.quit()

# Standardize column names
team_stats.columns = team_stats.columns.str.replace('\xa0', ' ', regex=False).str.strip()

# Drop the specified columns
columns_to_drop = [
    'Unnamed: 0', 'GP', 'W', 'L', 'MIN', 'GP RANK', 'W RANK', 'L RANK', 'MIN RANK', 'PTS OFF TO RANK',
       '2nd PTS RANK', 'FBPs RANK', 'PITP RANK', 'Opp PTS OFF TO RANK',
       'Opp 2nd PTS RANK', 'Opp FBPs RANK', 'Opp PITP RANK'
]
team_stats = team_stats.drop(columns=[col for col in columns_to_drop if col in team_stats.columns])

# Ensure numeric columns are correctly identified
numeric_cols = team_stats.select_dtypes(include=['number']).columns

# Calculate ranks and append ranks to numeric columns for display
invert_cols = ['Opp PTS OFF TO', 'Opp 2nd PTS', 'Opp FBPs', 'Opp PITP']  # Columns with descending rank
df_with_ranks = team_stats.copy()

for col in numeric_cols:
    # Calculate ranks (invert order for specified columns)
    if col in invert_cols:
        ranks = team_stats[col].rank(ascending=True, method='min').astype(int)
    else:
        ranks = team_stats[col].rank(ascending=False, method='min').astype(int)
    
    # Append ranks to column values for display
    df_with_ranks[col] = team_stats[col].astype(str) + ' (' + ranks.astype(str) + ')'

# Color coding logic
col_min = team_stats[numeric_cols].min()
col_max = team_stats[numeric_cols].max()

def luminance(color):
    rgb = mcolors.hex2color(color)
    return 0.2126 * rgb[0] + 0.7152 * rgb[1] + 0.0722 * rgb[2]

def color_cells(row):
    colors = []
    for col in numeric_cols:
        value = team_stats.loc[row.name, col]  # Use original numeric value for coloring
        if col in invert_cols:
            # Invert normalization for specified columns
            norm = (col_max[col] - value) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5
        else:
            # Normal normalization
            norm = (value - col_min[col]) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5
        color = mcolors.to_hex(plt.cm.RdYlGn(norm))
        text_color = 'white' if luminance(color) < 0.5 else 'black'
        colors.append(f"background-color: {color}; color: {text_color};")
    return colors

# Apply the coloring logic to the DataFrame with ranks
styled_df = df_with_ranks.style.apply(color_cells, subset=numeric_cols, axis=1).format(precision=3)

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_8f2eb_row0_col1, #T_8f2eb_row1_col4, #T_8f2eb_row17_col1, #T_8f2eb_row23_col7, #T_8f2eb_row29_col1 {
#   background-color: #d5ed88;
#   color: black;
# }
# #T_8f2eb_row0_col2 {
#   background-color: #097940;
#   color: white;
# }
# #T_8f2eb_row0_col3, #T_8f2eb_row12_col6 {
#   background-color: #93d168;
#   color: black;
# }
# #T_8f2eb_row0_col4 {
#   background-color: #6bbf64;
#   color: black;
# }
# #T_8f2eb_row0_col5, #T_8f2eb_row5_col8 {
#   background-color: #c3e67d;
#   color: black;
# }
# #T_8f2eb_row0_col6 {
#   background-color: #0d8044;
#   color: white;
# }
# #T_8f2eb_row0_col7 {
#   background-color: #fed884;
#   color: black;
# }
# #T_8f2eb_row0_col8, #T_8f2eb_row4_col5, #T_8f2eb_row5_col5 {
#   background-color: #e9f6a1;
#   color: black;
# }
# #T_8f2eb_row1_col1, #T_8f2eb_row28_col3 {
#   background-color: #fdc776;
#   color: black;
# }
# #T_8f2eb_row1_col2, #T_8f2eb_row14_col6, #T_8f2eb_row19_col6 {
#   background-color: #c5e67e;
#   color: black;
# }
# #T_8f2eb_row1_col3, #T_8f2eb_row16_col1 {
#   background-color: #c82227;
#   color: white;
# }
# #T_8f2eb_row1_col5 {
#   background-color: #1b9950;
#   color: white;
# }
# #T_8f2eb_row1_col6, #T_8f2eb_row1_col7 {
#   background-color: #1e9a51;
#   color: white;
# }
# #T_8f2eb_row1_col8 {
#   background-color: #6ec064;
#   color: black;
# }
# #T_8f2eb_row2_col1, #T_8f2eb_row2_col5 {
#   background-color: #87cb67;
#   color: black;
# }
# #T_8f2eb_row2_col2 {
#   background-color: #b7e075;
#   color: black;
# }
# #T_8f2eb_row2_col3, #T_8f2eb_row9_col3, #T_8f2eb_row24_col4 {
#   background-color: #ebf7a3;
#   color: black;
# }
# #T_8f2eb_row2_col4, #T_8f2eb_row6_col8, #T_8f2eb_row20_col1, #T_8f2eb_row28_col2 {
#   background-color: #fee999;
#   color: black;
# }
# #T_8f2eb_row2_col6, #T_8f2eb_row23_col8 {
#   background-color: #199750;
#   color: white;
# }
# #T_8f2eb_row2_col7, #T_8f2eb_row21_col8 {
#   background-color: #7ac665;
#   color: black;
# }
# #T_8f2eb_row2_col8 {
#   background-color: #b9e176;
#   color: black;
# }
# #T_8f2eb_row3_col1, #T_8f2eb_row4_col2, #T_8f2eb_row24_col2 {
#   background-color: #fee695;
#   color: black;
# }
# #T_8f2eb_row3_col2, #T_8f2eb_row10_col8, #T_8f2eb_row13_col2 {
#   background-color: #addc6f;
#   color: black;
# }
# #T_8f2eb_row3_col3 {
#   background-color: #f67c4a;
#   color: black;
# }
# #T_8f2eb_row3_col4, #T_8f2eb_row20_col4 {
#   background-color: #fff8b4;
#   color: black;
# }
# #T_8f2eb_row3_col5, #T_8f2eb_row19_col5, #T_8f2eb_row21_col3 {
#   background-color: #e44c34;
#   color: white;
# }
# #T_8f2eb_row3_col6, #T_8f2eb_row11_col7 {
#   background-color: #fff0a6;
#   color: black;
# }
# #T_8f2eb_row3_col7, #T_8f2eb_row8_col7, #T_8f2eb_row21_col7, #T_8f2eb_row25_col7 {
#   background-color: #e5f49b;
#   color: black;
# }
# #T_8f2eb_row3_col8, #T_8f2eb_row16_col4 {
#   background-color: #fed27f;
#   color: black;
# }
# #T_8f2eb_row4_col1 {
#   background-color: #f36b42;
#   color: black;
# }
# #T_8f2eb_row4_col3, #T_8f2eb_row19_col7, #T_8f2eb_row26_col8 {
#   background-color: #fff7b2;
#   color: black;
# }
# #T_8f2eb_row4_col4, #T_8f2eb_row25_col4 {
#   background-color: #fdb567;
#   color: black;
# }
# #T_8f2eb_row4_col6, #T_8f2eb_row10_col7, #T_8f2eb_row13_col1, #T_8f2eb_row13_col3, #T_8f2eb_row13_col5, #T_8f2eb_row18_col8, #T_8f2eb_row22_col2, #T_8f2eb_row22_col4 {
#   background-color: #006837;
#   color: white;
# }
# #T_8f2eb_row4_col7 {
#   background-color: #0c7f43;
#   color: white;
# }
# #T_8f2eb_row4_col8, #T_8f2eb_row22_col1, #T_8f2eb_row25_col3 {
#   background-color: #e3f399;
#   color: black;
# }
# #T_8f2eb_row5_col1, #T_8f2eb_row16_col5, #T_8f2eb_row17_col8 {
#   background-color: #feeda1;
#   color: black;
# }
# #T_8f2eb_row5_col2, #T_8f2eb_row7_col8 {
#   background-color: #fff2aa;
#   color: black;
# }
# #T_8f2eb_row5_col3 {
#   background-color: #c41e27;
#   color: white;
# }
# #T_8f2eb_row5_col4, #T_8f2eb_row8_col6, #T_8f2eb_row9_col2, #T_8f2eb_row10_col3, #T_8f2eb_row11_col8, #T_8f2eb_row23_col1, #T_8f2eb_row24_col7, #T_8f2eb_row25_col5 {
#   background-color: #a50026;
#   color: white;
# }
# #T_8f2eb_row5_col6, #T_8f2eb_row30_col4 {
#   background-color: #fecc7b;
#   color: black;
# }
# #T_8f2eb_row5_col7 {
#   background-color: #60ba62;
#   color: black;
# }
# #T_8f2eb_row6_col1, #T_8f2eb_row25_col1 {
#   background-color: #fff6b0;
#   color: black;
# }
# #T_8f2eb_row6_col2 {
#   background-color: #fec877;
#   color: black;
# }
# #T_8f2eb_row6_col3, #T_8f2eb_row10_col5 {
#   background-color: #54b45f;
#   color: black;
# }
# #T_8f2eb_row6_col4, #T_8f2eb_row26_col5 {
#   background-color: #8ecf67;
#   color: black;
# }
# #T_8f2eb_row6_col5, #T_8f2eb_row20_col6 {
#   background-color: #108647;
#   color: white;
# }
# #T_8f2eb_row6_col6, #T_8f2eb_row13_col6 {
#   background-color: #8ccd67;
#   color: black;
# }
# #T_8f2eb_row6_col7, #T_8f2eb_row7_col5, #T_8f2eb_row27_col5 {
#   background-color: #d9ef8b;
#   color: black;
# }
# #T_8f2eb_row7_col1, #T_8f2eb_row9_col5 {
#   background-color: #f7814c;
#   color: black;
# }
# #T_8f2eb_row7_col2 {
#   background-color: #57b65f;
#   color: black;
# }
# #T_8f2eb_row7_col3, #T_8f2eb_row15_col3, #T_8f2eb_row15_col4 {
#   background-color: #fdbf6f;
#   color: black;
# }
# #T_8f2eb_row7_col4 {
#   background-color: #f57547;
#   color: black;
# }
# #T_8f2eb_row7_col6, #T_8f2eb_row8_col1, #T_8f2eb_row27_col1, #T_8f2eb_row27_col4, #T_8f2eb_row28_col1 {
#   background-color: #fafdb8;
#   color: black;
# }
# #T_8f2eb_row7_col7, #T_8f2eb_row25_col6 {
#   background-color: #fdbb6c;
#   color: black;
# }
# #T_8f2eb_row8_col2, #T_8f2eb_row16_col3, #T_8f2eb_row30_col2 {
#   background-color: #ce2827;
#   color: white;
# }
# #T_8f2eb_row8_col3, #T_8f2eb_row14_col7, #T_8f2eb_row16_col7, #T_8f2eb_row22_col8 {
#   background-color: #fed481;
#   color: black;
# }
# #T_8f2eb_row8_col4 {
#   background-color: #f8864f;
#   color: black;
# }
# #T_8f2eb_row8_col5 {
#   background-color: #96d268;
#   color: black;
# }
# #T_8f2eb_row8_col8, #T_8f2eb_row21_col5 {
#   background-color: #fffab6;
#   color: black;
# }
# #T_8f2eb_row9_col1, #T_8f2eb_row11_col2, #T_8f2eb_row28_col4 {
#   background-color: #c1e57b;
#   color: black;
# }
# #T_8f2eb_row9_col4 {
#   background-color: #d93429;
#   color: white;
# }
# #T_8f2eb_row9_col6 {
#   background-color: #f7fcb4;
#   color: black;
# }
# #T_8f2eb_row9_col7, #T_8f2eb_row23_col5 {
#   background-color: #fba35c;
#   color: black;
# }
# #T_8f2eb_row9_col8, #T_8f2eb_row24_col8 {
#   background-color: #f5fbb2;
#   color: black;
# }
# #T_8f2eb_row10_col1, #T_8f2eb_row25_col2 {
#   background-color: #f57245;
#   color: black;
# }
# #T_8f2eb_row10_col2, #T_8f2eb_row12_col4, #T_8f2eb_row26_col4 {
#   background-color: #feda86;
#   color: black;
# }
# #T_8f2eb_row10_col4, #T_8f2eb_row27_col6 {
#   background-color: #fba05b;
#   color: black;
# }
# #T_8f2eb_row10_col6, #T_8f2eb_row11_col4 {
#   background-color: #eff8aa;
#   color: black;
# }
# #T_8f2eb_row11_col1, #T_8f2eb_row29_col4 {
#   background-color: #fdaf62;
#   color: black;
# }
# #T_8f2eb_row11_col3, #T_8f2eb_row12_col3, #T_8f2eb_row19_col2, #T_8f2eb_row24_col3 {
#   background-color: #feec9f;
#   color: black;
# }
# #T_8f2eb_row11_col5 {
#   background-color: #cfeb85;
#   color: black;
# }
# #T_8f2eb_row11_col6, #T_8f2eb_row14_col4, #T_8f2eb_row17_col6 {
#   background-color: #dff293;
#   color: black;
# }
# #T_8f2eb_row12_col1, #T_8f2eb_row13_col7, #T_8f2eb_row19_col8, #T_8f2eb_row29_col7 {
#   background-color: #9bd469;
#   color: black;
# }
# #T_8f2eb_row12_col2 {
#   background-color: #7dc765;
#   color: black;
# }
# #T_8f2eb_row12_col5, #T_8f2eb_row12_col7, #T_8f2eb_row28_col7 {
#   background-color: #a9da6c;
#   color: black;
# }
# #T_8f2eb_row12_col8 {
#   background-color: #69be63;
#   color: black;
# }
# #T_8f2eb_row13_col4 {
#   background-color: #fffdbc;
#   color: black;
# }
# #T_8f2eb_row13_col8 {
#   background-color: #c7e77f;
#   color: black;
# }
# #T_8f2eb_row14_col1 {
#   background-color: #fdb768;
#   color: black;
# }
# #T_8f2eb_row14_col2, #T_8f2eb_row22_col3, #T_8f2eb_row22_col6 {
#   background-color: #fdfebc;
#   color: black;
# }
# #T_8f2eb_row14_col3 {
#   background-color: #f7844e;
#   color: black;
# }
# #T_8f2eb_row14_col5 {
#   background-color: #36a657;
#   color: black;
# }
# #T_8f2eb_row14_col8 {
#   background-color: #e6f59d;
#   color: black;
# }
# #T_8f2eb_row15_col1, #T_8f2eb_row19_col1 {
#   background-color: #fdc372;
#   color: black;
# }
# #T_8f2eb_row15_col2, #T_8f2eb_row26_col3, #T_8f2eb_row27_col2 {
#   background-color: #feefa3;
#   color: black;
# }
# #T_8f2eb_row15_col5 {
#   background-color: #bde379

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import time

# Set up Selenium WebDriver
service = Service("/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver")  # Update with your path to chromedriver

#Mac file path
#"/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver"

#PC file path
#r"C:\Users\PC\OneDrive\Documents\GitHub\chromedriver-win64\chromedriver.exe"

options = Options()
options.add_argument('--headless')  # Run in headless mode
options.add_argument('--disable-gpu')
options.add_argument('--start-maximized')

driver = webdriver.Chrome(service=service, options=options)

# URL of the webpage to scrape
url = "https://stats.gleague.nba.com/teams/misc/?sort=W&dir=-1"

# Load the webpage
driver.get(url)

# Allow time for JavaScript to load
time.sleep(10)  # Adjust the time as per your internet speed and website response time

# Locate the table
table_xpath = '//div[contains(@class, "nba-stat-table__overflow")]/table'
table_element = driver.find_element(By.XPATH, table_xpath)

# Extract the table data
table_html = table_element.get_attribute('outerHTML')

# Convert the table HTML into a pandas DataFrame
team_stats = pd.read_html(table_html)[0]

# Quit the driver
driver.quit()

# Standardize column names
team_stats.columns = team_stats.columns.str.replace('\xa0', ' ', regex=False).str.strip()

# Drop the specified columns
columns_to_drop = [
    'Unnamed: 0', 'GP', 'W', 'L', 'MIN', 'GP RANK', 'W RANK', 'L RANK', 'MIN RANK', 'PTS OFF TO RANK',
       '2nd PTS RANK', 'FBPs RANK', 'PITP RANK', 'Opp PTS OFF TO RANK',
       'Opp 2nd PTS RANK', 'Opp FBPs RANK', 'Opp PITP RANK'
]

team_stats = team_stats.drop(columns=[col for col in columns_to_drop if col in team_stats.columns])

# Ensure numeric columns are correctly identified
numeric_cols = team_stats.select_dtypes(include=['number']).columns

# Check for NaN or inf values
#print("Checking for NaN and inf values...")
#print(team_stats[numeric_cols].isna().sum())
#print((team_stats[numeric_cols] == np.inf).sum())
#print((team_stats[numeric_cols] == -np.inf).sum())

# Calculate ranks and append ranks to numeric columns for display
invert_cols = ['Opp PTS OFF TO', 'Opp 2nd PTS', 'Opp FBPs', 'Opp PITP']  # PF will be descending, all others ascending
df_with_ranks = team_stats.copy()

for col in numeric_cols:
    # Calculate ranks (invert order for specified columns)
    if col in invert_cols:
        ranks = team_stats[col].rank(ascending=True, method='min').astype(int)
    else:
        ranks = team_stats[col].rank(ascending=False, method='min').astype(int)
    
    # Append ranks to column values for display
    df_with_ranks[col] = team_stats[col].astype(str) + ' (' + ranks.astype(str) + ')'

# Filter for Raptors 905 only
raptors_row = df_with_ranks[df_with_ranks['TEAM'] == 'Raptors 905']

# Color coding logic
col_min = team_stats[numeric_cols].min()
col_max = team_stats[numeric_cols].max()

def luminance(color):
    rgb = mcolors.hex2color(color)
    return 0.2126 * rgb[0] + 0.7152 * rgb[1] + 0.0722 * rgb[2]

def color_cells(row):
    colors = []
    for col in numeric_cols:
        value = team_stats.loc[row.name, col]  # Use original numeric value for coloring
        if col in invert_cols:
            # Invert normalization for PF (descending order)
            norm = (col_max[col] - value) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5            
        else:
            # Normal normalization for ascending order
            norm = (value - col_min[col]) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5
        color = mcolors.to_hex(plt.cm.RdYlGn(norm))
        text_color = 'white' if luminance(color) < 0.5 else 'black'
        colors.append(f"background-color: {color}; color: {text_color};")
    return colors

# Style the Raptors 905 row
styled_df = raptors_row.style.apply(color_cells, subset=numeric_cols, axis=1).format(precision=3)

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_c38d5_row0_col1 {
#   background-color: #fafdb8;
#   color: black;
# }
# #T_c38d5_row0_col2 {
#   background-color: #fee999;
#   color: black;
# }
# #T_c38d5_row0_col3 {
#   background-color: #fdc776;
#   color: black;
# }
# #T_c38d5_row0_col4 {
#   background-color: #c1e57b;
#   color: black;
# }
# #T_c38d5_row0_col5 {
#   background-color: #fff3ac;
#   color: black;
# }
# #T_c38d5_row0_col6 {
#   background-color: #fdad60;
#   color: black;
# }
# #T_c38d5_row0_col7 {
#   background-color: #a9da6c;
#   color: black;
# }
# #T_c38d5_row0_col8 {
#   background-color: #fff5ae;
#   color: black;
# }
# </style>
# <table id="T_c38d5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c38d5_level0_col0" class="col_heading level0 col0" >TEAM</th>
#       <th id="T_c38d5_level0_col1" class="col_heading level0 col1" >PTS OFF TO</th>
#       <th id="T_c38d5_level0_col2" class="col_heading level0 col2" >2nd PTS</th>
#       <th id="T_c38d5_level0_col3" class="col_heading level0 col3" >FBPs</th>
#       <th id="T_c38d5_level0_col4" class="col_heading level0 col4" >PITP</th>
#       <th id="T_c38d5_level0_col5" class="col_heading level0 col5" >Opp PTS OFF TO</th>
#       <th id="T_c38d5_level0_col6" class="col_heading level0 col6" >Opp 2nd PTS</th>
#       <th id="T_c38d5_level0_col7" class="col_heading level0 col7" >Opp FBPs</th>
#       <th id="T_c38d5_level0_col8" class="col_heading level0 col8" >Opp PITP</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c38d5_level0_row0" class="row_heading level0 row0" >28</th>
#       <td id="T_c38d5_row0_col0" class="data row0 col0" >Raptors 905</td>
#       <td id="T_c38d5_row0_col1" class="data row0 col1" >21.0 (11)</td>
#       <td id="T_c38d5_row0_col2" class="data row0 col2" >14.6 (21)</td>
#       <td id="T_c38d5_row0_col3" class="data row0 col3" >14.0 (17)</td>
#       <td id="T_c38d5_row0_col4" class="data row0 col4" >57.1 (4)</td>
#       <td id="T_c38d5_row0_col5" class="data row0 col5" >21.1 (23)</td>
#       <td id="T_c38d5_row0_col6" class="data row0 col6" >18.8 (27)</td>
#       <td id="T_c38d5_row0_col7" class="data row0 col7" >13.0 (11)</td>
#       <td id="T_c38d5_row0_col8" class="data row0 col8" >52.2 (21)</td>
#     </tr>
#   </tbody>
# </table>

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import time

# Set up Selenium WebDriver
service = Service("/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver")  # Update with your path to chromedriver

#Mac file path
#"/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver"

#PC file path
#r"C:\Users\PC\OneDrive\Documents\GitHub\chromedriver-win64\chromedriver.exe"

options = Options()
options.add_argument('--headless')  # Run in headless mode
options.add_argument('--disable-gpu')
options.add_argument('--start-maximized')

driver = webdriver.Chrome(service=service, options=options)

# URL of the webpage to scrape
url = "https://stats.gleague.nba.com/teams/misc/?sort=W&dir=-1"

# Load the webpage
driver.get(url)

# Allow time for JavaScript to load
time.sleep(10)  # Adjust the time as per your internet speed and website response time

# Locate the table
table_xpath = '//div[contains(@class, "nba-stat-table__overflow")]/table'
table_element = driver.find_element(By.XPATH, table_xpath)

# Extract the table data
table_html = table_element.get_attribute('outerHTML')

# Convert the table HTML into a pandas DataFrame
team_stats = pd.read_html(table_html)[0]

# Quit the driver
driver.quit()

# Standardize column names
team_stats.columns = team_stats.columns.str.replace('\xa0', ' ', regex=False).str.strip()

# Drop the specified columns
columns_to_drop = [
    'Unnamed: 0', 'GP', 'W', 'L', 'MIN', 'GP RANK', 'W RANK', 'L RANK', 'MIN RANK', 'PTS OFF TO RANK',
       '2nd PTS RANK', 'FBPs RANK', 'PITP RANK', 'Opp PTS OFF TO RANK',
       'Opp 2nd PTS RANK', 'Opp FBPs RANK', 'Opp PITP RANK'
]

team_stats = team_stats.drop(columns=[col for col in columns_to_drop if col in team_stats.columns])

# Ensure numeric columns are correctly identified
numeric_cols = team_stats.select_dtypes(include=['number']).columns

# Check for NaN or inf values
#print("Checking for NaN and inf values...")
#print(team_stats[numeric_cols].isna().sum())
#print((team_stats[numeric_cols] == np.inf).sum())
#print((team_stats[numeric_cols] == -np.inf).sum())

# Calculate ranks and append ranks to numeric columns for display
invert_cols = ['Opp PTS OFF TO', 'Opp 2nd PTS', 'Opp FBPs', 'Opp PITP']  # PF will be descending, all others ascending
df_with_ranks = team_stats.copy()

for col in numeric_cols:
    # Calculate ranks (invert order for specified columns)
    if col in invert_cols:
        ranks = team_stats[col].rank(ascending=True, method='min').astype(int)
    else:
        ranks = team_stats[col].rank(ascending=False, method='min').astype(int)
    
    # Append ranks to column values for display
    df_with_ranks[col] = team_stats[col].astype(str) + ' (' + ranks.astype(str) + ')'

# Filter for opponents 905 only
opponents_row = df_with_ranks[df_with_ranks['TEAM'] == 'Westchester Knicks']

# Color coding logic
col_min = team_stats[numeric_cols].min()
col_max = team_stats[numeric_cols].max()

def luminance(color):
    rgb = mcolors.hex2color(color)
    return 0.2126 * rgb[0] + 0.7152 * rgb[1] + 0.0722 * rgb[2]

def color_cells(row):
    colors = []
    for col in numeric_cols:
        value = team_stats.loc[row.name, col]  # Use original numeric value for coloring
        if col in invert_cols:
            # Invert normalization for PF (descending order)
            norm = (col_max[col] - value) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5            
        else:
            # Normal normalization for ascending order
            norm = (value - col_min[col]) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5
        color = mcolors.to_hex(plt.cm.RdYlGn(norm))
        text_color = 'white' if luminance(color) < 0.5 else 'black'
        colors.append(f"background-color: {color}; color: {text_color};")
    return colors

# Style the opponents 905 row
styled_df = opponents_row.style.apply(color_cells, subset=numeric_cols, axis=1).format(precision=3)

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_ac16e_row0_col1 {
#   background-color: #e3f399;
#   color: black;
# }
# #T_ac16e_row0_col2, #T_ac16e_row0_col4 {
#   background-color: #006837;
#   color: white;
# }
# #T_ac16e_row0_col3, #T_ac16e_row0_col6 {
#   background-color: #fdfebc;
#   color: black;
# }
# #T_ac16e_row0_col5 {
#   background-color: #fee491;
#   color: black;
# }
# #T_ac16e_row0_col7 {
#   background-color: #e2f397;
#   color: black;
# }
# #T_ac16e_row0_col8 {
#   background-color: #fed481;
#   color: black;
# }
# </style>
# <table id="T_ac16e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ac16e_level0_col0" class="col_heading level0 col0" >TEAM</th>
#       <th id="T_ac16e_level0_col1" class="col_heading level0 col1" >PTS OFF TO</th>
#       <th id="T_ac16e_level0_col2" class="col_heading level0 col2" >2nd PTS</th>
#       <th id="T_ac16e_level0_col3" class="col_heading level0 col3" >FBPs</th>
#       <th id="T_ac16e_level0_col4" class="col_heading level0 col4" >PITP</th>
#       <th id="T_ac16e_level0_col5" class="col_heading level0 col5" >Opp PTS OFF TO</th>
#       <th id="T_ac16e_level0_col6" class="col_heading level0 col6" >Opp 2nd PTS</th>
#       <th id="T_ac16e_level0_col7" class="col_heading level0 col7" >Opp FBPs</th>
#       <th id="T_ac16e_level0_col8" class="col_heading level0 col8" >Opp PITP</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac16e_level0_row0" class="row_heading level0 row0" >22</th>
#       <td id="T_ac16e_row0_col0" class="data row0 col0" >Westchester Knicks</td>
#       <td id="T_ac16e_row0_col1" class="data row0 col1" >21.8 (10)</td>
#       <td id="T_ac16e_row0_col2" class="data row0 col2" >20.6 (1)</td>
#       <td id="T_ac16e_row0_col3" class="data row0 col3" >16.4 (7)</td>
#       <td id="T_ac16e_row0_col4" class="data row0 col4" >67.5 (1)</td>
#       <td id="T_ac16e_row0_col5" class="data row0 col5" >21.6 (25)</td>
#       <td id="T_ac16e_row0_col6" class="data row0 col6" >16.5 (22)</td>
#       <td id="T_ac16e_row0_col7" class="data row0 col7" >14.4 (16)</td>
#       <td id="T_ac16e_row0_col8" class="data row0 col8" >54.5 (26)</td>
#     </tr>
#   </tbody>
# </table>

# %%
team_stats.columns
# Out:
# Index(['Unnamed: 0', 'TEAM', 'GP', 'W', 'L', 'MIN', 'PTS OFF TO', '2nd PTS',
#        'FBPs', 'PITP', 'Opp PTS OFF TO', 'Opp 2nd PTS', 'Opp FBPs', 'Opp PITP',
#        'GP RANK', 'W RANK', 'L RANK', 'MIN RANK', 'PTS OFF TO RANK',
#        '2nd PTS RANK', 'FBPs RANK', 'PITP RANK', 'Opp PTS OFF TO RANK',
#        'Opp 2nd PTS RANK', 'Opp FBPs RANK', 'Opp PITP RANK'],
#       dtype='object')

# %%
print(team_stats.columns.tolist())
# Out:
# ['Unnamed: 0', 'TEAM', 'GP', 'W', 'L', 'MIN', 'PTS OFF\xa0TO', '2nd PTS', 'FBPs', 'PITP', 'Opp\xa0PTS OFF\xa0TO', 'Opp 2nd\xa0PTS', 'Opp FBPs', 'Opp PITP', 'GP RANK', 'W RANK', 'L RANK', 'MIN RANK', 'PTS OFF\xa0TO RANK', '2nd PTS RANK', 'FBPs RANK', 'PITP RANK', 'Opp\xa0PTS OFF\xa0TO RANK', 'Opp 2nd\xa0PTS RANK', 'Opp FBPs RANK', 'Opp PITP RANK']

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import time

# Set up Selenium WebDriver
service = Service("/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver")  # Update with your path to chromedriver

# Mac file path
# "/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver"

# PC file path
# r"C:\Users\PC\OneDrive\Documents\GitHub\chromedriver-win64\chromedriver.exe"

options = Options()
options.add_argument('--headless')  # Run in headless mode
options.add_argument('--disable-gpu')
options.add_argument('--start-maximized')

driver = webdriver.Chrome(service=service, options=options)

# URL of the webpage to scrape
url = "https://stats.gleague.nba.com/teams/scoring/"

# Load the webpage
driver.get(url)

# Allow time for JavaScript to load
time.sleep(10)  # Adjust the time as per your internet speed and website response time

# Locate the table
table_xpath = '//div[contains(@class, "nba-stat-table__overflow")]/table'
table_element = driver.find_element(By.XPATH, table_xpath)

# Extract the table data
table_html = table_element.get_attribute('outerHTML')

# Convert the table HTML into a pandas DataFrame
team_stats = pd.read_html(table_html)[0]

# Quit the driver
driver.quit()

# Standardize column names
team_stats.columns = team_stats.columns.str.replace('\xa0', ' ', regex=False).str.strip()

# Drop the specified columns
columns_to_drop = [
    'Unnamed: 0', 'GP', 'W', 'L', 'MIN', 'GP RANK', 'W RANK', 'L RANK',
    'MIN RANK', '%FGA 2PT RANK', '%FGA 3PT RANK', '%PTS 2PT RANK',
    '%PTS 2PT- MR RANK', '%PTS 3PT RANK', '%PTS FBPs RANK', '%PTS FT RANK',
    '%PTS OffTO RANK', '%PTS PITP RANK', '2FGM %AST RANK',
    '2FGM %UAST RANK', '3FGM %AST RANK', '3FGM %UAST RANK', 'FGM %AST RANK',
    'FGM %UAST RANK'
]
team_stats = team_stats.drop(columns=[col for col in columns_to_drop if col in team_stats.columns])

# Ensure numeric columns are correctly identified
numeric_cols = team_stats.select_dtypes(include=['number']).columns

# Calculate ranks and append ranks to numeric columns for display
df_with_ranks = team_stats.copy()

for col in numeric_cols:
    # Calculate ranks (all in descending order since no inversion is needed)
    ranks = team_stats[col].rank(ascending=False, method='min').astype(int)
    
    # Append ranks to column values for display
    df_with_ranks[col] = team_stats[col].astype(str) + ' (' + ranks.astype(str) + ')'

# Color coding logic
col_min = team_stats[numeric_cols].min()
col_max = team_stats[numeric_cols].max()

def luminance(color):
    rgb = mcolors.hex2color(color)
    return 0.2126 * rgb[0] + 0.7152 * rgb[1] + 0.0722 * rgb[2]

def color_cells(row):
    colors = []
    for col in numeric_cols:
        value = team_stats.loc[row.name, col]  # Use original numeric value for coloring
        # Normal normalization for all columns (descending rank)
        norm = (value - col_min[col]) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5
        color = mcolors.to_hex(plt.cm.RdYlGn(norm))
        text_color = 'white' if luminance(color) < 0.5 else 'black'
        colors.append(f"background-color: {color}; color: {text_color};")
    return colors

# Apply the coloring logic to the DataFrame with ranks
styled_df = df_with_ranks.style.apply(color_cells, subset=numeric_cols, axis=1).format(precision=3)

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_84551_row0_col1, #T_84551_row1_col7, #T_84551_row7_col13, #T_84551_row11_col12 {
#   background-color: #0c7f43;
#   color: white;
# }
# #T_84551_row0_col2, #T_84551_row5_col6, #T_84551_row7_col12, #T_84551_row11_col13 {
#   background-color: #bd1726;
#   color: white;
# }
# #T_84551_row0_col3 {
#   background-color: #18954f;
#   color: white;
# }
# #T_84551_row0_col4, #T_84551_row9_col3, #T_84551_row13_col5, #T_84551_row14_col11, #T_84551_row15_col6 {
#   background-color: #feca79;
#   color: black;
# }
# #T_84551_row0_col5, #T_84551_row9_col12 {
#   background-color: #a70226;
#   color: white;
# }
# #T_84551_row0_col6 {
#   background-color: #7fc866;
#   color: black;
# }
# #T_84551_row0_col7, #T_84551_row3_col9, #T_84551_row12_col14 {
#   background-color: #e3f399;
#   color: black;
# }
# #T_84551_row0_col8, #T_84551_row17_col15, #T_84551_row26_col11 {
#   background-color: #e0f295;
#   color: black;
# }
# #T_84551_row0_col9, #T_84551_row13_col12 {
#   background-color: #249d53;
#   color: white;
# }
# #T_84551_row0_col10, #T_84551_row14_col9 {
#   background-color: #96d268;
#   color: black;
# }
# #T_84551_row0_col11 {
#   background-color: #fb9d59;
#   color: black;
# }
# #T_84551_row0_col12, #T_84551_row5_col1 {
#   background-color: #ce2827;
#   color: white;
# }
# #T_84551_row0_col13, #T_84551_row5_col2, #T_84551_row8_col5 {
#   background-color: #15904c;
#   color: white;
# }
# #T_84551_row0_col14, #T_84551_row3_col11, #T_84551_row4_col11, #T_84551_row10_col2, #T_84551_row11_col15, #T_84551_row30_col12 {
#   background-color: #fffbb8;
#   color: black;
# }
# #T_84551_row0_col15, #T_84551_row3_col10, #T_84551_row4_col10, #T_84551_row10_col1, #T_84551_row11_col14, #T_84551_row30_col13 {
#   background-color: #fafdb8;
#   color: black;
# }
# #T_84551_row1_col1, #T_84551_row1_col11, #T_84551_row1_col15, #T_84551_row3_col7, #T_84551_row5_col5, #T_84551_row10_col4, #T_84551_row13_col6, #T_84551_row13_col8, #T_84551_row18_col10, #T_84551_row18_col14, #T_84551_row19_col2, #T_84551_row21_col12, #T_84551_row22_col3, #T_84551_row22_col9, #T_84551_row29_col13 {
#   background-color: #006837;
#   color: white;
# }
# #T_84551_row1_col2, #T_84551_row1_col5, #T_84551_row1_col10, #T_84551_row1_col14, #T_84551_row5_col3, #T_84551_row5_col9, #T_84551_row10_col6, #T_84551_row12_col4, #T_84551_row18_col11, #T_84551_row18_col15, #T_84551_row19_col1, #T_84551_row21_col13, #T_84551_row23_col7, #T_84551_row23_col8, #T_84551_row29_col12 {
#   background-color: #a50026;
#   color: white;
# }
# #T_84551_row1_col3, #T_84551_row6_col3 {
#   background-color: #5db961;
#   color: black;
# }
# #T_84551_row1_col4, #T_84551_row5_col10 {
#   background-color: #fbfdba;
#   color: black;
# }
# #T_84551_row1_col6 {
#   background-color: #c01a27;
#   color: white;
# }
# #T_84551_row1_col8, #T_84551_row15_col8, #T_84551_row19_col8 {
#   background-color: #fdaf62;
#   color: black;
# }
# #T_84551_row1_col9, #T_84551_row26_col4 {
#   background-color: #89cc67;
#   color: black;
# }
# #T_84551_row1_col12, #T_84551_row10_col14, #T_84551_row28_col5, #T_84551_row29_col5 {
#   background-color: #fee08b;
#   color: black;
# }
# #T_84551_row1_col13, #T_84551_row10_col15, #T_84551_row29_col9 {
#   background-color: #d9ef8b;
#   color: black;
# }
# #T_84551_row2_col1, #T_84551_row19_col11 {
#   background-color: #fdc372;
#   color: black;
# }
# #T_84551_row2_col2, #T_84551_row19_col10 {
#   background-color: #bbe278;
#   color: black;
# }
# #T_84551_row2_col3, #T_84551_row4_col15, #T_84551_row24_col8 {
#   background-color: #e5f49b;
#   color: black;
# }
# #T_84551_row2_col4, #T_84551_row7_col10, #T_84551_row9_col11, #T_84551_row17_col11, #T_84551_row19_col12 {
#   background-color: #cbe982;
#   color: black;
# }
# #T_84551_row2_col5, #T_84551_row7_col1, #T_84551_row10_col12, #T_84551_row13_col9, #T_84551_row15_col12, #T_84551_row25_col3 {
#   background-color: #fff1a8;
#   color: black;
# }
# #T_84551_row2_col6, #T_84551_row4_col2, #T_84551_row7_col14 {
#   background-color: #e2f397;
#   color: black;
# }
# #T_84551_row2_col7, #T_84551_row7_col7, #T_84551_row15_col5 {
#   background-color: #fede89;
#   color: black;
# }
# #T_84551_row2_col8 {
#   background-color: #70c164;
#   color: black;
# }
# #T_84551_row2_col9 {
#   background-color: #fff5ae;
#   color: black;
# }
# #T_84551_row2_col10, #T_84551_row11_col2, #T_84551_row27_col11, #T_84551_row28_col13 {
#   background-color: #fecc7b;
#   color: black;
# }
# #T_84551_row2_col11, #T_84551_row11_col1, #T_84551_row27_col10, #T_84551_row28_col12 {
#   background-color: #c5e67e;
#   color: black;
# }
# #T_84551_row2_col12, #T_84551_row8_col11, #T_84551_row16_col2 {
#   background-color: #fa9656;
#   color: black;
# }
# #T_84551_row2_col13, #T_84551_row8_col10, #T_84551_row16_col1, #T_84551_row30_col9 {
#   background-color: #8ecf67;
#   color: black;
# }
# #T_84551_row2_col14, #T_84551_row9_col1, #T_84551_row26_col14, #T_84551_row28_col2 {
#   background-color: #fed07e;
#   color: black;
# }
# #T_84551_row2_col15, #T_84551_row9_col2, #T_84551_row26_col15, #T_84551_row28_col1 {
#   background-color: #c9e881;
#   color: black;
# }
# #T_84551_row3_col1, #T_84551_row23_col13, #T_84551_row25_col2 {
#   background-color: #a9da6c;
#   color: black;
# }
# #T_84551_row3_col2, #T_84551_row7_col6, #T_84551_row23_col12, #T_84551_row25_col1, #T_84551_row25_col4 {
#   background-color: #fdb163;
#   color: black;
# }
# #T_84551_row3_col3, #T_84551_row13_col3, #T_84551_row14_col14 {
#   background-color: #f7fcb4;
#   color: black;
# }
# #T_84551_row3_col4 {
#   background-color: #b50f26;
#   color: white;
# }
# #T_84551_row3_col5 {
#   background-color: #f8864f;
#   color: black;
# }
# #T_84551_row3_col6 {
#   background-color: #f67c4a;
#   color: black;
# }
# #T_84551_row3_col8, #T_84551_row6_col8, #T_84551_row20_col8, #T_84551_row20_col14, #T_84551_row22_col14, #T_84551_row30_col15 {
#   background-color: #feda86;
#   color: black;
# }
# #T_84551_row3_col12 {
#   background-color: #e44c34;
#   color: white;
# }
# #T_84551_row3_col13 {
#   background-color: #3ca959;
#   color: black;
# }
# #T_84551_row3_col14 {
#   background-color: #fee593;
#   color: black;
# }
# #T_84551_row3_col15, #T_84551_row23_col5 {
#   background-color: #dff293;
#   color: black;
# }
# #T_84551_row4_col1, #T_84551_row7_col15 {
#   background-color: #fee797;
#   color: black;
# }
# #T_84551_row4_col3 {
#   background-color: #d7ee8a;
#   color: black;
# }
# #T_84551_row4_col4 {
#   background-color: #5ab760;
#   color: black;
# }
# #T_84551_row4_col5, #T_84551_row17_col5 {
#   background-color: #fff7b2;
#   color: black;
# }
# #T_84551_row4_col6, #T_84551_row11_col9, #T_84551_row17_col13, #T_84551_row23_col2, #T_84551_row26_col7 {
#   background-color: #e9f6a1;
#   color: black;
# }
# #T_84551_row4_col7, #T_84551_row12_col3, #T_84551_row17_col7 {
#   background-color: #fece7c;
#   color: black;
# }
# #T_84551_row4_col8, #T_84551_row21_col6 {
#   background-color: #e54e35;
#   color: white;
# }
# #T_84551_row4_col9, #T_84551_row23_col1 {
#   background-color: #feefa3;
#   color: black;
# }
# #T_84551_row4_col12 {
#   background-color: #c82227;
#   color: white;
# }
# #T_84551_row4_col13 {
#   background-color: #128a49;
#   color: white;
# }
# #T_84551_row4_col14, #T_84551_row11_col6, #T_84551_row22_col8, #T_84551_row26_col8 {
#   background-color: #feea9b;
#   color: black;
# }
# #T_84551_row5_col4, #T_84551_row24_col4 {
#   background-color: #eb5a3a;
#   color: white;
# }
# #T_84551_row5_col7, #T_84551_row26_col1 {
#   background-color: #bfe47a;
#   color: black;
# }
# #T_84551_row5_col8, #T_84551_row27_col8 {
#   background-color: #feec9f;
#   color: black;
# }
# #T_84551_row5_col11, #T_84551_row24_col3 {
#   background-color: #fffcba;
#   color: black;
# }
# #T_84551_row5_col12, #T_84551_row18_col12, #T_84551_row30_col10 {
#   background-color: #6bbf64;
#   color: black;
# }
# #T_84551_row5_col13, #T_84551_row18_col13, #T_84551_row29_col6, #T_84551_row30_col11 {
#   background-color: #f57245;
#   color: black;
# }
# #T_84551_row5_col14 {
#   background-color: #60ba62;
#   color: black;
# }
# #T_84551_row5_col15 {
#   background-color: #f26841;
#   color: black;
# }
# #T_84551_row6_col1, #T_84551_row13_col14, #T_84551_row22_col12, #T_84551_row23_col9 {
#   background-color: #daf08d;
#   color: black;
# }
# #T_84551_row6_col2, #T_84551_row13_col15, #T_84551_row22_col13 {
#   background-color: #fee18d;
#   color: black;
# }
# #T_84551_row6_col4, #T_84551_row6_col15, #T_84551_row8_col8, #T_84551_row25_col11 {
#   backg

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import time

# Set up Selenium WebDriver
service = Service("/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver")  # Update with your path to chromedriver

options = Options()
options.add_argument('--headless')  # Run in headless mode
options.add_argument('--disable-gpu')
options.add_argument('--start-maximized')

driver = webdriver.Chrome(service=service, options=options)

# URL of the webpage to scrape
url = "https://stats.gleague.nba.com/teams/scoring/"

# Load the webpage
driver.get(url)

# Allow time for JavaScript to load
time.sleep(10)

# Locate the table
table_xpath = '//div[contains(@class, "nba-stat-table__overflow")]/table'
table_element = driver.find_element(By.XPATH, table_xpath)

# Extract the table data
table_html = table_element.get_attribute('outerHTML')

# Convert the table HTML into a pandas DataFrame
team_stats = pd.read_html(table_html)[0]

# Quit the driver
driver.quit()

# Standardize column names
team_stats.columns = team_stats.columns.str.replace('\xa0', ' ', regex=False).str.strip()

# Drop the specified columns
columns_to_drop = [
    'Unnamed: 0', 'GP', 'W', 'L', 'MIN', 'GP RANK', 'W RANK', 'L RANK',
    'MIN RANK', '%FGA 2PT RANK', '%FGA 3PT RANK', '%PTS 2PT RANK',
    '%PTS 2PT- MR RANK', '%PTS 3PT RANK', '%PTS FBPs RANK', '%PTS FT RANK',
    '%PTS OffTO RANK', '%PTS PITP RANK', '2FGM %AST RANK',
    '2FGM %UAST RANK', '3FGM %AST RANK', '3FGM %UAST RANK', 'FGM %AST RANK',
    'FGM %UAST RANK'
]
team_stats = team_stats.drop(columns=[col for col in columns_to_drop if col in team_stats.columns])

# Ensure numeric columns are correctly identified
numeric_cols = team_stats.select_dtypes(include=['number']).columns

# Calculate ranks and append ranks to numeric columns for display
df_with_ranks = team_stats.copy()

for col in numeric_cols:
    # Calculate ranks (all in descending order)
    ranks = team_stats[col].rank(ascending=False, method='min').astype(int)
    
    # Append ranks to column values for display
    df_with_ranks[col] = team_stats[col].astype(str) + ' (' + ranks.astype(str) + ')'

# Filter for Raptors 905 only
raptors_row = df_with_ranks[df_with_ranks['TEAM'] == 'Raptors 905']

# Color coding logic
col_min = team_stats[numeric_cols].min()
col_max = team_stats[numeric_cols].max()

def luminance(color):
    rgb = mcolors.hex2color(color)
    return 0.2126 * rgb[0] + 0.7152 * rgb[1] + 0.0722 * rgb[2]

def color_cells(row):
    colors = []
    for col in numeric_cols:
        value = team_stats.loc[row.name, col]  # Use original numeric value for coloring
        # Normal normalization for all columns
        norm = (value - col_min[col]) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5
        color = mcolors.to_hex(plt.cm.RdYlGn(norm))
        text_color = 'white' if luminance(color) < 0.5 else 'black'
        colors.append(f"background-color: {color}; color: {text_color};")
    return colors

# Style the Raptors 905 row
styled_df = raptors_row.style.apply(color_cells, subset=numeric_cols, axis=1).format(precision=3)

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_7548f_row0_col1 {
#   background-color: #c9e881;
#   color: black;
# }
# #T_7548f_row0_col2 {
#   background-color: #fed07e;
#   color: black;
# }
# #T_7548f_row0_col3, #T_7548f_row0_col9 {
#   background-color: #69be63;
#   color: black;
# }
# #T_7548f_row0_col4 {
#   background-color: #fa9b58;
#   color: black;
# }
# #T_7548f_row0_col5 {
#   background-color: #fee08b;
#   color: black;
# }
# #T_7548f_row0_col6 {
#   background-color: #fed481;
#   color: black;
# }
# #T_7548f_row0_col7 {
#   background-color: #cc2627;
#   color: white;
# }
# #T_7548f_row0_col8 {
#   background-color: #f1f9ac;
#   color: black;
# }
# #T_7548f_row0_col10 {
#   background-color: #98d368;
#   color: black;
# }
# #T_7548f_row0_col11 {
#   background-color: #fba05b;
#   color: black;
# }
# #T_7548f_row0_col12 {
#   background-color: #c5e67e;
#   color: black;
# }
# #T_7548f_row0_col13 {
#   background-color: #fecc7b;
#   color: black;
# }
# #T_7548f_row0_col14 {
#   background-color: #c1e57b;
#   color: black;
# }
# #T_7548f_row0_col15 {
#   background-color: #fec877;
#   color: black;
# }
# </style>
# <table id="T_7548f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7548f_level0_col0" class="col_heading level0 col0" >TEAM</th>
#       <th id="T_7548f_level0_col1" class="col_heading level0 col1" >%FGA 2PT</th>
#       <th id="T_7548f_level0_col2" class="col_heading level0 col2" >%FGA 3PT</th>
#       <th id="T_7548f_level0_col3" class="col_heading level0 col3" >%PTS 2PT</th>
#       <th id="T_7548f_level0_col4" class="col_heading level0 col4" >%PTS 2PT- MR</th>
#       <th id="T_7548f_level0_col5" class="col_heading level0 col5" >%PTS 3PT</th>
#       <th id="T_7548f_level0_col6" class="col_heading level0 col6" >%PTS FBPs</th>
#       <th id="T_7548f_level0_col7" class="col_heading level0 col7" >%PTS FT</th>
#       <th id="T_7548f_level0_col8" class="col_heading level0 col8" >%PTS OffTO</th>
#       <th id="T_7548f_level0_col9" class="col_heading level0 col9" >%PTS PITP</th>
#       <th id="T_7548f_level0_col10" class="col_heading level0 col10" >2FGM %AST</th>
#       <th id="T_7548f_level0_col11" class="col_heading level0 col11" >2FGM %UAST</th>
#       <th id="T_7548f_level0_col12" class="col_heading level0 col12" >3FGM %AST</th>
#       <th id="T_7548f_level0_col13" class="col_heading level0 col13" >3FGM %UAST</th>
#       <th id="T_7548f_level0_col14" class="col_heading level0 col14" >FGM %AST</th>
#       <th id="T_7548f_level0_col15" class="col_heading level0 col15" >FGM %UAST</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7548f_level0_row0" class="row_heading level0 row0" >28</th>
#       <td id="T_7548f_row0_col0" class="data row0 col0" >Raptors 905</td>
#       <td id="T_7548f_row0_col1" class="data row0 col1" >60.5 (11)</td>
#       <td id="T_7548f_row0_col2" class="data row0 col2" >39.5 (21)</td>
#       <td id="T_7548f_row0_col3" class="data row0 col3" >54.6 (6)</td>
#       <td id="T_7548f_row0_col4" class="data row0 col4" >2.8 (24)</td>
#       <td id="T_7548f_row0_col5" class="data row0 col5" >33.3 (17)</td>
#       <td id="T_7548f_row0_col6" class="data row0 col6" >12.7 (16)</td>
#       <td id="T_7548f_row0_col7" class="data row0 col7" >7.4 (30)</td>
#       <td id="T_7548f_row0_col8" class="data row0 col8" >19.1 (10)</td>
#       <td id="T_7548f_row0_col9" class="data row0 col9" >51.8 (3)</td>
#       <td id="T_7548f_row0_col10" class="data row0 col10" >51.7 (7)</td>
#       <td id="T_7548f_row0_col11" class="data row0 col11" >48.3 (25)</td>
#       <td id="T_7548f_row0_col12" class="data row0 col12" >88.2 (8)</td>
#       <td id="T_7548f_row0_col13" class="data row0 col13" >11.8 (24)</td>
#       <td id="T_7548f_row0_col14" class="data row0 col14" >62.2 (7)</td>
#       <td id="T_7548f_row0_col15" class="data row0 col15" >37.8 (24)</td>
#     </tr>
#   </tbody>
# </table>

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import time

# Set up Selenium WebDriver
service = Service("/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver")  # Update with your path to chromedriver

options = Options()
options.add_argument('--headless')  # Run in headless mode
options.add_argument('--disable-gpu')
options.add_argument('--start-maximized')

driver = webdriver.Chrome(service=service, options=options)

# URL of the webpage to scrape
url = "https://stats.gleague.nba.com/teams/scoring/"

# Load the webpage
driver.get(url)

# Allow time for JavaScript to load
time.sleep(10)

# Locate the table
table_xpath = '//div[contains(@class, "nba-stat-table__overflow")]/table'
table_element = driver.find_element(By.XPATH, table_xpath)

# Extract the table data
table_html = table_element.get_attribute('outerHTML')

# Convert the table HTML into a pandas DataFrame
team_stats = pd.read_html(table_html)[0]

# Quit the driver
driver.quit()

# Standardize column names
team_stats.columns = team_stats.columns.str.replace('\xa0', ' ', regex=False).str.strip()

# Drop the specified columns
columns_to_drop = [
    'Unnamed: 0', 'GP', 'W', 'L', 'MIN', 'GP RANK', 'W RANK', 'L RANK',
    'MIN RANK', '%FGA 2PT RANK', '%FGA 3PT RANK', '%PTS 2PT RANK',
    '%PTS 2PT- MR RANK', '%PTS 3PT RANK', '%PTS FBPs RANK', '%PTS FT RANK',
    '%PTS OffTO RANK', '%PTS PITP RANK', '2FGM %AST RANK',
    '2FGM %UAST RANK', '3FGM %AST RANK', '3FGM %UAST RANK', 'FGM %AST RANK',
    'FGM %UAST RANK'
]
team_stats = team_stats.drop(columns=[col for col in columns_to_drop if col in team_stats.columns])

# Ensure numeric columns are correctly identified
numeric_cols = team_stats.select_dtypes(include=['number']).columns

# Calculate ranks and append ranks to numeric columns for display
df_with_ranks = team_stats.copy()

for col in numeric_cols:
    # Calculate ranks (all in descending order)
    ranks = team_stats[col].rank(ascending=False, method='min').astype(int)
    
    # Append ranks to column values for display
    df_with_ranks[col] = team_stats[col].astype(str) + ' (' + ranks.astype(str) + ')'

# Filter for opponent 905 only
opponent_row = df_with_ranks[df_with_ranks['TEAM'] == 'Westchester Knicks']

# Color coding logic
col_min = team_stats[numeric_cols].min()
col_max = team_stats[numeric_cols].max()

def luminance(color):
    rgb = mcolors.hex2color(color)
    return 0.2126 * rgb[0] + 0.7152 * rgb[1] + 0.0722 * rgb[2]

def color_cells(row):
    colors = []
    for col in numeric_cols:
        value = team_stats.loc[row.name, col]  # Use original numeric value for coloring
        # Normal normalization for all columns
        norm = (value - col_min[col]) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5
        color = mcolors.to_hex(plt.cm.RdYlGn(norm))
        text_color = 'white' if luminance(color) < 0.5 else 'black'
        colors.append(f"background-color: {color}; color: {text_color};")
    return colors

# Style the opponent 905 row
styled_df = opponent_row.style.apply(color_cells, subset=numeric_cols, axis=1).format(precision=3)

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_9fd92_row0_col1 {
#   background-color: #45ad5b;
#   color: black;
# }
# #T_9fd92_row0_col2, #T_9fd92_row0_col7 {
#   background-color: #e75337;
#   color: white;
# }
# #T_9fd92_row0_col3, #T_9fd92_row0_col9 {
#   background-color: #006837;
#   color: white;
# }
# #T_9fd92_row0_col4 {
#   background-color: #fca55d;
#   color: black;
# }
# #T_9fd92_row0_col5 {
#   background-color: #dc3b2c;
#   color: white;
# }
# #T_9fd92_row0_col6 {
#   background-color: #fff0a6;
#   color: black;
# }
# #T_9fd92_row0_col8 {
#   background-color: #feea9b;
#   color: black;
# }
# #T_9fd92_row0_col10 {
#   background-color: #fffab6;
#   color: black;
# }
# #T_9fd92_row0_col11 {
#   background-color: #f8fcb6;
#   color: black;
# }
# #T_9fd92_row0_col12 {
#   background-color: #daf08d;
#   color: black;
# }
# #T_9fd92_row0_col13 {
#   background-color: #fee18d;
#   color: black;
# }
# #T_9fd92_row0_col14 {
#   background-color: #feda86;
#   color: black;
# }
# #T_9fd92_row0_col15 {
#   background-color: #d3ec87;
#   color: black;
# }
# </style>
# <table id="T_9fd92">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9fd92_level0_col0" class="col_heading level0 col0" >TEAM</th>
#       <th id="T_9fd92_level0_col1" class="col_heading level0 col1" >%FGA 2PT</th>
#       <th id="T_9fd92_level0_col2" class="col_heading level0 col2" >%FGA 3PT</th>
#       <th id="T_9fd92_level0_col3" class="col_heading level0 col3" >%PTS 2PT</th>
#       <th id="T_9fd92_level0_col4" class="col_heading level0 col4" >%PTS 2PT- MR</th>
#       <th id="T_9fd92_level0_col5" class="col_heading level0 col5" >%PTS 3PT</th>
#       <th id="T_9fd92_level0_col6" class="col_heading level0 col6" >%PTS FBPs</th>
#       <th id="T_9fd92_level0_col7" class="col_heading level0 col7" >%PTS FT</th>
#       <th id="T_9fd92_level0_col8" class="col_heading level0 col8" >%PTS OffTO</th>
#       <th id="T_9fd92_level0_col9" class="col_heading level0 col9" >%PTS PITP</th>
#       <th id="T_9fd92_level0_col10" class="col_heading level0 col10" >2FGM %AST</th>
#       <th id="T_9fd92_level0_col11" class="col_heading level0 col11" >2FGM %UAST</th>
#       <th id="T_9fd92_level0_col12" class="col_heading level0 col12" >3FGM %AST</th>
#       <th id="T_9fd92_level0_col13" class="col_heading level0 col13" >3FGM %UAST</th>
#       <th id="T_9fd92_level0_col14" class="col_heading level0 col14" >FGM %AST</th>
#       <th id="T_9fd92_level0_col15" class="col_heading level0 col15" >FGM %UAST</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9fd92_level0_row0" class="row_heading level0 row0" >22</th>
#       <td id="T_9fd92_row0_col0" class="data row0 col0" >Westchester Knicks</td>
#       <td id="T_9fd92_row0_col1" class="data row0 col1" >65.2 (3)</td>
#       <td id="T_9fd92_row0_col2" class="data row0 col2" >34.8 (29)</td>
#       <td id="T_9fd92_row0_col3" class="data row0 col3" >59.1 (1)</td>
#       <td id="T_9fd92_row0_col4" class="data row0 col4" >2.9 (23)</td>
#       <td id="T_9fd92_row0_col5" class="data row0 col5" >27.5 (28)</td>
#       <td id="T_9fd92_row0_col6" class="data row0 col6" >13.6 (13)</td>
#       <td id="T_9fd92_row0_col7" class="data row0 col7" >7.9 (26)</td>
#       <td id="T_9fd92_row0_col8" class="data row0 col8" >18.1 (15)</td>
#       <td id="T_9fd92_row0_col9" class="data row0 col9" >56.2 (1)</td>
#       <td id="T_9fd92_row0_col10" class="data row0 col10" >45.8 (22)</td>
#       <td id="T_9fd92_row0_col11" class="data row0 col11" >54.2 (10)</td>
#       <td id="T_9fd92_row0_col12" class="data row0 col12" >87.5 (10)</td>
#       <td id="T_9fd92_row0_col13" class="data row0 col13" >12.5 (22)</td>
#       <td id="T_9fd92_row0_col14" class="data row0 col14" >55.6 (24)</td>
#       <td id="T_9fd92_row0_col15" class="data row0 col15" >44.4 (7)</td>
#     </tr>
#   </tbody>
# </table>

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import time

# Set up Selenium WebDriver
service = Service("/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver")  # Update with your path to chromedriver

# Mac file path
# "/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver"

# PC file path
# r"C:\Users\PC\OneDrive\Documents\GitHub\chromedriver-win64\chromedriver.exe"

options = Options()
options.add_argument('--headless')  # Run in headless mode
options.add_argument('--disable-gpu')
options.add_argument('--start-maximized')

driver = webdriver.Chrome(service=service, options=options)

# URL of the webpage to scrape
url = "https://stats.gleague.nba.com/teams/opponent/?sort=W&dir=-1"

# Load the webpage
driver.get(url)

# Allow time for JavaScript to load
time.sleep(10)  # Adjust the time as per your internet speed and website response time

# Locate the table
table_xpath = '//div[contains(@class, "nba-stat-table__overflow")]/table'
table_element = driver.find_element(By.XPATH, table_xpath)

# Extract the table data
table_html = table_element.get_attribute('outerHTML')

# Convert the table HTML into a pandas DataFrame
team_stats = pd.read_html(table_html)[0]

# Quit the driver
driver.quit()

# Drop the specified columns
columns_to_drop = [
    'Unnamed: 0', 'GP', 'W', 'L', 'MIN', 'GP RANK', 'W RANK', 'L RANK', 'MIN RANK', 'Opp FGM RANK',
       'Opp FGA RANK', 'Opp FG% RANK', 'Opp 3PM RANK', 'Opp 3PA RANK',
       'Opp 3P% RANK', 'Opp FTM RANK', 'Opp FTA RANK', 'Opp FT% RANK',
       'Opp OREB RANK', 'Opp DREB RANK', 'Opp REB RANK', 'Opp AST RANK',
       'Opp TOV RANK', 'Opp STL RANK', 'Opp BLK RANK', 'Opp BLKA RANK',
       'Opp PF RANK', 'Opp PFD RANK', 'Opp PTS RANK', '+/- RANK', 'Opp FTM', 'Opp FT%', 'Opp DREB', 'Opp PFD' 
]
team_stats = team_stats.drop(columns=[col for col in columns_to_drop if col in team_stats.columns])

# Ensure numeric columns are correctly identified
numeric_cols = team_stats.select_dtypes(include=['number']).columns

# Calculate ranks and append ranks to numeric columns for display
invert_cols = ['Opp PF', 'Opp TOV']  # Columns with descending rank
df_with_ranks = team_stats.copy()

for col in numeric_cols:
    # Calculate ranks (invert order for specified columns)
    if col in invert_cols:
        ranks = team_stats[col].rank(ascending=False, method='min').astype(int)
    else:
        ranks = team_stats[col].rank(ascending=True, method='min').astype(int)
    
    # Append ranks to column values for display
    df_with_ranks[col] = team_stats[col].astype(str) + ' (' + ranks.astype(str) + ')'

# Color coding logic
col_min = team_stats[numeric_cols].min()
col_max = team_stats[numeric_cols].max()

def luminance(color):
    rgb = mcolors.hex2color(color)
    return 0.2126 * rgb[0] + 0.7152 * rgb[1] + 0.0722 * rgb[2]

def color_cells(row):
    colors = []
    for col in numeric_cols:
        value = team_stats.loc[row.name, col]  # Use original numeric value for coloring
        if col in invert_cols:
            # Invert normalization for specified columns
            norm = (col_max[col] - value) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5
        else:
            # Normal normalization
            norm = (value - col_min[col]) / (col_max[col] - col_min[col]) if col_min[col] != col_max[col] else 0.5
        color = mcolors.to_hex(plt.cm.RdYlGn(norm))
        text_color = 'white' if luminance(color) < 0.5 else 'black'
        colors.append(f"background-color: {color}; color: {text_color};")
    return colors

# Apply the coloring logic to the DataFrame with ranks
styled_df = df_with_ranks.style.apply(color_cells, subset=numeric_cols, axis=1).format(precision=3)

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_08379_row0_col1, #T_08379_row21_col14 {
#   background-color: #fa9656;
#   color: black;
# }
# #T_08379_row0_col2, #T_08379_row7_col17 {
#   background-color: #fdbf6f;
#   color: black;
# }
# #T_08379_row0_col3, #T_08379_row1_col4, #T_08379_row4_col17, #T_08379_row25_col3 {
#   background-color: #f7844e;
#   color: black;
# }
# #T_08379_row0_col4, #T_08379_row11_col4, #T_08379_row14_col13 {
#   background-color: #de402e;
#   color: white;
# }
# #T_08379_row0_col5, #T_08379_row6_col16, #T_08379_row29_col16 {
#   background-color: #f99355;
#   color: black;
# }
# #T_08379_row0_col6 {
#   background-color: #f67f4b;
#   color: black;
# }
# #T_08379_row0_col7, #T_08379_row24_col11, #T_08379_row26_col1 {
#   background-color: #feffbe;
#   color: black;
# }
# #T_08379_row0_col8, #T_08379_row3_col6, #T_08379_row8_col10, #T_08379_row8_col13, #T_08379_row10_col13, #T_08379_row16_col4 {
#   background-color: #eb5a3a;
#   color: white;
# }
# #T_08379_row0_col9 {
#   background-color: #d93429;
#   color: white;
# }
# #T_08379_row0_col10, #T_08379_row18_col7, #T_08379_row25_col10 {
#   background-color: #fdbd6d;
#   color: black;
# }
# #T_08379_row0_col11, #T_08379_row16_col13, #T_08379_row20_col13, #T_08379_row21_col13 {
#   background-color: #fbfdba;
#   color: black;
# }
# #T_08379_row0_col12, #T_08379_row11_col6, #T_08379_row13_col10, #T_08379_row16_col10 {
#   background-color: #ebf7a3;
#   color: black;
# }
# #T_08379_row0_col13, #T_08379_row1_col13, #T_08379_row2_col4, #T_08379_row8_col1, #T_08379_row28_col4 {
#   background-color: #c5e67e;
#   color: black;
# }
# #T_08379_row0_col14, #T_08379_row9_col2, #T_08379_row12_col14, #T_08379_row19_col14, #T_08379_row28_col14 {
#   background-color: #daf08d;
#   color: black;
# }
# #T_08379_row0_col15 {
#   background-color: #f57748;
#   color: black;
# }
# #T_08379_row0_col16, #T_08379_row12_col3 {
#   background-color: #f16640;
#   color: black;
# }
# #T_08379_row0_col17 {
#   background-color: #bb1526;
#   color: white;
# }
# #T_08379_row1_col1, #T_08379_row1_col9, #T_08379_row1_col10, #T_08379_row1_col16, #T_08379_row1_col17, #T_08379_row2_col2, #T_08379_row2_col10, #T_08379_row3_col15, #T_08379_row4_col4, #T_08379_row4_col6, #T_08379_row7_col13, #T_08379_row10_col12, #T_08379_row11_col5, #T_08379_row13_col11, #T_08379_row16_col14, #T_08379_row20_col8, #T_08379_row23_col3, #T_08379_row23_col7 {
#   background-color: #a50026;
#   color: white;
# }
# #T_08379_row1_col2, #T_08379_row17_col2 {
#   background-color: #c62027;
#   color: white;
# }
# #T_08379_row1_col3 {
#   background-color: #c41e27;
#   color: white;
# }
# #T_08379_row1_col5, #T_08379_row2_col1, #T_08379_row22_col15, #T_08379_row24_col15 {
#   background-color: #fed27f;
#   color: black;
# }
# #T_08379_row1_col6, #T_08379_row24_col9 {
#   background-color: #fa9857;
#   color: black;
# }
# #T_08379_row1_col7, #T_08379_row4_col7, #T_08379_row4_col15, #T_08379_row6_col11, #T_08379_row11_col2, #T_08379_row25_col2 {
#   background-color: #e9f6a1;
#   color: black;
# }
# #T_08379_row1_col8, #T_08379_row2_col8, #T_08379_row4_col1, #T_08379_row13_col8 {
#   background-color: #dc3b2c;
#   color: white;
# }
# #T_08379_row1_col11, #T_08379_row6_col15, #T_08379_row13_col1, #T_08379_row13_col9, #T_08379_row18_col9 {
#   background-color: #e5f49b;
#   color: black;
# }
# #T_08379_row1_col12, #T_08379_row2_col12, #T_08379_row9_col3, #T_08379_row9_col6, #T_08379_row17_col12, #T_08379_row18_col3 {
#   background-color: #e95538;
#   color: white;
# }
# #T_08379_row1_col14, #T_08379_row9_col16 {
#   background-color: #fba05b;
#   color: black;
# }
# #T_08379_row1_col15, #T_08379_row13_col14 {
#   background-color: #dd3d2d;
#   color: white;
# }
# #T_08379_row2_col3, #T_08379_row11_col16, #T_08379_row25_col6, #T_08379_row27_col6 {
#   background-color: #abdb6d;
#   color: black;
# }
# #T_08379_row2_col5, #T_08379_row4_col5, #T_08379_row4_col13, #T_08379_row8_col15, #T_08379_row12_col7, #T_08379_row19_col13, #T_08379_row21_col7, #T_08379_row22_col3, #T_08379_row29_col13 {
#   background-color: #fdad60;
#   color: black;
# }
# #T_08379_row2_col6 {
#   background-color: #0c7f43;
#   color: white;
# }
# #T_08379_row2_col7, #T_08379_row4_col8, #T_08379_row6_col17, #T_08379_row23_col13 {
#   background-color: #ce2827;
#   color: white;
# }
# #T_08379_row2_col9, #T_08379_row9_col10, #T_08379_row30_col1 {
#   background-color: #fb9d59;
#   color: black;
# }
# #T_08379_row2_col11, #T_08379_row4_col9, #T_08379_row18_col14 {
#   background-color: #ec5c3b;
#   color: white;
# }
# #T_08379_row2_col13, #T_08379_row30_col7 {
#   background-color: #a5d86a;
#   color: black;
# }
# #T_08379_row2_col14, #T_08379_row13_col17, #T_08379_row15_col14, #T_08379_row22_col4, #T_08379_row25_col13, #T_08379_row30_col2 {
#   background-color: #fee18d;
#   color: black;
# }
# #T_08379_row2_col15, #T_08379_row5_col12, #T_08379_row5_col15, #T_08379_row12_col12, #T_08379_row14_col12, #T_08379_row20_col15, #T_08379_row26_col15 {
#   background-color: #f1f9ac;
#   color: black;
# }
# #T_08379_row2_col16, #T_08379_row22_col17 {
#   background-color: #f98e52;
#   color: black;
# }
# #T_08379_row2_col17 {
#   background-color: #ee613e;
#   color: white;
# }
# #T_08379_row3_col1, #T_08379_row9_col4, #T_08379_row14_col6, #T_08379_row15_col6 {
#   background-color: #fff6b0;
#   color: black;
# }
# #T_08379_row3_col2 {
#   background-color: #2aa054;
#   color: black;
# }
# #T_08379_row3_col3 {
#   background-color: #da362a;
#   color: white;
# }
# #T_08379_row3_col4 {
#   background-color: #f47044;
#   color: black;
# }
# #T_08379_row3_col5, #T_08379_row16_col16, #T_08379_row23_col12, #T_08379_row29_col7 {
#   background-color: #fee999;
#   color: black;
# }
# #T_08379_row3_col7, #T_08379_row15_col11 {
#   background-color: #89cc67;
#   color: black;
# }
# #T_08379_row3_col8 {
#   background-color: #5ab760;
#   color: black;
# }
# #T_08379_row3_col9 {
#   background-color: #f57245;
#   color: black;
# }
# #T_08379_row3_col10, #T_08379_row16_col6 {
#   background-color: #e44c34;
#   color: white;
# }
# #T_08379_row3_col11, #T_08379_row10_col11, #T_08379_row25_col12 {
#   background-color: #91d068;
#   color: black;
# }
# #T_08379_row3_col12, #T_08379_row5_col5, #T_08379_row8_col9, #T_08379_row10_col6, #T_08379_row10_col15, #T_08379_row13_col4, #T_08379_row15_col2, #T_08379_row15_col8, #T_08379_row16_col11, #T_08379_row22_col13, #T_08379_row23_col11, #T_08379_row24_col10, #T_08379_row24_col12, #T_08379_row24_col16, #T_08379_row27_col1, #T_08379_row27_col3, #T_08379_row28_col7, #T_08379_row28_col17, #T_08379_row30_col14 {
#   background-color: #006837;
#   color: white;
# }
# #T_08379_row3_col13, #T_08379_row10_col3, #T_08379_row30_col13 {
#   background-color: #6ec064;
#   color: black;
# }
# #T_08379_row3_col14 {
#   background-color: #98d368;
#   color: black;
# }
# #T_08379_row3_col16, #T_08379_row12_col1, #T_08379_row12_col16, #T_08379_row26_col7, #T_08379_row30_col6 {
#   background-color: #fdc372;
#   color: black;
# }
# #T_08379_row3_col17, #T_08379_row6_col7 {
#   background-color: #fee593;
#   color: black;
# }
# #T_08379_row4_col2 {
#   background-color: #fdb768;
#   color: black;
# }
# #T_08379_row4_col3, #T_08379_row8_col12, #T_08379_row13_col12 {
#   background-color: #b71126;
#   color: white;
# }
# #T_08379_row4_col10, #T_08379_row24_col8 {
#   background-color: #be1827;
#   color: white;
# }
# #T_08379_row4_col11 {
#   background-color: #3faa59;
#   color: black;
# }
# #T_08379_row4_col12, #T_08379_row10_col10, #T_08379_row28_col10 {
#   background-color: #fffebe;
#   color: black;
# }
# #T_08379_row4_col14, #T_08379_row22_col6, #T_08379_row27_col14 {
#   background-color: #feec9f;
#   color: black;
# }
# #T_08379_row4_col16, #T_08379_row19_col3 {
#   background-color: #bd1726;
#   color: white;
# }
# #T_08379_row5_col1, #T_08379_row6_col1, #T_08379_row19_col1 {
#   background-color: #fee08b;
#   color: black;
# }
# #T_08379_row5_col2, #T_08379_row17_col6 {
#   background-color: #d7ee8a;
#   color: black;
# }
# #T_08379_row5_col3, #T_08379_row18_col16, #T_08379_row29_col3 {
#   background-color: #f67c4a;
#   color: black;
# }
# #T_08379_row5_col4, #T_08379_row23_col5 {
#   background-color: #a2d76a;
#   color: black;
# }
# #T_08379_row5_col6, #T_08379_row29_col1 {
#   background-color: #fba35c;
#   color: black;
# }
# #T_08379_row5_col7, #T_08379_row15_col7 {
#   background-color: #e34933;
#   color: white;
# }
# #T_08379_row5_col8, #T_08379_row12_col2, #T_08379_row25_col7 {
#   background-color:

# %%
print(team_stats.columns.tolist())
# Out:
# ['Unnamed: 0', 'TEAM', 'GP', 'W', 'L', 'MIN', 'Opp FGM', 'Opp FGA', 'Opp FG%', 'Opp 3PM', 'Opp 3PA', 'Opp 3P%', 'Opp FTM', 'Opp FTA', 'Opp FT%', 'Opp OREB', 'Opp DREB', 'Opp REB', 'Opp AST', 'Opp TOV', 'Opp STL', 'Opp BLK', 'Opp BLKA', 'Opp PF', 'Opp PFD', 'Opp PTS', '+/-', 'GP RANK', 'W RANK', 'L RANK', 'MIN RANK', 'Opp FGM RANK', 'Opp FGA RANK', 'Opp FG% RANK', 'Opp 3PM RANK', 'Opp 3PA RANK', 'Opp 3P% RANK', 'Opp FTM RANK', 'Opp FTA RANK', 'Opp FT% RANK', 'Opp OREB RANK', 'Opp DREB RANK', 'Opp REB RANK', 'Opp AST RANK', 'Opp TOV RANK', 'Opp STL RANK', 'Opp BLK RANK', 'Opp BLKA RANK', 'Opp PF RANK', 'Opp PFD RANK', 'Opp PTS RANK', '+/- RANK']

# %%
team_stats.columns
# Out:
# Index(['Unnamed: 0', 'TEAM', 'GP', 'W', 'L', 'MIN', 'Opp FGM', 'Opp FGA',
#        'Opp FG%', 'Opp 3PM', 'Opp 3PA', 'Opp 3P%', 'Opp FTM', 'Opp FTA',
#        'Opp FT%', 'Opp OREB', 'Opp DREB', 'Opp REB', 'Opp AST', 'Opp TOV',
#        'Opp STL', 'Opp BLK', 'Opp BLKA', 'Opp PF', 'Opp PFD', 'Opp PTS', '+/-',
#        'GP RANK', 'W RANK', 'L RANK', 'MIN RANK', 'Opp FGM RANK',
#        'Opp FGA RANK', 'Opp FG% RANK', 'Opp 3PM RANK', 'Opp 3PA RANK',
#        'Opp 3P% RANK', 'Opp FTM RANK', 'Opp FTA RANK', 'Opp FT% RANK',
#        'Opp OREB RANK', 'Opp DREB RANK', 'Opp REB RANK', 'Opp AST RANK',
#        'Opp TOV RANK', 'Opp STL RANK', 'Opp BLK RANK', 'Opp BLKA RANK',
#        'Opp PF RANK', 'Opp PFD RANK', 'Opp PTS RANK', '+/- RANK'],
#       dtype='object')
