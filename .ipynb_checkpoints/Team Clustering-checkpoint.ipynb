# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
from IPython.display import display, Markdown
import matplotlib.colors as mcolors

# %%
# Display the full DataFrame without truncation
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', None)     # Show all rows

# %% [markdown]
# ## General Overview

# %%
import os
import warnings
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from threadpoolctl import threadpool_limits
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import time
from IPython.display import display

# Suppress MKL-related warning
warnings.filterwarnings("ignore", message="KMeans is known to have a memory leak", category=UserWarning)

# Set environment variable for MKL threads (optional, but may help)
os.environ["OMP_NUM_THREADS"] = "1"

# Set up Selenium WebDriver
service = Service(r"C:\Users\PC\OneDrive\Documents\GitHub\chromedriver-win64\chromedriver.exe")  # Update with your path

#Mac file path
#"/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver"

#PC file path
#r"C:\Users\PC\OneDrive\Documents\GitHub\chromedriver-win64\chromedriver.exe"

options = Options()
options.add_argument('--headless')  # Run in headless mode
options.add_argument('--disable-gpu')
options.add_argument('--start-maximized')
driver = webdriver.Chrome(service=service, options=options)

# URL of the webpage to scrape
url = "https://stats.gleague.nba.com/teams/advanced/?sort=W&dir=-1&Season=2024-25&SeasonType=Regular%20Season"

# Load the webpage
driver.get(url)
time.sleep(10)  # Allow time for JavaScript to load

# Locate the table and extract its data
table_xpath = '//div[contains(@class, "nba-stat-table__overflow")]/table'
table_element = driver.find_element(By.XPATH, table_xpath)
table_html = table_element.get_attribute('outerHTML')
team_stats = pd.read_html(table_html)[0]  # Convert the table HTML into a pandas DataFrame
driver.quit()  # Close the WebDriver

# Keep only the specified columns
columns_to_keep = ['TEAM', 'OffRtg', 'DefRtg', 'NetRtg']
team_stats = team_stats[columns_to_keep]

# Rearrange columns in the specified order
column_order = ['TEAM', 'NetRtg', 'OffRtg', 'DefRtg']
team_stats = team_stats[column_order]

# Identify numeric columns
numeric_cols = team_stats.select_dtypes(include=['number']).columns

# Define weights for grouped statistics (used ONLY during clustering)
weights = {
    'NetRtg': 1.0,  # Higher weight for NetRtg
    'OffRtg': 0.8,
    'DefRtg': 0.8
}

# Standardize numeric data for clustering
scaler = StandardScaler()
scaled_data = scaler.fit_transform(team_stats[numeric_cols])

# Apply weights to the standardized data (affects clustering only)
weighted_scaled_data = scaled_data.copy()
for i, col in enumerate(numeric_cols):
    if col in weights:
        weighted_scaled_data[:, i] *= weights[col]

# Elbow Method: Compute WCSS for different numbers of clusters
wcss = []
max_clusters = 30  # Test up to 30 clusters
for i in range(1, max_clusters + 1):
    with threadpool_limits(limits=1, user_api='blas'):  # Limit MKL threads
        kmeans = KMeans(n_clusters=i, random_state=42, n_init=10)
        kmeans.fit(weighted_scaled_data)  # Use weighted scaled data
        wcss.append(kmeans.inertia_)  # WCSS (Within-Cluster Sum of Squares)

# Plot the elbow method
plt.figure(figsize=(10, 6))
plt.plot(range(1, max_clusters + 1), wcss, marker='o', linestyle='--')
plt.title('Elbow Method for Optimal Number of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.xticks(range(1, max_clusters + 1))
plt.grid()
plt.show()

# Prompt user to enter the optimal number of clusters (based on the elbow chart)
optimal_clusters = int(input("Enter the optimal number of clusters (as observed from the elbow plot): "))

# Perform K-Means clustering
with threadpool_limits(limits=1, user_api='blas'):
    kmeans = KMeans(n_clusters=optimal_clusters, random_state=42, n_init=10)
    cluster_labels = kmeans.fit_predict(weighted_scaled_data)  # Use weighted scaled data

# Add cluster labels to the DataFrame
df_with_ranks = team_stats.copy()  # Use original data for display
df_with_ranks['Cluster'] = cluster_labels

# Sort the DataFrame by the Cluster column in ascending order
df_with_ranks = df_with_ranks.sort_values(by='Cluster', ascending=True).reset_index(drop=True)

# Calculate ranks for numeric columns
invert_cols = ['DefRtg']  # Columns where lower values are better
ranks_data = {}

for col in numeric_cols:
    if col in invert_cols:
        ranks = df_with_ranks[col].rank(ascending=True, method='min').astype(int)
    else:
        ranks = df_with_ranks[col].rank(ascending=False, method='min').astype(int)
    df_with_ranks[col] = df_with_ranks[col].astype(str) + ' (' + ranks.astype(str) + ')'
    ranks_data[col] = ranks  # Store ranks for conditional formatting

# Define luminance function for text readability
def luminance(color):
    rgb = mcolors.hex2color(color)
    return 0.2126 * rgb[0] + 0.7152 * rgb[1] + 0.0722 * rgb[2]

# Define color_cells function for conditional formatting
def color_cells(row):
    colors = []
    for col in numeric_cols:
        rank = ranks_data[col].loc[row.name]
        max_rank = ranks_data[col].max()
        min_rank = ranks_data[col].min()
        # Normalize rank to 0-1 scale for color mapping
        norm = (rank - min_rank) / (max_rank - min_rank) if max_rank != min_rank else 0.5
        color = mcolors.to_hex(plt.cm.RdYlGn(1 - norm))  # Best ranks in green
        text_color = 'white' if luminance(color) < 0.5 else 'black'
        colors.append(f"background-color: {color}; color: {text_color};")
    return colors

# Apply the coloring logic to the sorted DataFrame
styled_df = df_with_ranks.style.apply(color_cells, subset=numeric_cols, axis=1).format(precision=3)

# Rename clusters at the end
cluster_names = {
    0: "The Average", 
    1: "The Greats (Defensive Dynamos)", 
    2: "Good Offense, Bad Defense", 
    3: "The Greats (Offensive Juggernauts)", 
    4: "Bad Teams", 
    5: "I Can't Score, You Can't Score", 
    6: "Cellar Dwellers",
    7: "The Best of the Best"
}
df_with_ranks['Cluster'] = df_with_ranks['Cluster'].map(cluster_names)

# Display the styled DataFrame (sorted by clusters)
display(styled_df)

# Optional: Visualize the clusters using PCA
pca = PCA(n_components=2)
reduced_data = pca.fit_transform(weighted_scaled_data)  # Use weighted scaled data for visualization

plt.figure(figsize=(10, 6))
for cluster, cluster_name in cluster_names.items():
    cluster_points = reduced_data[cluster_labels == cluster]
    plt.scatter(cluster_points[:, 0], cluster_points[:, 1], label=cluster_name, s=100)  # Use names for the legend
plt.title('Cluster Visualization')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.legend()
plt.grid()
plt.show()
# Out:
# Enter the optimal number of clusters (as observed from the elbow plot): 8
# <style type="text/css">
# #T_fa9f5_row0_col1, #T_fa9f5_row17_col3 {
#   background-color: #c7e77f;
#   color: black;
# }
# #T_fa9f5_row0_col2, #T_fa9f5_row2_col3, #T_fa9f5_row6_col1 {
#   background-color: #d9ef8b;
#   color: black;
# }
# #T_fa9f5_row0_col3, #T_fa9f5_row5_col1, #T_fa9f5_row8_col2, #T_fa9f5_row13_col1 {
#   background-color: #f2faae;
#   color: black;
# }
# #T_fa9f5_row1_col1, #T_fa9f5_row1_col3, #T_fa9f5_row10_col1 {
#   background-color: #feea9b;
#   color: black;
# }
# #T_fa9f5_row1_col2, #T_fa9f5_row4_col2, #T_fa9f5_row19_col3, #T_fa9f5_row22_col3 {
#   background-color: #fee08b;
#   color: black;
# }
# #T_fa9f5_row2_col1, #T_fa9f5_row14_col2, #T_fa9f5_row18_col3 {
#   background-color: #a5d86a;
#   color: black;
# }
# #T_fa9f5_row2_col2, #T_fa9f5_row4_col1, #T_fa9f5_row6_col3, #T_fa9f5_row10_col2 {
#   background-color: #b7e075;
#   color: black;
# }
# #T_fa9f5_row3_col1, #T_fa9f5_row21_col2, #T_fa9f5_row23_col2, #T_fa9f5_row24_col3 {
#   background-color: #fff5ae;
#   color: black;
# }
# #T_fa9f5_row3_col2, #T_fa9f5_row3_col3 {
#   background-color: #feffbe;
#   color: black;
# }
# #T_fa9f5_row4_col3, #T_fa9f5_row8_col1, #T_fa9f5_row18_col2 {
#   background-color: #66bd63;
#   color: black;
# }
# #T_fa9f5_row5_col2, #T_fa9f5_row13_col3, #T_fa9f5_row24_col1 {
#   background-color: #fdad60;
#   color: black;
# }
# #T_fa9f5_row5_col3, #T_fa9f5_row9_col1, #T_fa9f5_row13_col2 {
#   background-color: #7ac665;
#   color: black;
# }
# #T_fa9f5_row6_col2, #T_fa9f5_row11_col1, #T_fa9f5_row26_col3 {
#   background-color: #e5f49b;
#   color: black;
# }
# #T_fa9f5_row7_col1, #T_fa9f5_row11_col2, #T_fa9f5_row27_col3 {
#   background-color: #199750;
#   color: white;
# }
# #T_fa9f5_row7_col2, #T_fa9f5_row9_col2, #T_fa9f5_row21_col1, #T_fa9f5_row25_col3 {
#   background-color: #f7814c;
#   color: black;
# }
# #T_fa9f5_row7_col3, #T_fa9f5_row17_col1, #T_fa9f5_row19_col2 {
#   background-color: #08773f;
#   color: white;
# }
# #T_fa9f5_row8_col3, #T_fa9f5_row15_col2, #T_fa9f5_row18_col1 {
#   background-color: #4bb05c;
#   color: black;
# }
# #T_fa9f5_row9_col3, #T_fa9f5_row12_col2, #T_fa9f5_row16_col1 {
#   background-color: #118848;
#   color: white;
# }
# #T_fa9f5_row10_col3, #T_fa9f5_row20_col1, #T_fa9f5_row22_col2, #T_fa9f5_row28_col1 {
#   background-color: #ea5739;
#   color: white;
# }
# #T_fa9f5_row11_col3, #T_fa9f5_row23_col1, #T_fa9f5_row26_col2 {
#   background-color: #d62f27;
#   color: white;
# }
# #T_fa9f5_row12_col1, #T_fa9f5_row16_col3, #T_fa9f5_row30_col2 {
#   background-color: #91d068;
#   color: black;
# }
# #T_fa9f5_row12_col3, #T_fa9f5_row15_col1, #T_fa9f5_row24_col2 {
#   background-color: #fa9857;
#   color: black;
# }
# #T_fa9f5_row14_col1 {
#   background-color: #fece7c;
#   color: black;
# }
# #T_fa9f5_row14_col3, #T_fa9f5_row29_col2 {
#   background-color: #e14430;
#   color: white;
# }
# #T_fa9f5_row15_col3, #T_fa9f5_row25_col1, #T_fa9f5_row27_col2 {
#   background-color: #b50f26;
#   color: white;
# }
# #T_fa9f5_row16_col2, #T_fa9f5_row19_col1, #T_fa9f5_row28_col3 {
#   background-color: #33a456;
#   color: black;
# }
# #T_fa9f5_row17_col2, #T_fa9f5_row30_col1, #T_fa9f5_row30_col3 {
#   background-color: #006837;
#   color: white;
# }
# #T_fa9f5_row20_col2, #T_fa9f5_row20_col3, #T_fa9f5_row27_col1 {
#   background-color: #fdbf6f;
#   color: black;
# }
# #T_fa9f5_row21_col3, #T_fa9f5_row26_col1 {
#   background-color: #f46d43;
#   color: black;
# }
# #T_fa9f5_row22_col1, #T_fa9f5_row23_col3, #T_fa9f5_row25_col2 {
#   background-color: #c62027;
#   color: white;
# }
# #T_fa9f5_row28_col2, #T_fa9f5_row29_col1, #T_fa9f5_row29_col3 {
#   background-color: #a50026;
#   color: white;
# }
# </style>
# <table id="T_fa9f5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fa9f5_level0_col0" class="col_heading level0 col0" >TEAM</th>
#       <th id="T_fa9f5_level0_col1" class="col_heading level0 col1" >NetRtg</th>
#       <th id="T_fa9f5_level0_col2" class="col_heading level0 col2" >OffRtg</th>
#       <th id="T_fa9f5_level0_col3" class="col_heading level0 col3" >DefRtg</th>
#       <th id="T_fa9f5_level0_col4" class="col_heading level0 col4" >Cluster</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa9f5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fa9f5_row0_col0" class="data row0 col0" >Osceola Magic</td>
#       <td id="T_fa9f5_row0_col1" class="data row0 col1" >1.5 (12)</td>
#       <td id="T_fa9f5_row0_col2" class="data row0 col2" >111.5 (13)</td>
#       <td id="T_fa9f5_row0_col3" class="data row0 col3" >110.0 (15)</td>
#       <td id="T_fa9f5_row0_col4" class="data row0 col4" >The Average</td>
#     </tr>
#     <tr>
#       <th id="T_fa9f5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fa9f5_row1_col0" class="data row1 col0" >Motor City Cruise</td>
#       <td id="T_fa9f5_row1_col1" class="data row1 col1" >-1.7 (18)</td>
#       <td id="T_fa9f5_row1_col2" class="data row1 col2" >109.3 (19)</td>
#       <td id="T_fa9f5_row1_col3" class="data row1 col3" >111.0 (18)</td>
#       <td id="T_fa9f5_row1_col4" class="data row1 col4" >The Average</td>
#     </tr>
#     <tr>
#       <th id="T_fa9f5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fa9f5_row2_col0" class="data row2 col0" >Long Island Nets</td>
#       <td id="T_fa9f5_row2_col1" class="data row2 col1" >2.0 (10)</td>
#       <td id="T_fa9f5_row2_col2" class="data row2 col2" >111.7 (11)</td>
#       <td id="T_fa9f5_row2_col3" class="data row2 col3" >109.7 (13)</td>
#       <td id="T_fa9f5_row2_col4" class="data row2 col4" >The Average</td>
#     </tr>
#     <tr>
#       <th id="T_fa9f5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fa9f5_row3_col0" class="data row3 col0" >Valley Suns</td>
#       <td id="T_fa9f5_row3_col1" class="data row3 col1" >-0.1 (17)</td>
#       <td id="T_fa9f5_row3_col2" class="data row3 col2" >110.0 (16)</td>
#       <td id="T_fa9f5_row3_col3" class="data row3 col3" >110.1 (16)</td>
#       <td id="T_fa9f5_row3_col4" class="data row3 col4" >The Average</td>
#     </tr>
#     <tr>
#       <th id="T_fa9f5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fa9f5_row4_col0" class="data row4 col0" >Greensboro Swarm</td>
#       <td id="T_fa9f5_row4_col1" class="data row4 col1" >1.7 (11)</td>
#       <td id="T_fa9f5_row4_col2" class="data row4 col2" >109.3 (19)</td>
#       <td id="T_fa9f5_row4_col3" class="data row4 col3" >107.6 (7)</td>
#       <td id="T_fa9f5_row4_col4" class="data row4 col4" >The Average</td>
#     </tr>
#     <tr>
#       <th id="T_fa9f5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fa9f5_row5_col0" class="data row5 col0" >Maine Celtics</td>
#       <td id="T_fa9f5_row5_col1" class="data row5 col1" >0.2 (15)</td>
#       <td id="T_fa9f5_row5_col2" class="data row5 col2" >108.5 (22)</td>
#       <td id="T_fa9f5_row5_col3" class="data row5 col3" >108.3 (8)</td>
#       <td id="T_fa9f5_row5_col4" class="data row5 col4" >The Average</td>
#     </tr>
#     <tr>
#       <th id="T_fa9f5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fa9f5_row6_col0" class="data row6 col0" >Sioux Falls Skyforce</td>
#       <td id="T_fa9f5_row6_col1" class="data row6 col1" >1.2 (13)</td>
#       <td id="T_fa9f5_row6_col2" class="data row6 col2" >110.6 (14)</td>
#       <td id="T_fa9f5_row6_col3" class="data row6 col3" >109.4 (11)</td>
#       <td id="T_fa9f5_row6_col4" class="data row6 col4" >The Average</td>
#     </tr>
#     <tr>
#       <th id="T_fa9f5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fa9f5_row7_col0" class="data row7 col0" >Ciudad de Mexico Capitanes</td>
#       <td id="T_fa9f5_row7_col1" class="data row7 col1" >4.8 (4)</td>
#       <td id="T_fa9f5_row7_col2" class="data row7 col2" >107.9 (24)</td>
#       <td id="T_fa9f5_row7_col3" class="data row7 col3" >103.1 (2)</td>
#       <td id="T_fa9f5_row7_col4" class="data row7 col4" >The Greats (Defensive Dynamos)</td>
#     </tr>
#     <tr>
#       <th id="T_fa9f5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fa9f5_row8_col0" class="data row8 col0" >College Park Skyhawks</td>
#       <td id="T_fa9f5_row8_col1" class="data row8 col1" >3.7 (7)</td>
#       <td id="T_fa9f5_row8_col2" class="data row8 col2" >110.1 (15)</td

# %% [markdown]
# ## Offense

# %% [markdown]
# ## Scoring

# %%
import os
import warnings
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from threadpoolctl import threadpool_limits
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import time
from IPython.display import display

# Suppress MKL-related warning
warnings.filterwarnings("ignore", message="KMeans is known to have a memory leak", category=UserWarning)

# Set environment variable for MKL threads (optional, but may help)
os.environ["OMP_NUM_THREADS"] = "1"

# Set up Selenium WebDriver
service = Service(r"C:\Users\PC\OneDrive\Documents\GitHub\chromedriver-win64\chromedriver.exe")  # Update with your path

#Mac file path
#"/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver"

#PC file path
#r"C:\Users\PC\OneDrive\Documents\GitHub\chromedriver-win64\chromedriver.exe"

options = Options()
options.add_argument('--headless')  # Run in headless mode
options.add_argument('--disable-gpu')
options.add_argument('--start-maximized')
driver = webdriver.Chrome(service=service, options=options)

# URL of the webpage to scrape
url = "https://stats.gleague.nba.com/teams/scoring/?sort=W&dir=-1&Season=2024-25&SeasonType=Regular%20Season"

# Load the webpage
driver.get(url)
time.sleep(10)  # Allow time for JavaScript to load

# Locate the table and extract its data
table_xpath = '//div[contains(@class, "nba-stat-table__overflow")]/table'
table_element = driver.find_element(By.XPATH, table_xpath)
table_html = table_element.get_attribute('outerHTML')
team_stats = pd.read_html(table_html)[0]  # Convert the table HTML into a pandas DataFrame
driver.quit()  # Close the WebDriver

# Standardize column names: replace non-breaking spaces and strip whitespace
team_stats.columns = team_stats.columns.str.replace('\xa0', ' ', regex=False).str.strip()

# Keep only the specified columns
columns_to_keep = [
    'TEAM', '%FGA 2PT', '%FGA 3PT', '%PTS PITP', '%PTS 2PT- MR', '%PTS 3PT' #%PTS 2PT
]
team_stats = team_stats[columns_to_keep]

# Identify numeric columns
numeric_cols = team_stats.select_dtypes(include=['number']).columns

# Standardize numeric data for clustering
scaler = StandardScaler()
scaled_data = scaler.fit_transform(team_stats[numeric_cols])  # Standardize the numeric data

# Define weights for clustering
weights = {
    '%FGA 2PT': 1.2,
    '%FGA 3PT': 1.2
}

# Apply weights to the standardized data for clustering
weighted_scaled_data = scaled_data.copy()
for i, col in enumerate(numeric_cols):
    if col in weights:
        weighted_scaled_data[:, i] *= weights[col]

# Elbow Method: Compute WCSS for different numbers of clusters
wcss = []
max_clusters = 30  # Test up to 30 clusters
for i in range(1, max_clusters + 1):
    with threadpool_limits(limits=1, user_api='blas'):  # Limit MKL threads
        kmeans = KMeans(n_clusters=i, random_state=42, n_init=10)
        kmeans.fit(weighted_scaled_data)  # Use weighted scaled data
        wcss.append(kmeans.inertia_)  # WCSS (Within-Cluster Sum of Squares)

# Plot the elbow method
plt.figure(figsize=(10, 6))
plt.plot(range(1, max_clusters + 1), wcss, marker='o', linestyle='--')
plt.title('Elbow Method for Optimal Number of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.xticks(range(1, max_clusters + 1))
plt.grid()
plt.show()

# Prompt user to enter the optimal number of clusters (based on the elbow chart)
optimal_clusters = int(input("Enter the optimal number of clusters (as observed from the elbow plot): "))

# Perform K-Means clustering
with threadpool_limits(limits=1, user_api='blas'):
    kmeans = KMeans(n_clusters=optimal_clusters, random_state=42, n_init=10)
    cluster_labels = kmeans.fit_predict(weighted_scaled_data)  # Use weighted scaled data

# Add cluster labels to the DataFrame
df_with_ranks = team_stats.copy()  # Use original data for display
df_with_ranks['Cluster'] = cluster_labels

# Sort the DataFrame by the Cluster column in ascending order
df_with_ranks = df_with_ranks.sort_values(by='Cluster', ascending=True).reset_index(drop=True)

# Calculate ranks for numeric columns
ranks_data = {}
for col in numeric_cols:
    ranks = df_with_ranks[col].rank(ascending=False, method='min').astype(int)  # Higher is better for all columns
    df_with_ranks[col] = df_with_ranks[col].astype(str) + ' (' + ranks.astype(str) + ')'
    ranks_data[col] = ranks  # Store ranks for conditional formatting

# Define luminance function for text readability
def luminance(color):
    rgb = mcolors.hex2color(color)
    return 0.2126 * rgb[0] + 0.7152 * rgb[1] + 0.0722 * rgb[2]

# Define color_cells function for conditional formatting
def color_cells(row):
    colors = []
    for col in numeric_cols:
        rank = ranks_data[col].loc[row.name]
        max_rank = ranks_data[col].max()
        min_rank = ranks_data[col].min()
        # Normalize rank to 0-1 scale for color mapping
        norm = (rank - min_rank) / (max_rank - min_rank) if max_rank != min_rank else 0.5
        color = mcolors.to_hex(plt.cm.RdYlGn(1 - norm))  # Best ranks in green
        text_color = 'white' if luminance(color) < 0.5 else 'black'
        colors.append(f"background-color: {color}; color: {text_color};")
    return colors

# Apply the coloring logic to the sorted DataFrame
styled_df = df_with_ranks.style.apply(color_cells, subset=numeric_cols, axis=1).format(precision=3)

# Rename clusters at the end
cluster_names = {
    0: "Three Point Focus", 
    1: "90's Basketball (Two Point Heavy)", 
    2: "Midrange Assassin's", 
    3: "Low Midrange Shooting Teams", 
    4: "Three Point Snipers", 
    5: "Two Point Focus" 
}
df_with_ranks['Cluster'] = df_with_ranks['Cluster'].map(cluster_names)

# Display the styled DataFrame (sorted by clusters)
display(styled_df)

# Optional: Visualize the clusters using PCA
pca = PCA(n_components=2)
reduced_data = pca.fit_transform(weighted_scaled_data)  # Use weighted scaled data for visualization

plt.figure(figsize=(10, 6))
for cluster in range(optimal_clusters):
    cluster_points = reduced_data[cluster_labels == cluster]
    plt.scatter(cluster_points[:, 0], cluster_points[:, 1], label=f"Cluster {cluster}", s=100)  # Use cluster number in legend
plt.title('Cluster Visualization')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.legend()
plt.grid()
plt.show()
# Out:
# Enter the optimal number of clusters (as observed from the elbow plot): 6
# <style type="text/css">
# #T_256d0_row0_col1, #T_256d0_row4_col3, #T_256d0_row12_col3, #T_256d0_row18_col5, #T_256d0_row26_col2 {
#   background-color: #feea9b;
#   color: black;
# }
# #T_256d0_row0_col2, #T_256d0_row20_col3, #T_256d0_row26_col1, #T_256d0_row30_col4 {
#   background-color: #e5f49b;
#   color: black;
# }
# #T_256d0_row0_col3, #T_256d0_row5_col1, #T_256d0_row7_col1, #T_256d0_row7_col3, #T_256d0_row11_col2, #T_256d0_row25_col5 {
#   background-color: #fdbf6f;
#   color: black;
# }
# #T_256d0_row0_col4, #T_256d0_row5_col2, #T_256d0_row7_col2, #T_256d0_row14_col3, #T_256d0_row17_col5, #T_256d0_row25_col1 {
#   background-color: #a5d86a;
#   color: black;
# }
# #T_256d0_row0_col5, #T_256d0_row1_col2, #T_256d0_row12_col1, #T_256d0_row15_col4, #T_256d0_row16_col2, #T_256d0_row16_col3, #T_256d0_row29_col3 {
#   background-color: #4bb05c;
#   color: black;
# }
# #T_256d0_row1_col1, #T_256d0_row10_col2, #T_256d0_row12_col5, #T_256d0_row16_col1, #T_256d0_row23_col3, #T_256d0_row23_col4 {
#   background-color: #f46d43;
#   color: black;
# }
# #T_256d0_row1_col3, #T_256d0_row6_col1, #T_256d0_row11_col5, #T_256d0_row16_col4, #T_256d0_row20_col4, #T_256d0_row28_col2 {
#   background-color: #e14430;
#   color: white;
# }
# #T_256d0_row1_col4, #T_256d0_row2_col2, #T_256d0_row3_col1, #T_256d0_row4_col1, #T_256d0_row6_col4, #T_256d0_row21_col4, #T_256d0_row28_col5 {
#   background-color: #fee08b;
#   color: black;
# }
# #T_256d0_row1_col5, #T_256d0_row3_col4, #T_256d0_row5_col5, #T_256d0_row15_col3, #T_256d0_row19_col2, #T_256d0_row30_col1 {
#   background-color: #7ac665;
#   color: black;
# }
# #T_256d0_row2_col1, #T_256d0_row6_col5, #T_256d0_row8_col4, #T_256d0_row10_col3, #T_256d0_row13_col5 {
#   background-color: #d9ef8b;
#   color: black;
# }
# #T_256d0_row2_col3, #T_256d0_row15_col2, #T_256d0_row18_col4, #T_256d0_row24_col1 {
#   background-color: #c62027;
#   color: white;
# }
# #T_256d0_row2_col4, #T_256d0_row13_col1, #T_256d0_row19_col3, #T_256d0_row20_col2 {
#   background-color: #91d068;
#   color: black;
# }
# #T_256d0_row2_col5, #T_256d0_row6_col2, #T_256d0_row13_col4, #T_256d0_row28_col1, #T_256d0_row30_col3 {
#   background-color: #33a456;
#   color: black;
# }
# #T_256d0_row3_col2, #T_256d0_row3_col5, #T_256d0_row4_col2, #T_256d0_row26_col4, #T_256d0_row28_col3, #T_256d0_row29_col1 {
#   background-color: #c7e77f;
#   color: black;
# }
# #T_256d0_row3_col3, #T_256d0_row19_col1, #T_256d0_row27_col5, #T_256d0_row28_col4, #T_256d0_row30_col2 {
#   background-color: #f7814c;
#   color: black;
# }
# #T_256d0_row4_col4, #T_256d0_row4_col5, #T_256d0_row11_col1, #T_256d0_row27_col3 {
#   background-color: #b7e075;
#   color: black;
# }
# #T_256d0_row5_col3, #T_256d0_row8_col2, #T_256d0_row15_col5, #T_256d0_row19_col4, #T_256d0_row23_col1 {
#   background-color: #b50f26;
#   color: white;
# }
# #T_256d0_row5_col4, #T_256d0_row10_col1, #T_256d0_row20_col5 {
#   background-color: #66bd63;
#   color: black;
# }
# #T_256d0_row6_col3, #T_256d0_row13_col2, #T_256d0_row20_col1, #T_256d0_row25_col4, #T_256d0_row29_col5 {
#   background-color: #fa9857;
#   color: black;
# }
# #T_256d0_row7_col4, #T_256d0_row13_col3, #T_256d0_row16_col5, #T_256d0_row27_col2, #T_256d0_row29_col4 {
#   background-color: #fff5ae;
#   color: black;
# }
# #T_256d0_row7_col5, #T_256d0_row9_col4, #T_256d0_row17_col2, #T_256d0_row18_col2, #T_256d0_row22_col4, #T_256d0_row26_col3, #T_256d0_row27_col1 {
#   background-color: #f2faae;
#   color: black;
# }
# #T_256d0_row8_col1, #T_256d0_row9_col3, #T_256d0_row11_col4, #T_256d0_row23_col2, #T_256d0_row24_col5 {
#   background-color: #08773f;
#   color: white;
# }
# #T_256d0_row8_col3, #T_256d0_row9_col1, #T_256d0_row12_col4, #T_256d0_row22_col2, #T_256d0_row22_col5 {
#   background-color: #006837;
#   color: white;
# }
# #T_256d0_row8_col5, #T_256d0_row14_col2, #T_256d0_row14_col5, #T_256d0_row21_col1, #T_256d0_row21_col3 {
#   background-color: #d62f27;
#   color: white;
# }
# #T_256d0_row9_col2, #T_256d0_row9_col5, #T_256d0_row17_col4, #T_256d0_row22_col1, #T_256d0_row22_col3 {
#   background-color: #a50026;
#   color: white;
# }
# #T_256d0_row10_col4, #T_256d0_row14_col1, #T_256d0_row21_col2, #T_256d0_row21_col5, #T_256d0_row25_col3 {
#   background-color: #199750;
#   color: white;
# }
# #T_256d0_row10_col5, #T_256d0_row11_col3, #T_256d0_row29_col2 {
#   background-color: #fece7c;
#   color: black;
# }
# #T_256d0_row12_col2, #T_256d0_row24_col3, #T_256d0_row24_col4, #T_256d0_row30_col5 {
#   background-color: #ea5739;
#   color: white;
# }
# #T_256d0_row14_col4, #T_256d0_row15_col1, #T_256d0_row18_col3, #T_256d0_row23_col5, #T_256d0_row24_col2 {
#   background-color: #118848;
#   color: white;
# }
# #T_256d0_row17_col1, #T_256d0_row17_col3, #T_256d0_row18_col1, #T_256d0_row19_col5 {
#   background-color: #feffbe;
#   color: black;
# }
# #T_256d0_row25_col2, #T_256d0_row26_col5, #T_256d0_row27_col4 {
#   background-color: #fdad60;
#   color: black;
# }
# </style>
# <table id="T_256d0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_256d0_level0_col0" class="col_heading level0 col0" >TEAM</th>
#       <th id="T_256d0_level0_col1" class="col_heading level0 col1" >%FGA 2PT</th>
#       <th id="T_256d0_level0_col2" class="col_heading level0 col2" >%FGA 3PT</th>
#       <th id="T_256d0_level0_col3" class="col_heading level0 col3" >%PTS PITP</th>
#       <th id="T_256d0_level0_col4" class="col_heading level0 col4" >%PTS 2PT- MR</th>
#       <th id="T_256d0_level0_col5" class="col_heading level0 col5" >%PTS 3PT</th>
#       <th id="T_256d0_level0_col6" class="col_heading level0 col6" >Cluster</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_256d0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_256d0_row0_col0" class="data row0 col0" >Stockton Kings</td>
#       <td id="T_256d0_row0_col1" class="data row0 col1" >57.2 (18)</td>
#       <td id="T_256d0_row0_col2" class="data row0 col2" >42.8 (14)</td>
#       <td id="T_256d0_row0_col3" class="data row0 col3" >43.7 (21)</td>
#       <td id="T_256d0_row0_col4" class="data row0 col4" >4.9 (10)</td>
#       <td id="T_256d0_row0_col5" class="data row0 col5" >38.4 (6)</td>
#       <td id="T_256d0_row0_col6" class="data row0 col6" >Three Point Focus</td>
#     </tr>
#     <tr>
#       <th id="T_256d0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_256d0_row1_col0" class="data row1 col0" >Salt Lake City Stars</td>
#       <td id="T_256d0_row1_col1" class="data row1 col1" >55.1 (25)</td>
#       <td id="T_256d0_row1_col2" class="data row1 col2" >44.9 (6)</td>
#       <td id="T_256d0_row1_col3" class="data row1 col3" >41.9 (27)</td>
#       <td id="T_256d0_row1_col4" class="data row1 col4" >3.9 (19)</td>
#       <td id="T_256d0_row1_col5" class="data row1 col5" >37.4 (8)</td>
#       <td id="T_256d0_row1_col6" class="data row1 col6" >Three Point Focus</td>
#     </tr>
#     <tr>
#       <th id="T_256d0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_256d0_row2_col0" class="data row2 col0" >Wisconsin Herd</td>
#       <td id="T_256d0_row2_col1" class="data row2 col1" >58.4 (13)</td>
#       <td id="T_256d0_row2_col2" class="data row2 col2" >41.6 (19)</td>
#       <td id="T_256d0_row2_col3" class="data row2 col3" >40.6 (29)</td>
#       <td id="T_256d0_row2_col4" class="data row2 col4" >5.4 (9)</td>
#       <td id="T_256d0_row2_col5" class="data row2 col5" >38.6 (5)</td>
#       <td id="T_256d0_row2_col6" class="data row2 col6" >Three Point Focus</td>
#     </tr>
#     <tr>
#       <th id="T_256d0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_256d0_row3_col0" class="data row3 col0" >Santa Cruz Warriors</td>
#       <td id="T_256d0_row3_col1" class="data row3 col1" >56.4 (19)</td>
#       <td id="T_256d0_row3_col2" class="data row3 col2" >43.6 (12)</td>
#       <td id="T_256d0_row3_col3" class="data row3 col3" >42.7 (24)</td>
#       <td id="T_256d0_row3_col4" class="data row3 col4" >5.6 (8)</td>
#       <td id="T_256d0_row3_col5" class="data row3 col5" >36.5 (12)</td>
#       <td id="T_256d0_row3_col6" class="data row3 col6" >Three Point Focus</td>
#     </tr>
#     <tr>
#       <th id="T_256d0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_256d0_row4_col0" class="data row4 col0"

# %% [markdown]
# ### Scoring Part II (So far ineffective)

# %%
import os
import warnings
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from threadpoolctl import threadpool_limits
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import time
from IPython.display import display

# Suppress MKL-related warning
warnings.filterwarnings("ignore", message="KMeans is known to have a memory leak", category=UserWarning)

# Set environment variable for MKL threads (optional, but may help)
os.environ["OMP_NUM_THREADS"] = "1"

# Set up Selenium WebDriver
service = Service("/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver")  # Update with your path

#Mac file path
#"/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver"

#PC file path
#r"C:\Users\PC\OneDrive\Documents\GitHub\chromedriver-win64\chromedriver.exe"

options = Options()
options.add_argument('--headless')  # Run in headless mode
options.add_argument('--disable-gpu')
options.add_argument('--start-maximized')
driver = webdriver.Chrome(service=service, options=options)

# URL of the webpage to scrape
url = "https://stats.gleague.nba.com/teams/scoring/?sort=W&dir=-1&Season=2024-25&SeasonType=Regular%20Season"

# Load the webpage
driver.get(url)
time.sleep(10)  # Allow time for JavaScript to load

# Locate the table and extract its data
table_xpath = '//div[contains(@class, "nba-stat-table__overflow")]/table'
table_element = driver.find_element(By.XPATH, table_xpath)
table_html = table_element.get_attribute('outerHTML')
team_stats = pd.read_html(table_html)[0]  # Convert the table HTML into a pandas DataFrame
driver.quit()  # Close the WebDriver

# Standardize column names: replace non-breaking spaces and strip whitespace
team_stats.columns = team_stats.columns.str.replace('\xa0', ' ', regex=False).str.strip()

# Keep only the specified columns
columns_to_keep = [
    'TEAM', '%PTS FBPs','%PTS FT', '%PTS OffTO'
]

#'2FGM %AST', '2FGM %UAST', '3FGM %AST','3FGM %UAST', 'FGM %AST', 'FGM %UAST'

team_stats = team_stats[columns_to_keep]

# Identify numeric columns
numeric_cols = team_stats.select_dtypes(include=['number']).columns

# Standardize numeric data for clustering
scaler = StandardScaler()
scaled_data = scaler.fit_transform(team_stats[numeric_cols])  # Standardize the numeric data

# Elbow Method: Compute WCSS for different numbers of clusters
wcss = []
max_clusters = 30  # Test up to 30 clusters
for i in range(1, max_clusters + 1):
    with threadpool_limits(limits=1, user_api='blas'):  # Limit MKL threads
        kmeans = KMeans(n_clusters=i, random_state=42, n_init=10)
        kmeans.fit(scaled_data)  # Use scaled data
        wcss.append(kmeans.inertia_)  # WCSS (Within-Cluster Sum of Squares)

# Plot the elbow method
plt.figure(figsize=(10, 6))
plt.plot(range(1, max_clusters + 1), wcss, marker='o', linestyle='--')
plt.title('Elbow Method for Optimal Number of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.xticks(range(1, max_clusters + 1))
plt.grid()
plt.show()

# Prompt user to enter the optimal number of clusters (based on the elbow chart)
optimal_clusters = int(input("Enter the optimal number of clusters (as observed from the elbow plot): "))

# Perform K-Means clustering
with threadpool_limits(limits=1, user_api='blas'):
    kmeans = KMeans(n_clusters=optimal_clusters, random_state=42, n_init=10)
    cluster_labels = kmeans.fit_predict(scaled_data)  # Use scaled data

# Add cluster labels to the DataFrame
df_with_ranks = team_stats.copy()  # Use original data for display
df_with_ranks['Cluster'] = cluster_labels

# Sort the DataFrame by the Cluster column in ascending order
df_with_ranks = df_with_ranks.sort_values(by='Cluster', ascending=True).reset_index(drop=True)

# Calculate ranks for numeric columns
ranks_data = {}
for col in numeric_cols:
    ranks = df_with_ranks[col].rank(ascending=False, method='min').astype(int)  # Higher is better for all columns
    df_with_ranks[col] = df_with_ranks[col].astype(str) + ' (' + ranks.astype(str) + ')'
    ranks_data[col] = ranks  # Store ranks for conditional formatting

# Define luminance function for text readability
def luminance(color):
    rgb = mcolors.hex2color(color)
    return 0.2126 * rgb[0] + 0.7152 * rgb[1] + 0.0722 * rgb[2]

# Define color_cells function for conditional formatting
def color_cells(row):
    colors = []
    for col in numeric_cols:
        rank = ranks_data[col].loc[row.name]
        max_rank = ranks_data[col].max()
        min_rank = ranks_data[col].min()
        # Normalize rank to 0-1 scale for color mapping
        norm = (rank - min_rank) / (max_rank - min_rank) if max_rank != min_rank else 0.5
        color = mcolors.to_hex(plt.cm.RdYlGn(1 - norm))  # Best ranks in green
        text_color = 'white' if luminance(color) < 0.5 else 'black'
        colors.append(f"background-color: {color}; color: {text_color};")
    return colors

# Apply the coloring logic to the sorted DataFrame
styled_df = df_with_ranks.style.apply(color_cells, subset=numeric_cols, axis=1).format(precision=3)

# Rename clusters at the end
cluster_names = {
    0: "Low FBPs, Low FT Points", 
    1: "Elite PTS OffTO, Good PTS FT, Good FBPs", 
    2: "Good FBPs, Bad PTS FTs, High Points OffTO", 
    3: "Average to Good FBPs, Good Points Off FT", 
    4: "Elite PTS OffTO, Bad PTS OffTO, and Bad PTS Off FT", 
    5: "Good FBPs, Good FT Points Elite, PTS OffTO", 
    6: "Mediocre",
    7: "b",
}
df_with_ranks['Cluster'] = df_with_ranks['Cluster'].map(cluster_names)

# Display the styled DataFrame (sorted by clusters)
display(styled_df)

# Optional: Visualize the clusters using PCA
pca = PCA(n_components=2)
reduced_data = pca.fit_transform(scaled_data)  # Use scaled data for visualization

plt.figure(figsize=(10, 6))
for cluster in range(optimal_clusters):
    cluster_points = reduced_data[cluster_labels == cluster]
    plt.scatter(cluster_points[:, 0], cluster_points[:, 1], label=f"Cluster {cluster}", s=100)  # Use cluster number in legend
plt.title('Cluster Visualization')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.legend()
plt.grid()
plt.show()
# Out:
# Enter the optimal number of clusters (as observed from the elbow plot): 10
# <style type="text/css">
# #T_1ccd9_row0_col1, #T_1ccd9_row12_col1 {
#   background-color: #c7e77f;
#   color: black;
# }
# #T_1ccd9_row0_col2, #T_1ccd9_row7_col2, #T_1ccd9_row7_col3, #T_1ccd9_row9_col1, #T_1ccd9_row19_col1 {
#   background-color: #c62027;
#   color: white;
# }
# #T_1ccd9_row0_col3, #T_1ccd9_row13_col1 {
#   background-color: #f2faae;
#   color: black;
# }
# #T_1ccd9_row1_col1, #T_1ccd9_row26_col3 {
#   background-color: #33a456;
#   color: black;
# }
# #T_1ccd9_row1_col2, #T_1ccd9_row10_col1, #T_1ccd9_row30_col3 {
#   background-color: #a50026;
#   color: white;
# }
# #T_1ccd9_row1_col3, #T_1ccd9_row12_col2, #T_1ccd9_row29_col1 {
#   background-color: #66bd63;
#   color: black;
# }
# #T_1ccd9_row2_col1, #T_1ccd9_row17_col2, #T_1ccd9_row22_col3 {
#   background-color: #4bb05c;
#   color: black;
# }
# #T_1ccd9_row2_col2, #T_1ccd9_row3_col3, #T_1ccd9_row4_col1, #T_1ccd9_row13_col3, #T_1ccd9_row19_col2, #T_1ccd9_row20_col1, #T_1ccd9_row20_col2 {
#   background-color: #fee08b;
#   color: black;
# }
# #T_1ccd9_row2_col3, #T_1ccd9_row27_col2 {
#   background-color: #d9ef8b;
#   color: black;
# }
# #T_1ccd9_row3_col1, #T_1ccd9_row11_col3, #T_1ccd9_row15_col2 {
#   background-color: #7ac665;
#   color: black;
# }
# #T_1ccd9_row3_col2, #T_1ccd9_row21_col2, #T_1ccd9_row28_col3 {
#   background-color: #fa9857;
#   color: black;
# }
# #T_1ccd9_row4_col2, #T_1ccd9_row23_col3, #T_1ccd9_row28_col1 {
#   background-color: #006837;
#   color: white;
# }
# #T_1ccd9_row4_col3, #T_1ccd9_row9_col2, #T_1ccd9_row17_col1, #T_1ccd9_row24_col1 {
#   background-color: #08773f;
#   color: white;
# }
# #T_1ccd9_row5_col1, #T_1ccd9_row16_col3, #T_1ccd9_row18_col1 {
#   background-color: #feffbe;
#   color: black;
# }
# #T_1ccd9_row5_col2, #T_1ccd9_row6_col1, #T_1ccd9_row12_col3, #T_1ccd9_row22_col1 {
#   background-color: #fdad60;
#   color: black;
# }
# #T_1ccd9_row5_col3, #T_1ccd9_row21_col1 {
#   background-color: #f7814c;
#   color: black;
# }
# #T_1ccd9_row6_col2, #T_1ccd9_row7_col1, #T_1ccd9_row18_col3 {
#   background-color: #e14430;
#   color: white;
# }
# #T_1ccd9_row6_col3, #T_1ccd9_row8_col1, #T_1ccd9_row8_col2, #T_1ccd9_row29_col2 {
#   background-color: #f46d43;
#   color: black;
# }
# #T_1ccd9_row8_col3, #T_1ccd9_row23_col1 {
#   background-color: #fdbf6f;
#   color: black;
# }
# #T_1ccd9_row9_col3, #T_1ccd9_row24_col2 {
#   background-color: #a5d86a;
#   color: black;
# }
# #T_1ccd9_row10_col2, #T_1ccd9_row18_col2, #T_1ccd9_row25_col3, #T_1ccd9_row27_col1 {
#   background-color: #199750;
#   color: white;
# }
# #T_1ccd9_row10_col3, #T_1ccd9_row13_col2, #T_1ccd9_row14_col1, #T_1ccd9_row16_col1 {
#   background-color: #91d068;
#   color: black;
# }
# #T_1ccd9_row11_col1, #T_1ccd9_row15_col3 {
#   background-color: #ea5739;
#   color: white;
# }
# #T_1ccd9_row11_col2, #T_1ccd9_row24_col3 {
#   background-color: #118848;
#   color: white;
# }
# #T_1ccd9_row14_col2, #T_1ccd9_row16_col2, #T_1ccd9_row21_col3, #T_1ccd9_row26_col1, #T_1ccd9_row30_col2 {
#   background-color: #e5f49b;
#   color: black;
# }
# #T_1ccd9_row14_col3, #T_1ccd9_row19_col3, #T_1ccd9_row25_col1, #T_1ccd9_row25_col2, #T_1ccd9_row26_col2 {
#   background-color: #b7e075;
#   color: black;
# }
# #T_1ccd9_row15_col1, #T_1ccd9_row17_col3, #T_1ccd9_row22_col2 {
#   background-color: #feea9b;
#   color: black;
# }
# #T_1ccd9_row20_col3, #T_1ccd9_row28_col2 {
#   background-color: #fff5ae;
#   color: black;
# }
# #T_1ccd9_row23_col2, #T_1ccd9_row27_col3, #T_1ccd9_row30_col1 {
#   background-color: #d62f27;
#   color: white;
# }
# #T_1ccd9_row29_col3 {
#   background-color: #b50f26;
#   color: white;
# }
# </style>
# <table id="T_1ccd9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1ccd9_level0_col0" class="col_heading level0 col0" >TEAM</th>
#       <th id="T_1ccd9_level0_col1" class="col_heading level0 col1" >%PTS FBPs</th>
#       <th id="T_1ccd9_level0_col2" class="col_heading level0 col2" >%PTS FT</th>
#       <th id="T_1ccd9_level0_col3" class="col_heading level0 col3" >%PTS OffTO</th>
#       <th id="T_1ccd9_level0_col4" class="col_heading level0 col4" >Cluster</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ccd9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1ccd9_row0_col0" class="data row0 col0" >Windy City Bulls</td>
#       <td id="T_1ccd9_row0_col1" class="data row0 col1" >13.5 (12)</td>
#       <td id="T_1ccd9_row0_col2" class="data row0 col2" >7.5 (29)</td>
#       <td id="T_1ccd9_row0_col3" class="data row0 col3" >17.1 (15)</td>
#       <td id="T_1ccd9_row0_col4" class="data row0 col4" >Low FBPs, Low FT Points</td>
#     </tr>
#     <tr>
#       <th id="T_1ccd9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1ccd9_row1_col0" class="data row1 col0" >Texas Legends</td>
#       <td id="T_1ccd9_row1_col1" class="data row1 col1" >14.8 (5)</td>
#       <td id="T_1ccd9_row1_col2" class="data row1 col2" >7.3 (31)</td>
#       <td id="T_1ccd9_row1_col3" class="data row1 col3" >18.4 (7)</td>
#       <td id="T_1ccd9_row1_col4" class="data row1 col4" >Low FBPs, Low FT Points</td>
#     </tr>
#     <tr>
#       <th id="T_1ccd9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1ccd9_row2_col0" class="data row2 col0" >College Park Skyhawks</td>
#       <td id="T_1ccd9_row2_col1" class="data row2 col1" >14.7 (6)</td>
#       <td id="T_1ccd9_row2_col2" class="data row2 col2" >8.6 (19)</td>
#       <td id="T_1ccd9_row2_col3" class="data row2 col3" >17.3 (13)</td>
#       <td id="T_1ccd9_row2_col4" class="data row2 col4" >Low FBPs, Low FT Points</td>
#     </tr>
#     <tr>
#       <th id="T_1ccd9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1ccd9_row3_col0" class="data row3 col0" >Motor City Cruise</td>
#       <td id="T_1ccd9_row3_col1" class="data row3 col1" >14.2 (8)</td>
#       <td id="T_1ccd9_row3_col2" class="data row3 col2" >8.3 (23)</td>
#       <td id="T_1ccd9_row3_col3" class="data row3 col3" >16.7 (19)</td>
#       <td id="T_1ccd9_row3_col4" class="data row3 col4" >Low FBPs, Low FT Points</td>
#     </tr>
#     <tr>
#       <th id="T_1ccd9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1ccd9_row4_col0" class="data row4 col0" >Delaware Blue Coats</td>
#       <td id="T_1ccd9_row4_col1" class="data row4 col1" >11.5 (19)</td>
#       <td id="T_1ccd9_row4_col2" class="data row4 col2" >11.0 (1)</td>
#       <td id="T_1ccd9_row4_col3" class="data row4 col3" >20.8 (2)</td>
#       <td id="T_1ccd9_row4_col4" class="data row4 col4" >Elite PTS OffTO, Good PTS FT, Good FBPs</td>
#     </tr>
#     <tr>
#       <th id="T_1ccd9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1ccd9_row5_col0" class="data row5 col0" >Stockton Kings</td>
#       <td id="T_1ccd9_row5_col1" class="data row5 col1" >12.7 (16)</td>
#       <td id="T_1ccd9_row5_col2" class="data row5 col2" >8.4 (22)</td>
#       <td id="T_1ccd9_row5_col3" class="data row5 col3" >15.5 (24)</td>
#       <td id="T_1ccd9_row5_col4" class="data row5 col4" >Good FBPs, Bad PTS FTs, High Points OffTO</td>
#     </tr>
#     <tr>
#       <th id="T_1ccd9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1ccd9_row6_col0" class="data row6 col0" >Valley Suns</td>
#       <td id="T_1ccd9_row6_col1" class="data row6 col1" >11.1 (22)</td>
#       <td id="T_1ccd9_row6_col2" class="data row6 col2" >8.0 (27)</td>
#       <td id="T_1ccd9_row6_col3" class="data row6 col3" >15.4 (25)</td>
#       <td id="T_1ccd9_row6_col4" class="data row6 col4" >Good FBPs, Bad PTS FTs, High Points OffTO</td>
#     </tr>
#     <tr>
#       <th id="T_1ccd9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1ccd9_row7_col0" class="data row7 col0" >Birmingham Squadron</td>
#       <td id="T_1ccd9_row7_col1" class="data row7 col1" >10.4 (27)</td>
#       <td id="T_1ccd9_row7_col2" class="data row7 col2" >7.5 (29)</td>
#       <td id="T_1ccd9_row7_col3" class="data row7 col3" >14.3 (29)</td>
#       <td id="T_1ccd9_row7_col4" class="data row7 col4" >Good FBPs, Bad PTS FTs, High Points OffTO</td>
#     </tr>
#     <tr>
#       <th id="T_1ccd9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1ccd9_row8_col0" class="data row8 col0" >Grand Rapids Gold</td>
#       <td id="T_1ccd9_row8_col1" class="data row8 col1" >10

# %% [markdown]
# ### Shooting

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from threadpoolctl import threadpool_limits
import warnings

# Suppress MKL-related warning
warnings.filterwarnings("ignore", message="KMeans is known to have a memory leak", category=UserWarning)

# Define the URL for the data request
url = "https://stats.gleague.nba.com/stats/leaguedashteamshotlocations"

# Define the headers for the network request
headers = {
    "Host": "stats.gleague.nba.com",
    "Connection": "keep-alive",
    "Accept": "application/json, text/plain, */*",
    "x-nba-stats-token": "true",
    "x-nba-stats-origin": "stats",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36",
    "Origin": "https://stats.gleague.nba.com",
    "Referer": "https://stats.gleague.nba.com/",
}

# Define the query parameters for "By Zone"
params = {
    "Conference": "",
    "DateFrom": "",
    "DateTo": "",
    "DistanceRange": "By Zone",
    "Division": "",
    "GameScope": "",
    "GameSegment": "",
    "LastNGames": "0",
    "LeagueID": "20",
    "Location": "",
    "MeasureType": "Base",
    "Month": "0",
    "OpponentTeamID": "0",
    "Outcome": "",
    "PORound": "0",
    "PaceAdjust": "N",
    "PerMode": "PerGame",
    "Period": "0",
    "PlayerExperience": "",
    "PlayerPosition": "",
    "PlusMinus": "N",
    "Rank": "N",
    "Season": "2024-25",
    "SeasonSegment": "",
    "SeasonType": "Regular Season",
    "ShotClockRange": "",
    "StarterBench": "",
    "TeamID": "0",
    "VsConference": "",
    "VsDivision": "",
}

# Send the GET request
response = requests.get(url, headers=headers, params=params)

# Verify if the request was successful
if response.status_code == 200:
    data = response.json()

    # Extract the relevant data
    result_set = data["resultSets"]["rowSet"]
    lower_level_columns = data["resultSets"]["headers"][1]["columnNames"]  # Lower-level columns (FGM, FGA, FG%)
    top_level_columns = data["resultSets"]["headers"][0]["columnNames"]  # Top-level columns (Shot categories)

    # Convert to a DataFrame
    team_stats = pd.DataFrame(result_set, columns=lower_level_columns)

    # Drop the TEAM_ID column
    if "TEAM_ID" in team_stats.columns:
        team_stats = team_stats.drop(columns=["TEAM_ID"])

    # Rename FG_PCT to FG% and TEAM_NAME to TEAM
    team_stats = team_stats.rename(columns=lambda x: x.replace("FG_PCT", "FG%") if "FG_PCT" in x else x)
    team_stats = team_stats.rename(columns={"TEAM_NAME": "TEAM"})

    # Drop the FGM columns for each shot category
    # Each shot category has 3 columns: FGM, FGA, FG%
    # We drop the FGM columns (every 3rd column starting from index 2)
    fgm_columns = [col for i, col in enumerate(team_stats.columns) if (i - 2) % 3 == 0]
    team_stats = team_stats.drop(columns=fgm_columns)

    # Create the MultiIndex columns
    # Each shot category has 2 columns (FGA, FG%) since we dropped FGM
    top_level = []
    lower_level = []
    for i, category in enumerate(top_level_columns):
        top_level.extend([category] * 2)  # Repeat each category 2 times (for FGA and FG%)
        lower_level.extend(["FGA", "FG%"])

    # Add the TEAM column to the MultiIndex
    top_level.insert(0, " ")  # Top-level for TEAM
    lower_level.insert(0, "TEAM")  # Lower-level for TEAM

    # Apply the MultiIndex to the DataFrame
    team_stats.columns = pd.MultiIndex.from_tuples(zip(top_level, lower_level))

    # Drop the "Left Corner 3", "Right Corner 3", and "Backcourt" columns
    zones_to_drop = ["Left Corner 3", "Right Corner 3", "Backcourt"]
    for zone in zones_to_drop:
        if zone in team_stats.columns.levels[0]:  # Check if the zone exists in the top-level columns
            team_stats = team_stats.drop(columns=zone, level=0)

    # Prepare data for clustering
    # Exclude the TEAM column and use all other columns
    numeric_cols = [col for col in team_stats.columns if col[1] in ["FGA", "FG%"]]
    clustering_data = team_stats[numeric_cols].astype(float)

    # Standardize the data
    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(clustering_data)

    # Elbow Method: Compute WCSS for different numbers of clusters
    wcss = []
    max_clusters = 30  # Test up to 30 clusters
    for i in range(1, max_clusters + 1):
        with threadpool_limits(limits=1, user_api='blas'):  # Limit MKL threads
            kmeans = KMeans(n_clusters=i, random_state=42, n_init=10)
            kmeans.fit(scaled_data)
            wcss.append(kmeans.inertia_)  # WCSS (Within-Cluster Sum of Squares)

    # Plot the elbow method
    plt.figure(figsize=(10, 6))
    plt.plot(range(1, max_clusters + 1), wcss, marker='o', linestyle='--')
    plt.title('Elbow Method for Optimal Number of Clusters')
    plt.xlabel('Number of Clusters')
    plt.ylabel('WCSS')
    plt.xticks(range(1, max_clusters + 1))
    plt.grid()
    plt.show()

    # Prompt user to enter the optimal number of clusters (based on the elbow chart)
    optimal_clusters = int(input("Enter the optimal number of clusters (as observed from the elbow plot): "))

    # Perform K-Means clustering
    with threadpool_limits(limits=1, user_api='blas'):
        kmeans = KMeans(n_clusters=optimal_clusters, random_state=42, n_init=10)
        cluster_labels = kmeans.fit_predict(scaled_data)

    # Add cluster labels to the DataFrame
    team_stats['Cluster'] = cluster_labels

    # Sort the DataFrame by the Cluster column in ascending order
    team_stats = team_stats.sort_values(by='Cluster', ascending=True).reset_index(drop=True)

    # Apply conditional formatting and ranking
    df_with_ranks = team_stats.copy()
    ranks_data = {}

    for col in numeric_cols:
        ranks = team_stats[col].rank(ascending=False, method='min').astype(int)
        df_with_ranks[col] = team_stats[col].astype(str) + ' (' + ranks.astype(str) + ')'
        ranks_data[col] = ranks

    def luminance(color):
        rgb = mcolors.hex2color(color)
        return 0.2126 * rgb[0] + 0.7152 * rgb[1] + 0.0722 * rgb[2]

    def color_cells(row):
        colors = []
        for col in numeric_cols:
            rank = ranks_data[col].loc[row.name]
            max_rank = ranks_data[col].max()
            min_rank = ranks_data[col].min()
            norm = (rank - min_rank) / (max_rank - min_rank) if max_rank != min_rank else 0.5
            color = mcolors.to_hex(plt.cm.RdYlGn(1 - norm))
            text_color = 'white' if luminance(color) < 0.5 else 'black'
            colors.append(f"background-color: {color}; color: {text_color};")
        return colors

    styled_df = df_with_ranks.style.apply(color_cells, subset=numeric_cols, axis=1).format(precision=3)

    # Rename clusters at the end
    cluster_names = {
        0: "The Average", 
        1: "The Greats (Defensive Dynamos)", 
        2: "Good Offense, Bad Defense", 
        3: "The Greats (Offensive Juggernauts)", 
        4: "Bad Teams", 
        5: "I Can't Score, You Can't Score", 
        6: "Cellar Dwellers",
        7: "The Best of the Best"
    }
    df_with_ranks['Cluster'] = df_with_ranks['Cluster'].map(cluster_names)

    # Display the styled DataFrame (sorted by clusters)
    from IPython.display import display
    display(styled_df)

    # Optional: Visualize the clusters using PCA
    pca = PCA(n_components=2)
    reduced_data = pca.fit_transform(scaled_data)

    plt.figure(figsize=(10, 6))
    for cluster in range(optimal_clusters):
        cluster_points = reduced_data[cluster_labels == cluster]
        plt.scatter(cluster_points[:, 0], cluster_points[:, 1], label=cluster_names.get(cluster, f"Cluster {cluster}"), s=100)
    plt.title('Cluster Visualization')
    plt.xlabel('PCA Component 1')
    plt.ylabel('PCA Component 2')
    plt.legend()
    plt.grid()
    plt.show()
# Out:
# Enter the optimal number of clusters (as observed from the elbow plot): 12
# <style type="text/css">
# #T_a9561_row0_col1 {
#   background-color: #d83128;
#   color: white;
# }
# #T_a9561_row0_col2, #T_a9561_row1_col1, #T_a9561_row4_col7, #T_a9561_row6_col3, #T_a9561_row7_col8, #T_a9561_row8_col6, #T_a9561_row8_col10, #T_a9561_row10_col4, #T_a9561_row22_col5, #T_a9561_row29_col7, #T_a9561_row30_col5 {
#   background-color: #c62027;
#   color: white;
# }
# #T_a9561_row0_col3, #T_a9561_row1_col4, #T_a9561_row3_col6, #T_a9561_row5_col5, #T_a9561_row9_col2, #T_a9561_row21_col10, #T_a9561_row28_col4 {
#   background-color: #33a456;
#   color: black;
# }
# #T_a9561_row0_col4, #T_a9561_row1_col5, #T_a9561_row17_col2, #T_a9561_row19_col6, #T_a9561_row22_col10, #T_a9561_row26_col8, #T_a9561_row27_col3, #T_a9561_row27_col7, #T_a9561_row29_col1, #T_a9561_row30_col9 {
#   background-color: #08773f;
#   color: white;
# }
# #T_a9561_row0_col5, #T_a9561_row2_col10, #T_a9561_row11_col2, #T_a9561_row11_col9, #T_a9561_row16_col7, #T_a9561_row19_col3, #T_a9561_row23_col5, #T_a9561_row23_col7, #T_a9561_row24_col6 {
#   background-color: #a5d86a;
#   color: black;
# }
# #T_a9561_row0_col6, #T_a9561_row1_col7, #T_a9561_row1_col10, #T_a9561_row4_col5, #T_a9561_row12_col2, #T_a9561_row19_col2, #T_a9561_row22_col3, #T_a9561_row30_col10 {
#   background-color: #4bb05c;
#   color: black;
# }
# #T_a9561_row0_col7, #T_a9561_row1_col3, #T_a9561_row2_col6, #T_a9561_row3_col4, #T_a9561_row7_col5, #T_a9561_row8_col2, #T_a9561_row13_col9, #T_a9561_row13_col10, #T_a9561_row14_col9, #T_a9561_row21_col7, #T_a9561_row22_col9 {
#   background-color: #199750;
#   color: white;
# }
# #T_a9561_row0_col8, #T_a9561_row12_col1, #T_a9561_row22_col8 {
#   background-color: #51b35e;
#   color: black;
# }
# #T_a9561_row0_col9, #T_a9561_row4_col6, #T_a9561_row12_col3, #T_a9561_row15_col3, #T_a9561_row16_col3, #T_a9561_row17_col4, #T_a9561_row19_col7, #T_a9561_row19_col10, #T_a9561_row27_col2 {
#   background-color: #feea9b;
#   color: black;
# }
# #T_a9561_row0_col10, #T_a9561_row4_col2, #T_a9561_row4_col3, #T_a9561_row9_col7, #T_a9561_row12_col9, #T_a9561_row13_col5, #T_a9561_row18_col4, #T_a9561_row30_col4, #T_a9561_row30_col6 {
#   background-color: #91d068;
#   color: black;
# }
# #T_a9561_row1_col2, #T_a9561_row6_col9, #T_a9561_row8_col7, #T_a9561_row12_col10, #T_a9561_row15_col4, #T_a9561_row16_col5, #T_a9561_row18_col6, #T_a9561_row19_col5, #T_a9561_row20_col4, #T_a9561_row20_col5, #T_a9561_row25_col4 {
#   background-color: #fee08b;
#   color: black;
# }
# #T_a9561_row1_col6, #T_a9561_row3_col5, #T_a9561_row6_col5, #T_a9561_row10_col9, #T_a9561_row12_col7, #T_a9561_row18_col9, #T_a9561_row24_col4, #T_a9561_row28_col3 {
#   background-color: #66bd63;
#   color: black;
# }
# #T_a9561_row1_col8, #T_a9561_row9_col1 {
#   background-color: #7fc866;
#   color: black;
# }
# #T_a9561_row1_col9, #T_a9561_row5_col9, #T_a9561_row5_col10, #T_a9561_row6_col4, #T_a9561_row14_col3, #T_a9561_row21_col5, #T_a9561_row29_col4 {
#   background-color: #ea5739;
#   color: white;
# }
# #T_a9561_row2_col1, #T_a9561_row29_col8 {
#   background-color: #ec5c3b;
#   color: white;
# }
# #T_a9561_row2_col2, #T_a9561_row2_col3, #T_a9561_row16_col6, #T_a9561_row17_col10, #T_a9561_row22_col4, #T_a9561_row25_col7 {
#   background-color: #7ac665;
#   color: black;
# }
# #T_a9561_row2_col4, #T_a9561_row2_col8, #T_a9561_row9_col10, #T_a9561_row10_col1, #T_a9561_row10_col7, #T_a9561_row15_col5, #T_a9561_row20_col2, #T_a9561_row25_col6, #T_a9561_row26_col3, #T_a9561_row28_col9 {
#   background-color: #118848;
#   color: white;
# }
# #T_a9561_row2_col5, #T_a9561_row3_col3, #T_a9561_row9_col9, #T_a9561_row14_col8, #T_a9561_row14_col10, #T_a9561_row15_col6, #T_a9561_row22_col2, #T_a9561_row27_col4, #T_a9561_row28_col7, #T_a9561_row30_col1 {
#   background-color: #006837;
#   color: white;
# }
# #T_a9561_row2_col7, #T_a9561_row6_col10, #T_a9561_row9_col6, #T_a9561_row12_col4 {
#   background-color: #fff5ae;
#   color: black;
# }
# #T_a9561_row2_col9, #T_a9561_row5_col2, #T_a9561_row14_col7, #T_a9561_row21_col6, #T_a9561_row27_col9, #T_a9561_row28_col10 {
#   background-color: #fece7c;
#   color: black;
# }
# #T_a9561_row3_col1, #T_a9561_row7_col10, #T_a9561_row11_col5, #T_a9561_row13_col3, #T_a9561_row13_col4, #T_a9561_row15_col8, #T_a9561_row15_col9, #T_a9561_row22_col6, #T_a9561_row24_col2, #T_a9561_row26_col7, #T_a9561_row28_col1, #T_a9561_row30_col8 {
#   background-color: #a50026;
#   color: white;
# }
# #T_a9561_row3_col2, #T_a9561_row3_col10, #T_a9561_row7_col3, #T_a9561_row13_col7, #T_a9561_row21_col3, #T_a9561_row23_col4, #T_a9561_row24_col3, #T_a9561_row29_col6 {
#   background-color: #f2faae;
#   color: black;
# }
# #T_a9561_row3_col7, #T_a9561_row6_col2, #T_a9561_row10_col10, #T_a9561_row17_col5, #T_a9561_row19_col4, #T_a9561_row20_col3, #T_a9561_row22_col7 {
#   background-color: #c7e77f;
#   color: black;
# }
# #T_a9561_row3_col8, #T_a9561_row25_col1 {
#   background-color: #ddf191;
#   color: black;
# }
# #T_a9561_row3_col9, #T_a9561_row7_col2, #T_a9561_row7_col4, #T_a9561_row14_col2, #T_a9561_row18_col7, #T_a9561_row20_col10, #T_a9561_row23_col9, #T_a9561_row26_col6 {
#   background-color: #feffbe;
#   color: black;
# }
# #T_a9561_row4_col1, #T_a9561_row19_col8 {
#   background-color: #f47044;
#   color: black;
# }
# #T_a9561_row4_col4, #T_a9561_row8_col5, #T_a9561_row10_col6, #T_a9561_row11_col10, #T_a9561_row16_col2, #T_a9561_row17_col3, #T_a9561_row18_col5, #T_a9561_row20_col9, #T_a9561_row26_col5, #T_a9561_row27_col5, #T_a9561_row28_col5, #T_a9561_row29_col5 {
#   background-color: #d9ef8b;
#   color: black;
# }
# #T_a9561_row4_col8, #T_a9561_row5_col1, #T_a9561_row25_col8 {
#   background-color: #fdb365;
#   color: black;
# }
# #T_a9561_row4_col9, #T_a9561_row5_col4, #T_a9561_row11_col7, #T_a9561_row14_col5, #T_a9561_row15_col7, #T_a9561_row20_col6, #T_a9561_row23_col3, #T_a9561_row23_col10, #T_a9561_row25_col3, #T_a9561_row25_col5, #T_a9561_row26_col2, #T_a9561_row29_col9 {
#   background-color: #fa9857;
#   color: black;
# }
# #T_a9561_row4_col10, #T_a9561_row9_col4, #T_a9561_row17_col6, #T_a9561_row29_col2 {
#   background-color: #f7814c;
#   color: black;
# }
# #T_a9561_row5_col3, #T_a9561_row7_col6, #T_a9561_row8_col4, #T_a9561_row13_col6, #T_a9561_row17_col7, #T_a9561_row20_col7, #T_a9561_row23_col2, #T_a9561_row24_col5, #T_a9561_row25_col2, #T_a9561_row25_col9, #T_a9561_row27_col10 {
#   background-color: #f46d43;
#   color: black;
# }
# #T_a9561_row5_col6, #T_a9561_row5_col7, #T_a9561_row9_col3, #T_a9561_row10_col2, #T_a9561_row16_col10, #T_a9561_row30_col7 {
#   background-color: #fdbf6f;
#   color: black;
# }
# #T_a9561_row5_col8, #T_a9561_row20_col1, #T_a9561_row27_col8 {
#   background-color: #96d268;
#   color: black;
# }
# #T_a9561_row6_col1, #T_a9561_row23_col8 {
#   background-color: #fdc574;
#   color: black;
# }
# #T_a9561_row6_col6, #T_a9561_row16_col9, #T_a9561_row17_col9, #T_a9561_row18_col3, #T_a9561_row23_col6, #T_a9561_row26_col4, #T_a9561_row28_col2, #T_a9561_row29_col10 {
#   background-color: #b7e075;
#   color: black;
# }
# #T_a9561_row6_col7, #T_a9561_row8_col3, #T_a9561_row14_col6, #T_a9561_row18_col2, #T_a9561_row18_col10, #T_a9561_row19_col9, #T_a9561_row21_col4, #T_a9561_row21_col9 {
#   background-color: #e5f49b;
#   color: black;
# }
# #T_a9561_row6_col8, #T_a9561_row26_col1 {
#   background-color: #cfeb85;
#   color: black;
# }
# #T_a9561_row7_col1, #T_a9561_row13_col1, #T_a9561_row16_col8, #T_a9561_row19_col1 {
#   background-color: #ebf7a3;
#   color: black;
# }
# #T_a9561_row7_col7, #T_a9561_row8_col9, #T_a9561_row12_col5, #T_a9561_row12_col6, #T_a9561_row14_col4, #T_a9561_row24_col10, #T_a9561_row26_col9, #T_a9561_row30_col2 {
#   background-color: #d62f27;
#   color: white;
# }
# #T_a9561_row7_col9, #T_a9561_row11_col3, #T_a9561_row11_col4, #T_a9561_row11_col6, #T_a9561_row11_col8, #T_a9561_row15_col2, #T_a9561_row15_col10, #T_a9561_row27_col1 {
#   background-color: #b50f26;
#   color: white;
# }
# #T_a9561_row8_col1 {
#   background-color: #69be63;
#   color: black;
# }
# #T_a9561_row8_col8 {
#   background-color: #f8fcb6;
#   color: black;
# }
# #T_a9561_row9_col5, #T_a9561_row16_col4, #T_a9561_row21_col2, #T_a9561_row24_col9, #T_a9561_row26_col10, #T_a9561_row28_col6, #T_a9561_row29_col3 {
#   background-color: #fdad60;
#   color: black;
# }
# #T_a9561_row9_col8, #T_a9561_row16_col

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# Define the URL for the data request
url = "https://stats.gleague.nba.com/stats/leaguedashteamshotlocations"

# Define the headers for the network request
headers = {
    "Host": "stats.gleague.nba.com",
    "Connection": "keep-alive",
    "Accept": "application/json, text/plain, */*",
    "x-nba-stats-token": "true",
    "x-nba-stats-origin": "stats",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36",
    "Origin": "https://stats.gleague.nba.com",
    "Referer": "https://stats.gleague.nba.com/",
}

# Define the query parameters for "By Zone"
params = {
    "Conference": "",
    "DateFrom": "",
    "DateTo": "",
    "DistanceRange": "By Zone",
    "Division": "",
    "GameScope": "",
    "GameSegment": "",
    "LastNGames": "0",
    "LeagueID": "20",
    "Location": "",
    "MeasureType": "Base",
    "Month": "0",
    "OpponentTeamID": "0",
    "Outcome": "",
    "PORound": "0",
    "PaceAdjust": "N",
    "PerMode": "PerGame",
    "Period": "0",
    "PlayerExperience": "",
    "PlayerPosition": "",
    "PlusMinus": "N",
    "Rank": "N",
    "Season": "2024-25",
    "SeasonSegment": "",
    "SeasonType": "Regular Season",
    "ShotClockRange": "",
    "StarterBench": "",
    "TeamID": "0",
    "VsConference": "",
    "VsDivision": "",
}

# Send the GET request
response = requests.get(url, headers=headers, params=params)

# Verify if the request was successful
if response.status_code == 200:
    data = response.json()

    # Extract the relevant data
    result_set = data["resultSets"]["rowSet"]
    lower_level_columns = data["resultSets"]["headers"][1]["columnNames"]  # Lower-level columns (FGM, FGA, FG%)
    top_level_columns = data["resultSets"]["headers"][0]["columnNames"]  # Top-level columns (Shot categories)

    # Convert to a DataFrame
    team_stats = pd.DataFrame(result_set, columns=lower_level_columns)

    # Drop the TEAM_ID column
    if "TEAM_ID" in team_stats.columns:
        team_stats = team_stats.drop(columns=["TEAM_ID"])

    # Rename FG_PCT to FG% and TEAM_NAME to TEAM
    team_stats = team_stats.rename(columns=lambda x: x.replace("FG_PCT", "FG%") if "FG_PCT" in x else x)
    team_stats = team_stats.rename(columns={"TEAM_NAME": "TEAM"})

    # Create the MultiIndex columns
    # Each shot category has 3 columns (FGM, FGA, FG%)
    top_level = []
    lower_level = []
    for i, category in enumerate(top_level_columns):
        top_level.extend([category] * 2)  # Repeat each category 3 times
        lower_level.extend(["FGA", "FG%"])

    # Add the TEAM column to the MultiIndex
    top_level.insert(0, " ")  # Top-level for TEAM
    lower_level.insert(0, "TEAM")  # Lower-level for TEAM

    # Drop the FGM columns for each shot category
    # Each shot category has 3 columns: FGM, FGA, FG%
    # We drop the FGM columns (every 3rd column starting from index 2)
    fgm_columns = [col for i, col in enumerate(team_stats.columns) if (i - 2) % 3 == 0]
    team_stats = team_stats.drop(columns=fgm_columns)

    # Create the MultiIndex columns
    # Each shot category has 2 columns (FGA, FG%) since we dropped FGM
    top_level = []
    lower_level = []
    for i, category in enumerate(top_level_columns):
        top_level.extend([category] * 2)  # Repeat each category 2 times (for FGA and FG%)
        lower_level.extend(["FGA", "FG%"])

    # Add the TEAM column to the MultiIndex
    top_level.insert(0, " ")  # Top-level for TEAM
    lower_level.insert(0, "TEAM")  # Lower-level for TEAM

    # Apply the MultiIndex to the DataFrame
    team_stats.columns = pd.MultiIndex.from_tuples(zip(top_level, lower_level))

    # Drop the "Left Corner 3", "Right Corner 3", and "Backcourt" columns
    zones_to_drop = ["Left Corner 3", "Right Corner 3", "Backcourt"]
    for zone in zones_to_drop:
        if zone in team_stats.columns.levels[0]:  # Check if the zone exists in the top-level columns
            team_stats = team_stats.drop(columns=zone, level=0)

    # Apply conditional formatting and ranking
    numeric_cols = [col for col in team_stats.columns if col[1] in ["FGA", "FG%"]]
    df_with_ranks = team_stats.copy()
    ranks_data = {}

    for col in numeric_cols:
        ranks = team_stats[col].rank(ascending=False, method='min').astype(int)
        df_with_ranks[col] = team_stats[col].astype(str) + ' (' + ranks.astype(str) + ')'
        ranks_data[col] = ranks

    def luminance(color):
        rgb = mcolors.hex2color(color)
        return 0.2126 * rgb[0] + 0.7152 * rgb[1] + 0.0722 * rgb[2]

    def color_cells(row):
        colors = []
        for col in numeric_cols:
            rank = ranks_data[col].loc[row.name]
            max_rank = ranks_data[col].max()
            min_rank = ranks_data[col].min()
            norm = (rank - min_rank) / (max_rank - min_rank) if max_rank != min_rank else 0.5
            color = mcolors.to_hex(plt.cm.RdYlGn(1 - norm))
            text_color = 'white' if luminance(color) < 0.5 else 'black'
            colors.append(f"background-color: {color}; color: {text_color};")
        return colors

    styled_df = df_with_ranks.style.apply(color_cells, subset=numeric_cols, axis=1).format(precision=3)

    from IPython.display import display
    display(styled_df)
# Out:
# <style type="text/css">
# #T_21ea2_row0_col1, #T_21ea2_row6_col1 {
#   background-color: #fee491;
#   color: black;
# }
# #T_21ea2_row0_col2, #T_21ea2_row0_col10, #T_21ea2_row3_col7, #T_21ea2_row10_col3, #T_21ea2_row12_col4, #T_21ea2_row12_col9, #T_21ea2_row16_col9, #T_21ea2_row17_col6 {
#   background-color: #e5f49b;
#   color: black;
# }
# #T_21ea2_row0_col3, #T_21ea2_row3_col6, #T_21ea2_row5_col6, #T_21ea2_row11_col4, #T_21ea2_row23_col9, #T_21ea2_row24_col9, #T_21ea2_row27_col2, #T_21ea2_row29_col10 {
#   background-color: #b7e075;
#   color: black;
# }
# #T_21ea2_row0_col4, #T_21ea2_row8_col2, #T_21ea2_row8_col3, #T_21ea2_row13_col7, #T_21ea2_row18_col4, #T_21ea2_row18_col6, #T_21ea2_row19_col9, #T_21ea2_row25_col10, #T_21ea2_row30_col5 {
#   background-color: #91d068;
#   color: black;
# }
# #T_21ea2_row0_col5, #T_21ea2_row4_col10, #T_21ea2_row8_col4, #T_21ea2_row10_col5, #T_21ea2_row11_col5, #T_21ea2_row14_col9, #T_21ea2_row20_col5, #T_21ea2_row23_col3, #T_21ea2_row24_col2, #T_21ea2_row27_col5, #T_21ea2_row28_col6, #T_21ea2_row29_col5 {
#   background-color: #d9ef8b;
#   color: black;
# }
# #T_21ea2_row0_col6, #T_21ea2_row3_col9, #T_21ea2_row6_col4, #T_21ea2_row7_col2, #T_21ea2_row10_col7, #T_21ea2_row14_col4, #T_21ea2_row14_col5, #T_21ea2_row15_col4, #T_21ea2_row16_col5, #T_21ea2_row19_col10, #T_21ea2_row24_col5 {
#   background-color: #fee08b;
#   color: black;
# }
# #T_21ea2_row0_col7, #T_21ea2_row5_col9, #T_21ea2_row11_col6, #T_21ea2_row14_col10, #T_21ea2_row17_col2, #T_21ea2_row21_col2, #T_21ea2_row21_col4, #T_21ea2_row22_col9 {
#   background-color: #feffbe;
#   color: black;
# }
# #T_21ea2_row0_col8 {
#   background-color: #fed683;
#   color: black;
# }
# #T_21ea2_row0_col9, #T_21ea2_row1_col4, #T_21ea2_row3_col5, #T_21ea2_row7_col6, #T_21ea2_row19_col7, #T_21ea2_row22_col5, #T_21ea2_row27_col3, #T_21ea2_row28_col9 {
#   background-color: #66bd63;
#   color: black;
# }
# #T_21ea2_row1_col1 {
#   background-color: #abdb6d;
#   color: black;
# }
# #T_21ea2_row1_col2, #T_21ea2_row2_col6, #T_21ea2_row4_col5, #T_21ea2_row6_col8, #T_21ea2_row6_col9, #T_21ea2_row11_col7, #T_21ea2_row18_col8, #T_21ea2_row21_col10, #T_21ea2_row22_col1, #T_21ea2_row27_col1, #T_21ea2_row30_col3, #T_21ea2_row30_col4 {
#   background-color: #a50026;
#   color: white;
# }
# #T_21ea2_row1_col3, #T_21ea2_row5_col4, #T_21ea2_row12_col3, #T_21ea2_row21_col3, #T_21ea2_row22_col2, #T_21ea2_row22_col10, #T_21ea2_row29_col6, #T_21ea2_row30_col7 {
#   background-color: #f2faae;
#   color: black;
# }
# #T_21ea2_row1_col5, #T_21ea2_row5_col2, #T_21ea2_row10_col4, #T_21ea2_row14_col7, #T_21ea2_row15_col2, #T_21ea2_row15_col9, #T_21ea2_row20_col10, #T_21ea2_row21_col6, #T_21ea2_row23_col7, #T_21ea2_row26_col3, #T_21ea2_row30_col6 {
#   background-color: #f46d43;
#   color: black;
# }
# #T_21ea2_row1_col6, #T_21ea2_row4_col2, #T_21ea2_row4_col9, #T_21ea2_row5_col5, #T_21ea2_row5_col7, #T_21ea2_row9_col10, #T_21ea2_row16_col3, #T_21ea2_row24_col7, #T_21ea2_row25_col5 {
#   background-color: #a5d86a;
#   color: black;
# }
# #T_21ea2_row1_col7, #T_21ea2_row15_col10, #T_21ea2_row18_col3, #T_21ea2_row20_col6, #T_21ea2_row28_col3, #T_21ea2_row28_col5, #T_21ea2_row30_col2 {
#   background-color: #e14430;
#   color: white;
# }
# #T_21ea2_row1_col8, #T_21ea2_row23_col1 {
#   background-color: #bde379;
#   color: black;
# }
# #T_21ea2_row1_col9, #T_21ea2_row11_col10, #T_21ea2_row12_col2, #T_21ea2_row13_col5, #T_21ea2_row24_col4, #T_21ea2_row27_col6, #T_21ea2_row29_col3 {
#   background-color: #fdad60;
#   color: black;
# }
# #T_21ea2_row1_col10, #T_21ea2_row10_col9, #T_21ea2_row11_col9, #T_21ea2_row17_col4, #T_21ea2_row18_col2, #T_21ea2_row19_col5, #T_21ea2_row19_col6, #T_21ea2_row21_col7 {
#   background-color: #d62f27;
#   color: white;
# }
# #T_21ea2_row2_col1, #T_21ea2_row19_col8 {
#   background-color: #f8864f;
#   color: black;
# }
# #T_21ea2_row2_col2, #T_21ea2_row6_col6, #T_21ea2_row9_col5, #T_21ea2_row13_col9, #T_21ea2_row17_col8, #T_21ea2_row17_col10, #T_21ea2_row18_col1, #T_21ea2_row20_col4, #T_21ea2_row22_col3, #T_21ea2_row27_col7 {
#   background-color: #006837;
#   color: white;
# }
# #T_21ea2_row2_col3, #T_21ea2_row7_col7, #T_21ea2_row7_col10, #T_21ea2_row8_col5, #T_21ea2_row16_col2, #T_21ea2_row18_col10, #T_21ea2_row19_col2, #T_21ea2_row25_col6 {
#   background-color: #4bb05c;
#   color: black;
# }
# #T_21ea2_row2_col4, #T_21ea2_row9_col2, #T_21ea2_row9_col3, #T_21ea2_row15_col7, #T_21ea2_row23_col10, #T_21ea2_row24_col6 {
#   background-color: #7ac665;
#   color: black;
# }
# #T_21ea2_row2_col5, #T_21ea2_row3_col3, #T_21ea2_row7_col1, #T_21ea2_row8_col7, #T_21ea2_row10_col6, #T_21ea2_row10_col10, #T_21ea2_row18_col5, #T_21ea2_row21_col8, #T_21ea2_row25_col2, #T_21ea2_row28_col4, #T_21ea2_row29_col7 {
#   background-color: #c62027;
#   color: white;
# }
# #T_21ea2_row2_col7, #T_21ea2_row3_col2, #T_21ea2_row14_col3, #T_21ea2_row16_col4, #T_21ea2_row22_col7, #T_21ea2_row23_col5, #T_21ea2_row28_col10 {
#   background-color: #c7e77f;
#   color: black;
# }
# #T_21ea2_row2_col8, #T_21ea2_row19_col1, #T_21ea2_row25_col8 {
#   background-color: #51b35e;
#   color: black;
# }
# #T_21ea2_row2_col9, #T_21ea2_row7_col3, #T_21ea2_row9_col6, #T_21ea2_row10_col2, #T_21ea2_row12_col7, #T_21ea2_row17_col9, #T_21ea2_row21_col5, #T_21ea2_row22_col4, #T_21ea2_row25_col7, #T_21ea2_row30_col9, #T_21ea2_row30_col10 {
#   background-color: #199750;
#   color: white;
# }
# #T_21ea2_row2_col10, #T_21ea2_row7_col5, #T_21ea2_row11_col8, #T_21ea2_row16_col6, #T_21ea2_row18_col9, #T_21ea2_row20_col3, #T_21ea2_row20_col7, #T_21ea2_row23_col2, #T_21ea2_row25_col4, #T_21ea2_row29_col1 {
#   background-color: #08773f;
#   color: white;
# }
# #T_21ea2_row3_col1, #T_21ea2_row5_col8 {
#   background-color: #fdc574;
#   color: black;
# }
# #T_21ea2_row3_col4, #T_21ea2_row7_col9, #T_21ea2_row12_col5, #T_21ea2_row17_col3, #T_21ea2_row26_col9, #T_21ea2_row26_col10, #T_21ea2_row29_col4 {
#   background-color: #ea5739;
#   color: white;
# }
# #T_21ea2_row3_col8, #T_21ea2_row11_col1 {
#   background-color: #cfeb85;
#   color: black;
# }
# #T_21ea2_row3_col10, #T_21ea2_row9_col7, #T_21ea2_row13_col6, #T_21ea2_row19_col4 {
#   background-color: #fff5ae;
#   color: black;
# }
# #T_21ea2_row4_col1, #T_21ea2_row27_col8 {
#   background-color: #1b9950;
#   color: white;
# }
# #T_21ea2_row4_col3, #T_21ea2_row4_col4, #T_21ea2_row4_col6, #T_21ea2_row4_col8, #T_21ea2_row6_col2, #T_21ea2_row6_col10, #T_21ea2_row20_col1, #T_21ea2_row21_col9 {
#   background-color: #b50f26;
#   color: white;
# }
# #T_21ea2_row4_col7, #T_21ea2_row5_col3, #T_21ea2_row5_col10, #T_21ea2_row6_col7, #T_21ea2_row8_col9, #T_21ea2_row11_col2, #T_21ea2_row14_col6, #T_21ea2_row15_col3, #T_21ea2_row15_col5, #T_21ea2_row17_col5, #T_21ea2_row26_col4, #T_21ea2_row29_col9 {
#   background-color: #fa9857;
#   color: black;
# }
# #T_21ea2_row5_col1 {
#   background-color: #feefa3;
#   color: black;
# }
# #T_21ea2_row6_col3, #T_21ea2_row8_col6, #T_21ea2_row16_col7, #T_21ea2_row16_col10, #T_21ea2_row19_col3, #T_21ea2_row20_col2, #T_21ea2_row23_col4, #T_21ea2_row24_col3, #T_21ea2_row25_col9 {
#   background-color: #feea9b;
#   color: black;
# }
# #T_21ea2_row6_col5, #T_21ea2_row9_col4, #T_21ea2_row9_col8, #T_21ea2_row11_col3, #T_21ea2_row13_col10, #T_21ea2_row14_col2, #T_21ea2_row15_col6, #T_21ea2_row27_col9, #T_21ea2_row28_col1, #T_21ea2_row28_col7 {
#   background-color: #118848;
#   color: white;
# }
# #T_21ea2_row7_col4, #T_21ea2_row12_col10, #T_21ea2_row13_col2, #T_21ea2_row22_col6, #T_21ea2_row25_col3, #T_21ea2_row26_col5, #T_21ea2_row27_col4 {
#   background-color: #33a456;
#   color: black;
# }
# #T_21ea2_row7_col8, #T_21ea2_row13_col1 {
#   background-color: #7fc866;
#   color: black;
# }
# #T_21ea2_row8_col1, #T_21ea2_row16_col8 {
#   background-color: #f47044;
#   color: black;
# }
# #T_21ea2_row8_col8, #T_21ea2_row15_col8, #T_21ea2_row26_col1 {
#   background-color: #fdb365;
#   color: black;
# }
# #T_21ea2_row8_col10, #T_21ea2_row13_col4, #T_21ea2_row23_col6, #T_21ea2_row29_col2 {
#   background-color: #f7814c;
#   color: black;
# }
# #T_21ea2_row9_col1, #T_21ea2_row29_col8 {
#   background-color: #ec5c3b;
#   color: white;
# }
# #T_21ea2_row9_col9, #T_21ea2_row12_col6, #T_21ea2_row17_col7, #T_21ea2_row20_col9, #T_21ea2_row26_col2, #T_21ea2_row27_col10 {
#   background-color: #fece7c;
#   color:

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# Define the URL for the data request
url = "https://stats.gleague.nba.com/stats/leaguedashteamshotlocations"

# Define the headers for the network request
headers = {
    "Host": "stats.gleague.nba.com",
    "Connection": "keep-alive",
    "Accept": "application/json, text/plain, */*",
    "x-nba-stats-token": "true",
    "x-nba-stats-origin": "stats",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36",
    "Origin": "https://stats.gleague.nba.com",
    "Referer": "https://stats.gleague.nba.com/",
}

# Define the query parameters for "By Zone"
params = {
    "Conference": "",
    "DateFrom": "",
    "DateTo": "",
    "DistanceRange": "By Zone",
    "Division": "",
    "GameScope": "",
    "GameSegment": "",
    "LastNGames": "0",
    "LeagueID": "20",
    "Location": "",
    "MeasureType": "Base",
    "Month": "0",
    "OpponentTeamID": "0",
    "Outcome": "",
    "PORound": "0",
    "PaceAdjust": "N",
    "PerMode": "PerGame",
    "Period": "0",
    "PlayerExperience": "",
    "PlayerPosition": "",
    "PlusMinus": "N",
    "Rank": "N",
    "Season": "2024-25",
    "SeasonSegment": "",
    "SeasonType": "Regular Season",
    "ShotClockRange": "",
    "StarterBench": "",
    "TeamID": "0",
    "VsConference": "",
    "VsDivision": "",
}

# Send the GET request
response = requests.get(url, headers=headers, params=params)

# Verify if the request was successful
if response.status_code == 200:
    data = response.json()

    # Extract the relevant data
    result_set = data["resultSets"]["rowSet"]
    lower_level_columns = data["resultSets"]["headers"][1]["columnNames"]  # Lower-level columns (FGM, FGA, FG%)
    top_level_columns = data["resultSets"]["headers"][0]["columnNames"]  # Top-level columns (Shot categories)

    # Convert to a DataFrame
    team_stats = pd.DataFrame(result_set, columns=lower_level_columns)

    # Drop the TEAM_ID column
    if "TEAM_ID" in team_stats.columns:
        team_stats = team_stats.drop(columns=["TEAM_ID"])

    # Rename FG_PCT to FG% and TEAM_NAME to TEAM
    team_stats = team_stats.rename(columns=lambda x: x.replace("FG_PCT", "FG%") if "FG_PCT" in x else x)
    team_stats = team_stats.rename(columns={"TEAM_NAME": "TEAM"})

    # Drop the FGM columns for each shot category
    # Each shot category has 3 columns: FGM, FGA, FG%
    # We drop the FGM columns (every 3rd column starting from index 2)
    fgm_columns = [col for i, col in enumerate(team_stats.columns) if (i - 2) % 3 == 0]
    team_stats = team_stats.drop(columns=fgm_columns)

    # Create the MultiIndex columns
    # Each shot category has 2 columns (FGA, FG%) since we dropped FGM
    top_level = []
    lower_level = []
    for i, category in enumerate(top_level_columns):
        top_level.extend([category] * 2)  # Repeat each category 2 times (for FGA and FG%)
        lower_level.extend(["FGA", "FG%"])

    # Add the TEAM column to the MultiIndex
    top_level.insert(0, " ")  # Top-level for TEAM
    lower_level.insert(0, "TEAM")  # Lower-level for TEAM

    # Apply the MultiIndex to the DataFrame
    team_stats.columns = pd.MultiIndex.from_tuples(zip(top_level, lower_level))

    # Drop the "Left Corner 3", "Right Corner 3", and "Backcourt" columns
    zones_to_drop = ["Left Corner 3", "Right Corner 3", "Backcourt"]
    for zone in zones_to_drop:
        if zone in team_stats.columns.levels[0]:  # Check if the zone exists in the top-level columns
            team_stats = team_stats.drop(columns=zone, level=0)

    # Display the DataFrame
    print(team_stats)

    # ... [Keep the rest of the code for styling and formatting] ...
# Out:
#                                Restricted Area        In The Paint (Non-RA)  \
#                           TEAM             FGA    FG%                   FGA
# 0                 Austin Spurs            17.0  0.648                   8.4
# 1          Birmingham Squadron            18.3  0.571                   7.0
# 2           Capital City Go-Go            15.7  0.709                  10.6
# 3   Ciudad de Mexico Capitanes            16.9  0.655                   5.3
# 4             Cleveland Charge            21.2  0.660                   4.4
# 5        College Park Skyhawks            17.6  0.613                   6.2
# 6          Delaware Blue Coats            17.0  0.578                   6.8
# 7            Grand Rapids Gold            12.4  0.629                  11.8
# 8             Greensboro Swarm            15.6  0.663                   9.4
# 9             Indiana Mad Ants            15.5  0.669                   9.8
# 10                 Iowa Wolves            19.6  0.683                   7.6
# 11            Long Island Nets            18.0  0.621                  12.5
# 12               Maine Celtics            16.6  0.622                   7.0
# 13              Memphis Hustle            19.1  0.679                   6.6
# 14           Motor City Cruise            18.6  0.684                   7.9
# 15          Oklahoma City Blue            17.9  0.613                   6.2
# 16               Osceola Magic            17.8  0.674                   9.0
# 17                 Raptors 905            20.9  0.635                   6.0
# 18    Rio Grande Valley Vipers            23.3  0.609                   5.6
# 19              Rip City Remix            19.9  0.674                   6.8
# 20        Salt Lake City Stars            11.9  0.633                  12.6
# 21          San Diego Clippers            17.8  0.635                   7.0
# 22         Santa Cruz Warriors            11.2  0.645                  13.6
# 23        Sioux Falls Skyforce            18.1  0.692                   7.8
# 24            South Bay Lakers            14.9  0.651                   6.8
# 25              Stockton Kings            13.4  0.605                  11.2
# 26               Texas Legends            16.7  0.627                   6.1
# 27                 Valley Suns            11.2  0.658                  10.5
# 28          Westchester Knicks            21.7  0.624                   5.6
# 29            Windy City Bulls            21.9  0.614                   6.4
# 30              Wisconsin Herd            17.8  0.612                   4.1
#
#           Mid-Range        Above the Break 3        Corner 3
#       FG%       FGA    FG%               FGA    FG%      FGA    FG%
# 0   0.455       2.4  0.380               9.6  0.339      4.1  0.376
# 1   0.463       1.8  0.406               8.4  0.358      3.0  0.306
# 2   0.458       1.1  0.305              10.1  0.369      4.3  0.453
# 3   0.382       3.6  0.403               9.8  0.356      3.3  0.366
# 4   0.343       1.0  0.333               8.8  0.310      3.9  0.380
# 5   0.416       2.8  0.403              10.2  0.337      3.5  0.339
# 6   0.408       4.2  0.513               8.8  0.309      1.9  0.276
# 7   0.472       4.6  0.429              11.1  0.366      2.5  0.429
# 8   0.424       3.8  0.386               7.2  0.336      2.8  0.338
# 9   0.492       5.3  0.466               9.3  0.383      3.1  0.387
# 10  0.388       2.4  0.344               9.1  0.348      2.3  0.296
# 11  0.447       2.4  0.392               6.8  0.384      2.3  0.346
# 12  0.420       1.6  0.378              11.2  0.345      3.6  0.437
# 13  0.391       2.0  0.390              10.3  0.318      5.9  0.451
# 14  0.408       2.3  0.371               8.6  0.345      3.7  0.368
# 15  0.408       1.9  0.473              10.4  0.336      2.6  0.319
# 16  0.442       2.3  0.494               9.2  0.327      3.6  0.365
# 17  0.379       1.9  0.398               9.0  0.395      4.3  0.477
# 18  0.455       1.1  0.419               8.9  0.309      4.6  0.429
# 19  0.414       1.3  0.345              10.8  0.334      4.0  0.364
# 20  0.505       2.4  0.351              11.5  0.362      3.1  0.333
# 21  0.415       4.1  0.358               7.6  0.313      2.1  0.269
# 22  0.490       3.6  0.459              10.1  0.355      3.5  0.369
# 23  0.410       2.5  0.369               8.6  0.318      3.8  0.421
# 24  0.398       2.3  0.420              10.2  0.354      3.8  0.351
# 25  0.500       2.8  0.437              11.2  0.369      3.4  0.400
# 26  0.395       4.0  0.376               8.9  0.362      2.5  0.323
# 27  0.472       2.4  0.373              13.1  0.378      4.4  0.363
# 28  0.361       1.4  0.400              11.4  0.345      4.1  0.381
# 29  0.382       2.4  0.396               7.2  0.320      2.8  0.385
# 30  0.329       3.0  0.358               9.7  0.372      4.3  0.446

# %% [markdown]
# ## Traditional

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import time

# Set up Selenium WebDriver
service = Service("/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver")  # Update with your path to chromedriver

#Mac file path
#"/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver"

#PC file path
#r"C:\Users\PC\OneDrive\Documents\GitHub\chromedriver-win64\chromedriver.exe"

options = Options()
options.add_argument('--headless')  # Run in headless mode
options.add_argument('--disable-gpu')
options.add_argument('--start-maximized')

driver = webdriver.Chrome(service=service, options=options)

# URL of the webpage to scrape
url = "https://stats.gleague.nba.com/teams/traditional/?sort=W_PCT&dir=-1&Season=2024-25&SeasonType=Regular%20Season"

# Load the webpage
driver.get(url)

# Allow time for JavaScript to load
time.sleep(10)  # Adjust the time as per your internet speed and website response time

# Locate the table
table_xpath = '//div[contains(@class, "nba-stat-table__overflow")]/table'
table_element = driver.find_element(By.XPATH, table_xpath)

# Extract the table data
table_html = table_element.get_attribute('outerHTML')

# Convert the table HTML into a pandas DataFrame
team_stats = pd.read_html(table_html)[0]

# Quit the driver
driver.quit()

# Drop the specified columns
columns_to_drop = [
    'Unnamed: 0', 'GP', 'W', 'L', 'WIN%', 'MIN', 'GP RANK', 'W RANK', 'L RANK', 'WIN% RANK', 'MIN RANK', 'PTS RANK',
    'FGM RANK', 'FGA RANK', 'FG% RANK', '3PM RANK', '3PA RANK', '3P% RANK',
    'FTM RANK', 'FTA RANK', 'FT% RANK', 'OREB RANK', 'DREB RANK',
    'REB RANK', 'AST RANK', 'TOV RANK', 'STL RANK', 'BLK RANK', 'BLKA RANK',
    'PF RANK', 'PFD RANK', '+/- RANK'
]
team_stats = team_stats.drop(columns=[col for col in columns_to_drop if col in team_stats.columns])

# Ensure numeric columns are correctly identified
numeric_cols = team_stats.select_dtypes(include=['number']).columns

# Calculate ranks and append ranks to numeric columns for display
invert_cols = ['TOV', 'BLKA', 'PF']  # PF will be descending, all others ascending
df_with_ranks = team_stats.copy()
ranks_data = {}

# Calculate ranks for numeric columns
for col in numeric_cols:
    if col in invert_cols:
        ranks = team_stats[col].rank(ascending=True, method='min').astype(int)  # Lower is better for inverted columns
    else:
        ranks = team_stats[col].rank(ascending=False, method='min').astype(int)  # Higher is better for regular columns
    df_with_ranks[col] = team_stats[col].astype(str) + ' (' + ranks.astype(str) + ')'
    ranks_data[col] = ranks  # Store ranks for color mapping

# Define luminance function for text color adjustment
def luminance(color):
    rgb = mcolors.hex2color(color)
    return 0.2126 * rgb[0] + 0.7152 * rgb[1] + 0.0722 * rgb[2]

# Adjusted color_cells function to use ranks for color scaling
def color_cells(row):
    colors = []
    for col in numeric_cols:
        rank = ranks_data[col].loc[row.name]
        max_rank = ranks_data[col].max()
        min_rank = ranks_data[col].min()
        # Normalize rank to 0-1 scale for color mapping
        norm = (rank - min_rank) / (max_rank - min_rank) if max_rank != min_rank else 0.5
        # Map normalized rank to color
        color = mcolors.to_hex(plt.cm.RdYlGn(1 - norm))  # Invert to make 1 (best) green
        # Adjust text color for readability
        text_color = 'white' if luminance(color) < 0.5 else 'black'
        colors.append(f"background-color: {color}; color: {text_color};")
    return colors

# Apply the coloring logic to the DataFrame with ranks
styled_df = df_with_ranks.style.apply(color_cells, subset=numeric_cols, axis=1).format(precision=3)

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_1da15_row0_col1, #T_1da15_row0_col6, #T_1da15_row4_col4, #T_1da15_row4_col13, #T_1da15_row6_col7, #T_1da15_row6_col20, #T_1da15_row7_col11, #T_1da15_row7_col17, #T_1da15_row11_col16, #T_1da15_row14_col8, #T_1da15_row18_col16, #T_1da15_row19_col10, #T_1da15_row21_col5, #T_1da15_row21_col6, #T_1da15_row21_col13, #T_1da15_row22_col3, #T_1da15_row22_col14, #T_1da15_row27_col18, #T_1da15_row30_col9 {
#   background-color: #7ac665;
#   color: black;
# }
# #T_1da15_row0_col2, #T_1da15_row1_col1, #T_1da15_row1_col5, #T_1da15_row2_col21, #T_1da15_row3_col8, #T_1da15_row3_col15, #T_1da15_row6_col4, #T_1da15_row7_col13, #T_1da15_row7_col16, #T_1da15_row8_col18, #T_1da15_row14_col9, #T_1da15_row15_col2, #T_1da15_row18_col11, #T_1da15_row19_col19, #T_1da15_row25_col6, #T_1da15_row25_col8, #T_1da15_row27_col10, #T_1da15_row29_col14, #T_1da15_row30_col2, #T_1da15_row30_col3, #T_1da15_row30_col20 {
#   background-color: #4bb05c;
#   color: black;
# }
# #T_1da15_row0_col3, #T_1da15_row0_col11, #T_1da15_row2_col5, #T_1da15_row5_col15, #T_1da15_row7_col21, #T_1da15_row8_col2, #T_1da15_row8_col10, #T_1da15_row10_col21, #T_1da15_row12_col7, #T_1da15_row12_col14, #T_1da15_row13_col8, #T_1da15_row14_col18, #T_1da15_row18_col14, #T_1da15_row18_col19, #T_1da15_row20_col4, #T_1da15_row23_col8, #T_1da15_row23_col9, #T_1da15_row23_col20, #T_1da15_row27_col17, #T_1da15_row28_col1, #T_1da15_row28_col5 {
#   background-color: #91d068;
#   color: black;
# }
# #T_1da15_row0_col4, #T_1da15_row1_col9, #T_1da15_row1_col11, #T_1da15_row2_col3, #T_1da15_row2_col19, #T_1da15_row8_col8, #T_1da15_row8_col20, #T_1da15_row9_col1, #T_1da15_row9_col10, #T_1da15_row11_col3, #T_1da15_row13_col6, #T_1da15_row13_col15, #T_1da15_row14_col5, #T_1da15_row14_col16, #T_1da15_row15_col17, #T_1da15_row20_col2, #T_1da15_row20_col14, #T_1da15_row21_col21, #T_1da15_row23_col5, #T_1da15_row23_col13, #T_1da15_row29_col5 {
#   background-color: #b7e075;
#   color: black;
# }
# #T_1da15_row0_col5, #T_1da15_row1_col18, #T_1da15_row3_col10, #T_1da15_row5_col2, #T_1da15_row5_col14, #T_1da15_row6_col12, #T_1da15_row6_col21, #T_1da15_row8_col4, #T_1da15_row8_col7, #T_1da15_row10_col15, #T_1da15_row11_col20, #T_1da15_row12_col6, #T_1da15_row12_col11, #T_1da15_row13_col9, #T_1da15_row13_col13, #T_1da15_row13_col20, #T_1da15_row15_col8, #T_1da15_row21_col3, #T_1da15_row21_col16, #T_1da15_row25_col1, #T_1da15_row25_col19, #T_1da15_row26_col17 {
#   background-color: #08773f;
#   color: white;
# }
# #T_1da15_row0_col7, #T_1da15_row0_col14, #T_1da15_row1_col17, #T_1da15_row3_col21, #T_1da15_row5_col19, #T_1da15_row8_col5, #T_1da15_row11_col8, #T_1da15_row11_col9, #T_1da15_row11_col15, #T_1da15_row12_col1, #T_1da15_row12_col19, #T_1da15_row13_col11, #T_1da15_row15_col16, #T_1da15_row21_col4, #T_1da15_row24_col18, #T_1da15_row25_col2, #T_1da15_row25_col4, #T_1da15_row25_col10, #T_1da15_row28_col3, #T_1da15_row28_col6, #T_1da15_row28_col12, #T_1da15_row28_col13, #T_1da15_row29_col16 {
#   background-color: #118848;
#   color: white;
# }
# #T_1da15_row0_col8, #T_1da15_row1_col20, #T_1da15_row3_col4, #T_1da15_row4_col3, #T_1da15_row9_col21, #T_1da15_row11_col1, #T_1da15_row13_col2, #T_1da15_row14_col13, #T_1da15_row14_col14, #T_1da15_row20_col1, #T_1da15_row20_col6, #T_1da15_row23_col15, #T_1da15_row26_col10, #T_1da15_row28_col7, #T_1da15_row28_col17, #T_1da15_row30_col5 {
#   background-color: #fa9857;
#   color: black;
# }
# #T_1da15_row0_col9, #T_1da15_row2_col11, #T_1da15_row2_col13, #T_1da15_row2_col20, #T_1da15_row3_col7, #T_1da15_row6_col14, #T_1da15_row7_col10, #T_1da15_row13_col19, #T_1da15_row15_col21, #T_1da15_row16_col2, #T_1da15_row17_col2, #T_1da15_row18_col3, #T_1da15_row18_col5, #T_1da15_row18_col17, #T_1da15_row19_col13, #T_1da15_row22_col6, #T_1da15_row26_col16, #T_1da15_row27_col1, #T_1da15_row27_col8, #T_1da15_row28_col14 {
#   background-color: #fdbf6f;
#   color: black;
# }
# #T_1da15_row0_col10, #T_1da15_row6_col17, #T_1da15_row7_col9, #T_1da15_row7_col20, #T_1da15_row8_col6, #T_1da15_row8_col16, #T_1da15_row9_col3, #T_1da15_row10_col9, #T_1da15_row10_col14, #T_1da15_row12_col8, #T_1da15_row19_col21, #T_1da15_row22_col2, #T_1da15_row22_col11, #T_1da15_row24_col4, #T_1da15_row29_col7, #T_1da15_row29_col19, #T_1da15_row30_col1, #T_1da15_row30_col4, #T_1da15_row30_col16 {
#   background-color: #d9ef8b;
#   color: black;
# }
# #T_1da15_row0_col12, #T_1da15_row0_col13, #T_1da15_row2_col10, #T_1da15_row2_col15, #T_1da15_row4_col7, #T_1da15_row4_col14, #T_1da15_row5_col4, #T_1da15_row6_col18, #T_1da15_row9_col8, #T_1da15_row9_col11, #T_1da15_row11_col19, #T_1da15_row12_col3, #T_1da15_row13_col16, #T_1da15_row13_col21, #T_1da15_row15_col9, #T_1da15_row15_col20, #T_1da15_row16_col5, #T_1da15_row16_col6, #T_1da15_row17_col17, #T_1da15_row21_col1, #T_1da15_row21_col2 {
#   background-color: #006837;
#   color: white;
# }
# #T_1da15_row0_col15, #T_1da15_row1_col6, #T_1da15_row2_col17, #T_1da15_row4_col16, #T_1da15_row4_col17, #T_1da15_row6_col1, #T_1da15_row6_col5, #T_1da15_row10_col3, #T_1da15_row10_col19, #T_1da15_row12_col10, #T_1da15_row14_col21, #T_1da15_row16_col8, #T_1da15_row16_col18, #T_1da15_row16_col20, #T_1da15_row18_col6, #T_1da15_row20_col13, #T_1da15_row20_col21, #T_1da15_row23_col4, #T_1da15_row23_col16, #T_1da15_row23_col17, #T_1da15_row24_col14, #T_1da15_row28_col8, #T_1da15_row28_col9, #T_1da15_row30_col8 {
#   background-color: #f2faae;
#   color: black;
# }
# #T_1da15_row0_col16, #T_1da15_row4_col19, #T_1da15_row9_col12, #T_1da15_row11_col7, #T_1da15_row11_col14, #T_1da15_row16_col4, #T_1da15_row17_col1, #T_1da15_row17_col5, #T_1da15_row17_col6, #T_1da15_row19_col3, #T_1da15_row22_col20, #T_1da15_row24_col8, #T_1da15_row24_col9, #T_1da15_row27_col11, #T_1da15_row29_col2, #T_1da15_row30_col13, #T_1da15_row30_col21 {
#   background-color: #b50f26;
#   color: white;
# }
# #T_1da15_row0_col17, #T_1da15_row0_col19, #T_1da15_row0_col21, #T_1da15_row1_col14, #T_1da15_row3_col11, #T_1da15_row6_col8, #T_1da15_row6_col16, #T_1da15_row8_col9, #T_1da15_row10_col2, #T_1da15_row10_col4, #T_1da15_row10_col13, #T_1da15_row10_col18, #T_1da15_row11_col18, #T_1da15_row17_col15, #T_1da15_row18_col13, #T_1da15_row19_col20, #T_1da15_row22_col18, #T_1da15_row23_col1, #T_1da15_row23_col6, #T_1da15_row23_col7, #T_1da15_row24_col10, #T_1da15_row25_col15 {
#   background-color: #c7e77f;
#   color: black;
# }
# #T_1da15_row0_col18, #T_1da15_row6_col6, #T_1da15_row7_col4, #T_1da15_row7_col8, #T_1da15_row9_col4, #T_1da15_row10_col7, #T_1da15_row10_col20, #T_1da15_row12_col21, #T_1da15_row13_col5, #T_1da15_row14_col1, #T_1da15_row15_col19, #T_1da15_row16_col13, #T_1da15_row16_col14, #T_1da15_row18_col9, #T_1da15_row20_col3, #T_1da15_row20_col11, #T_1da15_row24_col17, #T_1da15_row26_col18 {
#   background-color: #fece7c;
#   color: black;
# }
# #T_1da15_row0_col20, #T_1da15_row2_col2, #T_1da15_row5_col16, #T_1da15_row7_col6, #T_1da15_row11_col17, #T_1da15_row13_col4, #T_1da15_row13_col14, #T_1da15_row14_col4, #T_1da15_row16_col21, #T_1da15_row22_col10, #T_1da15_row24_col2, #T_1da15_row24_col3, #T_1da15_row24_col7, #T_1da15_row25_col13, #T_1da15_row26_col5, #T_1da15_row27_col15, #T_1da15_row29_col4, #T_1da15_row29_col8, #T_1da15_row29_col9 {
#   background-color: #f7814c;
#   color: black;
# }
# #T_1da15_row1_col2, #T_1da15_row1_col13, #T_1da15_row1_col21, #T_1da15_row2_col6, #T_1da15_row3_col19, #T_1da15_row4_col8, #T_1da15_row4_col9, #T_1da15_row5_col10, #T_1da15_row8_col1, #T_1da15_row8_col14, #T_1da15_row9_col16, #T_1da15_row14_col20, #T_1da15_row16_col3, #T_1da15_row19_col4, #T_1da15_row19_col15, #T_1da15_row20_col18, #T_1da15_row26_col11 {
#   background-color: #33a456;
#   color: black;
# }
# #T_1da15_row1_col3, #T_1da15_row2_col7, #T_1da15_row2_col14, #T_1da15_row4_col5, #T_1da15_row5_col5, #T_1da15_row6_col9, #T_1da15_row7_col2, #T_1da15_row7_col15, #T_1da15_row10_col1, #T_1da15_row11_col11, #T_1da15_row12_col18, #T_1da15_row16_col7, #T_1da15_row16_col19, #T_1da15_row17_col13, #T_1da15_row18_col4, #T_1da15_row19_col2, #T_1da15_row19_col7, #T_1da15_row19_col18, #T_1da15_row25_col3, #T_1da15_row25_col9, #T_1da15_row25_

# %% [markdown]
# ## Advanced Stats

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import time

# Set up Selenium WebDriver
service = Service("/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver")  # Update with your path to chromedriver

#Mac file path
#"/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver"

#PC file path
#r"C:\Users\PC\OneDrive\Documents\GitHub\chromedriver-win64\chromedriver.exe"

options = Options()
options.add_argument('--headless')  # Run in headless mode
options.add_argument('--disable-gpu')
options.add_argument('--start-maximized')

driver = webdriver.Chrome(service=service, options=options)

# URL of the webpage to scrape
url = "https://stats.gleague.nba.com/teams/advanced/?sort=W&dir=-1&Season=2024-25&SeasonType=Regular%20Season"

# Load the webpage
driver.get(url)

# Allow time for JavaScript to load
time.sleep(10)  # Adjust the time as per your internet speed and website response time

# Locate the table
table_xpath = '//div[contains(@class, "nba-stat-table__overflow")]/table'
table_element = driver.find_element(By.XPATH, table_xpath)

# Extract the table data
table_html = table_element.get_attribute('outerHTML')

# Convert the table HTML into a pandas DataFrame
team_stats = pd.read_html(table_html)[0]

# Quit the driver
driver.quit()

# Drop the specified columns
columns_to_drop = [
    'Unnamed: 0', 'GP', 'W', 'L', 'WIN%', 'MIN', 'GP RANK', 'W RANK', 'L RANK',
    'MIN RANK', 'OffRtg RANK', 'DefRtg RANK', 'NetRtg RANK', 'AST% RANK',
    'AST/TO RANK', 'AST Ratio RANK', 'OREB% RANK', 'DREB% RANK',
    'REB% RANK', 'TO Ratio RANK', 'eFG% RANK', 'TS% RANK', 'PACE RANK',
    'PIE RANK'
]
team_stats = team_stats.drop(columns=[col for col in columns_to_drop if col in team_stats.columns])

# Ensure numeric columns are correctly identified
numeric_cols = team_stats.select_dtypes(include=['number']).columns

# Calculate ranks and append ranks to numeric columns for display
invert_cols = ['DefRtg', 'TOV%']  # Invert ranks for specified columns
df_with_ranks = team_stats.copy()
ranks_data = {}

# Calculate ranks for numeric columns
for col in numeric_cols:
    if col in invert_cols:
        ranks = team_stats[col].rank(ascending=True, method='min').astype(int)  # Lower is better for inverted columns
    else:
        ranks = team_stats[col].rank(ascending=False, method='min').astype(int)  # Higher is better for regular columns
    df_with_ranks[col] = team_stats[col].astype(str) + ' (' + ranks.astype(str) + ')'
    ranks_data[col] = ranks  # Store ranks for color mapping

# Define luminance function for text color adjustment
def luminance(color):
    rgb = mcolors.hex2color(color)
    return 0.2126 * rgb[0] + 0.7152 * rgb[1] + 0.0722 * rgb[2]

# Adjusted color_cells function to use ranks for color scaling
def color_cells(row):
    colors = []
    for col in numeric_cols:
        rank = ranks_data[col].loc[row.name]
        max_rank = ranks_data[col].max()
        min_rank = ranks_data[col].min()
        # Normalize rank to 0-1 scale for color mapping
        norm = (rank - min_rank) / (max_rank - min_rank) if max_rank != min_rank else 0.5
        # Map normalized rank to color
        color = mcolors.to_hex(plt.cm.RdYlGn(1 - norm))  # Invert to make 1 (best) green
        # Adjust text color for readability
        text_color = 'white' if luminance(color) < 0.5 else 'black'
        colors.append(f"background-color: {color}; color: {text_color};")
    return colors

# Apply the coloring logic to the DataFrame with ranks
styled_df = df_with_ranks.style.apply(color_cells, subset=numeric_cols, axis=1).format(precision=3)

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_d2356_row0_col1, #T_d2356_row0_col6, #T_d2356_row3_col5, #T_d2356_row3_col10, #T_d2356_row5_col9, #T_d2356_row9_col9, #T_d2356_row10_col2, #T_d2356_row10_col3, #T_d2356_row10_col14, #T_d2356_row11_col11, #T_d2356_row11_col12, #T_d2356_row14_col7, #T_d2356_row19_col8, #T_d2356_row25_col13, #T_d2356_row30_col4 {
#   background-color: #006837;
#   color: white;
# }
# #T_d2356_row0_col2, #T_d2356_row0_col13, #T_d2356_row6_col12, #T_d2356_row7_col10, #T_d2356_row8_col5, #T_d2356_row8_col6, #T_d2356_row16_col3, #T_d2356_row16_col14, #T_d2356_row17_col1, #T_d2356_row18_col1, #T_d2356_row20_col8, #T_d2356_row24_col7, #T_d2356_row29_col10, #T_d2356_row30_col5 {
#   background-color: #f46d43;
#   color: black;
# }
# #T_d2356_row0_col3, #T_d2356_row0_col10, #T_d2356_row0_col14, #T_d2356_row1_col12, #T_d2356_row2_col5, #T_d2356_row3_col1, #T_d2356_row7_col11, #T_d2356_row7_col13, #T_d2356_row8_col3, #T_d2356_row8_col14, #T_d2356_row19_col2, #T_d2356_row19_col9, #T_d2356_row21_col8, #T_d2356_row22_col5, #T_d2356_row29_col7 {
#   background-color: #7ac665;
#   color: black;
# }
# #T_d2356_row0_col4, #T_d2356_row1_col11, #T_d2356_row6_col10, #T_d2356_row8_col7, #T_d2356_row14_col1, #T_d2356_row14_col9, #T_d2356_row15_col2, #T_d2356_row15_col3, #T_d2356_row16_col8, #T_d2356_row18_col4, #T_d2356_row18_col6, #T_d2356_row22_col12, #T_d2356_row24_col6, #T_d2356_row24_col13 {
#   background-color: #66bd63;
#   color: black;
# }
# #T_d2356_row0_col5, #T_d2356_row0_col12, #T_d2356_row1_col4, #T_d2356_row1_col8, #T_d2356_row1_col9, #T_d2356_row5_col2, #T_d2356_row5_col14, #T_d2356_row7_col6, #T_d2356_row12_col3, #T_d2356_row16_col13, #T_d2356_row17_col7, #T_d2356_row24_col1, #T_d2356_row24_col11 {
#   background-color: #118848;
#   color: white;
# }
# #T_d2356_row0_col7, #T_d2356_row1_col13, #T_d2356_row1_col14, #T_d2356_row5_col10, #T_d2356_row10_col9, #T_d2356_row11_col5, #T_d2356_row15_col6, #T_d2356_row20_col2, #T_d2356_row21_col11, #T_d2356_row22_col3, #T_d2356_row24_col10, #T_d2356_row28_col1 {
#   background-color: #b7e075;
#   color: black;
# }
# #T_d2356_row0_col8, #T_d2356_row1_col10, #T_d2356_row3_col6, #T_d2356_row3_col12, #T_d2356_row4_col5, #T_d2356_row8_col9, #T_d2356_row9_col4, #T_d2356_row14_col13, #T_d2356_row17_col14, #T_d2356_row19_col6, #T_d2356_row19_col11, #T_d2356_row20_col3, #T_d2356_row22_col10, #T_d2356_row23_col6, #T_d2356_row27_col8, #T_d2356_row30_col2 {
#   background-color: #e5f49b;
#   color: black;
# }
# #T_d2356_row0_col9, #T_d2356_row2_col3, #T_d2356_row2_col11, #T_d2356_row8_col2, #T_d2356_row9_col5, #T_d2356_row12_col12, #T_d2356_row13_col4, #T_d2356_row13_col7, #T_d2356_row15_col14, #T_d2356_row19_col10, #T_d2356_row22_col1, #T_d2356_row22_col13, #T_d2356_row23_col8, #T_d2356_row30_col6 {
#   background-color: #33a456;
#   color: black;
# }
# #T_d2356_row0_col11, #T_d2356_row5_col3, #T_d2356_row5_col8, #T_d2356_row7_col4, #T_d2356_row9_col7, #T_d2356_row11_col1, #T_d2356_row11_col6, #T_d2356_row12_col14, #T_d2356_row15_col5, #T_d2356_row15_col10, #T_d2356_row16_col10, #T_d2356_row24_col12, #T_d2356_row26_col2, #T_d2356_row29_col13 {
#   background-color: #08773f;
#   color: white;
# }
# #T_d2356_row1_col1, #T_d2356_row2_col10, #T_d2356_row3_col2, #T_d2356_row7_col8, #T_d2356_row10_col10, #T_d2356_row10_col13, #T_d2356_row13_col6, #T_d2356_row13_col9, #T_d2356_row20_col6, #T_d2356_row23_col4, #T_d2356_row25_col7, #T_d2356_row27_col11, #T_d2356_row27_col12, #T_d2356_row28_col7 {
#   background-color: #91d068;
#   color: black;
# }
# #T_d2356_row1_col2, #T_d2356_row4_col3, #T_d2356_row5_col5, #T_d2356_row18_col8, #T_d2356_row19_col4, #T_d2356_row20_col7, #T_d2356_row23_col11, #T_d2356_row25_col14, #T_d2356_row28_col12, #T_d2356_row30_col9 {
#   background-color: #feea9b;
#   color: black;
# }
# #T_d2356_row1_col3, #T_d2356_row1_col7, #T_d2356_row2_col2, #T_d2356_row2_col7, #T_d2356_row5_col1, #T_d2356_row7_col1, #T_d2356_row7_col5, #T_d2356_row10_col8, #T_d2356_row12_col1, #T_d2356_row15_col4, #T_d2356_row15_col12, #T_d2356_row15_col13, #T_d2356_row18_col11, #T_d2356_row22_col9, #T_d2356_row25_col10 {
#   background-color: #d9ef8b;
#   color: black;
# }
# #T_d2356_row1_col5, #T_d2356_row2_col12, #T_d2356_row2_col14, #T_d2356_row3_col3, #T_d2356_row3_col14, #T_d2356_row5_col7, #T_d2356_row7_col2, #T_d2356_row9_col1, #T_d2356_row9_col10, #T_d2356_row9_col13, #T_d2356_row12_col11, #T_d2356_row17_col9, #T_d2356_row19_col5, #T_d2356_row22_col6, #T_d2356_row27_col4, #T_d2356_row29_col8 {
#   background-color: #4bb05c;
#   color: black;
# }
# #T_d2356_row1_col6, #T_d2356_row2_col1, #T_d2356_row4_col10, #T_d2356_row7_col12, #T_d2356_row9_col8, #T_d2356_row11_col3, #T_d2356_row11_col4, #T_d2356_row11_col14, #T_d2356_row12_col2, #T_d2356_row16_col5, #T_d2356_row21_col13, #T_d2356_row22_col7, #T_d2356_row22_col11, #T_d2356_row29_col9 {
#   background-color: #199750;
#   color: white;
# }
# #T_d2356_row2_col4, #T_d2356_row6_col3, #T_d2356_row8_col10, #T_d2356_row10_col5, #T_d2356_row12_col9, #T_d2356_row18_col7, #T_d2356_row20_col13, #T_d2356_row21_col2, #T_d2356_row21_col10, #T_d2356_row21_col14, #T_d2356_row26_col8, #T_d2356_row26_col9, #T_d2356_row28_col10, #T_d2356_row29_col1, #T_d2356_row30_col11 {
#   background-color: #feffbe;
#   color: black;
# }
# #T_d2356_row2_col6, #T_d2356_row2_col9, #T_d2356_row6_col2, #T_d2356_row6_col8, #T_d2356_row8_col13, #T_d2356_row10_col7, #T_d2356_row14_col12, #T_d2356_row15_col11, #T_d2356_row18_col5, #T_d2356_row19_col1, #T_d2356_row19_col3, #T_d2356_row19_col14, #T_d2356_row22_col14, #T_d2356_row24_col4, #T_d2356_row27_col6 {
#   background-color: #c7e77f;
#   color: black;
# }
# #T_d2356_row2_col8, #T_d2356_row3_col11, #T_d2356_row5_col4, #T_d2356_row5_col6, #T_d2356_row14_col4, #T_d2356_row14_col14, #T_d2356_row18_col3, #T_d2356_row19_col7, #T_d2356_row20_col1, #T_d2356_row21_col5, #T_d2356_row23_col2, #T_d2356_row23_col12, #T_d2356_row25_col11 {
#   background-color: #f7814c;
#   color: black;
# }
# #T_d2356_row2_col13, #T_d2356_row4_col2, #T_d2356_row4_col7, #T_d2356_row6_col4, #T_d2356_row10_col1, #T_d2356_row12_col6, #T_d2356_row17_col6, #T_d2356_row18_col13, #T_d2356_row20_col5, #T_d2356_row21_col1, #T_d2356_row21_col3, #T_d2356_row24_col8, #T_d2356_row24_col14, #T_d2356_row25_col12, #T_d2356_row28_col11 {
#   background-color: #fff5ae;
#   color: black;
# }
# #T_d2356_row3_col4, #T_d2356_row7_col3, #T_d2356_row7_col9, #T_d2356_row7_col14, #T_d2356_row12_col8, #T_d2356_row15_col1, #T_d2356_row17_col2, #T_d2356_row19_col12, #T_d2356_row20_col4, #T_d2356_row20_col11, #T_d2356_row21_col12, #T_d2356_row24_col5, #T_d2356_row28_col13, #T_d2356_row30_col8 {
#   background-color: #a5d86a;
#   color: black;
# }
# #T_d2356_row3_col7, #T_d2356_row3_col8, #T_d2356_row6_col11, #T_d2356_row11_col13, #T_d2356_row12_col4, #T_d2356_row12_col5, #T_d2356_row13_col2, #T_d2356_row13_col3, #T_d2356_row13_col12, #T_d2356_row17_col4, #T_d2356_row17_col10, #T_d2356_row25_col5, #T_d2356_row26_col10, #T_d2356_row27_col10, #T_d2356_row29_col11, #T_d2356_row29_col12, #T_d2356_row30_col14 {
#   background-color: #fdad60;
#   color: black;
# }
# #T_d2356_row3_col9, #T_d2356_row8_col1, #T_d2356_row8_col4, #T_d2356_row8_col11, #T_d2356_row8_col12, #T_d2356_row13_col13, #T_d2356_row14_col10, #T_d2356_row17_col8, #T_d2356_row23_col7, #T_d2356_row23_col14, #T_d2356_row26_col3, #T_d2356_row28_col5, #T_d2356_row29_col2, #T_d2356_row29_col4 {
#   background-color: #e14430;
#   color: white;
# }
# #T_d2356_row3_col13, #T_d2356_row5_col11, #T_d2356_row12_col7, #T_d2356_row14_col2, #T_d2356_row14_col5, #T_d2356_row14_col8, #T_d2356_row15_col9, #T_d2356_row17_col12, #T_d2356_row23_col10, #T_d2356_row28_col4, #T_d2356_row29_col3, #T_d2356_row29_col14, #T_d2356_row30_col1 {
#   background-color: #c62027;
#   color: white;
# }
# #T_d2356_row4_col1, #T_d2356_row4_col14, #T_d2356_row6_col1, #T_d2356_row6_col7, #T_d2356_row9_col3, #T_d2356_row12_col13, #T_d2356_row14_col11, #T_d2356_row17_col11, #T_d2356_row21_col6, #T_d2356_row21_col9, #T_d2356_row22_col2, #T_d2356_row24_col9, #T_d2356_row25_col1, #T_d2356_row25_col2, #T_d2356_row28_col8, #T_d2356_row28_col9 {
#   background-color: #fece7c;
#   co

# %% [markdown]
# ## Four Factors

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import time

# Set up Selenium WebDriver
service = Service("/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver")  # Update with your path to chromedriver

# Mac file path
# "/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver"

# PC file path
# r"C:\Users\PC\OneDrive\Documents\GitHub\chromedriver-win64\chromedriver.exe"

options = Options()
options.add_argument('--headless')  # Run in headless mode
options.add_argument('--disable-gpu')
options.add_argument('--start-maximized')

driver = webdriver.Chrome(service=service, options=options)

# URL of the webpage to scrape
url = "https://stats.gleague.nba.com/teams/four-factors/?sort=W_PCT&dir=-1&Season=2024-25&SeasonType=Regular%20Season"

# Load the webpage
driver.get(url)

# Allow time for JavaScript to load
time.sleep(10)  # Adjust the time as per your internet speed and website response time

# Locate the table
table_xpath = '//div[contains(@class, "nba-stat-table__overflow")]/table'
table_element = driver.find_element(By.XPATH, table_xpath)

# Extract the table data
table_html = table_element.get_attribute('outerHTML')

# Convert the table HTML into a pandas DataFrame
team_stats = pd.read_html(table_html)[0]

# Quit the driver
driver.quit()

# Standardize column names
team_stats.columns = team_stats.columns.str.replace('\xa0', ' ', regex=False).str.strip()

# Drop the specified columns
columns_to_drop = [
    'Unnamed: 0', 'GP', 'W', 'L', 'WIN%', 'MIN', 'GP RANK', 'W RANK', 'L RANK', 'MIN RANK', 'eFG% RANK', 'TO Ratio RANK',
    'OREB% RANK', 'Opp FTA Rate RANK', 'Opp To Ratio RANK', 'WIN% RANK', 'FTA Rate RANK', 'Opp eFG% RANK', 'Opp OREB% RANK'
]
team_stats = team_stats.drop(columns=[col for col in columns_to_drop if col in team_stats.columns])

# Ensure numeric columns are correctly identified
numeric_cols = team_stats.select_dtypes(include=['number']).columns

# Calculate ranks and append ranks to numeric columns for display
invert_cols = ['TOV%', 'Opp eFG%', 'Opp FTA Rate', 'Opp OREB%']  # Columns with descending rank
df_with_ranks = team_stats.copy()
ranks_data = {}

# Calculate ranks for numeric columns
for col in numeric_cols:
    if col in invert_cols:
        ranks = team_stats[col].rank(ascending=True, method='min').astype(int)  # Lower is better for inverted columns
    else:
        ranks = team_stats[col].rank(ascending=False, method='min').astype(int)  # Higher is better for regular columns
    df_with_ranks[col] = team_stats[col].astype(str) + ' (' + ranks.astype(str) + ')'
    ranks_data[col] = ranks  # Store ranks for color mapping

# Define luminance function for text color adjustment
def luminance(color):
    rgb = mcolors.hex2color(color)
    return 0.2126 * rgb[0] + 0.7152 * rgb[1] + 0.0722 * rgb[2]

# Adjusted color_cells function to use ranks for color scaling
def color_cells(row):
    colors = []
    for col in numeric_cols:
        rank = ranks_data[col].loc[row.name]
        max_rank = ranks_data[col].max()
        min_rank = ranks_data[col].min()
        # Normalize rank to 0-1 scale for color mapping
        norm = (rank - min_rank) / (max_rank - min_rank) if max_rank != min_rank else 0.5
        # Map normalized rank to color
        color = mcolors.to_hex(plt.cm.RdYlGn(1 - norm))  # Invert to make 1 (best) green
        # Adjust text color for readability
        text_color = 'white' if luminance(color) < 0.5 else 'black'
        colors.append(f"background-color: {color}; color: {text_color};")
    return colors

# Apply the coloring logic to the DataFrame with ranks
styled_df = df_with_ranks.style.apply(color_cells, subset=numeric_cols, axis=1).format(precision=3)

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_dde16_row0_col1, #T_dde16_row7_col4, #T_dde16_row7_col7, #T_dde16_row10_col6, #T_dde16_row14_col2, #T_dde16_row14_col3, #T_dde16_row16_col8, #T_dde16_row20_col5, #T_dde16_row26_col6 {
#   background-color: #66bd63;
#   color: black;
# }
# #T_dde16_row0_col2, #T_dde16_row8_col4, #T_dde16_row10_col8, #T_dde16_row29_col5 {
#   background-color: #fa9857;
#   color: black;
# }
# #T_dde16_row0_col3, #T_dde16_row5_col8, #T_dde16_row10_col2, #T_dde16_row19_col1, #T_dde16_row19_col5, #T_dde16_row21_col3, #T_dde16_row23_col6, #T_dde16_row27_col8 {
#   background-color: #e5f49b;
#   color: black;
# }
# #T_dde16_row0_col4, #T_dde16_row0_col5, #T_dde16_row1_col4, #T_dde16_row3_col2, #T_dde16_row6_col7, #T_dde16_row13_col8, #T_dde16_row15_col3, #T_dde16_row20_col6, #T_dde16_row22_col1, #T_dde16_row23_col7, #T_dde16_row30_col7 {
#   background-color: #d9ef8b;
#   color: black;
# }
# #T_dde16_row0_col6, #T_dde16_row2_col5, #T_dde16_row6_col2, #T_dde16_row10_col1, #T_dde16_row13_col4, #T_dde16_row14_col8, #T_dde16_row15_col7 {
#   background-color: #c7e77f;
#   color: black;
# }
# #T_dde16_row0_col7, #T_dde16_row4_col6, #T_dde16_row10_col4, #T_dde16_row11_col1, #T_dde16_row12_col5, #T_dde16_row15_col8, #T_dde16_row18_col3, #T_dde16_row24_col2 {
#   background-color: #b50f26;
#   color: white;
# }
# #T_dde16_row0_col8, #T_dde16_row5_col6, #T_dde16_row10_col5, #T_dde16_row11_col7, #T_dde16_row13_col2, #T_dde16_row14_col7, #T_dde16_row17_col4, #T_dde16_row25_col1, #T_dde16_row26_col5 {
#   background-color: #118848;
#   color: white;
# }
# #T_dde16_row1_col1, #T_dde16_row3_col7, #T_dde16_row9_col2, #T_dde16_row17_col5, #T_dde16_row18_col4, #T_dde16_row19_col3, #T_dde16_row19_col6, #T_dde16_row24_col8, #T_dde16_row25_col6, #T_dde16_row29_col7 {
#   background-color: #33a456;
#   color: black;
# }
# #T_dde16_row1_col2, #T_dde16_row3_col3, #T_dde16_row5_col4, #T_dde16_row8_col5, #T_dde16_row23_col1, #T_dde16_row25_col3 {
#   background-color: #b7e075;
#   color: black;
# }
# #T_dde16_row1_col3, #T_dde16_row4_col5, #T_dde16_row4_col8, #T_dde16_row8_col2, #T_dde16_row13_col3, #T_dde16_row15_col4, #T_dde16_row17_col6, #T_dde16_row18_col6, #T_dde16_row18_col7, #T_dde16_row24_col6, #T_dde16_row27_col1, #T_dde16_row30_col4 {
#   background-color: #91d068;
#   color: black;
# }
# #T_dde16_row1_col5, #T_dde16_row4_col1, #T_dde16_row5_col3, #T_dde16_row23_col2, #T_dde16_row23_col8, #T_dde16_row26_col7, #T_dde16_row28_col4 {
#   background-color: #7ac665;
#   color: black;
# }
# #T_dde16_row1_col6, #T_dde16_row4_col4, #T_dde16_row8_col3, #T_dde16_row11_col8, #T_dde16_row14_col5, #T_dde16_row28_col2, #T_dde16_row28_col5 {
#   background-color: #fdbf6f;
#   color: black;
# }
# #T_dde16_row1_col7, #T_dde16_row7_col8, #T_dde16_row11_col5, #T_dde16_row12_col1, #T_dde16_row21_col2, #T_dde16_row27_col4, #T_dde16_row27_col6 {
#   background-color: #ea5739;
#   color: white;
# }
# #T_dde16_row1_col8, #T_dde16_row2_col1, #T_dde16_row5_col2, #T_dde16_row12_col7, #T_dde16_row15_col1, #T_dde16_row18_col5, #T_dde16_row19_col4 {
#   background-color: #f7814c;
#   color: black;
# }
# #T_dde16_row2_col2, #T_dde16_row4_col3, #T_dde16_row5_col7, #T_dde16_row9_col6, #T_dde16_row20_col8, #T_dde16_row21_col5, #T_dde16_row25_col4, #T_dde16_row28_col3 {
#   background-color: #f46d43;
#   color: black;
# }
# #T_dde16_row2_col3, #T_dde16_row6_col5, #T_dde16_row8_col1, #T_dde16_row9_col4, #T_dde16_row12_col6, #T_dde16_row15_col2, #T_dde16_row19_col8, #T_dde16_row21_col7 {
#   background-color: #006837;
#   color: white;
# }
# #T_dde16_row2_col4, #T_dde16_row2_col8, #T_dde16_row13_col6, #T_dde16_row14_col1, #T_dde16_row16_col2, #T_dde16_row16_col6, #T_dde16_row17_col3, #T_dde16_row19_col7, #T_dde16_row22_col6, #T_dde16_row24_col7, #T_dde16_row26_col3, #T_dde16_row27_col3, #T_dde16_row28_col1 {
#   background-color: #fdad60;
#   color: black;
# }
# #T_dde16_row2_col6, #T_dde16_row9_col7, #T_dde16_row12_col2, #T_dde16_row18_col2, #T_dde16_row20_col4, #T_dde16_row22_col8, #T_dde16_row24_col1, #T_dde16_row24_col5 {
#   background-color: #feea9b;
#   color: black;
# }
# #T_dde16_row2_col7, #T_dde16_row3_col5, #T_dde16_row6_col8, #T_dde16_row8_col7, #T_dde16_row20_col1, #T_dde16_row29_col8, #T_dde16_row30_col2 {
#   background-color: #a5d86a;
#   color: black;
# }
# #T_dde16_row3_col1, #T_dde16_row6_col4, #T_dde16_row9_col5, #T_dde16_row9_col8, #T_dde16_row22_col2, #T_dde16_row24_col3, #T_dde16_row25_col7, #T_dde16_row30_col6 {
#   background-color: #c62027;
#   color: white;
# }
# #T_dde16_row3_col4, #T_dde16_row6_col1, #T_dde16_row12_col3, #T_dde16_row13_col5, #T_dde16_row19_col2, #T_dde16_row28_col8 {
#   background-color: #4bb05c;
#   color: black;
# }
# #T_dde16_row3_col6, #T_dde16_row11_col2, #T_dde16_row11_col3, #T_dde16_row12_col8, #T_dde16_row21_col1, #T_dde16_row21_col4 {
#   background-color: #199750;
#   color: white;
# }
# #T_dde16_row3_col8, #T_dde16_row4_col2, #T_dde16_row5_col1, #T_dde16_row7_col5, #T_dde16_row10_col3, #T_dde16_row11_col6, #T_dde16_row12_col4, #T_dde16_row13_col7, #T_dde16_row16_col3 {
#   background-color: #08773f;
#   color: white;
# }
# #T_dde16_row4_col7, #T_dde16_row5_col5, #T_dde16_row11_col4, #T_dde16_row15_col6, #T_dde16_row25_col8, #T_dde16_row29_col2, #T_dde16_row30_col1 {
#   background-color: #fff5ae;
#   color: black;
# }
# #T_dde16_row6_col3, #T_dde16_row7_col6, #T_dde16_row14_col6, #T_dde16_row15_col5, #T_dde16_row16_col1, #T_dde16_row16_col7, #T_dde16_row18_col8, #T_dde16_row22_col3, #T_dde16_row29_col4 {
#   background-color: #fee08b;
#   color: black;
# }
# #T_dde16_row6_col6, #T_dde16_row8_col8, #T_dde16_row16_col4, #T_dde16_row26_col1, #T_dde16_row26_col2, #T_dde16_row28_col7, #T_dde16_row29_col3, #T_dde16_row30_col5 {
#   background-color: #a50026;
#   color: white;
# }
# #T_dde16_row7_col1, #T_dde16_row9_col3, #T_dde16_row17_col2, #T_dde16_row17_col7, #T_dde16_row17_col8, #T_dde16_row20_col2, #T_dde16_row24_col4, #T_dde16_row25_col5, #T_dde16_row28_col6 {
#   background-color: #e14430;
#   color: white;
# }
# #T_dde16_row7_col2, #T_dde16_row8_col6, #T_dde16_row18_col1, #T_dde16_row26_col4, #T_dde16_row27_col5 {
#   background-color: #f2faae;
#   color: black;
# }
# #T_dde16_row7_col3, #T_dde16_row22_col4, #T_dde16_row22_col7, #T_dde16_row23_col3, #T_dde16_row23_col5, #T_dde16_row25_col2, #T_dde16_row26_col8, #T_dde16_row29_col1, #T_dde16_row29_col6, #T_dde16_row30_col3 {
#   background-color: #feffbe;
#   color: black;
# }
# #T_dde16_row9_col1, #T_dde16_row10_col7, #T_dde16_row14_col4, #T_dde16_row16_col5, #T_dde16_row17_col1, #T_dde16_row20_col7, #T_dde16_row27_col2, #T_dde16_row30_col8 {
#   background-color: #fece7c;
#   color: black;
# }
# #T_dde16_row13_col1, #T_dde16_row20_col3, #T_dde16_row21_col6, #T_dde16_row21_col8, #T_dde16_row22_col5, #T_dde16_row23_col4, #T_dde16_row27_col7 {
#   background-color: #d62f27;
#   color: white;
# }
# </style>
# <table id="T_dde16">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dde16_level0_col0" class="col_heading level0 col0" >TEAM</th>
#       <th id="T_dde16_level0_col1" class="col_heading level0 col1" >eFG%</th>
#       <th id="T_dde16_level0_col2" class="col_heading level0 col2" >FTA Rate</th>
#       <th id="T_dde16_level0_col3" class="col_heading level0 col3" >TOV%</th>
#       <th id="T_dde16_level0_col4" class="col_heading level0 col4" >OREB%</th>
#       <th id="T_dde16_level0_col5" class="col_heading level0 col5" >Opp eFG%</th>
#       <th id="T_dde16_level0_col6" class="col_heading level0 col6" >Opp FTA Rate</th>
#       <th id="T_dde16_level0_col7" class="col_heading level0 col7" >Opp TOV%</th>
#       <th id="T_dde16_level0_col8" class="col_heading level0 col8" >Opp OREB%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dde16_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dde16_row0_col0" class="data row0 col0" >Santa Cruz Warriors</td>
#       <td id="T_dde16_row0_col1" class="data row0 col1" >55.6 (7)</td>
#       <td id="T_dde16_row0_col2" class="data row0 col2" >0.143 (23)</td>
#       <td id="T_dde16_row0_col3" class="data row0 col3" >16.6 (14)</td>
#       <td id="T_dde16_row0_col4" class="data row0 col4" >32.4 (13)</td>
#       <td id="T_dde16_row0_col5" class="data row0 col5

# %% [markdown]
# ## Scoring

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import time

# Set up Selenium WebDriver
service = Service("/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver")  # Update with your path to chromedriver

# Mac file path
# "/Users/fadihaddad/Documents/chromedriver-mac-arm64/chromedriver"

# PC file path
# r"C:\Users\PC\OneDrive\Documents\GitHub\chromedriver-win64\chromedriver.exe"

options = Options()
options.add_argument('--headless')  # Run in headless mode
options.add_argument('--disable-gpu')
options.add_argument('--start-maximized')

driver = webdriver.Chrome(service=service, options=options)

# URL of the webpage to scrape
url = "https://stats.gleague.nba.com/teams/scoring/?sort=W&dir=-1&Season=2024-25&SeasonType=Regular%20Season"

# Load the webpage
driver.get(url)

# Allow time for JavaScript to load
time.sleep(10)  # Adjust the time as per your internet speed and website response time

# Locate the table
table_xpath = '//div[contains(@class, "nba-stat-table__overflow")]/table'
table_element = driver.find_element(By.XPATH, table_xpath)

# Extract the table data
table_html = table_element.get_attribute('outerHTML')

# Convert the table HTML into a pandas DataFrame
team_stats = pd.read_html(table_html)[0]

# Quit the driver
driver.quit()

# Standardize column names
team_stats.columns = team_stats.columns.str.replace('\xa0', ' ', regex=False).str.strip()

# Drop the specified columns
columns_to_drop = [
    'Unnamed: 0', 'GP', 'W', 'L', 'MIN', 'GP RANK', 'W RANK', 'L RANK',
    'MIN RANK', '%FGA 2PT RANK', '%FGA 3PT RANK', '%PTS 2PT RANK',
    '%PTS 2PT- MR RANK', '%PTS 3PT RANK', '%PTS FBPs RANK', '%PTS FT RANK',
    '%PTS OffTO RANK', '%PTS PITP RANK', '2FGM %AST RANK',
    '2FGM %UAST RANK', '3FGM %AST RANK', '3FGM %UAST RANK', 'FGM %AST RANK',
    'FGM %UAST RANK'
]
team_stats = team_stats.drop(columns=[col for col in columns_to_drop if col in team_stats.columns])

# Ensure numeric columns are correctly identified
numeric_cols = team_stats.select_dtypes(include=['number']).columns

# Define invert columns (if any are needed in the future)
invert_cols = []  # Add column names here if inversion is needed
df_with_ranks = team_stats.copy()
ranks_data = {}

# Calculate ranks for numeric columns
for col in numeric_cols:
    if col in invert_cols:
        ranks = team_stats[col].rank(ascending=True, method='min').astype(int)  # Lower is better for inverted columns
    else:
        ranks = team_stats[col].rank(ascending=False, method='min').astype(int)  # Higher is better for regular columns
    df_with_ranks[col] = team_stats[col].astype(str) + ' (' + ranks.astype(str) + ')'
    ranks_data[col] = ranks  # Store ranks for color mapping

# Define luminance function for text color adjustment
def luminance(color):
    rgb = mcolors.hex2color(color)
    return 0.2126 * rgb[0] + 0.7152 * rgb[1] + 0.0722 * rgb[2]

# Adjusted color_cells function to use ranks for color scaling
def color_cells(row):
    colors = []
    for col in numeric_cols:
        rank = ranks_data[col].loc[row.name]
        max_rank = ranks_data[col].max()
        min_rank = ranks_data[col].min()
        # Normalize rank to 0-1 scale for color mapping
        norm = (rank - min_rank) / (max_rank - min_rank) if max_rank != min_rank else 0.5
        # Map normalized rank to color
        color = mcolors.to_hex(plt.cm.RdYlGn(1 - norm))  # Invert to make 1 (best) green
        # Adjust text color for readability
        text_color = 'white' if luminance(color) < 0.5 else 'black'
        colors.append(f"background-color: {color}; color: {text_color};")
    return colors

# Apply the coloring logic to the DataFrame with ranks
styled_df = df_with_ranks.style.apply(color_cells, subset=numeric_cols, axis=1).format(precision=3)

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_7e754_row0_col1, #T_7e754_row0_col14, #T_7e754_row3_col5, #T_7e754_row5_col3, #T_7e754_row5_col11, #T_7e754_row5_col15, #T_7e754_row7_col7, #T_7e754_row7_col8, #T_7e754_row10_col7, #T_7e754_row14_col4, #T_7e754_row14_col15, #T_7e754_row15_col6, #T_7e754_row17_col4, #T_7e754_row18_col8, #T_7e754_row18_col14, #T_7e754_row23_col10, #T_7e754_row24_col2, #T_7e754_row24_col12, #T_7e754_row25_col13, #T_7e754_row28_col9 {
#   background-color: #66bd63;
#   color: black;
# }
# #T_7e754_row0_col2, #T_7e754_row0_col7, #T_7e754_row3_col9, #T_7e754_row5_col10, #T_7e754_row6_col3, #T_7e754_row13_col4, #T_7e754_row17_col8, #T_7e754_row23_col11, #T_7e754_row24_col1, #T_7e754_row24_col13, #T_7e754_row25_col12, #T_7e754_row28_col5 {
#   background-color: #f46d43;
#   color: black;
# }
# #T_7e754_row0_col3, #T_7e754_row6_col5, #T_7e754_row6_col11, #T_7e754_row13_col9, #T_7e754_row13_col13, #T_7e754_row19_col10, #T_7e754_row21_col12, #T_7e754_row23_col1, #T_7e754_row25_col3, #T_7e754_row29_col2, #T_7e754_row30_col6 {
#   background-color: #7ac665;
#   color: black;
# }
# #T_7e754_row0_col4, #T_7e754_row0_col12, #T_7e754_row1_col14, #T_7e754_row5_col1, #T_7e754_row5_col8, #T_7e754_row6_col2, #T_7e754_row8_col13, #T_7e754_row13_col10, #T_7e754_row20_col6, #T_7e754_row23_col3, #T_7e754_row23_col9, #T_7e754_row28_col11, #T_7e754_row28_col15, #T_7e754_row30_col5 {
#   background-color: #118848;
#   color: white;
# }
# #T_7e754_row0_col5, #T_7e754_row1_col1, #T_7e754_row1_col7, #T_7e754_row2_col12, #T_7e754_row11_col6, #T_7e754_row20_col11, #T_7e754_row21_col3, #T_7e754_row21_col9, #T_7e754_row23_col15, #T_7e754_row27_col8, #T_7e754_row27_col13, #T_7e754_row29_col4 {
#   background-color: #fa9857;
#   color: black;
# }
# #T_7e754_row0_col6, #T_7e754_row0_col8, #T_7e754_row0_col9, #T_7e754_row2_col14, #T_7e754_row2_col15, #T_7e754_row8_col7, #T_7e754_row8_col10, #T_7e754_row8_col11, #T_7e754_row9_col12, #T_7e754_row9_col13, #T_7e754_row10_col4, #T_7e754_row12_col3, #T_7e754_row12_col5, #T_7e754_row15_col7, #T_7e754_row20_col8, #T_7e754_row22_col1, #T_7e754_row22_col2, #T_7e754_row27_col7, #T_7e754_row29_col7 {
#   background-color: #feffbe;
#   color: black;
# }
# #T_7e754_row0_col10, #T_7e754_row4_col8, #T_7e754_row5_col4, #T_7e754_row7_col1, #T_7e754_row8_col3, #T_7e754_row11_col2, #T_7e754_row11_col5, #T_7e754_row12_col11, #T_7e754_row13_col14, #T_7e754_row20_col9, #T_7e754_row25_col7, #T_7e754_row26_col6, #T_7e754_row26_col13, #T_7e754_row28_col3 {
#   background-color: #33a456;
#   color: black;
# }
# #T_7e754_row0_col11, #T_7e754_row7_col2, #T_7e754_row7_col13, #T_7e754_row8_col14, #T_7e754_row11_col1, #T_7e754_row12_col10, #T_7e754_row13_col15, #T_7e754_row14_col9, #T_7e754_row17_col13, #T_7e754_row20_col7, #T_7e754_row22_col4, #T_7e754_row24_col8, #T_7e754_row25_col5, #T_7e754_row26_col12, #T_7e754_row29_col14 {
#   background-color: #e14430;
#   color: white;
# }
# #T_7e754_row0_col13, #T_7e754_row1_col8, #T_7e754_row1_col9, #T_7e754_row1_col15, #T_7e754_row5_col2, #T_7e754_row5_col5, #T_7e754_row6_col1, #T_7e754_row8_col12, #T_7e754_row13_col11, #T_7e754_row23_col6, #T_7e754_row24_col4, #T_7e754_row28_col10, #T_7e754_row28_col14, #T_7e754_row30_col3 {
#   background-color: #c62027;
#   color: white;
# }
# #T_7e754_row0_col15, #T_7e754_row2_col8, #T_7e754_row2_col9, #T_7e754_row3_col4, #T_7e754_row5_col14, #T_7e754_row6_col6, #T_7e754_row6_col10, #T_7e754_row9_col3, #T_7e754_row13_col7, #T_7e754_row13_col12, #T_7e754_row14_col14, #T_7e754_row18_col15, #T_7e754_row19_col11, #T_7e754_row21_col13, #T_7e754_row23_col2, #T_7e754_row23_col5, #T_7e754_row28_col6, #T_7e754_row29_col1 {
#   background-color: #f7814c;
#   color: black;
# }
# #T_7e754_row1_col2, #T_7e754_row2_col13, #T_7e754_row4_col1, #T_7e754_row7_col9, #T_7e754_row9_col5, #T_7e754_row9_col11, #T_7e754_row12_col15, #T_7e754_row17_col15, #T_7e754_row18_col4, #T_7e754_row20_col1, #T_7e754_row20_col10, #T_7e754_row21_col7, #T_7e754_row21_col8, #T_7e754_row23_col14, #T_7e754_row24_col11, #T_7e754_row25_col6, #T_7e754_row27_col12 {
#   background-color: #91d068;
#   color: black;
# }
# #T_7e754_row1_col3, #T_7e754_row3_col1, #T_7e754_row3_col3, #T_7e754_row3_col12, #T_7e754_row5_col13, #T_7e754_row6_col9, #T_7e754_row8_col2, #T_7e754_row8_col5, #T_7e754_row9_col4, #T_7e754_row10_col10, #T_7e754_row12_col8, #T_7e754_row13_col6, #T_7e754_row17_col7, #T_7e754_row18_col6, #T_7e754_row18_col11, #T_7e754_row19_col6, #T_7e754_row25_col14, #T_7e754_row27_col15 {
#   background-color: #ea5739;
#   color: white;
# }
# #T_7e754_row1_col4, #T_7e754_row3_col2, #T_7e754_row3_col13, #T_7e754_row5_col12, #T_7e754_row6_col7, #T_7e754_row8_col1, #T_7e754_row10_col11, #T_7e754_row18_col10, #T_7e754_row22_col9, #T_7e754_row25_col15, #T_7e754_row26_col5, #T_7e754_row27_col6, #T_7e754_row27_col14, #T_7e754_row30_col8 {
#   background-color: #4bb05c;
#   color: black;
# }
# #T_7e754_row1_col5, #T_7e754_row3_col6, #T_7e754_row5_col7, #T_7e754_row7_col12, #T_7e754_row8_col8, #T_7e754_row8_col15, #T_7e754_row11_col10, #T_7e754_row11_col14, #T_7e754_row14_col13, #T_7e754_row17_col12, #T_7e754_row20_col3, #T_7e754_row21_col11, #T_7e754_row25_col9, #T_7e754_row26_col4, #T_7e754_row27_col2, #T_7e754_row28_col1, #T_7e754_row29_col15 {
#   background-color: #199750;
#   color: white;
# }
# #T_7e754_row1_col6, #T_7e754_row7_col11, #T_7e754_row7_col15, #T_7e754_row9_col8, #T_7e754_row16_col12, #T_7e754_row17_col2, #T_7e754_row17_col5, #T_7e754_row22_col7, #T_7e754_row25_col4, #T_7e754_row26_col10, #T_7e754_row26_col14, #T_7e754_row27_col3, #T_7e754_row27_col9, #T_7e754_row29_col13, #T_7e754_row30_col1 {
#   background-color: #b50f26;
#   color: white;
# }
# #T_7e754_row1_col10, #T_7e754_row2_col5, #T_7e754_row3_col14, #T_7e754_row4_col3, #T_7e754_row5_col9, #T_7e754_row6_col8, #T_7e754_row9_col6, #T_7e754_row10_col2, #T_7e754_row12_col7, #T_7e754_row12_col13, #T_7e754_row14_col6, #T_7e754_row15_col9, #T_7e754_row18_col5, #T_7e754_row19_col4, #T_7e754_row19_col12, #T_7e754_row20_col14, #T_7e754_row21_col2, #T_7e754_row22_col3, #T_7e754_row28_col8 {
#   background-color: #a5d86a;
#   color: black;
# }
# #T_7e754_row1_col11, #T_7e754_row2_col3, #T_7e754_row2_col7, #T_7e754_row4_col2, #T_7e754_row6_col4, #T_7e754_row9_col10, #T_7e754_row12_col12, #T_7e754_row12_col14, #T_7e754_row17_col14, #T_7e754_row19_col13, #T_7e754_row20_col2, #T_7e754_row24_col10, #T_7e754_row25_col8, #T_7e754_row26_col9 {
#   background-color: #fdad60;
#   color: black;
# }
# #T_7e754_row1_col12, #T_7e754_row4_col4, #T_7e754_row4_col7, #T_7e754_row4_col13, #T_7e754_row4_col15, #T_7e754_row12_col6, #T_7e754_row16_col2, #T_7e754_row16_col5, #T_7e754_row17_col3, #T_7e754_row17_col9, #T_7e754_row19_col1, #T_7e754_row22_col8, #T_7e754_row29_col11, #T_7e754_row30_col10, #T_7e754_row30_col14 {
#   background-color: #006837;
#   color: white;
# }
# #T_7e754_row1_col13, #T_7e754_row4_col12, #T_7e754_row4_col14, #T_7e754_row7_col4, #T_7e754_row16_col1, #T_7e754_row16_col3, #T_7e754_row16_col9, #T_7e754_row19_col2, #T_7e754_row19_col5, #T_7e754_row21_col6, #T_7e754_row26_col7, #T_7e754_row29_col8, #T_7e754_row29_col10, #T_7e754_row30_col11, #T_7e754_row30_col15 {
#   background-color: #a50026;
#   color: white;
# }
# #T_7e754_row2_col1, #T_7e754_row5_col6, #T_7e754_row7_col3, #T_7e754_row7_col5, #T_7e754_row9_col1, #T_7e754_row9_col15, #T_7e754_row10_col8, #T_7e754_row11_col13, #T_7e754_row14_col10, #T_7e754_row17_col11, #T_7e754_row19_col14, #T_7e754_row20_col4, #T_7e754_row26_col2, #T_7e754_row30_col12 {
#   background-color: #feea9b;
#   color: black;
# }
# #T_7e754_row2_col2, #T_7e754_row2_col4, #T_7e754_row9_col2, #T_7e754_row10_col6, #T_7e754_row11_col7, #T_7e754_row13_col8, #T_7e754_row14_col1, #T_7e754_row15_col3, #T_7e754_row15_col14, #T_7e754_row16_col11, #T_7e754_row22_col10, #T_7e754_row22_col13, #T_7e754_row27_col4, #T_7e754_row29_col5, #T_7e754_row29_col9 {
#   background-color: #d9ef8b;
#   color: black;
# }
# #T_7e754_row2_col6, #T_7e754_row3_col11, #T_7e754_row3_col15, #T_7e754_row10_col1, #T_7e754_row10_col13, #T_7e754_row10_col14, #T_7e754_row14_col5, #T_7e754_row16_col6, #T_7e754_row18_col2, #T_7e754_row20
